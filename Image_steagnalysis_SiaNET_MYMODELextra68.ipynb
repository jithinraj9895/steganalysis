# %% [markdown]
# <a href="https://colab.research.google.com/github/jithinraj9895/steganalysis/blob/second/Image_steagnalysis_SiaNET_MYMODELextra68.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
import logging
import os
import random
from PIL import Image
import cv2
import numpy as np
import torch
import random
import os
import os.path as osp

def set_random_seed(seed=None):
    """Sets random seed for reproducibility.

    Args:
        seed (int, optional): Random seed.
    """
    if seed is None:
        seed = (
                os.getpid()
                + int(datetime.now().strftime("%S%f"))
                + int.from_bytes(os.urandom(2), "big")
        )
        logger = logging.getLogger(__name__)
        logger.info('Using a generated random seed {}'.format(seed))
    random.seed(seed)
    np.random.seed(seed)
    torch.set_rng_state(torch.manual_seed(seed).get_state())


def get_random_seed():
    return np.random.randint(2 ** 31)

# %%
class RandomRot(object):

    def __call__(self, sample):
        rot = random.randint(0, 3)
        return {
            'image': np.rot90(sample['image'], rot, axes=[-3, -2]).copy(),
            'label': sample['label'],
        }


class RandomFlip(object):

    def __init__(self, p=0.5):
        self._p = p

    def __call__(self, sample):
        if random.random() < self._p:
            return {
                'image': np.flip(sample['image'], axis=-2).copy(),
                'label': sample['label'],
            }
        else:
            return sample


class ToTensor(object):

    def __call__(self, sample):
        image, label = sample['image'], sample['label']
        if image.ndim == 3:  # HxWxC
            image = image.transpose(2, 0, 1)
        else:  # NxHxWxC
            image = image.transpose(0, 3, 1, 2)
        return {
            'image': torch.from_numpy(image).type(torch.FloatTensor),
            'label': torch.tensor(label).long()
        }

# %%
from torch.utils.data import Dataset


class CoverStegoDataset(Dataset):

    def __init__(self, cover_dir, stego_dir, transform=None):
        self._transform = transform

        self.images, self.labels = self.get_items(cover_dir, stego_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = np.array(Image.open(self.images[idx]))
        image = np.expand_dims(image, 2)  # (H, W, C)
        assert image.ndim == 3

        sample = {
            'image': image,
            'label': self.labels[idx]
        }

        if self._transform:
            sample = self._transform(sample)
        return sample

    @staticmethod
    def get_items(cover_dir, stego_dir):
        images, labels = [], []

        cover_names = sorted(os.listdir(cover_dir))
        if stego_dir is not None:
            stego_names = sorted(os.listdir(stego_dir))
            assert cover_names == stego_names

        file_names = cover_names
        if stego_dir is None:
            dir_to_label = [(cover_dir, 0), ]
        else:
            dir_to_label = [(cover_dir, 0), (stego_dir, 1)]
        for image_dir, label in dir_to_label:
            for file_name in file_names:
                image_path = osp.join(image_dir, file_name)
                if not osp.isfile(image_path):
                    raise FileNotFoundError('{} not exists'.format(image_path))
                images.append(image_path)
                labels.append(label)

        return images, labels

# %%
import torchvision
from torch.utils.data import BatchSampler
from torch.utils.data import DataLoader
from torch.utils.data import Sampler
from torch.utils.data import SequentialSampler
import itertools
import logging
import math

class TrainingSampler(Sampler):

    def __init__(self, size, seed=None, shuffle=True):
        self._size = size
        self._shuffle = shuffle

        if seed is None:
            seed = get_random_seed()
        self._seed = seed

    def __iter__(self):
        yield from itertools.islice(self._infinite_indices(), 0, None, 1)

    def _infinite_indices(self):
        g = torch.Generator()
        g.manual_seed(self._seed)
        while True:
            if self._shuffle:
                yield from torch.randperm(self._size, generator=g)
            else:
                yield from torch.arange(self._size)




class BalancedBatchSampler(BatchSampler):

    def __init__(self, sampler, group_ids, batch_size):
        """
        Args:
            sampler (Sampler): Base sampler.
            group_ids (list[int]): If the sampler produces indices in range [0, N),
                `group_ids` must be a list of `N` ints which contains the group id of each
                sample. The group ids must be a set of integers in [0, num_groups).
            batch_size (int): Size of mini-batch.
        """
        if not isinstance(sampler, Sampler):
            raise ValueError("sampler should be an instance of torch.utils.data.Sampler, "
                             "but got sampler={}".format(sampler))

        self._sampler = sampler
        self._group_ids = np.asarray(group_ids)
        assert self._group_ids.ndim == 1
        self._batch_size = batch_size
        groups = np.unique(self._group_ids).tolist()
        assert batch_size % len(groups) == 0

        # buffer the indices of each group until batch size is reached
        self._buffer_per_group = {k: [] for k in groups}
        self._group_size = batch_size // len(groups)

    def __iter__(self):
        for idx in self._sampler:
            group_id = self._group_ids[idx]
            self._buffer_per_group[group_id].append(idx)
            if all(len(v) >= self._group_size for k, v in self._buffer_per_group.items()):
                idxs = []
                # Collect across all groups
                for k, v in self._buffer_per_group.items():
                    idxs.extend(v[:self._group_size])
                    del v[:self._group_size]

                idxs = np.random.permutation(idxs)
                yield idxs

    def __len__(self):
        raise NotImplementedError("len() of GroupedBatchSampler is not well-defined.")


def build_train_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        RandomRot(),
        RandomFlip(),
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    size = len(dataset)
    sampler = TrainingSampler(size)
    if stego_dir is not None:
        batch_sampler = BalancedBatchSampler(sampler, dataset.labels, batch_size)
    else:
        batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)
    epoch_length = math.ceil(size / batch_size)


    train_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
        worker_init_fn=worker_init_reset_seed,
    )
    return train_loader, epoch_length




def build_val_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    sampler = SequentialSampler(dataset)
    batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)


    test_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
    )
    return test_loader

def worker_init_reset_seed(worker_id):
    set_random_seed(np.random.randint(2 ** 31) + worker_id)

# %%
set_random_seed()

# %%
 train_cover_dir = "/content/drive/MyDrive/real_boss_256/train/cover"
 train_stego_dir = "/content/drive/MyDrive/real_boss_256/train/stego"
 val_cover_dir = "/content/drive/MyDrive/real_boss_256/validation/cover"
 val_stego_dir = "/content/drive/MyDrive/real_boss_256/validation/stego"
 
 
 train_loader, epoch_length = build_train_loader(
        train_cover_dir, train_stego_dir, batch_size=32,
        num_workers=0)

# %%
print(epoch_length)
# Out:
# 375

# %%
val_loader = build_val_loader(
    val_cover_dir, val_stego_dir, batch_size=32,
    num_workers=0
)

# %%
train_loader_iter = iter(train_loader)

# %%
from torch import nn

def activation(x):
    a = torch.ones(x.shape).cuda()
    a = torch.mul(a, -3).cuda()
    b = torch.ones(x.shape).cuda()
    b = torch.mul(b, 3).cuda()
    c = torch.where(x > -3,x,a).cuda()
    d = torch.where(c < 3,c,b).cuda()
    return d     


class the_tlu(nn.Module):
    def __init__(self):
        super(the_tlu, self).__init__()
    def forward(self, x):
        return activation(x)

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.nn import Parameter


srm_dir = "/content/drive/MyDrive"
SRM_npy = np.load(os.path.join(srm_dir,"SRM_Kernels.npy"))


def accuracy(outputs, labels):
    _, argmax = torch.max(outputs, 1)
    return (labels == argmax.squeeze()).float().mean()


def conv3x3(in_planes, out_planes, stride=1, groups=1, dilation=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                     padding=dilation, groups=groups, bias=False, dilation=dilation)


def conv1x1(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


class SRMConv2d(nn.Module):

    def __init__(self, stride=1, padding=0):
        super(SRMConv2d, self).__init__()
        self.in_channels = 1
        self.out_channels = 30
        self.kernel_size = (5, 5)
        if isinstance(stride, int):
            self.stride = (stride, stride)
        else:
            self.stride = stride
        if isinstance(padding, int):
            self.padding = (padding, padding)
        else:
            self.padding = padding
        self.dilation = (1, 1)
        self.transpose = False
        self.output_padding = (0,)
        self.groups = 1
        self.weight = Parameter(torch.Tensor(30, 1, 5, 5), requires_grad=True)
        self.bias = Parameter(torch.Tensor(30), requires_grad=True)
        self.reset_parameters()

    def reset_parameters(self):
        self.weight.data.numpy()[:] = SRM_npy
        self.bias.data.zero_()

    def forward(self, input):
        return F.conv2d(input, self.weight, self.bias, self.stride, self.padding,
                        self.dilation, self.groups)


class BlockA(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockA, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += identity
        out = self.relu(out)

        return out


class BlockB(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockB, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes, stride=2)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)
        # self.pool = nn.AvgPool2d(3, stride=2, padding=1)

        self.shortcut_conv = conv1x1(in_planes, out_planes, stride=2)
        self.shortcut_bn = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        # out = self.pool(out)

        identity = self.shortcut_conv(identity)
        identity = self.shortcut_bn(identity)

        out += identity
        out = self.relu(out)

        return out

# %%
class KeNet(nn.Module):

    def __init__(self, norm_layer=None, zero_init_residual=True, p=0.5):
        super(KeNet, self).__init__()

        self.zero_init_residual = zero_init_residual

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.srm = SRMConv2d(1, 0)
        self.bn1 = norm_layer(30)
        self.tlu = the_tlu()

        self.A1 = BlockA(30, 30, norm_layer=norm_layer)
        self.A2 = BlockA(30, 30, norm_layer=norm_layer)
        self.AA = BlockA(30, 30, norm_layer=norm_layer)

        # self.B1 = BlockB(30, 30, norm_layer=norm_layer)
        # self.B2 = BlockB(30, 64, norm_layer=norm_layer)

        self.B3 = BlockB(30, 64, norm_layer=norm_layer)
        self.A3 = BlockA(64, 64, norm_layer=norm_layer)

        self.B4 = BlockB(64, 128, norm_layer=norm_layer)
        self.A4 = BlockA(128, 128, norm_layer=norm_layer)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # self.bnfc = nn.BatchNorm1d(128)
        self.relu = nn.ReLU(inplace=True)
        # self.fcfusion = nn.Linear(128, 128) #4
        self.fc = nn.Linear(128 * 4 + 1, 2)
        self.dropout = nn.Dropout(p=p)

        self.reset_parameters()

    def reset_parameters(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # nn.init.xavier_uniform_(m.weight)
                # nn.init.constant_(m.bias, 0.2)
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, std=0.01)

        if self.zero_init_residual:
            for m in self.modules():
                if isinstance(m, (BlockA, BlockB)):
                    nn.init.constant_(m.bn2.weight, 0)

    def extract_feat(self, x):
        x = x.float()
        out = self.srm(x)
        out = self.bn1(out)
        out = self.tlu(out)
    #    out = self.relu(out)

        out = self.A1(out)
        out = self.A2(out)
        out = self.AA(out)

        # out = self.B1(out)
        # out = self.B2(out)

        out = self.B3(out)
        out = self.A3(out)

        out = self.B4(out)
        out = self.A4(out)

        out = self.avgpool(out)
        out = out.view(out.size(0), out.size(1))

        # out = self.relu(out)
        # out = self.bnfc(out)

        return out

    def forward(self, *args):
        ############# statistics fusion start #############
        feats = torch.stack(
            [self.extract_feat(subarea) for subarea in args], dim=0
        )

        euclidean_distance = F.pairwise_distance(feats[0], feats[1], eps=1e-6,
                                                 keepdim=True)

        if feats.shape[0] == 1:
            final_feat = feats.squeeze(dim=0)
        else:
            # feats_sum = feats.sum(dim=0)
            # feats_sub = feats[0] - feats[1]
            feats_mean = feats.mean(dim=0)
            feats_var = feats.var(dim=0)
            feats_min, _ = feats.min(dim=0)
            feats_max, _ = feats.max(dim=0)

            '''feats_sum = feats.sum(dim=0)
            feats_sub = abs(feats[0] - feats[1])
            feats_prod = feats.prod(dim=0)
            feats_max, _ = feats.max(dim=0)'''
            
            #final_feat = torch.cat(
            #    [feats[0], feats[1], feats[0], feats[1]], dim=-1
            #    #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            #)

            final_feat = torch.cat(
                [euclidean_distance, feats_mean, feats_var, feats_min, feats_max], dim=-1
                #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            )

        out = self.dropout(final_feat)
        # out = self.fcfusion(out)
        # out = self.relu(out)
        out = self.fc(out)

        return out, feats[0], feats[1]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ContrastiveLoss(nn.Module):

    def __init__(self, margin=1.25):  # margin=2
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        label = label.to(torch.float32)
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean(
            (1 - label) * torch.pow(euclidean_distance, 2) +
            label * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2)
        )

        return loss_contrastive

# %%
criterion_1 = nn.CrossEntropyLoss()
criterion_2 = ContrastiveLoss(margin=1)

# %%
net = KeNet();

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

device = get_default_device()


if device.type == "cuda":
    net.cuda()
    criterion_1.cuda()
    criterion_2.cuda()

# %%
from torch.optim.adamax import Adamax

optimizer = Adamax(net.parameters(), lr=0.001, eps=1e-08, weight_decay=0.0001)

# %%
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', factor=0.3,
                                                           patience=10, verbose=True, min_lr=0,
                                                           eps=1e-08)

# %%
import logging
import time
import shutil
logger = logging.getLogger(__name__)


def preprocess_data(images, labels, random_crop,gpu):
    # images of shape: NxCxHxW
    if images.ndim == 5:  # 1xNxCxHxW
        images = images.squeeze(0)
        labels = labels.squeeze(0)
    h, w = images.shape[-2:]

    if random_crop:
        ch = random.randint(h * 3 // 4, h)  # h // 2      #256
        cw = random.randint(w * 3 // 4, w)  # square ch   #256

        h0 = random.randint(0, h - ch)  # 128
        w0 = random.randint(0, w - cw)  # 128
    else:
        ch, cw, h0, w0 = h, w, 0, 0


    cw = cw & ~1
    inputs = [
            images[..., h0:h0 + ch, w0:w0 + cw // 2],
            images[..., h0:h0 + ch, w0 + cw // 2:w0 + cw]
        ]

    if gpu:
        inputs = [x.cuda() for x in inputs]
        labels = labels.cuda()
    return inputs, labels

# %%
def train(epoch):
    net.train()
    running_loss, running_accuracy = 0., 0.

    for batch_idx in range(epoch_length):
        data = next(train_loader_iter)
        inputs, labels = preprocess_data(data['image'], data['label'], False,gpu=True)

        optimizer.zero_grad()
   
        outputs, feats_0, feats_1 = net(*inputs)

            # count parameters start
            # print('parameters_count: {}'.format(sum(p.numel() for p in net.parameters() if p.requires_grad)))
            # count parameters end

        loss = criterion_1(outputs, labels) + \
                   0.1 * criterion_2(feats_0, feats_1, labels)

        accuracy1 = accuracy(outputs, labels).item()
        running_accuracy += accuracy1
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        if (batch_idx + 1) % 10 == 0:
            running_accuracy /= 10
            running_loss /= 10
            
            print(
                'Train epoch: {} [{}/{}]\tAccuracy: {:.2f}%\tLoss: {:.6f}'.format(
                    epoch, batch_idx + 1, epoch_length, 100 * running_accuracy,
                    running_loss))
                    
            ###############################log per log_interval start
            is_best=False
            save_checkpoint(
                {
                    'iteration': batch_idx + 1,
                    'state_dict': net.state_dict(),
                    'best_prec1': running_accuracy,
                    'optimizer': optimizer.state_dict(),
                },
                is_best,
                filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
                best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
            ###############################
            running_loss = 0.
            running_accuracy = 0.
            net.train()

# %%
def valid():
    net.eval()
    valid_loss = 0.
    valid_accuracy = 0.
    with torch.no_grad():
        for data in val_loader:
            inputs, labels = preprocess_data(data['image'], data['label'], False,gpu = True)

            outputs, feats_0, feats_1 = net(*inputs)
            valid_loss += criterion_1(outputs, labels).item() + \
                              0.01 * criterion_2(feats_0, feats_1, labels)
            valid_accuracy += accuracy(outputs, labels).item()
    valid_loss /= len(val_loader)
    valid_accuracy /= len(val_loader)
    print('Test set: Loss: {:.4f}, Accuracy: {:.2f}%)'.format(
        valid_loss, 100 * valid_accuracy))
    return valid_loss, valid_accuracy

# %%
fine_tune = "/content/drive/MyDrive/dataset/checkpoint.pth.tar"

if fine_tune is not None:
    net.load_state_dict(torch.load(fine_tune)['state_dict'], strict=False)
    e = torch.load(fine_tune)['iteration']

# %%
print(e)
# Out:
# 140

# %%
def save_checkpoint(state, is_best, filename, best_name):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, best_name)


_time = time.time()
best_accuracy = 0.
for e in range(1, 100 + 1):
    logger.info('Epoch: {}'.format(e))
    logger.info('Train')
    train(e)
    logger.info('Time: {}'.format(time.time() - _time))
    logger.info('Test')
    _, accuracy1 = valid()
    if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
        scheduler.step(accuracy1)
    else:
        scheduler.step()
    if accuracy1 > best_accuracy:
        best_accuracy = accuracy1
        is_best = True
    else:
        is_best = False
    logger.info('Best accuracy: {}'.format(best_accuracy))
    logger.info('Time: {}'.format(time.time() - _time))
    save_checkpoint(
        {
            'epoch': e,
            'state_dict': net.state_dict(),
            'best_prec1': accuracy1,
            'optimizer': optimizer.state_dict(),
        },
        is_best,
        filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
        best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
# Out:
# Train epoch: 1 [10/375]	Accuracy: 81.88%	Loss: 0.480134
# Train epoch: 1 [20/375]	Accuracy: 85.31%	Loss: 0.306130
# Train epoch: 1 [30/375]	Accuracy: 84.38%	Loss: 0.359300
# Train epoch: 1 [40/375]	Accuracy: 89.06%	Loss: 0.258173
# Train epoch: 1 [50/375]	Accuracy: 85.94%	Loss: 0.279130
# Train epoch: 1 [60/375]	Accuracy: 87.19%	Loss: 0.255831
# Train epoch: 1 [70/375]	Accuracy: 87.81%	Loss: 0.275215
# Train epoch: 1 [80/375]	Accuracy: 88.12%	Loss: 0.272169
# Train epoch: 1 [90/375]	Accuracy: 86.88%	Loss: 0.285913
# Train epoch: 1 [100/375]	Accuracy: 84.38%	Loss: 0.338086
# Train epoch: 1 [110/375]	Accuracy: 87.81%	Loss: 0.244377
# Train epoch: 1 [120/375]	Accuracy: 89.38%	Loss: 0.249377
# Train epoch: 1 [130/375]	Accuracy: 88.75%	Loss: 0.247343
# Train epoch: 1 [140/375]	Accuracy: 89.06%	Loss: 0.246856
# Train epoch: 1 [150/375]	Accuracy: 87.50%	Loss: 0.242024
# Train epoch: 1 [160/375]	Accuracy: 88.12%	Loss: 0.267845
# Train epoch: 1 [170/375]	Accuracy: 89.06%	Loss: 0.265325
# Train epoch: 1 [180/375]	Accuracy: 90.00%	Loss: 0.247347
# Train epoch: 1 [190/375]	Accuracy: 87.19%	Loss: 0.255221
# Train epoch: 1 [200/375]	Accuracy: 89.38%	Loss: 0.254938
# Train epoch: 1 [210/375]	Accuracy: 90.31%	Loss: 0.253610
# Train epoch: 1 [220/375]	Accuracy: 86.88%	Loss: 0.264977
# Train epoch: 1 [230/375]	Accuracy: 90.31%	Loss: 0.260216
# Train epoch: 1 [240/375]	Accuracy: 89.38%	Loss: 0.246544
# Train epoch: 1 [250/375]	Accuracy: 87.19%	Loss: 0.269196
# Train epoch: 1 [260/375]	Accuracy: 86.88%	Loss: 0.279051
# Train epoch: 1 [270/375]	Accuracy: 92.50%	Loss: 0.187095
# Train epoch: 1 [280/375]	Accuracy: 87.81%	Loss: 0.250626
# Train epoch: 1 [290/375]	Accuracy: 86.25%	Loss: 0.267979
# Train epoch: 1 [300/375]	Accuracy: 89.38%	Loss: 0.231117
# Train epoch: 1 [310/375]	Accuracy: 85.94%	Loss: 0.266121
# Train epoch: 1 [320/375]	Accuracy: 91.56%	Loss: 0.194813
# Train epoch: 1 [330/375]	Accuracy: 88.75%	Loss: 0.250593
# Train epoch: 1 [340/375]	Accuracy: 88.12%	Loss: 0.232198
# Train epoch: 1 [350/375]	Accuracy: 88.44%	Loss: 0.243195
# Train epoch: 1 [360/375]	Accuracy: 87.19%	Loss: 0.265497
# Train epoch: 1 [370/375]	Accuracy: 90.94%	Loss: 0.241404
# Test set: Loss: 0.4071, Accuracy: 84.52%)
# Train epoch: 2 [10/375]	Accuracy: 88.12%	Loss: 0.264404
# Train epoch: 2 [20/375]	Accuracy: 88.75%	Loss: 0.246647
# Train epoch: 2 [30/375]	Accuracy: 85.62%	Loss: 0.294952
# Train epoch: 2 [40/375]	Accuracy: 88.12%	Loss: 0.259227
# Train epoch: 2 [50/375]	Accuracy: 83.75%	Loss: 0.288272
# Train epoch: 2 [60/375]	Accuracy: 88.12%	Loss: 0.258313
# Train epoch: 2 [70/375]	Accuracy: 88.12%	Loss: 0.243060
# Train epoch: 2 [80/375]	Accuracy: 89.38%	Loss: 0.236456
# Train epoch: 2 [90/375]	Accuracy: 88.75%	Loss: 0.259600
# Train epoch: 2 [100/375]	Accuracy: 89.06%	Loss: 0.238630
# Train epoch: 2 [110/375]	Accuracy: 89.38%	Loss: 0.237327
# Train epoch: 2 [120/375]	Accuracy: 87.50%	Loss: 0.277663
# Train epoch: 2 [130/375]	Accuracy: 90.62%	Loss: 0.217543
# Train epoch: 2 [140/375]	Accuracy: 90.00%	Loss: 0.226549
# Train epoch: 2 [150/375]	Accuracy: 91.88%	Loss: 0.212897
# Train epoch: 2 [160/375]	Accuracy: 88.12%	Loss: 0.250176
# Train epoch: 2 [170/375]	Accuracy: 87.81%	Loss: 0.240933
# Train epoch: 2 [180/375]	Accuracy: 90.94%	Loss: 0.199699
# Train epoch: 2 [190/375]	Accuracy: 87.81%	Loss: 0.285995
# Train epoch: 2 [200/375]	Accuracy: 87.81%	Loss: 0.242678
# Train epoch: 2 [210/375]	Accuracy: 88.44%	Loss: 0.256547
# Train epoch: 2 [220/375]	Accuracy: 88.75%	Loss: 0.282446
# Train epoch: 2 [230/375]	Accuracy: 88.12%	Loss: 0.254726
# Train epoch: 2 [240/375]	Accuracy: 90.31%	Loss: 0.254323
# Train epoch: 2 [250/375]	Accuracy: 93.12%	Loss: 0.207255
# Train epoch: 2 [260/375]	Accuracy: 90.31%	Loss: 0.249090
# Train epoch: 2 [270/375]	Accuracy: 87.81%	Loss: 0.234395
# Train epoch: 2 [280/375]	Accuracy: 86.25%	Loss: 0.267479
# Train epoch: 2 [290/375]	Accuracy: 86.56%	Loss: 0.279786
# Train epoch: 2 [300/375]	Accuracy: 91.25%	Loss: 0.246778
# Train epoch: 2 [310/375]	Accuracy: 88.12%	Loss: 0.273053
# Train epoch: 2 [320/375]	Accuracy: 87.81%	Loss: 0.247649
# Train epoch: 2 [330/375]	Accuracy: 86.88%	Loss: 0.251264
# Train epoch: 2 [340/375]	Accuracy: 92.19%	Loss: 0.195880
# Train epoch: 2 [350/375]	Accuracy: 88.12%	Loss: 0.296581
# Train epoch: 2 [360/375]	Accuracy: 90.31%	Loss: 0.226109
# Train epoch: 2 [370/375]	Accuracy: 90.31%	Loss: 0.230384
# Test set: Loss: 0.3284, Accuracy: 87.00%)
# Train epoch: 3 [10/375]	Accuracy: 89.69%	Loss: 0.222666
# Train epoch: 3 [20/375]	Accuracy: 88.75%	Loss: 0.236693
# Train epoch: 3 [30/375]	Accuracy: 85.31%	Loss: 0.283997
# Train epoch: 3 [40/375]	Accuracy: 92.19%	Loss: 0.209272
# Train epoch: 3 [50/375]	Accuracy: 90.94%	Loss: 0.210083
# Train epoch: 3 [60/375]	Accuracy: 90.00%	Loss: 0.239879
# Train epoch: 3 [70/375]	Accuracy: 85.31%	Loss: 0.278238
# Train epoch: 3 [80/375]	Accuracy: 85.94%	Loss: 0.317526
# Train epoch: 3 [90/375]	Accuracy: 89.38%	Loss: 0.246511
# Train epoch: 3 [100/375]	Accuracy: 89.38%	Loss: 0.255135
# Train epoch: 3 [110/375]	Accuracy: 89.06%	Loss: 0.237580
# Train epoch: 3 [120/375]	Accuracy: 90.62%	Loss: 0.258663
# Train epoch: 3 [130/375]	Accuracy: 88.75%	Loss: 0.263953
# Train epoch: 3 [140/375]	Accuracy: 88.44%	Loss: 0.256540
# Train epoch: 3 [150/375]	Accuracy: 87.81%	Loss: 0.256284
# Train epoch: 3 [160/375]	Accuracy: 91.56%	Loss: 0.197893
# Train epoch: 3 [170/375]	Accuracy: 88.75%	Loss: 0.288017
# Train epoch: 3 [180/375]	Accuracy: 89.38%	Loss: 0.262562
# Train epoch: 3 [190/375]	Accuracy: 89.38%	Loss: 0.225251
# Train epoch: 3 [200/375]	Accuracy: 90.00%	Loss: 0.214865
# Train epoch: 3 [210/375]	Accuracy: 91.25%	Loss: 0.227814
# Train epoch: 3 [220/375]	Accuracy: 88.75%	Loss: 0.256492
# Train epoch: 3 [230/375]	Accuracy: 89.69%	Loss: 0.239850
# Train epoch: 3 [240/375]	Accuracy: 90.62%	Loss: 0.226531
# Train epoch: 3 [250/375]	Accuracy: 88.12%	Loss: 0.257664
# Train epoch: 3 [260/375]	Accuracy: 83.44%	Loss: 0.305008
# Train epoch: 3 [270/375]	Accuracy: 90.00%	Loss: 0.233657
# Train epoch: 3 [280/375]	Accuracy: 88.44%	Loss: 0.255785
# Train epoch: 3 [290/375]	Accuracy: 90.94%	Loss: 0.221466
# Train epoch: 3 [300/375]	Accuracy: 90.94%	Loss: 0.218186
# Train epoch: 3 [310/375]	Accuracy: 90.31%	Loss: 0.218683
# Train epoch: 3 [320/375]	Accuracy: 87.19%	Loss: 0.278270
# Train epoch: 3 [330/375]	Accuracy: 89.69%	Loss: 0.251137
# Train epoch: 3 [340/375]	Accuracy: 89.38%	Loss: 0.224158
# Train epoch: 3 [350/375]	Accuracy: 88.75%	Loss: 0.257648
# Train epoch: 3 [360/375]	Accuracy: 85.94%	Loss: 0.273031
# Train epoch: 3 [370/375]	Accuracy: 87.81%	Loss: 0.261833
# Test set: Loss: 0.2006, Accuracy: 91.02%)
# Train epoch: 4 [10/375]	Accuracy: 88.75%	Loss: 0.227333
# Train epoch: 4 [20/375]	Accuracy: 90.00%	Loss: 0.253238
# Train epoch: 4 [30/375]	Accuracy: 91.56%	Loss: 0.220790
# Train epoch: 4 [40/375]	Accuracy: 85.31%	Loss: 0.277913
# Train epoch: 4 [50/375]	Accuracy: 88.44%	Loss: 0.241520
# Train epoch: 4 [60/375]	Accuracy: 89.69%	Loss: 0.226647
# Train epoch: 4 [70/375]	Accuracy: 86.88%	Loss: 0.273509
# Train epoch: 4 [80/375]	Accuracy: 90.31%	Loss: 0.249835
# Train epoch: 4 [90/375]	Accuracy: 90.62%	Loss: 0.212267
# Train epoch: 4 [100/375]	Accuracy: 87.81%	Loss: 0.247374
# Train epoch: 4 [110/375]	Accuracy: 89.69%	Loss: 0.221881
# Train epoch: 4 [120/375]	Accuracy: 89.38%	Loss: 0.254995
# Train epoch: 4 [130/375]	Accuracy: 91.88%	Loss: 0.214136
# Train epoch: 4 [140/375]	Accuracy: 89.38%	Loss: 0.210857
# Train epoch: 4 [150/375]	Accuracy: 91.25%	Loss: 0.200208
# Train epoch: 4 [160/375]	Accuracy: 90.94%	Loss: 0.212095
# Train epoch: 4 [170/375]	Accuracy: 90.62%	Loss: 0.203154
# Train epoch: 4 [180/375]	Accuracy: 87.50%	Loss: 0.271550
# Train epoch: 4 [190/375]	Accuracy: 86.88%	Loss: 0.273552
# Train epoch: 4 [200/375]	Accuracy: 90.62%	Loss: 0.223898
# Train epoch: 4 [210/375]	Accuracy: 88.75%	Loss: 0.225079
# Train epoch: 4 [220/375]	Accuracy: 88.44%	Loss: 0.256375
# Train epoch: 4 [230/375]	Accuracy: 91.56%	Loss: 0.209984
# Train epoch: 4 [240/375]	Accuracy: 88.75%	Loss: 0.235489
# Train epoch: 4 [250/375]	Accuracy: 87.50%	Loss: 0.274012
# Train epoch: 4 [260/375]	Accuracy: 89.06%	Loss: 0.254172
# Train epoch: 4 [270/375]	Accuracy: 88.75%	Loss: 0.246206
# Train epoch: 4 [280/375]	Accuracy: 87.50%	Loss: 0.257515
# Train epoch: 4 [290/375]	Accuracy: 90.31%	Loss: 0.233905
# Train epoch: 4 [300/375]	Accuracy: 90.00%	Loss: 0.255918
# Train epoch: 4 [310/375]	Accuracy: 90.00%	Loss: 0.221679
# Train epoch: 4 [320/375]	Accuracy: 86.56%	Loss: 0.257869
# Train epoch: 4 [330/375]	Accuracy: 90.31%	Loss: 0.225379
# Train epoch: 4 [340/375]	Accuracy: 86.56%	Loss: 0.287556
# Train epoch: 4 [350/375]	Accuracy: 90.00%	Loss: 0.242267
# Train epoch: 4 [360/375]	Accuracy: 90.94%	Loss: 0.219921
# Train epoch: 4 [370/375]	Accuracy: 88.12%	Loss: 0.264331
# Test set: Loss: 0.1954, Accuracy: 91.42%)
# Train epoch: 5 [10/375]	Accuracy: 86.56%	Loss: 0.266035
# Train epoch: 5 [20/375]	Accuracy: 90.94%	Loss: 0.214216
# Train epoch: 5 [30/375]	Accuracy: 91.25%	Loss: 0.219429
# Train epoch: 5 [40/375]	Accuracy: 88.75%	Loss: 0.220721
# Train epoch: 5 [50/375]	Accuracy: 87.19%	Loss: 0.257066
# Train epoch: 5 [60/375]	Accuracy: 89.69%	Loss: 0.254036
# Train epoch: 5 [70/375]	Accuracy: 87.81%	Loss: 0.242257
# Train epoch: 5 [80/375]	Accuracy: 89.06%	Loss: 0.248057
# Train epoch: 5 [90/375]	Accuracy: 90.94%	Loss: 0.222329
# Train epoch: 5 [100/375]	Accuracy: 88.12%	Loss: 0.268638
# Train epoch: 5 [110/375]	Accuracy: 88.44%	Loss: 0.238096
# Train epoch: 5 [120/375]	Accuracy: 88.75%	Loss: 0.245706
# Train epoch: 5 [130/375]	Accuracy: 89.69%	Loss: 0.235457
# Train epoch: 5 [140/375]	Accuracy: 90.94%	Loss: 0.223711
# Train epoch: 5 [150/375]	Accuracy: 88.75%	Loss: 0.250012
# Train epoch: 5 [160/375]	Accuracy: 90.31%	Loss: 0.262505
# Train epoch: 5 [170/375]	Accuracy: 89.69%	Loss: 0.276910
# Train epoch: 5 [180/375]	Accuracy: 86.88%	Loss: 0.286975
# Train epoch: 5 [190/375]	Accuracy: 87.81%	Loss: 0.240918
# Train epoch: 5 [200/375]	Accuracy: 89.69%	Loss: 0.210755
# Train epoch: 5 [210/375]	Accuracy: 91.56%	Loss: 0.189152
# Train epoch: 5 [220/375]	Accuracy: 87.50%	Loss: 0.230780
# Train epoch: 5 [230/375]	Accuracy: 89.38%	Loss: 0.245877
# Train epoch: 5 [240/375]	Accuracy: 88.44%	Loss: 0.231256
# Train epoch: 5 [250/375]	Accuracy: 89.06%	Loss: 0.236726
# Train epoch: 5 [260/375]	Accuracy: 87.19%	Loss: 0.270087
# Train epoch: 5 [270/375]	Accuracy: 88.44%	Loss: 0.239138
# Train epoch: 5 [280/375]	Accuracy: 89.38%	Loss: 0.202021
# Train epoch: 5 [290/375]	Accuracy: 93.12%	Loss: 0.200473
# Train epoch: 5 [300/375]	Accuracy: 91.88%	Loss: 0.204115
# Train epoch: 5 [310/375]	Accuracy: 85.31%	Loss: 0.256618
# Train epoch: 5 [320/375]	Accuracy: 86.25%	Loss: 0.249530
# Train epoch: 5 [330/375]	Accuracy: 89.69%	Loss: 0.242717
# Train epoch: 5 [340/375]	Accuracy: 87.81%	Loss: 0.250282
# Train epoch: 5 [350/375]	Accuracy: 85.31%	Loss: 0.261796
# Train epoch: 5 [360/375]	Accuracy: 88.75%	Loss: 0.239800
# Train epoch: 5 [370/375]	Accuracy: 85.94%	Loss: 0.301443
# Test set: Loss: 0.1975, Accuracy: 91.67%)
# Train epoch: 6 [10/375]	Accuracy: 89.69%	Loss: 0.224440
# Train epoch: 6 [20/375]	Accuracy: 87.81%	Loss: 0.271312
# Train epoch: 6 [30/375]	Accuracy: 85.31%	Loss: 0.275150
# Train epoch: 6 [40/375]	Accuracy: 83.12%	Loss: 0.346003
# Train epoch: 6 [50/375]	Accuracy: 87.81%	Loss: 0.242352
# Train epoch: 6 [60/375]	Accuracy: 85.62%	Loss: 0.317991
# Train epoch: 6 [70/375]	Accuracy: 89.06%	Loss: 0.278070
# Train epoch: 6 [80/375]	Accuracy: 87.81%	Loss: 0.229544
# Train epoch: 6 [90/375]	Accuracy: 87.81%	Loss: 0.270365
# Train epoch: 6 [100/375]	Accuracy: 91.56%	Loss: 0.222363
# Train epoch: 6 [110/375]	Accuracy: 87.81%	Loss: 0.241140
# Train epoch: 6 [120/375]	Accuracy: 90.00%	Loss: 0.234589
# Train epoch: 6 [130/375]	Accuracy: 89.06%	Loss: 0.244670
# Train epoch: 6 [140/375]	Accuracy: 92.50%	Loss: 0.177250
# Train epoch: 6 [150/375]	Accuracy: 89.06%	Loss: 0.248346
# Train epoch: 6 [160/375]	Accuracy: 88.75%	Loss: 0.227608
# Train epoch: 6 [170/375]	Accuracy: 89.06%	Loss: 0.239693
# Train epoch: 6 [180/375]	Accuracy: 92.50%	Loss: 0.227792
# Train epoch: 6 [190/375]	Accuracy: 90.31%	Loss: 0.213807
# Train epoch: 6 [200/375]	Accuracy: 83.44%	Loss: 0.334004
# Train epoch: 6 [210/375]	Accuracy: 89.38%	Loss: 0.244513
# Train epoch: 6 [220/375]	Accuracy: 89.69%	Loss: 0.237131
# Train epoch: 6 [230/375]	Accuracy: 88.12%	Loss: 0.224095
# Train epoch: 6 [240/375]	Accuracy: 88.75%	Loss: 0.235291
# Train epoch: 6 [250/375]	Accuracy: 90.62%	Loss: 0.203463
# Train epoch: 6 [260/375]	Accuracy: 90.94%	Loss: 0.221060
# Train epoch: 6 [270/375]	Accuracy: 93.44%	Loss: 0.188234
# Train epoch: 6 [280/375]	Accuracy: 87.50%	Loss: 0.253929
# Train epoch: 6 [290/375]	Accuracy: 92.19%	Loss: 0.185435
# Train epoch: 6 [300/375]	Accuracy: 90.31%	Loss: 0.227260
# Train epoch: 6 [310/375]	Accuracy: 90.94%	Loss: 0.228531
# Train epoch: 6 [320/375]	Accuracy: 87.81%	Loss: 0.260669
# Train epoch: 6 [330/375]	Accuracy: 87.50%	Loss: 0.278799
# Train epoch: 6 [340/375]	Accuracy: 91.25%	Loss: 0.240559
# Train epoch: 6 [350/375]	Accuracy: 86.56%	Loss: 0.322842
# Train epoch: 6 [360/375]	Accuracy: 89.06%	Loss: 0.231345
# Train epoch: 6 [370/375]	Accuracy: 87.81%	Loss: 0.261704
# Test set: Loss: 0.2028, Accuracy: 90.48%)
# Train epoch: 7 [10/375]	Accuracy: 87.19%	Loss: 0.250548
# Train epoch: 7 [20/375]	Accuracy: 90.31%	Loss: 0.213239
# Train epoch: 7 [30/375]	Accuracy: 90.00%	Loss: 0.221617
# Train epoch: 7 [40/375]	Accuracy: 91.56%	Loss: 0.224057
# Train epoch: 7 [50/375]	Accuracy: 87.81%	Loss: 0.258934
# Train epoch: 7 [60/375]	Accuracy: 87.19%	Loss: 0.272045
# Train epoch: 7 [70/375]	Accuracy: 90.00%	Loss: 0.250161
# Train epoch: 7 [80/375]	Accuracy: 89.06%	Loss: 0.294060
# Train epoch: 7 [90/375]	Accuracy: 86.56%	Loss: 0.258083
# Train epoch: 7 [100/375]	Accuracy: 89.38%	Loss: 0.228968
# Train epoch: 7 [110/375]	Accuracy: 87.81%	Loss: 0.264897
# Train epoch: 7 [120/375]	Accuracy: 88.75%	Loss: 0.216738
# Train epoch: 7 [130/375]	Accuracy: 90.00%	Loss: 0.232556
# Train epoch: 7 [140/375]	Accuracy: 90.31%	Loss: 0.236228
# Train epoch: 7 [150/375]	Accuracy: 88.12%	Loss: 0.247120
# Train epoch: 7 [160/375]	Accuracy: 86.25%	Loss: 0.251783
# Train epoch: 7 [170/375]	Accuracy: 86.88%	Loss: 0.236646
# Train epoch: 7 [180/375]	Accuracy: 90.94%	Loss: 0.201655
# Train epoch: 7 [190/375]	Accuracy: 88.44%	Loss: 0.257126
# Train epoch: 7 [200/375]	Accuracy: 88.12%	Loss: 0.262913
# Train epoch: 7 [210/375]	Accuracy: 91.25%	Loss: 0.241972
# Train epoch: 7 [220/375]	Accuracy: 91.25%	Loss: 0.233064
# Train epoch: 7 [230/375]	Accuracy: 89.69%	Loss: 0.240283
# Train epoch: 7 [240/375]	Accuracy: 90.31%	Loss: 0.222468
# Train epoch: 7 [250/375]	Accuracy: 89.38%	Loss: 0.222642
# Train epoch: 7 [260/375]	Accuracy: 90.00%	Loss: 0.237713
# Train epoch: 7 [270/375]	Accuracy: 87.81%	Loss: 0.233942
# Train epoch: 7 [280/375]	Accuracy: 90.00%	Loss: 0.253779
# Train epoch: 7 [290/375]	Accuracy: 90.00%	Loss: 0.233603
# Train epoch: 7 [300/375]	Accuracy: 88.75%	Loss: 0.257753
# Train epoch: 7 [310/375]	Accuracy: 85.94%	Loss: 0.301751
# Train epoch: 7 [320/375]	Accuracy: 88.75%	Loss: 0.246691
# Train epoch: 7 [330/375]	Accuracy: 88.75%	Loss: 0.237550
# Train epoch: 7 [340/375]	Accuracy: 89.69%	Loss: 0.222407
# Train epoch: 7 [350/375]	Accuracy: 89.38%	Loss: 0.239548
# Train epoch: 7 [360/375]	Accuracy: 88.44%	Loss: 0.269512
# Train epoch: 7 [370/375]	Accuracy: 92.19%	Loss: 0.208225
# Test set: Loss: 0.2041, Accuracy: 91.12%)
# Train epoch: 8 [10/375]	Accuracy: 90.94%	Loss: 0.228576
# Train epoch: 8 [20/375]	Accuracy: 88.44%	Loss: 0.259673
# Train epoch: 8 [30/375]	Accuracy: 89.38%	Loss: 0.229790
# Train epoch: 8 [40/375]	Accuracy: 87.81%	Loss: 0.263193
# Train epoch: 8 [50/375]	Accuracy: 89.38%	Loss: 0.239292
# Train epoch: 8 [60/375]	Accuracy: 88.75%	Loss: 0.257685
# Train epoch: 8 [70/375]	Accuracy: 88.75%	Loss: 0.256679
# Train epoch: 8 [80/375]	Accuracy: 90.94%	Loss: 0.228585
# Train epoch: 8 [90/375]	Accuracy: 88.75%	Loss: 0.249833
# Train epoch: 8 [100/375]	Accuracy: 90.31%	Loss: 0.231824
# Train epoch: 8 [110/375]	Accuracy: 89.38%	Loss: 0.226028
# Train epoch: 8 [120/375]	Accuracy: 90.00%	Loss: 0.245329
# Train epoch: 8 [130/375]	Accuracy: 91.25%	Loss: 0.215230
# Train epoch: 8 [140/375]	Accuracy: 91.88%	Loss: 0.210667
# Train epoch: 8 [150/375]	Accuracy: 90.00%	Loss: 0.255615
# Train epoch: 8 [160/375]	Accuracy: 92.50%	Loss: 0.212697
# Train epoch: 8 [170/375]	Accuracy: 89.69%	Loss: 0.228267
# Train epoch: 8 [180/375]	Accuracy: 88.12%	Loss: 0.292454
# Train epoch: 8 [190/375]	Accuracy: 89.06%	Loss: 0.248866
# Train epoch: 8 [200/375]	Accuracy: 90.31%	Loss: 0.209192
# Train epoch: 8 [210/375]	Accuracy: 90.62%	Loss: 0.255890
# Train epoch: 8 [220/375]	Accuracy: 89.38%	Loss: 0.251543
# Train epoch: 8 [230/375]	Accuracy: 88.12%	Loss: 0.232560
# Train epoch: 8 [240/375]	Accuracy: 85.00%	Loss: 0.278954
# Train epoch: 8 [250/375]	Accuracy: 91.25%	Loss: 0.216247
# Train epoch: 8 [260/375]	Accuracy: 90.00%	Loss: 0.231125
# Train epoch: 8 [270/375]	Accuracy: 88.12%	Loss: 0.260285
# Train epoch: 8 [280/375]	Accuracy: 89.38%	Loss: 0.241418
# Train epoch: 8 [290/375]	Accuracy: 88.44%	Loss: 0.245958
# Train epoch: 8 [300/375]	Accuracy: 88.12%	Loss: 0.259903
# Train epoch: 8 [310/375]	Accuracy: 91.56%	Loss: 0.198949
# Train epoch: 8 [320/375]	Accuracy: 88.75%	Loss: 0.252384
# Train epoch: 8 [330/375]	Accuracy: 90.94%	Loss: 0.233407
# Train epoch: 8 [340/375]	Accuracy: 89.38%	Loss: 0.248774
# Train epoch: 8 [350/375]	Accuracy: 88.12%	Loss: 0.236117
# Train epoch: 8 [360/375]	Accuracy: 87.50%	Loss: 0.293995
# Train epoch: 8 [370/375]	Accuracy: 90.31%	Loss: 0.244617
# Test set: Loss: 0.2653, Accuracy: 89.48%)
# Train epoch: 9 [10/375]	Accuracy: 89.06%	Loss: 0.242056
# Train epoch: 9 [20/375]	Accuracy: 90.94%	Loss: 0.229977
# Train epoch: 9 [30/375]	Accuracy: 90.31%	Loss: 0.229965
# Train epoch: 9 [40/375]	Accuracy: 92.81%	Loss: 0.181466
# Train epoch: 9 [50/375]	Accuracy: 90.94%	Loss: 0.247738
# Train epoch: 9 [60/375]	Accuracy: 86.25%	Loss: 0.278868
# Train epoch: 9 [70/375]	Accuracy: 90.94%	Loss: 0.206681
# Train epoch: 9 [80/375]	Accuracy: 91.56%	Loss: 0.198553
# Train epoch: 9 [90/375]	Accuracy: 88.44%	Loss: 0.240284
# Train epoch: 9 [100/375]	Accuracy: 90.62%	Loss: 0.230945
# Train epoch: 9 [110/375]	Accuracy: 88.12%	Loss: 0.261801
# Train epoch: 9 [120/375]	Accuracy: 88.12%	Loss: 0.302969
# Train epoch: 9 [130/375]	Accuracy: 88.75%	Loss: 0.261651
# Train epoch: 9 [140/375]	Accuracy: 94.69%	Loss: 0.165732
# Train epoch: 9 [150/375]	Accuracy: 91.56%	Loss: 0.215349
# Train epoch: 9 [160/375]	Accuracy: 90.00%	Loss: 0.219064
# Train epoch: 9 [170/375]	Accuracy: 83.75%	Loss: 0.315357
# Train epoch: 9 [180/375]	Accuracy: 88.44%	Loss: 0.263104
# Train epoch: 9 [190/375]	Accuracy: 89.69%	Loss: 0.227507
# Train epoch: 9 [200/375]	Accuracy: 90.31%	Loss: 0.223872
# Train epoch: 9 [210/375]	Accuracy: 85.94%	Loss: 0.253971
# Train epoch: 9 [220/375]	Accuracy: 88.12%	Loss: 0.246291
# Train epoch: 9 [230/375]	Accuracy: 90.62%	Loss: 0.233693
# Train epoch: 9 [240/375]	Accuracy: 88.12%	Loss: 0.253451
# Train epoch: 9 [250/375]	Accuracy: 87.81%	Loss: 0.258297
# Train epoch: 9 [260/375]	Accuracy: 88.75%	Loss: 0.237757
# Train epoch: 9 [270/375]	Accuracy: 88.75%	Loss: 0.258989
# Train epoch: 9 [280/375]	Accuracy: 87.19%	Loss: 0.238375
# Train epoch: 9 [290/375]	Accuracy: 89.69%	Loss: 0.269854
# Train epoch: 9 [300/375]	Accuracy: 86.25%	Loss: 0.268095
# Train epoch: 9 [310/375]	Accuracy: 89.06%	Loss: 0.244656
# Train epoch: 9 [320/375]	Accuracy: 85.31%	Loss: 0.266515
# Train epoch: 9 [330/375]	Accuracy: 91.88%	Loss: 0.195363
# Train epoch: 9 [340/375]	Accuracy: 85.31%	Loss: 0.293803
# Train epoch: 9 [350/375]	Accuracy: 88.44%	Loss: 0.271934
# Train epoch: 9 [360/375]	Accuracy: 89.69%	Loss: 0.239230
# Train epoch: 9 [370/375]	Accuracy: 88.12%	Loss: 0.286344
# Test set: Loss: 0.2415, Accuracy: 89.78%)
# Train epoch: 10 [10/375]	Accuracy: 87.81%	Loss: 0.248050
# Train epoch: 10 [20/375]	Accuracy: 89.38%	Loss: 0.249594
# Train epoch: 10 [30/375]	Accuracy: 87.19%	Loss: 0.277083
# Train epoch: 10 [40/375]	Accuracy: 90.00%	Loss: 0.229648
# Train epoch: 10 [50/375]	Accuracy: 90.94%	Loss: 0.212834
# Train epoch: 10 [60/375]	Accuracy: 90.31%	Loss: 0.197877
# Train epoch: 10 [70/375]	Accuracy: 88.12%	Loss: 0.260491
# Train epoch: 10 [80/375]	Accuracy: 87.19%	Loss: 0.264775
# Train epoch: 10 [90/375]	Accuracy: 90.31%	Loss: 0.219902
# Train epoch: 10 [100/375]	Accuracy: 88.44%	Loss: 0.255578
# Train epoch: 10 [110/375]	Accuracy: 86.56%	Loss: 0.272479
# Train epoch: 10 [120/375]	Accuracy: 90.00%	Loss: 0.224268
# Train epoch: 10 [130/375]	Accuracy: 87.50%	Loss: 0.235498
# Train epoch: 10 [140/375]	Accuracy: 90.94%	Loss: 0.199022
# Train epoch: 10 [150/375]	Accuracy: 90.94%	Loss: 0.235510
# Train epoch: 10 [160/375]	Accuracy: 90.62%	Loss: 0.230100
# Train epoch: 10 [170/375]	Accuracy: 91.25%	Loss: 0.196823
# Train epoch: 10 [180/375]	Accuracy: 87.81%	Loss: 0.275271
# Train epoch: 10 [190/375]	Accuracy: 89.69%	Loss: 0.249483
# Train epoch: 10 [200/375]	Accuracy: 88.44%	Loss: 0.237926
# Train epoch: 10 [210/375]	Accuracy: 90.94%	Loss: 0.212039
# Train epoch: 10 [220/375]	Accuracy: 88.75%	Loss: 0.239345
# Train epoch: 10 [230/375]	Accuracy: 87.81%	Loss: 0.279717
# Train epoch: 10 [240/375]	Accuracy: 84.69%	Loss: 0.294839
# Train epoch: 10 [250/375]	Accuracy: 89.38%	Loss: 0.254861
# Train epoch: 10 [260/375]	Accuracy: 89.06%	Loss: 0.237946
# Train epoch: 10 [270/375]	Accuracy: 90.31%	Loss: 0.239152
# Train epoch: 10 [280/375]	Accuracy: 90.00%	Loss: 0.225837
# Train epoch: 10 [290/375]	Accuracy: 86.25%	Loss: 0.267166
# Train epoch: 10 [300/375]	Accuracy: 90.31%	Loss: 0.247443
# Train epoch: 10 [310/375]	Accuracy: 90.00%	Loss: 0.231592
# Train epoch: 10 [320/375]	Accuracy: 89.38%	Loss: 0.236628
# Train epoch: 10 [330/375]	Accuracy: 88.12%	Loss: 0.249436
# Train epoch: 10 [340/375]	Accuracy: 87.19%	Loss: 0.281872
# Train epoch: 10 [350/375]	Accuracy: 89.38%	Loss: 0.232226
# Train epoch: 10 [360/375]	Accuracy: 90.00%	Loss: 0.254477
# Train epoch: 10 [370/375]	Accuracy: 85.62%	Loss: 0.272309
# Test set: Loss: 0.2689, Accuracy: 89.09%)
# Train epoch: 11 [10/375]	Accuracy: 90.31%	Loss: 0.249717
# Train epoch: 11 [20/375]	Accuracy: 91.25%	Loss: 0.208537
# Train epoch: 11 [30/375]	Accuracy: 89.38%	Loss: 0.255795
# Train epoch: 11 [40/375]	Accuracy: 91.88%	Loss: 0.240077
# Train epoch: 11 [50/375]	Accuracy: 92.19%	Loss: 0.212737
# Train epoch: 11 [60/375]	Accuracy: 90.62%	Loss: 0.224355
# Train epoch: 11 [70/375]	Accuracy: 90.31%	Loss: 0.216751
# Train epoch: 11 [80/375]	Accuracy: 86.56%	Loss: 0.271432
# Train epoch: 11 [90/375]	Accuracy: 87.19%	Loss: 0.280884
# Train epoch: 11 [100/375]	Accuracy: 89.06%	Loss: 0.236945
# Train epoch: 11 [110/375]	Accuracy: 89.38%	Loss: 0.231321
# Train epoch: 11 [120/375]	Accuracy: 90.00%	Loss: 0.236583
# Train epoch: 11 [130/375]	Accuracy: 88.12%	Loss: 0.240638
# Train epoch: 11 [140/375]	Accuracy: 92.19%	Loss: 0.212313
# Train epoch: 11 [150/375]	Accuracy: 88.75%	Loss: 0.239743
# Train epoch: 11 [160/375]	Accuracy: 87.19%	Loss: 0.272915
# Train epoch: 11 [170/375]	Accuracy: 92.81%	Loss: 0.189327
# Train epoch: 11 [180/375]	Accuracy: 89.38%	Loss: 0.237398
# Train epoch: 11 [190/375]	Accuracy: 88.44%	Loss: 0.236129
# Train epoch: 11 [200/375]	Accuracy: 89.38%	Loss: 0.267236
# Train epoch: 11 [210/375]	Accuracy: 88.44%	Loss: 0.261837
# Train epoch: 11 [220/375]	Accuracy: 91.56%	Loss: 0.195491
# Train epoch: 11 [230/375]	Accuracy: 88.75%	Loss: 0.246095
# Train epoch: 11 [240/375]	Accuracy: 89.06%	Loss: 0.293488
# Train epoch: 11 [250/375]	Accuracy: 89.69%	Loss: 0.229947
# Train epoch: 11 [260/375]	Accuracy: 87.19%	Loss: 0.252549
# Train epoch: 11 [270/375]	Accuracy: 91.56%	Loss: 0.199659
# Train epoch: 11 [280/375]	Accuracy: 88.75%	Loss: 0.244291
# Train epoch: 11 [290/375]	Accuracy: 87.19%	Loss: 0.266673
# Train epoch: 11 [300/375]	Accuracy: 85.00%	Loss: 0.291160
# Train epoch: 11 [310/375]	Accuracy: 88.12%	Loss: 0.236252
# Train epoch: 11 [320/375]	Accuracy: 92.19%	Loss: 0.185463
# Train epoch: 11 [330/375]	Accuracy: 90.00%	Loss: 0.210205
# Train epoch: 11 [340/375]	Accuracy: 88.75%	Loss: 0.241820
# Train epoch: 11 [350/375]	Accuracy: 86.88%	Loss: 0.324085
# Train epoch: 11 [360/375]	Accuracy: 88.44%	Loss: 0.269546
# Train epoch: 11 [370/375]	Accuracy: 90.00%	Loss: 0.229004
# Test set: Loss: 0.1983, Accuracy: 90.92%)
# Train epoch: 12 [10/375]	Accuracy: 89.38%	Loss: 0.238251
# Train epoch: 12 [20/375]	Accuracy: 89.69%	Loss: 0.222640
# Train epoch: 12 [30/375]	Accuracy: 89.69%	Loss: 0.214619
# Train epoch: 12 [40/375]	Accuracy: 91.88%	Loss: 0.207505
# Train epoch: 12 [50/375]	Accuracy: 86.88%	Loss: 0.275397
# Train epoch: 12 [60/375]	Accuracy: 89.38%	Loss: 0.253726
# Train epoch: 12 [70/375]	Accuracy: 87.81%	Loss: 0.241645
# Train epoch: 12 [80/375]	Accuracy: 90.31%	Loss: 0.219978
# Train epoch: 12 [90/375]	Accuracy: 88.12%	Loss: 0.219971
# Train epoch: 12 [100/375]	Accuracy: 90.00%	Loss: 0.225329
# Train epoch: 12 [110/375]	Accuracy: 90.94%	Loss: 0.204483
# Train epoch: 12 [120/375]	Accuracy: 87.81%	Loss: 0.235798
# Train epoch: 12 [130/375]	Accuracy: 90.31%	Loss: 0.214728
# Train epoch: 12 [140/375]	Accuracy: 86.56%	Loss: 0.277927
# Train epoch: 12 [150/375]	Accuracy: 92.19%	Loss: 0.213024
# Train epoch: 12 [160/375]	Accuracy: 89.38%	Loss: 0.250230
# Train epoch: 12 [170/375]	Accuracy: 89.38%	Loss: 0.241319
# Train epoch: 12 [180/375]	Accuracy: 91.25%	Loss: 0.224535
# Train epoch: 12 [190/375]	Accuracy: 88.75%	Loss: 0.248502
# Train epoch: 12 [200/375]	Accuracy: 88.44%	Loss: 0.270271
# Train epoch: 12 [210/375]	Accuracy: 90.62%	Loss: 0.220079
# Train epoch: 12 [220/375]	Accuracy: 88.75%	Loss: 0.231743
# Train epoch: 12 [230/375]	Accuracy: 89.06%	Loss: 0.243093
# Train epoch: 12 [240/375]	Accuracy: 89.06%	Loss: 0.230766
# Train epoch: 12 [250/375]	Accuracy: 90.00%	Loss: 0.228226
# Train epoch: 12 [260/375]	Accuracy: 89.38%	Loss: 0.219088
# Train epoch: 12 [270/375]	Accuracy: 88.75%	Loss: 0.260906
# Train epoch: 12 [280/375]	Accuracy: 89.38%	Loss: 0.243415
# Train epoch: 12 [290/375]	Accuracy: 87.81%	Loss: 0.250460
# Train epoch: 12 [300/375]	Accuracy: 86.56%	Loss: 0.279140
# Train epoch: 12 [310/375]	Accuracy: 90.62%	Loss: 0.205289
# Train epoch: 12 [320/375]	Accuracy: 85.94%	Loss: 0.280137
# Train epoch: 12 [330/375]	Accuracy: 86.25%	Loss: 0.283834
# Train epoch: 12 [340/375]	Accuracy: 87.19%	Loss: 0.242949
# Train epoch: 12 [350/375]	Accuracy: 86.56%	Loss: 0.255666
# Train epoch: 12 [360/375]	Accuracy: 88.44%	Loss: 0.232210
# Train epoch: 12 [370/375]	Accuracy: 92.50%	Loss: 0.196808
# Test set: Loss: 0.1954, Accuracy: 91.82%)
# Train epoch: 13 [10/375]	Accuracy: 88.75%	Loss: 0.221804
# Train epoch: 13 [20/375]	Accuracy: 88.12%	Loss: 0.263158
# Train epoch: 13 [30/375]	Accuracy: 89.69%	Loss: 0.229143
# Train epoch: 13 [40/375]	Accuracy: 91.25%	Loss: 0.226048
# Train epoch: 13 [50/375]	Accuracy: 90.31%	Loss: 0.225855
# Train epoch: 13 [60/375]	Accuracy: 89.38%	Loss: 0.270802
# Train epoch: 13 [70/375]	Accuracy: 88.44%	Loss: 0.223831
# Train epoch: 13 [80/375]	Accuracy: 87.19%	Loss: 0.294644
# Train epoch: 13 [90/375]	Accuracy: 86.56%	Loss: 0.302446
# Train epoch: 13 [100/375]	Accuracy: 90.31%	Loss: 0.247935
# Train epoch: 13 [110/375]	Accuracy: 86.56%	Loss: 0.263757
# Train epoch: 13 [120/375]	Accuracy: 90.31%	Loss: 0.213129
# Train epoch: 13 [130/375]	Accuracy: 87.81%	Loss: 0.261973
# Train epoch: 13 [140/375]	Accuracy: 91.25%	Loss: 0.221902
# Train epoch: 13 [150/375]	Accuracy: 90.62%	Loss: 0.213696
# Train epoch: 13 [160/375]	Accuracy: 88.44%	Loss: 0.243488
# Train epoch: 13 [170/375]	Accuracy: 90.94%	Loss: 0.224605
# Train epoch: 13 [180/375]	Accuracy: 90.00%	Loss: 0.224168
# Train epoch: 13 [190/375]	Accuracy: 90.94%	Loss: 0.207291
# Train epoch: 13 [200/375]	Accuracy: 90.00%	Loss: 0.244106
# Train epoch: 13 [210/375]	Accuracy: 87.50%	Loss: 0.218856
# Train epoch: 13 [220/375]	Accuracy: 87.81%	Loss: 0.236653
# Train epoch: 13 [230/375]	Accuracy: 87.19%	Loss: 0.265628
# Train epoch: 13 [240/375]	Accuracy: 89.06%	Loss: 0.229344
# Train epoch: 13 [250/375]	Accuracy: 89.06%	Loss: 0.231893
# Train epoch: 13 [260/375]	Accuracy: 89.38%	Loss: 0.213034
# Train epoch: 13 [270/375]	Accuracy: 88.44%	Loss: 0.259321
# Train epoch: 13 [280/375]	Accuracy: 88.12%	Loss: 0.257311
# Train epoch: 13 [290/375]	Accuracy: 86.25%	Loss: 0.250576
# Train epoch: 13 [300/375]	Accuracy: 88.75%	Loss: 0.254937
# Train epoch: 13 [310/375]	Accuracy: 90.00%	Loss: 0.223726
# Train epoch: 13 [320/375]	Accuracy: 92.50%	Loss: 0.196167
# Train epoch: 13 [330/375]	Accuracy: 89.06%	Loss: 0.232608
# Train epoch: 13 [340/375]	Accuracy: 92.19%	Loss: 0.234705
# Train epoch: 13 [350/375]	Accuracy: 85.94%	Loss: 0.272469
# Train epoch: 13 [360/375]	Accuracy: 86.88%	Loss: 0.293314
# Train epoch: 13 [370/375]	Accuracy: 89.38%	Loss: 0.223564
# Test set: Loss: 0.1870, Accuracy: 91.32%)
# Train epoch: 14 [10/375]	Accuracy: 89.69%	Loss: 0.223013
# Train epoch: 14 [20/375]	Accuracy: 89.06%	Loss: 0.254200
# Train epoch: 14 [30/375]	Accuracy: 91.56%	Loss: 0.229192
# Train epoch: 14 [40/375]	Accuracy: 90.62%	Loss: 0.208449
# Train epoch: 14 [50/375]	Accuracy: 90.31%	Loss: 0.234581
# Train epoch: 14 [60/375]	Accuracy: 90.62%	Loss: 0.212849
# Train epoch: 14 [70/375]	Accuracy: 89.38%	Loss: 0.221737
# Train epoch: 14 [80/375]	Accuracy: 89.69%	Loss: 0.219264
# Train epoch: 14 [90/375]	Accuracy: 89.69%	Loss: 0.233398
# Train epoch: 14 [100/375]	Accuracy: 90.62%	Loss: 0.220817
# Train epoch: 14 [110/375]	Accuracy: 88.75%	Loss: 0.224817
# Train epoch: 14 [120/375]	Accuracy: 88.12%	Loss: 0.244235
# Train epoch: 14 [130/375]	Accuracy: 92.81%	Loss: 0.210890
# Train epoch: 14 [140/375]	Accuracy: 91.56%	Loss: 0.201397
# Train epoch: 14 [150/375]	Accuracy: 88.75%	Loss: 0.244187
# Train epoch: 14 [160/375]	Accuracy: 88.75%	Loss: 0.283146
# Train epoch: 14 [170/375]	Accuracy: 88.75%	Loss: 0.250316
# Train epoch: 14 [180/375]	Accuracy: 84.38%	Loss: 0.302453
# Train epoch: 14 [190/375]	Accuracy: 90.31%	Loss: 0.231060
# Train epoch: 14 [200/375]	Accuracy: 87.19%	Loss: 0.246731
# Train epoch: 14 [210/375]	Accuracy: 87.19%	Loss: 0.259168
# Train epoch: 14 [220/375]	Accuracy: 87.81%	Loss: 0.258774
# Train epoch: 14 [230/375]	Accuracy: 89.06%	Loss: 0.245659
# Train epoch: 14 [240/375]	Accuracy: 88.44%	Loss: 0.230565
# Train epoch: 14 [250/375]	Accuracy: 89.38%	Loss: 0.232242
# Train epoch: 14 [260/375]	Accuracy: 89.69%	Loss: 0.226817
# Train epoch: 14 [270/375]	Accuracy: 87.81%	Loss: 0.244829
# Train epoch: 14 [280/375]	Accuracy: 91.88%	Loss: 0.204420
# Train epoch: 14 [290/375]	Accuracy: 91.25%	Loss: 0.210445
# Train epoch: 14 [300/375]	Accuracy: 88.12%	Loss: 0.224144
# Train epoch: 14 [310/375]	Accuracy: 87.81%	Loss: 0.221915
# Train epoch: 14 [320/375]	Accuracy: 90.62%	Loss: 0.228981
# Train epoch: 14 [330/375]	Accuracy: 89.06%	Loss: 0.220850
# Train epoch: 14 [340/375]	Accuracy: 88.44%	Loss: 0.258711
# Train epoch: 14 [350/375]	Accuracy: 85.00%	Loss: 0.323022
# Train epoch: 14 [360/375]	Accuracy: 89.06%	Loss: 0.236710
# Train epoch: 14 [370/375]	Accuracy: 88.44%	Loss: 0.257750
# Test set: Loss: 0.2295, Accuracy: 90.77%)
# Train epoch: 15 [10/375]	Accuracy: 89.06%	Loss: 0.234711
# Train epoch: 15 [20/375]	Accuracy: 90.94%	Loss: 0.218476
# Train epoch: 15 [30/375]	Accuracy: 91.88%	Loss: 0.200427
# Train epoch: 15 [40/375]	Accuracy: 88.44%	Loss: 0.261152
# Train epoch: 15 [50/375]	Accuracy: 91.88%	Loss: 0.206363
# Train epoch: 15 [60/375]	Accuracy: 90.31%	Loss: 0.223570
# Train epoch: 15 [70/375]	Accuracy: 89.06%	Loss: 0.234508
# Train epoch: 15 [80/375]	Accuracy: 89.38%	Loss: 0.226075
# Train epoch: 15 [90/375]	Accuracy: 87.81%	Loss: 0.266684
# Train epoch: 15 [100/375]	Accuracy: 92.19%	Loss: 0.198293
# Train epoch: 15 [110/375]	Accuracy: 89.38%	Loss: 0.254103
# Train epoch: 15 [120/375]	Accuracy: 86.56%	Loss: 0.325936
# Train epoch: 15 [130/375]	Accuracy: 89.38%	Loss: 0.207076
# Train epoch: 15 [140/375]	Accuracy: 88.44%	Loss: 0.228296
# Train epoch: 15 [150/375]	Accuracy: 90.62%	Loss: 0.207473
# Train epoch: 15 [160/375]	Accuracy: 90.00%	Loss: 0.234107
# Train epoch: 15 [170/375]	Accuracy: 89.69%	Loss: 0.213799
# Train epoch: 15 [180/375]	Accuracy: 90.94%	Loss: 0.223266
# Train epoch: 15 [190/375]	Accuracy: 89.69%	Loss: 0.233083
# Train epoch: 15 [200/375]	Accuracy: 89.69%	Loss: 0.242142
# Train epoch: 15 [210/375]	Accuracy: 87.50%	Loss: 0.254122
# Train epoch: 15 [220/375]	Accuracy: 89.69%	Loss: 0.239523
# Train epoch: 15 [230/375]	Accuracy: 90.31%	Loss: 0.224937
# Train epoch: 15 [240/375]	Accuracy: 92.50%	Loss: 0.212668
# Train epoch: 15 [250/375]	Accuracy: 87.81%	Loss: 0.276931
# Train epoch: 15 [260/375]	Accuracy: 87.81%	Loss: 0.261807
# Train epoch: 15 [270/375]	Accuracy: 87.81%	Loss: 0.261770
# Train epoch: 15 [280/375]	Accuracy: 87.19%	Loss: 0.263908
# Train epoch: 15 [290/375]	Accuracy: 86.25%	Loss: 0.270939
# Train epoch: 15 [300/375]	Accuracy: 86.25%	Loss: 0.296595
# Train epoch: 15 [310/375]	Accuracy: 89.38%	Loss: 0.243336
# Train epoch: 15 [320/375]	Accuracy: 87.50%	Loss: 0.245276
# Train epoch: 15 [330/375]	Accuracy: 91.25%	Loss: 0.221560
# Train epoch: 15 [340/375]	Accuracy: 88.12%	Loss: 0.248283
# Train epoch: 15 [350/375]	Accuracy: 90.31%	Loss: 0.211009
# Train epoch: 15 [360/375]	Accuracy: 87.81%	Loss: 0.217082
# Train epoch: 15 [370/375]	Accuracy: 86.88%	Loss: 0.254293
# Test set: Loss: 0.2396, Accuracy: 90.13%)
# Train epoch: 16 [10/375]	Accuracy: 88.75%	Loss: 0.229362
# Train epoch: 16 [20/375]	Accuracy: 90.31%	Loss: 0.221994
# Train epoch: 16 [30/375]	Accuracy: 87.81%	Loss: 0.258681
# Train epoch: 16 [40/375]	Accuracy: 88.44%	Loss: 0.245969
# Train epoch: 16 [50/375]	Accuracy: 91.56%	Loss: 0.213852
# Train epoch: 16 [60/375]	Accuracy: 89.69%	Loss: 0.215554
# Train epoch: 16 [70/375]	Accuracy: 88.12%	Loss: 0.294497
# Train epoch: 16 [80/375]	Accuracy: 85.62%	Loss: 0.302862
# Train epoch: 16 [90/375]	Accuracy: 87.19%	Loss: 0.260883
# Train epoch: 16 [100/375]	Accuracy: 90.94%	Loss: 0.235411
# Train epoch: 16 [110/375]	Accuracy: 89.38%	Loss: 0.223085
# Train epoch: 16 [120/375]	Accuracy: 89.69%	Loss: 0.240173
# Train epoch: 16 [130/375]	Accuracy: 91.25%	Loss: 0.202974
# Train epoch: 16 [140/375]	Accuracy: 88.75%	Loss: 0.230897
# Train epoch: 16 [150/375]	Accuracy: 87.50%	Loss: 0.260770
# Train epoch: 16 [160/375]	Accuracy: 89.06%	Loss: 0.264109
# Train epoch: 16 [170/375]	Accuracy: 87.81%	Loss: 0.278880
# Train epoch: 16 [180/375]	Accuracy: 87.81%	Loss: 0.258366
# Train epoch: 16 [190/375]	Accuracy: 90.00%	Loss: 0.217348
# Train epoch: 16 [200/375]	Accuracy: 87.81%	Loss: 0.243408
# Train epoch: 16 [210/375]	Accuracy: 90.62%	Loss: 0.217999
# Train epoch: 16 [220/375]	Accuracy: 91.25%	Loss: 0.225817
# Train epoch: 16 [230/375]	Accuracy: 88.75%	Loss: 0.252806
# Train epoch: 16 [240/375]	Accuracy: 89.06%	Loss: 0.215529
# Train epoch: 16 [250/375]	Accuracy: 90.62%	Loss: 0.217453
# Train epoch: 16 [260/375]	Accuracy: 89.06%	Loss: 0.235539
# Train epoch: 16 [270/375]	Accuracy: 87.19%	Loss: 0.279140
# Train epoch: 16 [280/375]	Accuracy: 89.69%	Loss: 0.230470
# Train epoch: 16 [290/375]	Accuracy: 91.25%	Loss: 0.224768
# Train epoch: 16 [300/375]	Accuracy: 90.94%	Loss: 0.225677
# Train epoch: 16 [310/375]	Accuracy: 90.62%	Loss: 0.210939
# Train epoch: 16 [320/375]	Accuracy: 90.62%	Loss: 0.215633
# Train epoch: 16 [330/375]	Accuracy: 88.75%	Loss: 0.267858
# Train epoch: 16 [340/375]	Accuracy: 92.81%	Loss: 0.211815
# Train epoch: 16 [350/375]	Accuracy: 88.12%	Loss: 0.271963
# Train epoch: 16 [360/375]	Accuracy: 86.56%	Loss: 0.262015
# Train epoch: 16 [370/375]	Accuracy: 85.62%	Loss: 0.312742
# Test set: Loss: 0.1903, Accuracy: 90.38%)
# Train epoch: 17 [10/375]	Accuracy: 90.94%	Loss: 0.239650
# Train epoch: 17 [20/375]	Accuracy: 89.38%	Loss: 0.228953
# Train epoch: 17 [30/375]	Accuracy: 88.44%	Loss: 0.235303
# Train epoch: 17 [40/375]	Accuracy: 89.06%	Loss: 0.211056
# Train epoch: 17 [50/375]	Accuracy: 88.75%	Loss: 0.248809
# Train epoch: 17 [60/375]	Accuracy: 90.00%	Loss: 0.223972
# Train epoch: 17 [70/375]	Accuracy: 88.44%	Loss: 0.243302
# Train epoch: 17 [80/375]	Accuracy: 90.31%	Loss: 0.230609
# Train epoch: 17 [90/375]	Accuracy: 88.75%	Loss: 0.256267
# Train epoch: 17 [100/375]	Accuracy: 91.25%	Loss: 0.225089
# Train epoch: 17 [110/375]	Accuracy: 88.75%	Loss: 0.279256
# Train epoch: 17 [120/375]	Accuracy: 89.06%	Loss: 0.248708
# Train epoch: 17 [130/375]	Accuracy: 88.12%	Loss: 0.238779
# Train epoch: 17 [140/375]	Accuracy: 91.88%	Loss: 0.202924
# Train epoch: 17 [150/375]	Accuracy: 88.44%	Loss: 0.224029
# Train epoch: 17 [160/375]	Accuracy: 91.56%	Loss: 0.192515
# Train epoch: 17 [170/375]	Accuracy: 88.75%	Loss: 0.299137
# Train epoch: 17 [180/375]	Accuracy: 87.50%	Loss: 0.274634
# Train epoch: 17 [190/375]	Accuracy: 91.56%	Loss: 0.199784
# Train epoch: 17 [200/375]	Accuracy: 86.25%	Loss: 0.249242
# Train epoch: 17 [210/375]	Accuracy: 90.00%	Loss: 0.221041
# Train epoch: 17 [220/375]	Accuracy: 90.94%	Loss: 0.212162
# Train epoch: 17 [230/375]	Accuracy: 88.44%	Loss: 0.268253
# Train epoch: 17 [240/375]	Accuracy: 90.94%	Loss: 0.221247
# Train epoch: 17 [250/375]	Accuracy: 89.38%	Loss: 0.247112
# Train epoch: 17 [260/375]	Accuracy: 89.69%	Loss: 0.235547
# Train epoch: 17 [270/375]	Accuracy: 88.12%	Loss: 0.213062
# Train epoch: 17 [280/375]	Accuracy: 90.31%	Loss: 0.197914
# Train epoch: 17 [290/375]	Accuracy: 91.25%	Loss: 0.226587
# Train epoch: 17 [300/375]	Accuracy: 91.25%	Loss: 0.241388
# Train epoch: 17 [310/375]	Accuracy: 86.88%	Loss: 0.274580
# Train epoch: 17 [320/375]	Accuracy: 87.50%	Loss: 0.246046
# Train epoch: 17 [330/375]	Accuracy: 86.88%	Loss: 0.258309
# Train epoch: 17 [340/375]	Accuracy: 87.19%	Loss: 0.251528
# Train epoch: 17 [350/375]	Accuracy: 85.62%	Loss: 0.280323
# Train epoch: 17 [360/375]	Accuracy: 90.62%	Loss: 0.219545
# Train epoch: 17 [370/375]	Accuracy: 85.31%	Loss: 0.247857
# Test set: Loss: 0.1826, Accuracy: 92.26%)
# Train epoch: 18 [10/375]	Accuracy: 90.31%	Loss: 0.220555
# Train epoch: 18 [20/375]	Accuracy: 91.56%	Loss: 0.194584
# Train epoch: 18 [30/375]	Accuracy: 88.75%	Loss: 0.251652
# Train epoch: 18 [40/375]	Accuracy: 90.31%	Loss: 0.216993
# Train epoch: 18 [50/375]	Accuracy: 88.12%	Loss: 0.255706
# Train epoch: 18 [60/375]	Accuracy: 90.31%	Loss: 0.211738
# Train epoch: 18 [70/375]	Accuracy: 89.69%	Loss: 0.208304
# Train epoch: 18 [80/375]	Accuracy: 88.12%	Loss: 0.259424
# Train epoch: 18 [90/375]	Accuracy: 90.31%	Loss: 0.211118
# Train epoch: 18 [100/375]	Accuracy: 88.75%	Loss: 0.234206
# Train epoch: 18 [110/375]	Accuracy: 87.19%	Loss: 0.267454
# Train epoch: 18 [120/375]	Accuracy: 88.44%	Loss: 0.240446
# Train epoch: 18 [130/375]	Accuracy: 92.19%	Loss: 0.221277
# Train epoch: 18 [140/375]	Accuracy: 91.25%	Loss: 0.212793
# Train epoch: 18 [150/375]	Accuracy: 88.44%	Loss: 0.242110
# Train epoch: 18 [160/375]	Accuracy: 91.56%	Loss: 0.212220
# Train epoch: 18 [170/375]	Accuracy: 90.62%	Loss: 0.210640
# Train epoch: 18 [180/375]	Accuracy: 85.31%	Loss: 0.288270
# Train epoch: 18 [190/375]	Accuracy: 87.50%	Loss: 0.262344
# Train epoch: 18 [200/375]	Accuracy: 89.69%	Loss: 0.231002
# Train epoch: 18 [210/375]	Accuracy: 89.69%	Loss: 0.207773
# Train epoch: 18 [220/375]	Accuracy: 91.88%	Loss: 0.231044
# Train epoch: 18 [230/375]	Accuracy: 89.38%	Loss: 0.262715
# Train epoch: 18 [240/375]	Accuracy: 89.06%	Loss: 0.257016
# Train epoch: 18 [250/375]	Accuracy: 87.50%	Loss: 0.264044
# Train epoch: 18 [260/375]	Accuracy: 91.25%	Loss: 0.207348
# Train epoch: 18 [270/375]	Accuracy: 90.94%	Loss: 0.224437
# Train epoch: 18 [280/375]	Accuracy: 91.25%	Loss: 0.224142
# Train epoch: 18 [290/375]	Accuracy: 88.12%	Loss: 0.249849
# Train epoch: 18 [300/375]	Accuracy: 85.00%	Loss: 0.280331
# Train epoch: 18 [310/375]	Accuracy: 89.06%	Loss: 0.223311
# Train epoch: 18 [320/375]	Accuracy: 88.75%	Loss: 0.224981
# Train epoch: 18 [330/375]	Accuracy: 89.06%	Loss: 0.233413
# Train epoch: 18 [340/375]	Accuracy: 91.88%	Loss: 0.195537
# Train epoch: 18 [350/375]	Accuracy: 87.81%	Loss: 0.242028
# Train epoch: 18 [360/375]	Accuracy: 89.69%	Loss: 0.236458
# Train epoch: 18 [370/375]	Accuracy: 92.19%	Loss: 0.206051
# Test set: Loss: 0.1740, Accuracy: 92.71%)
# Train epoch: 19 [10/375]	Accuracy: 89.69%	Loss: 0.232824
# Train epoch: 19 [20/375]	Accuracy: 86.88%	Loss: 0.257425
# Train epoch: 19 [30/375]	Accuracy: 88.12%	Loss: 0.260549
# Train epoch: 19 [40/375]	Accuracy: 88.12%	Loss: 0.227792
# Train epoch: 19 [50/375]	Accuracy: 91.56%	Loss: 0.207509
# Train epoch: 19 [60/375]	Accuracy: 90.31%	Loss: 0.235908
# Train epoch: 19 [70/375]	Accuracy: 91.25%	Loss: 0.200042
# Train epoch: 19 [80/375]	Accuracy: 90.00%	Loss: 0.225659
# Train epoch: 19 [90/375]	Accuracy: 90.62%	Loss: 0.238473
# Train epoch: 19 [100/375]	Accuracy: 91.25%	Loss: 0.192698
# Train epoch: 19 [110/375]	Accuracy: 90.00%	Loss: 0.207555
# Train epoch: 19 [120/375]	Accuracy: 89.38%	Loss: 0.266992
# Train epoch: 19 [130/375]	Accuracy: 93.12%	Loss: 0.204227
# Train epoch: 19 [140/375]	Accuracy: 89.38%	Loss: 0.245154
# Train epoch: 19 [150/375]	Accuracy: 89.69%	Loss: 0.269181
# Train epoch: 19 [160/375]	Accuracy: 88.75%	Loss: 0.243852
# Train epoch: 19 [170/375]	Accuracy: 90.62%	Loss: 0.238394
# Train epoch: 19 [180/375]	Accuracy: 90.00%	Loss: 0.225063
# Train epoch: 19 [190/375]	Accuracy: 88.12%	Loss: 0.214396
# Train epoch: 19 [200/375]	Accuracy: 86.88%	Loss: 0.261928
# Train epoch: 19 [210/375]	Accuracy: 89.38%	Loss: 0.245362
# Train epoch: 19 [220/375]	Accuracy: 88.12%	Loss: 0.237251
# Train epoch: 19 [230/375]	Accuracy: 90.00%	Loss: 0.214425
# Train epoch: 19 [240/375]	Accuracy: 90.31%	Loss: 0.237705
# Train epoch: 19 [250/375]	Accuracy: 86.88%	Loss: 0.266093
# Train epoch: 19 [260/375]	Accuracy: 87.50%	Loss: 0.244403
# Train epoch: 19 [270/375]	Accuracy: 90.31%	Loss: 0.205865
# Train epoch: 19 [280/375]	Accuracy: 87.81%	Loss: 0.252842
# Train epoch: 19 [290/375]	Accuracy: 90.00%	Loss: 0.225909
# Train epoch: 19 [300/375]	Accuracy: 90.31%	Loss: 0.231087
# Train epoch: 19 [310/375]	Accuracy: 90.31%	Loss: 0.219716
# Train epoch: 19 [320/375]	Accuracy: 89.38%	Loss: 0.224813
# Train epoch: 19 [330/375]	Accuracy: 87.50%	Loss: 0.249862
# Train epoch: 19 [340/375]	Accuracy: 86.88%	Loss: 0.267509
# Train epoch: 19 [350/375]	Accuracy: 88.12%	Loss: 0.245119
# Train epoch: 19 [360/375]	Accuracy: 91.25%	Loss: 0.221385
# Train epoch: 19 [370/375]	Accuracy: 90.94%	Loss: 0.225382
# Test set: Loss: 0.1831, Accuracy: 92.11%)
# Train epoch: 20 [10/375]	Accuracy: 90.00%	Loss: 0.249654
# Train epoch: 20 [20/375]	Accuracy: 89.06%	Loss: 0.244014
# Train epoch: 20 [30/375]	Accuracy: 90.31%	Loss: 0.237333
# Train epoch: 20 [40/375]	Accuracy: 89.69%	Loss: 0.235543
# Train epoch: 20 [50/375]	Accuracy: 91.88%	Loss: 0.196452
# Train epoch: 20 [60/375]	Accuracy: 88.75%	Loss: 0.251737
# Train epoch: 20 [70/375]	Accuracy: 93.12%	Loss: 0.193720
# Train epoch: 20 [80/375]	Accuracy: 90.31%	Loss: 0.226063
# Train epoch: 20 [90/375]	Accuracy: 89.38%	Loss: 0.226066
# Train epoch: 20 [100/375]	Accuracy: 91.88%	Loss: 0.228522
# Train epoch: 20 [110/375]	Accuracy: 90.31%	Loss: 0.200562
# Train epoch: 20 [120/375]	Accuracy: 88.75%	Loss: 0.239907
# Train epoch: 20 [130/375]	Accuracy: 91.88%	Loss: 0.240330
# Train epoch: 20 [140/375]	Accuracy: 92.19%	Loss: 0.209958
# Train epoch: 20 [150/375]	Accuracy: 92.19%	Loss: 0.190786
# Train epoch: 20 [160/375]	Accuracy: 91.25%	Loss: 0.218009
# Train epoch: 20 [170/375]	Accuracy: 89.38%	Loss: 0.252242
# Train epoch: 20 [180/375]	Accuracy: 88.12%	Loss: 0.229943
# Train epoch: 20 [190/375]	Accuracy: 85.94%	Loss: 0.274742
# Train epoch: 20 [200/375]	Accuracy: 87.81%	Loss: 0.286830
# Train epoch: 20 [210/375]	Accuracy: 86.25%	Loss: 0.259971
# Train epoch: 20 [220/375]	Accuracy: 88.44%	Loss: 0.252624
# Train epoch: 20 [230/375]	Accuracy: 85.62%	Loss: 0.284577
# Train epoch: 20 [240/375]	Accuracy: 89.06%	Loss: 0.229689
# Train epoch: 20 [250/375]	Accuracy: 87.81%	Loss: 0.238764
# Train epoch: 20 [260/375]	Accuracy: 87.19%	Loss: 0.266034
# Train epoch: 20 [270/375]	Accuracy: 90.31%	Loss: 0.197164
# Train epoch: 20 [280/375]	Accuracy: 90.94%	Loss: 0.233982
# Train epoch: 20 [290/375]	Accuracy: 90.94%	Loss: 0.244748
# Train epoch: 20 [300/375]	Accuracy: 92.19%	Loss: 0.216187
# Train epoch: 20 [310/375]	Accuracy: 90.94%	Loss: 0.209259
# Train epoch: 20 [320/375]	Accuracy: 90.94%	Loss: 0.222198
# Train epoch: 20 [330/375]	Accuracy: 90.62%	Loss: 0.235445
# Train epoch: 20 [340/375]	Accuracy: 90.62%	Loss: 0.239787
# Train epoch: 20 [350/375]	Accuracy: 90.62%	Loss: 0.214939
# Train epoch: 20 [360/375]	Accuracy: 89.06%	Loss: 0.233252
# Train epoch: 20 [370/375]	Accuracy: 91.56%	Loss: 0.204816
# Test set: Loss: 0.2358, Accuracy: 90.23%)
# Train epoch: 21 [10/375]	Accuracy: 91.56%	Loss: 0.195586
# Train epoch: 21 [20/375]	Accuracy: 88.12%	Loss: 0.248532
# Train epoch: 21 [30/375]	Accuracy: 89.06%	Loss: 0.235614
# Train epoch: 21 [40/375]	Accuracy: 90.94%	Loss: 0.240649
# Train epoch: 21 [50/375]	Accuracy: 87.81%	Loss: 0.261661
# Train epoch: 21 [60/375]	Accuracy: 85.94%	Loss: 0.281078
# Train epoch: 21 [70/375]	Accuracy: 93.75%	Loss: 0.180510
# Train epoch: 21 [80/375]	Accuracy: 91.25%	Loss: 0.219487
# Train epoch: 21 [90/375]	Accuracy: 89.38%	Loss: 0.208844
# Train epoch: 21 [100/375]	Accuracy: 91.25%	Loss: 0.208528
# Train epoch: 21 [110/375]	Accuracy: 88.75%	Loss: 0.242644
# Train epoch: 21 [120/375]	Accuracy: 88.12%	Loss: 0.245216
# Train epoch: 21 [130/375]	Accuracy: 88.44%	Loss: 0.244794
# Train epoch: 21 [140/375]	Accuracy: 89.69%	Loss: 0.223659
# Train epoch: 21 [150/375]	Accuracy: 88.44%	Loss: 0.239110
# Train epoch: 21 [160/375]	Accuracy: 88.75%	Loss: 0.239461
# Train epoch: 21 [170/375]	Accuracy: 89.06%	Loss: 0.228871
# Train epoch: 21 [180/375]	Accuracy: 90.94%	Loss: 0.223917
# Train epoch: 21 [190/375]	Accuracy: 91.88%	Loss: 0.224162
# Train epoch: 21 [200/375]	Accuracy: 90.62%	Loss: 0.248133
# Train epoch: 21 [210/375]	Accuracy: 88.75%	Loss: 0.243281
# Train epoch: 21 [220/375]	Accuracy: 90.00%	Loss: 0.237718
# Train epoch: 21 [230/375]	Accuracy: 84.38%	Loss: 0.295679
# Train epoch: 21 [240/375]	Accuracy: 90.94%	Loss: 0.226714
# Train epoch: 21 [250/375]	Accuracy: 90.94%	Loss: 0.251646
# Train epoch: 21 [260/375]	Accuracy: 88.75%	Loss: 0.257141
# Train epoch: 21 [270/375]	Accuracy: 89.38%	Loss: 0.241698
# Train epoch: 21 [280/375]	Accuracy: 87.19%	Loss: 0.251319
# Train epoch: 21 [290/375]	Accuracy: 89.38%	Loss: 0.213826
# Train epoch: 21 [300/375]	Accuracy: 91.88%	Loss: 0.189729
# Train epoch: 21 [310/375]	Accuracy: 89.69%	Loss: 0.217212
# Train epoch: 21 [320/375]	Accuracy: 87.50%	Loss: 0.254912
# Train epoch: 21 [330/375]	Accuracy: 87.81%	Loss: 0.243732
# Train epoch: 21 [340/375]	Accuracy: 94.69%	Loss: 0.177202
# Train epoch: 21 [350/375]	Accuracy: 85.94%	Loss: 0.258693
# Train epoch: 21 [360/375]	Accuracy: 87.50%	Loss: 0.258966
# Train epoch: 21 [370/375]	Accuracy: 91.25%	Loss: 0.213749
# Test set: Loss: 0.1861, Accuracy: 92.86%)
# Train epoch: 22 [10/375]	Accuracy: 90.31%	Loss: 0.205536
# Train epoch: 22 [20/375]	Accuracy: 94.38%	Loss: 0.171353
# Train epoch: 22 [30/375]	Accuracy: 90.62%	Loss: 0.240758
# Train epoch: 22 [40/375]	Accuracy: 91.25%	Loss: 0.198001
# Train epoch: 22 [50/375]	Accuracy: 87.50%	Loss: 0.251440
# Train epoch: 22 [60/375]	Accuracy: 90.94%	Loss: 0.228435
# Train epoch: 22 [70/375]	Accuracy: 92.81%	Loss: 0.166912
# Train epoch: 22 [80/375]	Accuracy: 87.50%	Loss: 0.257668
# Train epoch: 22 [90/375]	Accuracy: 87.81%	Loss: 0.266799
# Train epoch: 22 [100/375]	Accuracy: 89.38%	Loss: 0.217437
# Train epoch: 22 [110/375]	Accuracy: 89.69%	Loss: 0.235944
# Train epoch: 22 [120/375]	Accuracy: 87.19%	Loss: 0.299681
# Train epoch: 22 [130/375]	Accuracy: 88.75%	Loss: 0.264406
# Train epoch: 22 [140/375]	Accuracy: 87.50%	Loss: 0.285526
# Train epoch: 22 [150/375]	Accuracy: 89.06%	Loss: 0.240737
# Train epoch: 22 [160/375]	Accuracy: 90.00%	Loss: 0.213137
# Train epoch: 22 [170/375]	Accuracy: 90.94%	Loss: 0.231697
# Train epoch: 22 [180/375]	Accuracy: 86.25%	Loss: 0.281093
# Train epoch: 22 [190/375]	Accuracy: 88.12%	Loss: 0.216952
# Train epoch: 22 [200/375]	Accuracy: 92.81%	Loss: 0.180309
# Train epoch: 22 [210/375]	Accuracy: 89.38%	Loss: 0.260621
# Train epoch: 22 [220/375]	Accuracy: 89.38%	Loss: 0.245066
# Train epoch: 22 [230/375]	Accuracy: 90.62%	Loss: 0.229867
# Train epoch: 22 [240/375]	Accuracy: 90.62%	Loss: 0.205301
# Train epoch: 22 [250/375]	Accuracy: 89.38%	Loss: 0.236981
# Train epoch: 22 [260/375]	Accuracy: 89.69%	Loss: 0.215394
# Train epoch: 22 [270/375]	Accuracy: 87.50%	Loss: 0.231546
# Train epoch: 22 [280/375]	Accuracy: 86.56%	Loss: 0.274888
# Train epoch: 22 [290/375]	Accuracy: 91.25%	Loss: 0.207072
# Train epoch: 22 [300/375]	Accuracy: 88.44%	Loss: 0.259246
# Train epoch: 22 [310/375]	Accuracy: 89.06%	Loss: 0.224162
# Train epoch: 22 [320/375]	Accuracy: 92.81%	Loss: 0.175223
# Train epoch: 22 [330/375]	Accuracy: 89.38%	Loss: 0.228246
# Train epoch: 22 [340/375]	Accuracy: 89.38%	Loss: 0.246094
# Train epoch: 22 [350/375]	Accuracy: 91.56%	Loss: 0.203862
# Train epoch: 22 [360/375]	Accuracy: 89.38%	Loss: 0.257152
# Train epoch: 22 [370/375]	Accuracy: 89.69%	Loss: 0.222157
# Test set: Loss: 0.1855, Accuracy: 92.76%)
# Train epoch: 23 [10/375]	Accuracy: 88.12%	Loss: 0.224803
# Train epoch: 23 [20/375]	Accuracy: 90.31%	Loss: 0.224759
# Train epoch: 23 [30/375]	Accuracy: 92.50%	Loss: 0.202538
# Train epoch: 23 [40/375]	Accuracy: 91.56%	Loss: 0.214011
# Train epoch: 23 [50/375]	Accuracy: 93.12%	Loss: 0.206638
# Train epoch: 23 [60/375]	Accuracy: 91.25%	Loss: 0.217980
# ...
# Train epoch: 60 [300/375]	Accuracy: 93.44%	Loss: 0.144548
# Train epoch: 60 [310/375]	Accuracy: 93.12%	Loss: 0.179214
# Train epoch: 60 [320/375]	Accuracy: 94.69%	Loss: 0.158202
# Train epoch: 60 [330/375]	Accuracy: 93.12%	Loss: 0.167714
# Train epoch: 60 [340/375]	Accuracy: 95.62%	Loss: 0.114027
# Train epoch: 60 [350/375]	Accuracy: 92.50%	Loss: 0.178085
# Train epoch: 60 [360/375]	Accuracy: 92.50%	Loss: 0.169311
# Train epoch: 60 [370/375]	Accuracy: 90.31%	Loss: 0.207781
# Test set: Loss: 0.1687, Accuracy: 92.91%)
# Train epoch: 61 [10/375]	Accuracy: 92.19%	Loss: 0.174598
# Train epoch: 61 [20/375]	Accuracy: 92.50%	Loss: 0.198531
# Train epoch: 61 [30/375]	Accuracy: 90.00%	Loss: 0.187064
# Train epoch: 61 [40/375]	Accuracy: 92.50%	Loss: 0.181677
# Train epoch: 61 [50/375]	Accuracy: 92.50%	Loss: 0.160736
# Train epoch: 61 [60/375]	Accuracy: 93.44%	Loss: 0.165472
# Train epoch: 61 [70/375]	Accuracy: 94.06%	Loss: 0.144042
# Train epoch: 61 [80/375]	Accuracy: 92.19%	Loss: 0.183164
# Train epoch: 61 [90/375]	Accuracy: 91.56%	Loss: 0.183396
# Train epoch: 61 [100/375]	Accuracy: 91.56%	Loss: 0.166332
# Train epoch: 61 [110/375]	Accuracy: 89.69%	Loss: 0.190948
# Train epoch: 61 [120/375]	Accuracy: 94.38%	Loss: 0.153071
# Train epoch: 61 [130/375]	Accuracy: 93.12%	Loss: 0.165098
# Train epoch: 61 [140/375]	Accuracy: 93.44%	Loss: 0.160945
# Train epoch: 61 [150/375]	Accuracy: 90.94%	Loss: 0.202166
# Train epoch: 61 [160/375]	Accuracy: 95.62%	Loss: 0.146544
# Train epoch: 61 [170/375]	Accuracy: 92.50%	Loss: 0.163557
# Train epoch: 61 [180/375]	Accuracy: 94.69%	Loss: 0.142149
# Train epoch: 61 [190/375]	Accuracy: 93.75%	Loss: 0.168664
# Train epoch: 61 [200/375]	Accuracy: 92.50%	Loss: 0.168870
# Train epoch: 61 [210/375]	Accuracy: 89.69%	Loss: 0.188408
# Train epoch: 61 [220/375]	Accuracy: 91.25%	Loss: 0.190713
# Train epoch: 61 [230/375]	Accuracy: 92.19%	Loss: 0.178555
# Train epoch: 61 [240/375]	Accuracy: 93.75%	Loss: 0.157295
# Train epoch: 61 [250/375]	Accuracy: 92.50%	Loss: 0.176550
# Train epoch: 61 [260/375]	Accuracy: 94.69%	Loss: 0.162745
# Train epoch: 61 [270/375]	Accuracy: 91.56%	Loss: 0.178022
# Train epoch: 61 [280/375]	Accuracy: 91.88%	Loss: 0.169191
# Train epoch: 61 [290/375]	Accuracy: 95.31%	Loss: 0.114382
# Train epoch: 61 [300/375]	Accuracy: 93.75%	Loss: 0.155836
# Train epoch: 61 [310/375]	Accuracy: 93.44%	Loss: 0.152522
# Train epoch: 61 [320/375]	Accuracy: 92.19%	Loss: 0.181928
# Train epoch: 61 [330/375]	Accuracy: 93.12%	Loss: 0.174698
# Train epoch: 61 [340/375]	Accuracy: 90.94%	Loss: 0.197694
# Train epoch: 61 [350/375]	Accuracy: 92.81%	Loss: 0.150102
# Train epoch: 61 [360/375]	Accuracy: 92.81%	Loss: 0.161727
# Train epoch: 61 [370/375]	Accuracy: 92.50%	Loss: 0.172589
# Test set: Loss: 0.1592, Accuracy: 93.55%)
# Train epoch: 62 [10/375]	Accuracy: 93.12%	Loss: 0.166750
# Train epoch: 62 [20/375]	Accuracy: 92.19%	Loss: 0.148770
# Train epoch: 62 [30/375]	Accuracy: 90.31%	Loss: 0.195554
# Train epoch: 62 [40/375]	Accuracy: 94.38%	Loss: 0.148967
# Train epoch: 62 [50/375]	Accuracy: 94.38%	Loss: 0.140424
# Train epoch: 62 [60/375]	Accuracy: 91.88%	Loss: 0.161261
# Train epoch: 62 [70/375]	Accuracy: 93.75%	Loss: 0.130093
# Train epoch: 62 [80/375]	Accuracy: 93.12%	Loss: 0.168775
# Train epoch: 62 [90/375]	Accuracy: 93.12%	Loss: 0.170839
# Train epoch: 62 [100/375]	Accuracy: 92.81%	Loss: 0.160884
# Train epoch: 62 [110/375]	Accuracy: 92.81%	Loss: 0.185669
# Train epoch: 62 [120/375]	Accuracy: 93.44%	Loss: 0.170603
# Train epoch: 62 [130/375]	Accuracy: 94.69%	Loss: 0.138435
# Train epoch: 62 [140/375]	Accuracy: 94.38%	Loss: 0.148981
# Train epoch: 62 [150/375]	Accuracy: 94.06%	Loss: 0.150206
# Train epoch: 62 [160/375]	Accuracy: 93.75%	Loss: 0.178899
# Train epoch: 62 [170/375]	Accuracy: 94.06%	Loss: 0.136703
# Train epoch: 62 [180/375]	Accuracy: 93.75%	Loss: 0.151196
# Train epoch: 62 [190/375]	Accuracy: 94.06%	Loss: 0.152656
# Train epoch: 62 [200/375]	Accuracy: 93.12%	Loss: 0.184082
# Train epoch: 62 [210/375]	Accuracy: 89.38%	Loss: 0.199831
# Train epoch: 62 [220/375]	Accuracy: 93.75%	Loss: 0.145606
# Train epoch: 62 [230/375]	Accuracy: 90.62%	Loss: 0.197437
# Train epoch: 62 [240/375]	Accuracy: 92.50%	Loss: 0.165087
# Train epoch: 62 [250/375]	Accuracy: 87.81%	Loss: 0.210497
# Train epoch: 62 [260/375]	Accuracy: 92.19%	Loss: 0.156278
# Train epoch: 62 [270/375]	Accuracy: 92.50%	Loss: 0.160558
# Train epoch: 62 [280/375]	Accuracy: 90.31%	Loss: 0.210389
# Train epoch: 62 [290/375]	Accuracy: 91.25%	Loss: 0.166241
# Train epoch: 62 [300/375]	Accuracy: 94.06%	Loss: 0.153616
# Train epoch: 62 [310/375]	Accuracy: 92.50%	Loss: 0.174862
# Train epoch: 62 [320/375]	Accuracy: 91.25%	Loss: 0.197199
# Train epoch: 62 [330/375]	Accuracy: 93.44%	Loss: 0.172652
# Train epoch: 62 [340/375]	Accuracy: 93.12%	Loss: 0.164588
# Train epoch: 62 [350/375]	Accuracy: 92.50%	Loss: 0.179675
# Train epoch: 62 [360/375]	Accuracy: 94.38%	Loss: 0.169137
# Train epoch: 62 [370/375]	Accuracy: 91.88%	Loss: 0.178790
# Test set: Loss: 0.1634, Accuracy: 93.15%)
# Train epoch: 63 [10/375]	Accuracy: 92.19%	Loss: 0.189827
# Train epoch: 63 [20/375]	Accuracy: 95.62%	Loss: 0.135538
# Train epoch: 63 [30/375]	Accuracy: 94.06%	Loss: 0.157048
# Train epoch: 63 [40/375]	Accuracy: 91.25%	Loss: 0.193900
# Train epoch: 63 [50/375]	Accuracy: 90.94%	Loss: 0.175765
# Train epoch: 63 [60/375]	Accuracy: 94.06%	Loss: 0.166096
# Train epoch: 63 [70/375]	Accuracy: 93.12%	Loss: 0.172803
# Train epoch: 63 [80/375]	Accuracy: 94.38%	Loss: 0.150375
# Train epoch: 63 [90/375]	Accuracy: 93.75%	Loss: 0.163422
# Train epoch: 63 [100/375]	Accuracy: 92.19%	Loss: 0.166918
# Train epoch: 63 [110/375]	Accuracy: 91.88%	Loss: 0.192744
# Train epoch: 63 [120/375]	Accuracy: 92.81%	Loss: 0.167358
# Train epoch: 63 [130/375]	Accuracy: 91.56%	Loss: 0.179626
# Train epoch: 63 [140/375]	Accuracy: 90.94%	Loss: 0.222885
# Train epoch: 63 [150/375]	Accuracy: 95.31%	Loss: 0.141050
# Train epoch: 63 [160/375]	Accuracy: 92.19%	Loss: 0.179503
# Train epoch: 63 [170/375]	Accuracy: 93.44%	Loss: 0.154819
# Train epoch: 63 [180/375]	Accuracy: 92.50%	Loss: 0.163391
# Train epoch: 63 [190/375]	Accuracy: 95.00%	Loss: 0.158557
# Train epoch: 63 [200/375]	Accuracy: 92.19%	Loss: 0.192236
# Train epoch: 63 [210/375]	Accuracy: 94.69%	Loss: 0.135550
# Train epoch: 63 [220/375]	Accuracy: 95.31%	Loss: 0.137303
# Train epoch: 63 [230/375]	Accuracy: 93.44%	Loss: 0.154340
# Train epoch: 63 [240/375]	Accuracy: 92.19%	Loss: 0.152470
# Train epoch: 63 [250/375]	Accuracy: 90.31%	Loss: 0.183549
# Train epoch: 63 [260/375]	Accuracy: 92.50%	Loss: 0.173980
# Train epoch: 63 [270/375]	Accuracy: 93.12%	Loss: 0.158981
# Train epoch: 63 [280/375]	Accuracy: 92.81%	Loss: 0.180154
# Train epoch: 63 [290/375]	Accuracy: 91.88%	Loss: 0.178092
# Train epoch: 63 [300/375]	Accuracy: 91.56%	Loss: 0.185856
# Train epoch: 63 [310/375]	Accuracy: 92.50%	Loss: 0.176390
# Train epoch: 63 [320/375]	Accuracy: 92.50%	Loss: 0.164246
# Train epoch: 63 [330/375]	Accuracy: 93.12%	Loss: 0.162446
# Train epoch: 63 [340/375]	Accuracy: 91.88%	Loss: 0.179797
# Train epoch: 63 [350/375]	Accuracy: 92.81%	Loss: 0.180137
# Train epoch: 63 [360/375]	Accuracy: 92.50%	Loss: 0.174706
# Train epoch: 63 [370/375]	Accuracy: 90.31%	Loss: 0.210244
# Test set: Loss: 0.1853, Accuracy: 92.91%)
# Train epoch: 64 [10/375]	Accuracy: 91.56%	Loss: 0.194377
# Train epoch: 64 [20/375]	Accuracy: 93.44%	Loss: 0.173587
# Train epoch: 64 [30/375]	Accuracy: 93.12%	Loss: 0.159310
# Train epoch: 64 [40/375]	Accuracy: 91.88%	Loss: 0.178915
# Train epoch: 64 [50/375]	Accuracy: 91.88%	Loss: 0.173092
# Train epoch: 64 [60/375]	Accuracy: 91.88%	Loss: 0.189182
# Train epoch: 64 [70/375]	Accuracy: 95.00%	Loss: 0.155801
# Train epoch: 64 [80/375]	Accuracy: 94.69%	Loss: 0.169677
# Train epoch: 64 [90/375]	Accuracy: 95.31%	Loss: 0.144008
# Train epoch: 64 [100/375]	Accuracy: 93.12%	Loss: 0.176005
# Train epoch: 64 [110/375]	Accuracy: 92.50%	Loss: 0.168441
# Train epoch: 64 [120/375]	Accuracy: 91.25%	Loss: 0.172942
# Train epoch: 64 [130/375]	Accuracy: 91.88%	Loss: 0.173531
# Train epoch: 64 [140/375]	Accuracy: 92.50%	Loss: 0.177744
# Train epoch: 64 [150/375]	Accuracy: 90.94%	Loss: 0.188086
# Train epoch: 64 [160/375]	Accuracy: 92.50%	Loss: 0.173418
# Train epoch: 64 [170/375]	Accuracy: 89.69%	Loss: 0.217965
# Train epoch: 64 [180/375]	Accuracy: 93.12%	Loss: 0.161338
# Train epoch: 64 [190/375]	Accuracy: 94.06%	Loss: 0.158356
# Train epoch: 64 [200/375]	Accuracy: 93.44%	Loss: 0.164064
# Train epoch: 64 [210/375]	Accuracy: 93.12%	Loss: 0.164468
# Train epoch: 64 [220/375]	Accuracy: 91.56%	Loss: 0.154640
# Train epoch: 64 [230/375]	Accuracy: 91.56%	Loss: 0.181662
# Train epoch: 64 [240/375]	Accuracy: 93.44%	Loss: 0.160397
# Train epoch: 64 [250/375]	Accuracy: 90.31%	Loss: 0.177621
# Train epoch: 64 [260/375]	Accuracy: 94.06%	Loss: 0.161158
# Train epoch: 64 [270/375]	Accuracy: 94.06%	Loss: 0.157619
# Train epoch: 64 [280/375]	Accuracy: 91.88%	Loss: 0.177230
# Train epoch: 64 [290/375]	Accuracy: 92.81%	Loss: 0.156875
# Train epoch: 64 [300/375]	Accuracy: 94.69%	Loss: 0.142911
# Train epoch: 64 [310/375]	Accuracy: 95.94%	Loss: 0.119984
# Train epoch: 64 [320/375]	Accuracy: 93.75%	Loss: 0.139633
# Train epoch: 64 [330/375]	Accuracy: 94.06%	Loss: 0.140400
# Train epoch: 64 [340/375]	Accuracy: 93.12%	Loss: 0.179427
# Train epoch: 64 [350/375]	Accuracy: 94.38%	Loss: 0.155632
# Train epoch: 64 [360/375]	Accuracy: 93.75%	Loss: 0.153734
# Train epoch: 64 [370/375]	Accuracy: 92.19%	Loss: 0.155108
# Test set: Loss: 0.1745, Accuracy: 93.20%)
# Train epoch: 65 [10/375]	Accuracy: 94.38%	Loss: 0.158641
# Train epoch: 65 [20/375]	Accuracy: 94.06%	Loss: 0.149361
# Train epoch: 65 [30/375]	Accuracy: 92.81%	Loss: 0.154883
# Train epoch: 65 [40/375]	Accuracy: 89.69%	Loss: 0.203805
# Train epoch: 65 [50/375]	Accuracy: 94.69%	Loss: 0.160431
# Train epoch: 65 [60/375]	Accuracy: 94.06%	Loss: 0.158599
# Train epoch: 65 [70/375]	Accuracy: 94.69%	Loss: 0.160270
# Train epoch: 65 [80/375]	Accuracy: 93.75%	Loss: 0.146750
# Train epoch: 65 [90/375]	Accuracy: 95.00%	Loss: 0.154198
# Train epoch: 65 [100/375]	Accuracy: 93.44%	Loss: 0.162723
# Train epoch: 65 [110/375]	Accuracy: 93.75%	Loss: 0.193501
# Train epoch: 65 [120/375]	Accuracy: 92.81%	Loss: 0.162092
# Train epoch: 65 [130/375]	Accuracy: 96.25%	Loss: 0.130282
# Train epoch: 65 [140/375]	Accuracy: 92.19%	Loss: 0.156977
# Train epoch: 65 [150/375]	Accuracy: 92.81%	Loss: 0.186854
# Train epoch: 65 [160/375]	Accuracy: 92.50%	Loss: 0.161008
# Train epoch: 65 [170/375]	Accuracy: 93.12%	Loss: 0.165846
# Train epoch: 65 [180/375]	Accuracy: 93.44%	Loss: 0.173287
# Train epoch: 65 [190/375]	Accuracy: 92.19%	Loss: 0.181605
# Train epoch: 65 [200/375]	Accuracy: 91.56%	Loss: 0.160236
# Train epoch: 65 [210/375]	Accuracy: 94.06%	Loss: 0.163143
# Train epoch: 65 [220/375]	Accuracy: 91.88%	Loss: 0.176198
# Train epoch: 65 [230/375]	Accuracy: 94.06%	Loss: 0.166348
# Train epoch: 65 [240/375]	Accuracy: 91.88%	Loss: 0.181327
# Train epoch: 65 [250/375]	Accuracy: 93.12%	Loss: 0.170568
# Train epoch: 65 [260/375]	Accuracy: 95.94%	Loss: 0.135510
# Train epoch: 65 [270/375]	Accuracy: 91.56%	Loss: 0.169838
# Train epoch: 65 [280/375]	Accuracy: 94.06%	Loss: 0.160761
# Train epoch: 65 [290/375]	Accuracy: 92.81%	Loss: 0.174121
# Train epoch: 65 [300/375]	Accuracy: 96.25%	Loss: 0.130803
# Train epoch: 65 [310/375]	Accuracy: 90.94%	Loss: 0.195604
# Train epoch: 65 [320/375]	Accuracy: 93.12%	Loss: 0.157597
# Train epoch: 65 [330/375]	Accuracy: 93.44%	Loss: 0.165414
# Train epoch: 65 [340/375]	Accuracy: 91.88%	Loss: 0.179903
# Train epoch: 65 [350/375]	Accuracy: 90.31%	Loss: 0.192773
# Train epoch: 65 [360/375]	Accuracy: 93.12%	Loss: 0.152116
# Train epoch: 65 [370/375]	Accuracy: 94.06%	Loss: 0.156254
# Test set: Loss: 0.1797, Accuracy: 92.86%)
# Train epoch: 66 [10/375]	Accuracy: 92.19%	Loss: 0.161632
# Train epoch: 66 [20/375]	Accuracy: 93.12%	Loss: 0.163291
# Train epoch: 66 [30/375]	Accuracy: 90.31%	Loss: 0.185592
# Train epoch: 66 [40/375]	Accuracy: 92.81%	Loss: 0.149576
# Train epoch: 66 [50/375]	Accuracy: 94.06%	Loss: 0.147938
# Train epoch: 66 [60/375]	Accuracy: 91.88%	Loss: 0.167609
# Train epoch: 66 [70/375]	Accuracy: 91.88%	Loss: 0.169880
# Train epoch: 66 [80/375]	Accuracy: 94.69%	Loss: 0.154816
# Train epoch: 66 [90/375]	Accuracy: 92.19%	Loss: 0.172752
# Train epoch: 66 [100/375]	Accuracy: 94.69%	Loss: 0.143958
# Train epoch: 66 [110/375]	Accuracy: 92.81%	Loss: 0.194269
# Train epoch: 66 [120/375]	Accuracy: 92.50%	Loss: 0.173288
# Train epoch: 66 [130/375]	Accuracy: 92.19%	Loss: 0.170482
# Train epoch: 66 [140/375]	Accuracy: 94.69%	Loss: 0.144971
# Train epoch: 66 [150/375]	Accuracy: 90.62%	Loss: 0.183090
# Train epoch: 66 [160/375]	Accuracy: 93.75%	Loss: 0.170075
# Train epoch: 66 [170/375]	Accuracy: 94.69%	Loss: 0.155208
# Train epoch: 66 [180/375]	Accuracy: 92.81%	Loss: 0.175935
# Train epoch: 66 [190/375]	Accuracy: 92.50%	Loss: 0.181488
# Train epoch: 66 [200/375]	Accuracy: 91.56%	Loss: 0.192542
# Train epoch: 66 [210/375]	Accuracy: 92.50%	Loss: 0.158929
# Train epoch: 66 [220/375]	Accuracy: 91.88%	Loss: 0.173707
# Train epoch: 66 [230/375]	Accuracy: 94.06%	Loss: 0.156314
# Train epoch: 66 [240/375]	Accuracy: 92.50%	Loss: 0.155197
# Train epoch: 66 [250/375]	Accuracy: 91.56%	Loss: 0.181577
# Train epoch: 66 [260/375]	Accuracy: 95.00%	Loss: 0.158692
# Train epoch: 66 [270/375]	Accuracy: 92.50%	Loss: 0.172697
# Train epoch: 66 [280/375]	Accuracy: 90.94%	Loss: 0.198300
# Train epoch: 66 [290/375]	Accuracy: 92.19%	Loss: 0.192533
# Train epoch: 66 [300/375]	Accuracy: 91.56%	Loss: 0.178408
# Train epoch: 66 [310/375]	Accuracy: 93.12%	Loss: 0.155001
# Train epoch: 66 [320/375]	Accuracy: 93.12%	Loss: 0.196618
# Train epoch: 66 [330/375]	Accuracy: 92.50%	Loss: 0.163567
# Train epoch: 66 [340/375]	Accuracy: 91.56%	Loss: 0.178226
# Train epoch: 66 [350/375]	Accuracy: 95.31%	Loss: 0.131634
# Train epoch: 66 [360/375]	Accuracy: 92.50%	Loss: 0.169087
# Train epoch: 66 [370/375]	Accuracy: 94.06%	Loss: 0.149292
# Test set: Loss: 0.1542, Accuracy: 93.35%)
# Train epoch: 67 [10/375]	Accuracy: 94.69%	Loss: 0.149253
# Train epoch: 67 [20/375]	Accuracy: 93.44%	Loss: 0.157695
# Train epoch: 67 [30/375]	Accuracy: 93.75%	Loss: 0.144149
# Train epoch: 67 [40/375]	Accuracy: 92.50%	Loss: 0.153497
# Train epoch: 67 [50/375]	Accuracy: 95.00%	Loss: 0.147000
# Train epoch: 67 [60/375]	Accuracy: 94.69%	Loss: 0.142238
# Train epoch: 67 [70/375]	Accuracy: 90.94%	Loss: 0.195357
# Train epoch: 67 [80/375]	Accuracy: 91.88%	Loss: 0.185726
# Train epoch: 67 [90/375]	Accuracy: 93.12%	Loss: 0.174514
# Train epoch: 67 [100/375]	Accuracy: 91.25%	Loss: 0.197200
# Train epoch: 67 [110/375]	Accuracy: 92.19%	Loss: 0.183275
# Train epoch: 67 [120/375]	Accuracy: 94.69%	Loss: 0.121367
# Train epoch: 67 [130/375]	Accuracy: 93.44%	Loss: 0.164109
# Train epoch: 67 [140/375]	Accuracy: 93.12%	Loss: 0.159969
# Train epoch: 67 [150/375]	Accuracy: 92.81%	Loss: 0.152483
# Train epoch: 67 [160/375]	Accuracy: 93.75%	Loss: 0.143241
# Train epoch: 67 [170/375]	Accuracy: 92.81%	Loss: 0.158705
# Train epoch: 67 [180/375]	Accuracy: 93.12%	Loss: 0.151110
# Train epoch: 67 [190/375]	Accuracy: 94.06%	Loss: 0.143881
# Train epoch: 67 [200/375]	Accuracy: 91.56%	Loss: 0.192365
# Train epoch: 67 [210/375]	Accuracy: 94.38%	Loss: 0.173139
# Train epoch: 67 [220/375]	Accuracy: 93.12%	Loss: 0.161673
# Train epoch: 67 [230/375]	Accuracy: 92.50%	Loss: 0.179503
# Train epoch: 67 [240/375]	Accuracy: 92.81%	Loss: 0.182843
# Train epoch: 67 [250/375]	Accuracy: 95.00%	Loss: 0.170644
# Train epoch: 67 [260/375]	Accuracy: 94.06%	Loss: 0.145052
# Train epoch: 67 [270/375]	Accuracy: 91.25%	Loss: 0.192227
# Train epoch: 67 [280/375]	Accuracy: 92.50%	Loss: 0.165059
# Train epoch: 67 [290/375]	Accuracy: 91.56%	Loss: 0.184424
# Train epoch: 67 [300/375]	Accuracy: 89.38%	Loss: 0.195732
# Train epoch: 67 [310/375]	Accuracy: 89.38%	Loss: 0.221249
# Train epoch: 67 [320/375]	Accuracy: 93.75%	Loss: 0.148743
# Train epoch: 67 [330/375]	Accuracy: 95.62%	Loss: 0.135056
# Train epoch: 67 [340/375]	Accuracy: 91.88%	Loss: 0.194866
# Train epoch: 67 [350/375]	Accuracy: 93.12%	Loss: 0.194993
# Train epoch: 67 [360/375]	Accuracy: 91.25%	Loss: 0.176515
# Train epoch: 67 [370/375]	Accuracy: 93.75%	Loss: 0.146450
# Test set: Loss: 0.1680, Accuracy: 93.20%)
# Train epoch: 68 [10/375]	Accuracy: 91.56%	Loss: 0.167314
# Train epoch: 68 [20/375]	Accuracy: 92.81%	Loss: 0.184369
# Train epoch: 68 [30/375]	Accuracy: 91.88%	Loss: 0.182841
# Train epoch: 68 [40/375]	Accuracy: 90.94%	Loss: 0.193634
