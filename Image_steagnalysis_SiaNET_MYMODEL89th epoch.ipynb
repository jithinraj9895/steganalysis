# %% [markdown]
# <a href="https://colab.research.google.com/github/jithinraj9895/steganalysis/blob/second/Image_steagnalysis_SiaNET_MYMODEL89th%20epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
import logging
import os
import random
from PIL import Image
import cv2
import numpy as np
import torch
import random
import os
import os.path as osp

def set_random_seed(seed=None):
    """Sets random seed for reproducibility.

    Args:
        seed (int, optional): Random seed.
    """
    if seed is None:
        seed = (
                os.getpid()
                + int(datetime.now().strftime("%S%f"))
                + int.from_bytes(os.urandom(2), "big")
        )
        logger = logging.getLogger(__name__)
        logger.info('Using a generated random seed {}'.format(seed))
    random.seed(seed)
    np.random.seed(seed)
    torch.set_rng_state(torch.manual_seed(seed).get_state())


def get_random_seed():
    return np.random.randint(2 ** 31)

# %%
class RandomRot(object):

    def __call__(self, sample):
        rot = random.randint(0, 3)
        return {
            'image': np.rot90(sample['image'], rot, axes=[-3, -2]).copy(),
            'label': sample['label'],
        }


class RandomFlip(object):

    def __init__(self, p=0.5):
        self._p = p

    def __call__(self, sample):
        if random.random() < self._p:
            return {
                'image': np.flip(sample['image'], axis=-2).copy(),
                'label': sample['label'],
            }
        else:
            return sample


class ToTensor(object):

    def __call__(self, sample):
        image, label = sample['image'], sample['label']
        if image.ndim == 3:  # HxWxC
            image = image.transpose(2, 0, 1)
        else:  # NxHxWxC
            image = image.transpose(0, 3, 1, 2)
        return {
            'image': torch.from_numpy(image).type(torch.FloatTensor),
            'label': torch.tensor(label).long()
        }

# %%
from torch.utils.data import Dataset


class CoverStegoDataset(Dataset):

    def __init__(self, cover_dir, stego_dir, transform=None):
        self._transform = transform

        self.images, self.labels = self.get_items(cover_dir, stego_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = np.array(Image.open(self.images[idx]))
        image = np.expand_dims(image, 2)  # (H, W, C)
        assert image.ndim == 3

        sample = {
            'image': image,
            'label': self.labels[idx]
        }

        if self._transform:
            sample = self._transform(sample)
        return sample

    @staticmethod
    def get_items(cover_dir, stego_dir):
        images, labels = [], []

        cover_names = sorted(os.listdir(cover_dir))
        if stego_dir is not None:
            stego_names = sorted(os.listdir(stego_dir))
            assert cover_names == stego_names

        file_names = cover_names
        if stego_dir is None:
            dir_to_label = [(cover_dir, 0), ]
        else:
            dir_to_label = [(cover_dir, 0), (stego_dir, 1)]
        for image_dir, label in dir_to_label:
            for file_name in file_names:
                image_path = osp.join(image_dir, file_name)
                if not osp.isfile(image_path):
                    raise FileNotFoundError('{} not exists'.format(image_path))
                images.append(image_path)
                labels.append(label)

        return images, labels

# %%
import torchvision
from torch.utils.data import BatchSampler
from torch.utils.data import DataLoader
from torch.utils.data import Sampler
from torch.utils.data import SequentialSampler
import itertools
import logging
import math

class TrainingSampler(Sampler):

    def __init__(self, size, seed=None, shuffle=True):
        self._size = size
        self._shuffle = shuffle

        if seed is None:
            seed = get_random_seed()
        self._seed = seed

    def __iter__(self):
        yield from itertools.islice(self._infinite_indices(), 0, None, 1)

    def _infinite_indices(self):
        g = torch.Generator()
        g.manual_seed(self._seed)
        while True:
            if self._shuffle:
                yield from torch.randperm(self._size, generator=g)
            else:
                yield from torch.arange(self._size)




class BalancedBatchSampler(BatchSampler):

    def __init__(self, sampler, group_ids, batch_size):
        """
        Args:
            sampler (Sampler): Base sampler.
            group_ids (list[int]): If the sampler produces indices in range [0, N),
                `group_ids` must be a list of `N` ints which contains the group id of each
                sample. The group ids must be a set of integers in [0, num_groups).
            batch_size (int): Size of mini-batch.
        """
        if not isinstance(sampler, Sampler):
            raise ValueError("sampler should be an instance of torch.utils.data.Sampler, "
                             "but got sampler={}".format(sampler))

        self._sampler = sampler
        self._group_ids = np.asarray(group_ids)
        assert self._group_ids.ndim == 1
        self._batch_size = batch_size
        groups = np.unique(self._group_ids).tolist()
        assert batch_size % len(groups) == 0

        # buffer the indices of each group until batch size is reached
        self._buffer_per_group = {k: [] for k in groups}
        self._group_size = batch_size // len(groups)

    def __iter__(self):
        for idx in self._sampler:
            group_id = self._group_ids[idx]
            self._buffer_per_group[group_id].append(idx)
            if all(len(v) >= self._group_size for k, v in self._buffer_per_group.items()):
                idxs = []
                # Collect across all groups
                for k, v in self._buffer_per_group.items():
                    idxs.extend(v[:self._group_size])
                    del v[:self._group_size]

                idxs = np.random.permutation(idxs)
                yield idxs

    def __len__(self):
        raise NotImplementedError("len() of GroupedBatchSampler is not well-defined.")


def build_train_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        RandomRot(),
        RandomFlip(),
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    size = len(dataset)
    sampler = TrainingSampler(size)
    if stego_dir is not None:
        batch_sampler = BalancedBatchSampler(sampler, dataset.labels, batch_size)
    else:
        batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)
    epoch_length = math.ceil(size / batch_size)


    train_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
        worker_init_fn=worker_init_reset_seed,
    )
    return train_loader, epoch_length




def build_val_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    sampler = SequentialSampler(dataset)
    batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)


    test_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
    )
    return test_loader

def worker_init_reset_seed(worker_id):
    set_random_seed(np.random.randint(2 ** 31) + worker_id)

# %%
set_random_seed()

# %%
 train_cover_dir = "/content/drive/MyDrive/real_boss_256/train/cover"
 train_stego_dir = "/content/drive/MyDrive/real_boss_256/train/stego"
 val_cover_dir = "/content/drive/MyDrive/real_boss_256/validation/cover"
 val_stego_dir = "/content/drive/MyDrive/real_boss_256/validation/stego"
 
 
 train_loader, epoch_length = build_train_loader(
        train_cover_dir, train_stego_dir, batch_size=32,
        num_workers=0)

# %%
print(epoch_length)
# Out:
# 375

# %%
val_loader = build_val_loader(
    val_cover_dir, val_stego_dir, batch_size=32,
    num_workers=0
)

# %%
train_loader_iter = iter(train_loader)

# %%
def activation(x):
    a = torch.ones(x.shape).cuda()
    a = torch.mul(a, -3).cuda()
    b = torch.ones(x.shape).cuda()
    b = torch.mul(b, 3).cuda()
    c = torch.where(x > -3,x,a).cuda()
    d = torch.where(c < 3,c,b).cuda()
    return d     


class the_tlu(nn.Module):
    def __init__(self):
        super(the_tlu, self).__init__()
    def forward(self, x):
        return activation(x)

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.nn import Parameter


srm_dir = "/content/drive/MyDrive"
SRM_npy = np.load(os.path.join(srm_dir,"SRM_Kernels.npy"))


def accuracy(outputs, labels):
    _, argmax = torch.max(outputs, 1)
    return (labels == argmax.squeeze()).float().mean()


def conv3x3(in_planes, out_planes, stride=1, groups=1, dilation=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                     padding=dilation, groups=groups, bias=False, dilation=dilation)


def conv1x1(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


class SRMConv2d(nn.Module):

    def __init__(self, stride=1, padding=0):
        super(SRMConv2d, self).__init__()
        self.in_channels = 1
        self.out_channels = 30
        self.kernel_size = (5, 5)
        if isinstance(stride, int):
            self.stride = (stride, stride)
        else:
            self.stride = stride
        if isinstance(padding, int):
            self.padding = (padding, padding)
        else:
            self.padding = padding
        self.dilation = (1, 1)
        self.transpose = False
        self.output_padding = (0,)
        self.groups = 1
        self.weight = Parameter(torch.Tensor(30, 1, 5, 5), requires_grad=True)
        self.bias = Parameter(torch.Tensor(30), requires_grad=True)
        self.reset_parameters()

    def reset_parameters(self):
        self.weight.data.numpy()[:] = SRM_npy
        self.bias.data.zero_()

    def forward(self, input):
        return F.conv2d(input, self.weight, self.bias, self.stride, self.padding,
                        self.dilation, self.groups)


class BlockA(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockA, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += identity
        out = self.relu(out)

        return out


class BlockB(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockB, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes, stride=2)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)
        # self.pool = nn.AvgPool2d(3, stride=2, padding=1)

        self.shortcut_conv = conv1x1(in_planes, out_planes, stride=2)
        self.shortcut_bn = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        # out = self.pool(out)

        identity = self.shortcut_conv(identity)
        identity = self.shortcut_bn(identity)

        out += identity
        out = self.relu(out)

        return out

# %%
class KeNet(nn.Module):

    def __init__(self, norm_layer=None, zero_init_residual=True, p=0.5):
        super(KeNet, self).__init__()

        self.zero_init_residual = zero_init_residual

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.srm = SRMConv2d(1, 0)
        self.bn1 = norm_layer(30)
        self.tlu = the_tlu()

        self.A1 = BlockA(30, 30, norm_layer=norm_layer)
        self.A2 = BlockA(30, 30, norm_layer=norm_layer)
        self.AA = BlockA(30, 30, norm_layer=norm_layer)

        # self.B1 = BlockB(30, 30, norm_layer=norm_layer)
        # self.B2 = BlockB(30, 64, norm_layer=norm_layer)

        self.B3 = BlockB(30, 64, norm_layer=norm_layer)
        self.A3 = BlockA(64, 64, norm_layer=norm_layer)

        self.B4 = BlockB(64, 128, norm_layer=norm_layer)
        self.A4 = BlockA(128, 128, norm_layer=norm_layer)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # self.bnfc = nn.BatchNorm1d(128)
        self.relu = nn.ReLU(inplace=True)
        # self.fcfusion = nn.Linear(128, 128) #4
        self.fc = nn.Linear(128 * 4 + 1, 2)
        self.dropout = nn.Dropout(p=p)

        self.reset_parameters()

    def reset_parameters(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # nn.init.xavier_uniform_(m.weight)
                # nn.init.constant_(m.bias, 0.2)
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, std=0.01)

        if self.zero_init_residual:
            for m in self.modules():
                if isinstance(m, (BlockA, BlockB)):
                    nn.init.constant_(m.bn2.weight, 0)

    def extract_feat(self, x):
        x = x.float()
        out = self.srm(x)
        out = self.bn1(out)
        out = self.tlu(out)
    #    out = self.relu(out)

        out = self.A1(out)
        out = self.A2(out)
        out = self.AA(out)

        # out = self.B1(out)
        # out = self.B2(out)

        out = self.B3(out)
        out = self.A3(out)

        out = self.B4(out)
        out = self.A4(out)

        out = self.avgpool(out)
        out = out.view(out.size(0), out.size(1))

        # out = self.relu(out)
        # out = self.bnfc(out)

        return out

    def forward(self, *args):
        ############# statistics fusion start #############
        feats = torch.stack(
            [self.extract_feat(subarea) for subarea in args], dim=0
        )

        euclidean_distance = F.pairwise_distance(feats[0], feats[1], eps=1e-6,
                                                 keepdim=True)

        if feats.shape[0] == 1:
            final_feat = feats.squeeze(dim=0)
        else:
            # feats_sum = feats.sum(dim=0)
            # feats_sub = feats[0] - feats[1]
            feats_mean = feats.mean(dim=0)
            feats_var = feats.var(dim=0)
            feats_min, _ = feats.min(dim=0)
            feats_max, _ = feats.max(dim=0)

            '''feats_sum = feats.sum(dim=0)
            feats_sub = abs(feats[0] - feats[1])
            feats_prod = feats.prod(dim=0)
            feats_max, _ = feats.max(dim=0)'''
            
            #final_feat = torch.cat(
            #    [feats[0], feats[1], feats[0], feats[1]], dim=-1
            #    #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            #)

            final_feat = torch.cat(
                [euclidean_distance, feats_mean, feats_var, feats_min, feats_max], dim=-1
                #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            )

        out = self.dropout(final_feat)
        # out = self.fcfusion(out)
        # out = self.relu(out)
        out = self.fc(out)

        return out, feats[0], feats[1]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ContrastiveLoss(nn.Module):

    def __init__(self, margin=1.25):  # margin=2
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        label = label.to(torch.float32)
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean(
            (1 - label) * torch.pow(euclidean_distance, 2) +
            label * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2)
        )

        return loss_contrastive

# %%
criterion_1 = nn.CrossEntropyLoss()
criterion_2 = ContrastiveLoss(margin=1)

# %%
net = KeNet();

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

device = get_default_device()


if device.type == "cuda":
    net.cuda()
    criterion_1.cuda()
    criterion_2.cuda()

# %%
from torch.optim.adamax import Adamax

optimizer = Adamax(net.parameters(), lr=0.001, eps=1e-08, weight_decay=0.0001)

# %%
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', factor=0.3,
                                                           patience=10, verbose=True, min_lr=0,
                                                           eps=1e-08)

# %%
import logging
import time
import shutil
logger = logging.getLogger(__name__)


def preprocess_data(images, labels, random_crop,gpu):
    # images of shape: NxCxHxW
    if images.ndim == 5:  # 1xNxCxHxW
        images = images.squeeze(0)
        labels = labels.squeeze(0)
    h, w = images.shape[-2:]

    if random_crop:
        ch = random.randint(h * 3 // 4, h)  # h // 2      #256
        cw = random.randint(w * 3 // 4, w)  # square ch   #256

        h0 = random.randint(0, h - ch)  # 128
        w0 = random.randint(0, w - cw)  # 128
    else:
        ch, cw, h0, w0 = h, w, 0, 0


    cw = cw & ~1
    inputs = [
            images[..., h0:h0 + ch, w0:w0 + cw // 2],
            images[..., h0:h0 + ch, w0 + cw // 2:w0 + cw]
        ]

    if gpu:
        inputs = [x.cuda() for x in inputs]
        labels = labels.cuda()
    return inputs, labels

# %%
def train(epoch):
    net.train()
    running_loss, running_accuracy = 0., 0.

    for batch_idx in range(epoch_length):
        data = next(train_loader_iter)
        inputs, labels = preprocess_data(data['image'], data['label'], False,gpu=True)

        optimizer.zero_grad()
   
        outputs, feats_0, feats_1 = net(*inputs)

            # count parameters start
            # print('parameters_count: {}'.format(sum(p.numel() for p in net.parameters() if p.requires_grad)))
            # count parameters end

        loss = criterion_1(outputs, labels) + \
                   0.1 * criterion_2(feats_0, feats_1, labels)

        accuracy1 = accuracy(outputs, labels).item()
        running_accuracy += accuracy1
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        if (batch_idx + 1) % 10 == 0:
            running_accuracy /= 10
            running_loss /= 10
            
            print(
                'Train epoch: {} [{}/{}]\tAccuracy: {:.2f}%\tLoss: {:.6f}'.format(
                    epoch, batch_idx + 1, epoch_length, 100 * running_accuracy,
                    running_loss))
                    
            ###############################log per log_interval start
            is_best=False
            save_checkpoint(
                {
                    'iteration': batch_idx + 1,
                    'state_dict': net.state_dict(),
                    'best_prec1': running_accuracy,
                    'optimizer': optimizer.state_dict(),
                },
                is_best,
                filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
                best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
            ###############################
            running_loss = 0.
            running_accuracy = 0.
            net.train()

# %%
def valid():
    net.eval()
    valid_loss = 0.
    valid_accuracy = 0.
    with torch.no_grad():
        for data in val_loader:
            inputs, labels = preprocess_data(data['image'], data['label'], False,gpu = True)

            outputs, feats_0, feats_1 = net(*inputs)
            valid_loss += criterion_1(outputs, labels).item() + \
                              0.01 * criterion_2(feats_0, feats_1, labels)
            valid_accuracy += accuracy(outputs, labels).item()
    valid_loss /= len(val_loader)
    valid_accuracy /= len(val_loader)
    print('Test set: Loss: {:.4f}, Accuracy: {:.2f}%)'.format(
        valid_loss, 100 * valid_accuracy))
    return valid_loss, valid_accuracy

# %%
fine_tune = "/content/drive/MyDrive/dataset/checkpoint.pth.tar"

if fine_tune is not None:
    net.load_state_dict(torch.load(fine_tune)['state_dict'], strict=False)
    e = torch.load(fine_tune)['iteration']

# %%
print(e)
# Out:
# 100

# %%
def save_checkpoint(state, is_best, filename, best_name):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, best_name)


_time = time.time()
best_accuracy = 0.
for e in range(1, 100 + 1):
    logger.info('Epoch: {}'.format(e))
    logger.info('Train')
    train(e)
    logger.info('Time: {}'.format(time.time() - _time))
    logger.info('Test')
    _, accuracy1 = valid()
    if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
        scheduler.step(accuracy1)
    else:
        scheduler.step()
    if accuracy1 > best_accuracy:
        best_accuracy = accuracy1
        is_best = True
    else:
        is_best = False
    logger.info('Best accuracy: {}'.format(best_accuracy))
    logger.info('Time: {}'.format(time.time() - _time))
    save_checkpoint(
        {
            'epoch': e,
            'state_dict': net.state_dict(),
            'best_prec1': accuracy1,
            'optimizer': optimizer.state_dict(),
        },
        is_best,
        filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
        best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
# Out:
# Train epoch: 1 [10/375]	Accuracy: 84.38%	Loss: 0.315046
# Train epoch: 1 [20/375]	Accuracy: 82.81%	Loss: 0.393553
# Train epoch: 1 [30/375]	Accuracy: 84.38%	Loss: 0.303512
# Train epoch: 1 [40/375]	Accuracy: 85.00%	Loss: 0.276312
# Train epoch: 1 [50/375]	Accuracy: 89.06%	Loss: 0.249599
# Train epoch: 1 [60/375]	Accuracy: 83.44%	Loss: 0.332448
# Train epoch: 1 [70/375]	Accuracy: 90.00%	Loss: 0.262465
# Train epoch: 1 [80/375]	Accuracy: 86.25%	Loss: 0.284759
# Train epoch: 1 [90/375]	Accuracy: 85.31%	Loss: 0.283236
# Train epoch: 1 [100/375]	Accuracy: 86.25%	Loss: 0.264448
# Train epoch: 1 [110/375]	Accuracy: 85.00%	Loss: 0.315829
# Train epoch: 1 [120/375]	Accuracy: 86.56%	Loss: 0.276445
# Train epoch: 1 [130/375]	Accuracy: 84.69%	Loss: 0.281522
# Train epoch: 1 [140/375]	Accuracy: 86.56%	Loss: 0.293948
# Train epoch: 1 [150/375]	Accuracy: 87.81%	Loss: 0.268969
# Train epoch: 1 [160/375]	Accuracy: 85.31%	Loss: 0.297275
# Train epoch: 1 [170/375]	Accuracy: 89.06%	Loss: 0.251017
# Train epoch: 1 [180/375]	Accuracy: 88.75%	Loss: 0.307240
# Train epoch: 1 [190/375]	Accuracy: 84.38%	Loss: 0.296790
# Train epoch: 1 [200/375]	Accuracy: 89.69%	Loss: 0.261644
# Train epoch: 1 [210/375]	Accuracy: 91.56%	Loss: 0.209191
# Train epoch: 1 [220/375]	Accuracy: 90.00%	Loss: 0.230388
# Train epoch: 1 [230/375]	Accuracy: 90.62%	Loss: 0.241284
# Train epoch: 1 [240/375]	Accuracy: 89.06%	Loss: 0.252825
# Train epoch: 1 [250/375]	Accuracy: 89.38%	Loss: 0.265315
# Train epoch: 1 [260/375]	Accuracy: 89.38%	Loss: 0.253005
# Train epoch: 1 [270/375]	Accuracy: 85.62%	Loss: 0.299273
# Train epoch: 1 [280/375]	Accuracy: 88.75%	Loss: 0.250038
# Train epoch: 1 [290/375]	Accuracy: 86.88%	Loss: 0.275195
# Train epoch: 1 [300/375]	Accuracy: 85.94%	Loss: 0.285922
# Train epoch: 1 [310/375]	Accuracy: 89.69%	Loss: 0.245830
# Train epoch: 1 [320/375]	Accuracy: 87.50%	Loss: 0.264164
# Train epoch: 1 [330/375]	Accuracy: 88.44%	Loss: 0.271225
# Train epoch: 1 [340/375]	Accuracy: 87.50%	Loss: 0.287946
# Train epoch: 1 [350/375]	Accuracy: 87.81%	Loss: 0.266102
# Train epoch: 1 [360/375]	Accuracy: 86.88%	Loss: 0.317013
# Train epoch: 1 [370/375]	Accuracy: 85.62%	Loss: 0.311588
# Test set: Loss: 0.3719, Accuracy: 82.94%)
# Train epoch: 2 [10/375]	Accuracy: 89.69%	Loss: 0.240784
# Train epoch: 2 [20/375]	Accuracy: 88.44%	Loss: 0.286136
# Train epoch: 2 [30/375]	Accuracy: 86.88%	Loss: 0.254255
# Train epoch: 2 [40/375]	Accuracy: 90.31%	Loss: 0.250544
# Train epoch: 2 [50/375]	Accuracy: 88.75%	Loss: 0.246113
# Train epoch: 2 [60/375]	Accuracy: 87.19%	Loss: 0.269047
# Train epoch: 2 [70/375]	Accuracy: 87.19%	Loss: 0.293631
# Train epoch: 2 [80/375]	Accuracy: 89.69%	Loss: 0.247775
# Train epoch: 2 [90/375]	Accuracy: 87.19%	Loss: 0.229163
# Train epoch: 2 [100/375]	Accuracy: 92.50%	Loss: 0.225648
# Train epoch: 2 [110/375]	Accuracy: 89.38%	Loss: 0.233813
# Train epoch: 2 [120/375]	Accuracy: 85.94%	Loss: 0.285346
# Train epoch: 2 [130/375]	Accuracy: 88.75%	Loss: 0.245769
# Train epoch: 2 [140/375]	Accuracy: 87.50%	Loss: 0.273852
# Train epoch: 2 [150/375]	Accuracy: 85.62%	Loss: 0.269700
# Train epoch: 2 [160/375]	Accuracy: 87.50%	Loss: 0.298165
# Train epoch: 2 [170/375]	Accuracy: 83.12%	Loss: 0.334145
# Train epoch: 2 [180/375]	Accuracy: 89.06%	Loss: 0.256395
# Train epoch: 2 [190/375]	Accuracy: 82.50%	Loss: 0.360534
# Train epoch: 2 [200/375]	Accuracy: 87.50%	Loss: 0.280013
# Train epoch: 2 [210/375]	Accuracy: 90.31%	Loss: 0.265760
# Train epoch: 2 [220/375]	Accuracy: 84.69%	Loss: 0.368016
# Train epoch: 2 [230/375]	Accuracy: 89.69%	Loss: 0.224965
# Train epoch: 2 [240/375]	Accuracy: 89.06%	Loss: 0.239218
# Train epoch: 2 [250/375]	Accuracy: 86.25%	Loss: 0.280465
# Train epoch: 2 [260/375]	Accuracy: 89.69%	Loss: 0.244287
# Train epoch: 2 [270/375]	Accuracy: 84.06%	Loss: 0.317961
# Train epoch: 2 [280/375]	Accuracy: 88.44%	Loss: 0.258448
# Train epoch: 2 [290/375]	Accuracy: 86.56%	Loss: 0.308969
# Train epoch: 2 [300/375]	Accuracy: 86.56%	Loss: 0.262401
# Train epoch: 2 [310/375]	Accuracy: 86.56%	Loss: 0.288123
# Train epoch: 2 [320/375]	Accuracy: 86.88%	Loss: 0.268743
# Train epoch: 2 [330/375]	Accuracy: 89.06%	Loss: 0.242343
# Train epoch: 2 [340/375]	Accuracy: 86.88%	Loss: 0.278441
# Train epoch: 2 [350/375]	Accuracy: 89.38%	Loss: 0.231124
# Train epoch: 2 [360/375]	Accuracy: 88.75%	Loss: 0.229518
# Train epoch: 2 [370/375]	Accuracy: 86.56%	Loss: 0.258327
# Test set: Loss: 0.2539, Accuracy: 88.94%)
# Train epoch: 3 [10/375]	Accuracy: 88.75%	Loss: 0.259607
# Train epoch: 3 [20/375]	Accuracy: 90.00%	Loss: 0.219097
# Train epoch: 3 [30/375]	Accuracy: 86.56%	Loss: 0.316004
# Train epoch: 3 [40/375]	Accuracy: 89.69%	Loss: 0.269938
# Train epoch: 3 [50/375]	Accuracy: 85.31%	Loss: 0.300032
# Train epoch: 3 [60/375]	Accuracy: 88.44%	Loss: 0.247655
# Train epoch: 3 [70/375]	Accuracy: 87.50%	Loss: 0.263451
# Train epoch: 3 [80/375]	Accuracy: 89.06%	Loss: 0.246324
# Train epoch: 3 [90/375]	Accuracy: 86.25%	Loss: 0.267610
# Train epoch: 3 [100/375]	Accuracy: 88.75%	Loss: 0.249890
# Train epoch: 3 [110/375]	Accuracy: 85.94%	Loss: 0.283612
# Train epoch: 3 [120/375]	Accuracy: 86.25%	Loss: 0.277899
# Train epoch: 3 [130/375]	Accuracy: 90.62%	Loss: 0.239783
# Train epoch: 3 [140/375]	Accuracy: 87.81%	Loss: 0.272441
# Train epoch: 3 [150/375]	Accuracy: 86.56%	Loss: 0.272900
# Train epoch: 3 [160/375]	Accuracy: 86.88%	Loss: 0.258274
# Train epoch: 3 [170/375]	Accuracy: 89.69%	Loss: 0.225964
# Train epoch: 3 [180/375]	Accuracy: 87.81%	Loss: 0.269642
# Train epoch: 3 [190/375]	Accuracy: 87.50%	Loss: 0.291418
# Train epoch: 3 [200/375]	Accuracy: 85.00%	Loss: 0.299699
# Train epoch: 3 [210/375]	Accuracy: 87.50%	Loss: 0.258654
# Train epoch: 3 [220/375]	Accuracy: 89.06%	Loss: 0.288304
# Train epoch: 3 [230/375]	Accuracy: 89.38%	Loss: 0.270452
# Train epoch: 3 [240/375]	Accuracy: 87.19%	Loss: 0.272604
# Train epoch: 3 [250/375]	Accuracy: 84.06%	Loss: 0.330128
# Train epoch: 3 [260/375]	Accuracy: 87.19%	Loss: 0.240592
# Train epoch: 3 [270/375]	Accuracy: 87.81%	Loss: 0.263905
# Train epoch: 3 [280/375]	Accuracy: 87.50%	Loss: 0.258371
# Train epoch: 3 [290/375]	Accuracy: 88.12%	Loss: 0.256277
# Train epoch: 3 [300/375]	Accuracy: 88.12%	Loss: 0.263457
# Train epoch: 3 [310/375]	Accuracy: 87.50%	Loss: 0.248843
# Train epoch: 3 [320/375]	Accuracy: 85.94%	Loss: 0.260694
# Train epoch: 3 [330/375]	Accuracy: 86.25%	Loss: 0.313344
# Train epoch: 3 [340/375]	Accuracy: 88.44%	Loss: 0.244323
# Train epoch: 3 [350/375]	Accuracy: 86.25%	Loss: 0.266732
# Train epoch: 3 [360/375]	Accuracy: 85.00%	Loss: 0.292753
# Train epoch: 3 [370/375]	Accuracy: 87.81%	Loss: 0.254745
# Test set: Loss: 0.2076, Accuracy: 90.77%)
# Train epoch: 4 [10/375]	Accuracy: 88.44%	Loss: 0.257771
# Train epoch: 4 [20/375]	Accuracy: 88.75%	Loss: 0.254376
# Train epoch: 4 [30/375]	Accuracy: 91.56%	Loss: 0.215401
# Train epoch: 4 [40/375]	Accuracy: 90.62%	Loss: 0.223797
# Train epoch: 4 [50/375]	Accuracy: 85.94%	Loss: 0.291741
# Train epoch: 4 [60/375]	Accuracy: 90.62%	Loss: 0.226301
# Train epoch: 4 [70/375]	Accuracy: 86.56%	Loss: 0.264722
# Train epoch: 4 [80/375]	Accuracy: 87.50%	Loss: 0.298962
# Train epoch: 4 [90/375]	Accuracy: 90.94%	Loss: 0.235422
# Train epoch: 4 [100/375]	Accuracy: 87.50%	Loss: 0.249854
# Train epoch: 4 [110/375]	Accuracy: 90.00%	Loss: 0.227914
# Train epoch: 4 [120/375]	Accuracy: 87.50%	Loss: 0.275572
# Train epoch: 4 [130/375]	Accuracy: 89.06%	Loss: 0.246950
# Train epoch: 4 [140/375]	Accuracy: 82.81%	Loss: 0.325004
# Train epoch: 4 [150/375]	Accuracy: 89.06%	Loss: 0.237227
# Train epoch: 4 [160/375]	Accuracy: 83.75%	Loss: 0.296419
# Train epoch: 4 [170/375]	Accuracy: 90.62%	Loss: 0.273568
# Train epoch: 4 [180/375]	Accuracy: 89.38%	Loss: 0.253002
# Train epoch: 4 [190/375]	Accuracy: 88.75%	Loss: 0.258808
# Train epoch: 4 [200/375]	Accuracy: 87.81%	Loss: 0.311755
# Train epoch: 4 [210/375]	Accuracy: 89.38%	Loss: 0.240149
# Train epoch: 4 [220/375]	Accuracy: 87.50%	Loss: 0.298854
# Train epoch: 4 [230/375]	Accuracy: 86.25%	Loss: 0.264968
# Train epoch: 4 [240/375]	Accuracy: 86.56%	Loss: 0.299266
# Train epoch: 4 [250/375]	Accuracy: 88.75%	Loss: 0.238367
# Train epoch: 4 [260/375]	Accuracy: 87.81%	Loss: 0.247544
# Train epoch: 4 [270/375]	Accuracy: 88.44%	Loss: 0.271892
# Train epoch: 4 [280/375]	Accuracy: 87.19%	Loss: 0.313374
# Train epoch: 4 [290/375]	Accuracy: 88.44%	Loss: 0.271629
# Train epoch: 4 [300/375]	Accuracy: 85.31%	Loss: 0.284582
# Train epoch: 4 [310/375]	Accuracy: 86.25%	Loss: 0.304714
# Train epoch: 4 [320/375]	Accuracy: 90.94%	Loss: 0.224532
# Train epoch: 4 [330/375]	Accuracy: 85.00%	Loss: 0.284576
# Train epoch: 4 [340/375]	Accuracy: 87.81%	Loss: 0.273454
# Train epoch: 4 [350/375]	Accuracy: 90.62%	Loss: 0.236264
# Train epoch: 4 [360/375]	Accuracy: 86.25%	Loss: 0.296947
# Train epoch: 4 [370/375]	Accuracy: 87.50%	Loss: 0.242445
# Test set: Loss: 0.1987, Accuracy: 91.02%)
# Train epoch: 5 [10/375]	Accuracy: 86.88%	Loss: 0.296286
# Train epoch: 5 [20/375]	Accuracy: 88.75%	Loss: 0.286240
# Train epoch: 5 [30/375]	Accuracy: 89.06%	Loss: 0.260673
# Train epoch: 5 [40/375]	Accuracy: 92.19%	Loss: 0.214421
# Train epoch: 5 [50/375]	Accuracy: 89.06%	Loss: 0.275239
# Train epoch: 5 [60/375]	Accuracy: 91.56%	Loss: 0.233634
# Train epoch: 5 [70/375]	Accuracy: 90.94%	Loss: 0.209741
# Train epoch: 5 [80/375]	Accuracy: 86.56%	Loss: 0.299344
# Train epoch: 5 [90/375]	Accuracy: 89.06%	Loss: 0.268499
# Train epoch: 5 [100/375]	Accuracy: 89.38%	Loss: 0.291368
# Train epoch: 5 [110/375]	Accuracy: 88.44%	Loss: 0.251431
# Train epoch: 5 [120/375]	Accuracy: 88.12%	Loss: 0.279190
# Train epoch: 5 [130/375]	Accuracy: 86.88%	Loss: 0.271517
# Train epoch: 5 [140/375]	Accuracy: 84.69%	Loss: 0.301269
# Train epoch: 5 [150/375]	Accuracy: 85.00%	Loss: 0.298321
# Train epoch: 5 [160/375]	Accuracy: 87.81%	Loss: 0.257484
# Train epoch: 5 [170/375]	Accuracy: 91.56%	Loss: 0.218935
# Train epoch: 5 [180/375]	Accuracy: 86.25%	Loss: 0.248055
# Train epoch: 5 [190/375]	Accuracy: 87.81%	Loss: 0.271299
# Train epoch: 5 [200/375]	Accuracy: 87.81%	Loss: 0.299372
# Train epoch: 5 [210/375]	Accuracy: 90.00%	Loss: 0.241164
# Train epoch: 5 [220/375]	Accuracy: 88.12%	Loss: 0.258212
# Train epoch: 5 [230/375]	Accuracy: 87.19%	Loss: 0.277033
# Train epoch: 5 [240/375]	Accuracy: 87.50%	Loss: 0.251004
# Train epoch: 5 [250/375]	Accuracy: 89.69%	Loss: 0.248599
# Train epoch: 5 [260/375]	Accuracy: 90.00%	Loss: 0.251020
# Train epoch: 5 [270/375]	Accuracy: 89.38%	Loss: 0.230014
# Train epoch: 5 [280/375]	Accuracy: 90.94%	Loss: 0.227255
# Train epoch: 5 [290/375]	Accuracy: 90.62%	Loss: 0.246462
# Train epoch: 5 [300/375]	Accuracy: 90.00%	Loss: 0.250590
# Train epoch: 5 [310/375]	Accuracy: 90.62%	Loss: 0.216255
# Train epoch: 5 [320/375]	Accuracy: 85.62%	Loss: 0.298752
# Train epoch: 5 [330/375]	Accuracy: 89.06%	Loss: 0.264407
# Train epoch: 5 [340/375]	Accuracy: 87.50%	Loss: 0.278250
# Train epoch: 5 [350/375]	Accuracy: 88.12%	Loss: 0.249438
# Train epoch: 5 [360/375]	Accuracy: 85.31%	Loss: 0.298722
# Train epoch: 5 [370/375]	Accuracy: 87.81%	Loss: 0.283391
# Test set: Loss: 0.2701, Accuracy: 88.44%)
# Train epoch: 6 [10/375]	Accuracy: 90.00%	Loss: 0.249940
# Train epoch: 6 [20/375]	Accuracy: 87.50%	Loss: 0.286428
# Train epoch: 6 [30/375]	Accuracy: 89.38%	Loss: 0.246256
# Train epoch: 6 [40/375]	Accuracy: 88.75%	Loss: 0.261253
# Train epoch: 6 [50/375]	Accuracy: 90.00%	Loss: 0.236791
# Train epoch: 6 [60/375]	Accuracy: 85.94%	Loss: 0.353323
# Train epoch: 6 [70/375]	Accuracy: 86.56%	Loss: 0.288876
# Train epoch: 6 [80/375]	Accuracy: 90.62%	Loss: 0.210444
# Train epoch: 6 [90/375]	Accuracy: 90.31%	Loss: 0.234854
# Train epoch: 6 [100/375]	Accuracy: 84.38%	Loss: 0.279711
# Train epoch: 6 [110/375]	Accuracy: 87.81%	Loss: 0.261242
# Train epoch: 6 [120/375]	Accuracy: 88.75%	Loss: 0.238084
# Train epoch: 6 [130/375]	Accuracy: 87.50%	Loss: 0.278711
# Train epoch: 6 [140/375]	Accuracy: 88.12%	Loss: 0.312771
# Train epoch: 6 [150/375]	Accuracy: 88.44%	Loss: 0.246488
# Train epoch: 6 [160/375]	Accuracy: 85.00%	Loss: 0.288975
# Train epoch: 6 [170/375]	Accuracy: 90.62%	Loss: 0.238725
# Train epoch: 6 [180/375]	Accuracy: 87.50%	Loss: 0.301264
# Train epoch: 6 [190/375]	Accuracy: 88.75%	Loss: 0.275720
# Train epoch: 6 [200/375]	Accuracy: 87.81%	Loss: 0.276305
# Train epoch: 6 [210/375]	Accuracy: 90.00%	Loss: 0.229884
# Train epoch: 6 [220/375]	Accuracy: 87.19%	Loss: 0.271734
# Train epoch: 6 [230/375]	Accuracy: 88.75%	Loss: 0.235053
# Train epoch: 6 [240/375]	Accuracy: 88.44%	Loss: 0.258065
# Train epoch: 6 [250/375]	Accuracy: 89.38%	Loss: 0.215362
# Train epoch: 6 [260/375]	Accuracy: 87.81%	Loss: 0.251896
# Train epoch: 6 [270/375]	Accuracy: 91.56%	Loss: 0.202355
# Train epoch: 6 [280/375]	Accuracy: 88.75%	Loss: 0.257062
# Train epoch: 6 [290/375]	Accuracy: 87.81%	Loss: 0.244086
# Train epoch: 6 [300/375]	Accuracy: 88.75%	Loss: 0.266364
# Train epoch: 6 [310/375]	Accuracy: 87.19%	Loss: 0.281766
# Train epoch: 6 [320/375]	Accuracy: 90.62%	Loss: 0.222697
# Train epoch: 6 [330/375]	Accuracy: 85.94%	Loss: 0.304714
# Train epoch: 6 [340/375]	Accuracy: 84.38%	Loss: 0.300055
# Train epoch: 6 [350/375]	Accuracy: 87.50%	Loss: 0.284384
# Train epoch: 6 [360/375]	Accuracy: 86.88%	Loss: 0.324675
# Train epoch: 6 [370/375]	Accuracy: 87.50%	Loss: 0.266216
# Test set: Loss: 0.1846, Accuracy: 92.21%)
# Train epoch: 7 [10/375]	Accuracy: 89.69%	Loss: 0.252286
# Train epoch: 7 [20/375]	Accuracy: 89.38%	Loss: 0.254707
# Train epoch: 7 [30/375]	Accuracy: 86.56%	Loss: 0.287004
# Train epoch: 7 [40/375]	Accuracy: 89.69%	Loss: 0.230870
# Train epoch: 7 [50/375]	Accuracy: 85.62%	Loss: 0.278055
# Train epoch: 7 [60/375]	Accuracy: 92.50%	Loss: 0.214074
# Train epoch: 7 [70/375]	Accuracy: 90.00%	Loss: 0.221976
# Train epoch: 7 [80/375]	Accuracy: 90.94%	Loss: 0.242623
# Train epoch: 7 [90/375]	Accuracy: 89.06%	Loss: 0.251702
# Train epoch: 7 [100/375]	Accuracy: 88.12%	Loss: 0.260182
# Train epoch: 7 [110/375]	Accuracy: 86.88%	Loss: 0.274828
# Train epoch: 7 [120/375]	Accuracy: 88.75%	Loss: 0.238299
# Train epoch: 7 [130/375]	Accuracy: 87.50%	Loss: 0.287899
# Train epoch: 7 [140/375]	Accuracy: 85.94%	Loss: 0.280446
# Train epoch: 7 [150/375]	Accuracy: 87.81%	Loss: 0.267401
# Train epoch: 7 [160/375]	Accuracy: 86.56%	Loss: 0.300953
# Train epoch: 7 [170/375]	Accuracy: 88.44%	Loss: 0.253145
# Train epoch: 7 [180/375]	Accuracy: 89.06%	Loss: 0.248536
# Train epoch: 7 [190/375]	Accuracy: 89.69%	Loss: 0.238182
# Train epoch: 7 [200/375]	Accuracy: 88.75%	Loss: 0.273447
# Train epoch: 7 [210/375]	Accuracy: 90.00%	Loss: 0.265361
# Train epoch: 7 [220/375]	Accuracy: 86.56%	Loss: 0.275092
# Train epoch: 7 [230/375]	Accuracy: 89.69%	Loss: 0.238814
# Train epoch: 7 [240/375]	Accuracy: 85.62%	Loss: 0.321324
# Train epoch: 7 [250/375]	Accuracy: 86.56%	Loss: 0.282904
# Train epoch: 7 [260/375]	Accuracy: 89.38%	Loss: 0.242012
# Train epoch: 7 [270/375]	Accuracy: 85.62%	Loss: 0.297888
# Train epoch: 7 [280/375]	Accuracy: 84.38%	Loss: 0.308535
# Train epoch: 7 [290/375]	Accuracy: 88.12%	Loss: 0.224464
# Train epoch: 7 [300/375]	Accuracy: 88.12%	Loss: 0.263773
# Train epoch: 7 [310/375]	Accuracy: 87.81%	Loss: 0.273559
# Train epoch: 7 [320/375]	Accuracy: 87.50%	Loss: 0.291108
# Train epoch: 7 [330/375]	Accuracy: 86.25%	Loss: 0.278006
# Train epoch: 7 [340/375]	Accuracy: 88.12%	Loss: 0.253920
# Train epoch: 7 [350/375]	Accuracy: 89.38%	Loss: 0.251102
# Train epoch: 7 [360/375]	Accuracy: 89.06%	Loss: 0.241657
# Train epoch: 7 [370/375]	Accuracy: 90.31%	Loss: 0.232047
# Test set: Loss: 0.2337, Accuracy: 90.28%)
# Train epoch: 8 [10/375]	Accuracy: 89.06%	Loss: 0.267449
# Train epoch: 8 [20/375]	Accuracy: 91.56%	Loss: 0.242747
# Train epoch: 8 [30/375]	Accuracy: 88.12%	Loss: 0.272538
# Train epoch: 8 [40/375]	Accuracy: 88.12%	Loss: 0.274376
# Train epoch: 8 [50/375]	Accuracy: 87.19%	Loss: 0.265610
# Train epoch: 8 [60/375]	Accuracy: 88.12%	Loss: 0.251195
# Train epoch: 8 [70/375]	Accuracy: 82.81%	Loss: 0.308556
# Train epoch: 8 [80/375]	Accuracy: 89.06%	Loss: 0.238383
# Train epoch: 8 [90/375]	Accuracy: 85.94%	Loss: 0.265167
# Train epoch: 8 [100/375]	Accuracy: 88.75%	Loss: 0.233378
# Train epoch: 8 [110/375]	Accuracy: 87.50%	Loss: 0.249057
# Train epoch: 8 [120/375]	Accuracy: 88.12%	Loss: 0.263533
# Train epoch: 8 [130/375]	Accuracy: 89.38%	Loss: 0.246010
# Train epoch: 8 [140/375]	Accuracy: 88.12%	Loss: 0.249317
# Train epoch: 8 [150/375]	Accuracy: 90.00%	Loss: 0.282056
# Train epoch: 8 [160/375]	Accuracy: 85.94%	Loss: 0.297084
# Train epoch: 8 [170/375]	Accuracy: 86.25%	Loss: 0.271669
# Train epoch: 8 [180/375]	Accuracy: 89.06%	Loss: 0.284968
# Train epoch: 8 [190/375]	Accuracy: 85.00%	Loss: 0.296472
# Train epoch: 8 [200/375]	Accuracy: 89.38%	Loss: 0.263564
# Train epoch: 8 [210/375]	Accuracy: 86.88%	Loss: 0.249851
# Train epoch: 8 [220/375]	Accuracy: 86.56%	Loss: 0.256002
# Train epoch: 8 [230/375]	Accuracy: 88.75%	Loss: 0.280628
# Train epoch: 8 [240/375]	Accuracy: 92.19%	Loss: 0.233421
# Train epoch: 8 [250/375]	Accuracy: 89.69%	Loss: 0.236981
# Train epoch: 8 [260/375]	Accuracy: 90.31%	Loss: 0.253579
# Train epoch: 8 [270/375]	Accuracy: 90.31%	Loss: 0.243902
# Train epoch: 8 [280/375]	Accuracy: 88.12%	Loss: 0.268964
# Train epoch: 8 [290/375]	Accuracy: 87.81%	Loss: 0.265648
# Train epoch: 8 [300/375]	Accuracy: 90.62%	Loss: 0.228274
# Train epoch: 8 [310/375]	Accuracy: 90.00%	Loss: 0.247714
# Train epoch: 8 [320/375]	Accuracy: 86.88%	Loss: 0.257227
# Train epoch: 8 [330/375]	Accuracy: 88.75%	Loss: 0.238635
# Train epoch: 8 [340/375]	Accuracy: 91.25%	Loss: 0.221145
# Train epoch: 8 [350/375]	Accuracy: 86.88%	Loss: 0.275835
# Train epoch: 8 [360/375]	Accuracy: 84.69%	Loss: 0.326166
# Train epoch: 8 [370/375]	Accuracy: 87.19%	Loss: 0.258549
# Test set: Loss: 0.2774, Accuracy: 88.19%)
# Train epoch: 9 [10/375]	Accuracy: 89.06%	Loss: 0.244667
# Train epoch: 9 [20/375]	Accuracy: 86.88%	Loss: 0.250213
# Train epoch: 9 [30/375]	Accuracy: 89.06%	Loss: 0.265006
# Train epoch: 9 [40/375]	Accuracy: 89.69%	Loss: 0.280214
# Train epoch: 9 [50/375]	Accuracy: 88.44%	Loss: 0.246501
# Train epoch: 9 [60/375]	Accuracy: 88.44%	Loss: 0.250906
# Train epoch: 9 [70/375]	Accuracy: 89.06%	Loss: 0.266121
# Train epoch: 9 [80/375]	Accuracy: 88.12%	Loss: 0.244228
# Train epoch: 9 [90/375]	Accuracy: 88.12%	Loss: 0.235718
# Train epoch: 9 [100/375]	Accuracy: 86.88%	Loss: 0.252395
# Train epoch: 9 [110/375]	Accuracy: 88.12%	Loss: 0.252940
# Train epoch: 9 [120/375]	Accuracy: 87.19%	Loss: 0.244473
# Train epoch: 9 [130/375]	Accuracy: 86.88%	Loss: 0.308036
# Train epoch: 9 [140/375]	Accuracy: 89.69%	Loss: 0.244538
# Train epoch: 9 [150/375]	Accuracy: 85.62%	Loss: 0.277634
# Train epoch: 9 [160/375]	Accuracy: 88.12%	Loss: 0.268014
# Train epoch: 9 [170/375]	Accuracy: 88.12%	Loss: 0.311831
# Train epoch: 9 [180/375]	Accuracy: 86.88%	Loss: 0.246103
# Train epoch: 9 [190/375]	Accuracy: 88.12%	Loss: 0.278347
# Train epoch: 9 [200/375]	Accuracy: 89.69%	Loss: 0.249750
# Train epoch: 9 [210/375]	Accuracy: 90.94%	Loss: 0.206559
# Train epoch: 9 [220/375]	Accuracy: 87.50%	Loss: 0.298121
# Train epoch: 9 [230/375]	Accuracy: 88.44%	Loss: 0.250118
# Train epoch: 9 [240/375]	Accuracy: 90.31%	Loss: 0.259069
# Train epoch: 9 [250/375]	Accuracy: 88.12%	Loss: 0.256377
# Train epoch: 9 [260/375]	Accuracy: 90.00%	Loss: 0.224860
# Train epoch: 9 [270/375]	Accuracy: 87.81%	Loss: 0.273841
# Train epoch: 9 [280/375]	Accuracy: 85.94%	Loss: 0.297063
# Train epoch: 9 [290/375]	Accuracy: 86.25%	Loss: 0.272153
# Train epoch: 9 [300/375]	Accuracy: 84.06%	Loss: 0.305593
# Train epoch: 9 [310/375]	Accuracy: 86.56%	Loss: 0.288042
# Train epoch: 9 [320/375]	Accuracy: 85.94%	Loss: 0.312078
# Train epoch: 9 [330/375]	Accuracy: 89.06%	Loss: 0.232334
# Train epoch: 9 [340/375]	Accuracy: 89.06%	Loss: 0.263962
# Train epoch: 9 [350/375]	Accuracy: 93.12%	Loss: 0.192559
# Train epoch: 9 [360/375]	Accuracy: 89.06%	Loss: 0.258972
# Train epoch: 9 [370/375]	Accuracy: 88.75%	Loss: 0.263265
# Test set: Loss: 0.2191, Accuracy: 91.62%)
# Train epoch: 10 [10/375]	Accuracy: 89.38%	Loss: 0.234801
# Train epoch: 10 [20/375]	Accuracy: 87.19%	Loss: 0.283086
# Train epoch: 10 [30/375]	Accuracy: 88.75%	Loss: 0.261823
# Train epoch: 10 [40/375]	Accuracy: 85.94%	Loss: 0.259919
# Train epoch: 10 [50/375]	Accuracy: 91.25%	Loss: 0.216573
# Train epoch: 10 [60/375]	Accuracy: 87.50%	Loss: 0.275347
# Train epoch: 10 [70/375]	Accuracy: 88.44%	Loss: 0.238084
# Train epoch: 10 [80/375]	Accuracy: 89.38%	Loss: 0.262475
# Train epoch: 10 [90/375]	Accuracy: 91.88%	Loss: 0.205517
# Train epoch: 10 [100/375]	Accuracy: 90.00%	Loss: 0.236138
# Train epoch: 10 [110/375]	Accuracy: 88.75%	Loss: 0.272041
# Train epoch: 10 [120/375]	Accuracy: 89.69%	Loss: 0.250733
# Train epoch: 10 [130/375]	Accuracy: 87.50%	Loss: 0.285025
# Train epoch: 10 [140/375]	Accuracy: 90.31%	Loss: 0.220003
# Train epoch: 10 [150/375]	Accuracy: 90.94%	Loss: 0.260696
# Train epoch: 10 [160/375]	Accuracy: 85.00%	Loss: 0.326025
# Train epoch: 10 [170/375]	Accuracy: 88.75%	Loss: 0.255374
# Train epoch: 10 [180/375]	Accuracy: 87.50%	Loss: 0.250552
# Train epoch: 10 [190/375]	Accuracy: 89.38%	Loss: 0.235700
# Train epoch: 10 [200/375]	Accuracy: 86.56%	Loss: 0.265468
# Train epoch: 10 [210/375]	Accuracy: 87.50%	Loss: 0.286461
# Train epoch: 10 [220/375]	Accuracy: 86.88%	Loss: 0.284208
# Train epoch: 10 [230/375]	Accuracy: 91.25%	Loss: 0.221475
# Train epoch: 10 [240/375]	Accuracy: 89.69%	Loss: 0.226197
# Train epoch: 10 [250/375]	Accuracy: 90.00%	Loss: 0.242802
# Train epoch: 10 [260/375]	Accuracy: 89.69%	Loss: 0.223600
# Train epoch: 10 [270/375]	Accuracy: 90.00%	Loss: 0.255468
# Train epoch: 10 [280/375]	Accuracy: 88.44%	Loss: 0.262621
# Train epoch: 10 [290/375]	Accuracy: 82.50%	Loss: 0.345758
# Train epoch: 10 [300/375]	Accuracy: 88.44%	Loss: 0.252215
# Train epoch: 10 [310/375]	Accuracy: 89.38%	Loss: 0.227077
# Train epoch: 10 [320/375]	Accuracy: 87.50%	Loss: 0.260729
# Train epoch: 10 [330/375]	Accuracy: 90.31%	Loss: 0.226929
# Train epoch: 10 [340/375]	Accuracy: 86.25%	Loss: 0.297160
# Train epoch: 10 [350/375]	Accuracy: 83.12%	Loss: 0.349630
# Train epoch: 10 [360/375]	Accuracy: 86.56%	Loss: 0.291548
# Train epoch: 10 [370/375]	Accuracy: 86.56%	Loss: 0.272992
# Test set: Loss: 0.2209, Accuracy: 89.63%)
# Train epoch: 11 [10/375]	Accuracy: 88.12%	Loss: 0.234057
# Train epoch: 11 [20/375]	Accuracy: 87.19%	Loss: 0.270711
# Train epoch: 11 [30/375]	Accuracy: 88.44%	Loss: 0.264857
# Train epoch: 11 [40/375]	Accuracy: 86.56%	Loss: 0.279059
# Train epoch: 11 [50/375]	Accuracy: 84.06%	Loss: 0.332120
# Train epoch: 11 [60/375]	Accuracy: 87.81%	Loss: 0.258560
# Train epoch: 11 [70/375]	Accuracy: 89.38%	Loss: 0.227955
# Train epoch: 11 [80/375]	Accuracy: 88.12%	Loss: 0.272296
# Train epoch: 11 [90/375]	Accuracy: 88.12%	Loss: 0.255571
# Train epoch: 11 [100/375]	Accuracy: 89.69%	Loss: 0.230362
# Train epoch: 11 [110/375]	Accuracy: 90.00%	Loss: 0.239376
# Train epoch: 11 [120/375]	Accuracy: 89.38%	Loss: 0.230913
# Train epoch: 11 [130/375]	Accuracy: 87.50%	Loss: 0.268911
# Train epoch: 11 [140/375]	Accuracy: 88.44%	Loss: 0.242777
# Train epoch: 11 [150/375]	Accuracy: 88.44%	Loss: 0.261362
# Train epoch: 11 [160/375]	Accuracy: 92.19%	Loss: 0.211323
# Train epoch: 11 [170/375]	Accuracy: 89.69%	Loss: 0.237656
# Train epoch: 11 [180/375]	Accuracy: 87.50%	Loss: 0.267311
# Train epoch: 11 [190/375]	Accuracy: 88.75%	Loss: 0.242777
# Train epoch: 11 [200/375]	Accuracy: 90.62%	Loss: 0.204316
# Train epoch: 11 [210/375]	Accuracy: 90.94%	Loss: 0.233168
# Train epoch: 11 [220/375]	Accuracy: 88.12%	Loss: 0.241825
# Train epoch: 11 [230/375]	Accuracy: 87.19%	Loss: 0.266677
# Train epoch: 11 [240/375]	Accuracy: 86.56%	Loss: 0.262400
# Train epoch: 11 [250/375]	Accuracy: 87.50%	Loss: 0.301687
# Train epoch: 11 [260/375]	Accuracy: 86.25%	Loss: 0.283366
# Train epoch: 11 [270/375]	Accuracy: 90.00%	Loss: 0.229043
# Train epoch: 11 [280/375]	Accuracy: 84.06%	Loss: 0.314121
# Train epoch: 11 [290/375]	Accuracy: 83.75%	Loss: 0.339969
# Train epoch: 11 [300/375]	Accuracy: 86.88%	Loss: 0.271672
# Train epoch: 11 [310/375]	Accuracy: 91.25%	Loss: 0.202811
# Train epoch: 11 [320/375]	Accuracy: 87.19%	Loss: 0.255022
# Train epoch: 11 [330/375]	Accuracy: 87.50%	Loss: 0.268864
# Train epoch: 11 [340/375]	Accuracy: 86.25%	Loss: 0.295124
# Train epoch: 11 [350/375]	Accuracy: 90.00%	Loss: 0.233389
# Train epoch: 11 [360/375]	Accuracy: 88.12%	Loss: 0.244593
# Train epoch: 11 [370/375]	Accuracy: 86.56%	Loss: 0.267310
# Test set: Loss: 0.1979, Accuracy: 91.72%)
# Train epoch: 12 [10/375]	Accuracy: 87.19%	Loss: 0.279947
# Train epoch: 12 [20/375]	Accuracy: 88.12%	Loss: 0.266905
# Train epoch: 12 [30/375]	Accuracy: 87.19%	Loss: 0.264235
# Train epoch: 12 [40/375]	Accuracy: 87.50%	Loss: 0.262281
# Train epoch: 12 [50/375]	Accuracy: 90.62%	Loss: 0.219258
# Train epoch: 12 [60/375]	Accuracy: 90.62%	Loss: 0.232133
# Train epoch: 12 [70/375]	Accuracy: 89.69%	Loss: 0.273131
# Train epoch: 12 [80/375]	Accuracy: 89.38%	Loss: 0.236856
# Train epoch: 12 [90/375]	Accuracy: 88.75%	Loss: 0.260168
# Train epoch: 12 [100/375]	Accuracy: 91.88%	Loss: 0.217609
# Train epoch: 12 [110/375]	Accuracy: 87.19%	Loss: 0.268306
# Train epoch: 12 [120/375]	Accuracy: 86.25%	Loss: 0.286545
# Train epoch: 12 [130/375]	Accuracy: 89.06%	Loss: 0.229754
# Train epoch: 12 [140/375]	Accuracy: 88.75%	Loss: 0.243096
# Train epoch: 12 [150/375]	Accuracy: 87.50%	Loss: 0.261807
# Train epoch: 12 [160/375]	Accuracy: 90.62%	Loss: 0.266277
# Train epoch: 12 [170/375]	Accuracy: 88.75%	Loss: 0.237688
# Train epoch: 12 [180/375]	Accuracy: 91.25%	Loss: 0.212593
# Train epoch: 12 [190/375]	Accuracy: 86.88%	Loss: 0.268224
# Train epoch: 12 [200/375]	Accuracy: 89.38%	Loss: 0.233429
# Train epoch: 12 [210/375]	Accuracy: 85.94%	Loss: 0.298735
# Train epoch: 12 [220/375]	Accuracy: 86.88%	Loss: 0.271623
# Train epoch: 12 [230/375]	Accuracy: 86.88%	Loss: 0.255036
# Train epoch: 12 [240/375]	Accuracy: 87.81%	Loss: 0.278003
# Train epoch: 12 [250/375]	Accuracy: 87.50%	Loss: 0.248400
# Train epoch: 12 [260/375]	Accuracy: 92.19%	Loss: 0.200027
# Train epoch: 12 [270/375]	Accuracy: 86.88%	Loss: 0.325948
# Train epoch: 12 [280/375]	Accuracy: 88.75%	Loss: 0.239071
# Train epoch: 12 [290/375]	Accuracy: 87.19%	Loss: 0.261940
# Train epoch: 12 [300/375]	Accuracy: 88.12%	Loss: 0.293949
# Train epoch: 12 [310/375]	Accuracy: 86.56%	Loss: 0.285880
# Train epoch: 12 [320/375]	Accuracy: 86.88%	Loss: 0.267782
# Train epoch: 12 [330/375]	Accuracy: 86.88%	Loss: 0.268020
# Train epoch: 12 [340/375]	Accuracy: 88.12%	Loss: 0.266603
# Train epoch: 12 [350/375]	Accuracy: 87.81%	Loss: 0.285061
# Train epoch: 12 [360/375]	Accuracy: 86.56%	Loss: 0.280800
# Train epoch: 12 [370/375]	Accuracy: 86.25%	Loss: 0.286825
# Test set: Loss: 0.1896, Accuracy: 91.47%)
# Train epoch: 13 [10/375]	Accuracy: 90.94%	Loss: 0.235646
# Train epoch: 13 [20/375]	Accuracy: 90.31%	Loss: 0.221851
# Train epoch: 13 [30/375]	Accuracy: 91.25%	Loss: 0.212217
# Train epoch: 13 [40/375]	Accuracy: 90.94%	Loss: 0.240827
# Train epoch: 13 [50/375]	Accuracy: 88.44%	Loss: 0.255256
# Train epoch: 13 [60/375]	Accuracy: 87.81%	Loss: 0.245153
# Train epoch: 13 [70/375]	Accuracy: 90.94%	Loss: 0.237454
# Train epoch: 13 [80/375]	Accuracy: 86.88%	Loss: 0.267882
# Train epoch: 13 [90/375]	Accuracy: 88.75%	Loss: 0.273826
# Train epoch: 13 [100/375]	Accuracy: 85.94%	Loss: 0.266556
# Train epoch: 13 [110/375]	Accuracy: 89.06%	Loss: 0.245855
# Train epoch: 13 [120/375]	Accuracy: 88.75%	Loss: 0.265327
# Train epoch: 13 [130/375]	Accuracy: 90.62%	Loss: 0.233900
# Train epoch: 13 [140/375]	Accuracy: 89.69%	Loss: 0.232965
# Train epoch: 13 [150/375]	Accuracy: 90.00%	Loss: 0.230184
# Train epoch: 13 [160/375]	Accuracy: 86.56%	Loss: 0.279475
# Train epoch: 13 [170/375]	Accuracy: 90.94%	Loss: 0.218780
# Train epoch: 13 [180/375]	Accuracy: 87.50%	Loss: 0.254841
# Train epoch: 13 [190/375]	Accuracy: 90.62%	Loss: 0.247558
# Train epoch: 13 [200/375]	Accuracy: 88.44%	Loss: 0.258273
# Train epoch: 13 [210/375]	Accuracy: 87.19%	Loss: 0.284356
# Train epoch: 13 [220/375]	Accuracy: 86.25%	Loss: 0.276460
# Train epoch: 13 [230/375]	Accuracy: 88.75%	Loss: 0.243768
# Train epoch: 13 [240/375]	Accuracy: 89.69%	Loss: 0.229576
# Train epoch: 13 [250/375]	Accuracy: 86.25%	Loss: 0.266478
# Train epoch: 13 [260/375]	Accuracy: 87.81%	Loss: 0.260680
# Train epoch: 13 [270/375]	Accuracy: 90.00%	Loss: 0.241864
# Train epoch: 13 [280/375]	Accuracy: 90.31%	Loss: 0.227702
# Train epoch: 13 [290/375]	Accuracy: 85.94%	Loss: 0.257308
# Train epoch: 13 [300/375]	Accuracy: 86.25%	Loss: 0.290019
# Train epoch: 13 [310/375]	Accuracy: 87.81%	Loss: 0.248329
# Train epoch: 13 [320/375]	Accuracy: 86.88%	Loss: 0.272334
# Train epoch: 13 [330/375]	Accuracy: 88.12%	Loss: 0.242805
# Train epoch: 13 [340/375]	Accuracy: 91.88%	Loss: 0.223801
# Train epoch: 13 [350/375]	Accuracy: 88.12%	Loss: 0.255953
# Train epoch: 13 [360/375]	Accuracy: 85.94%	Loss: 0.280892
# Train epoch: 13 [370/375]	Accuracy: 87.19%	Loss: 0.272487
# Test set: Loss: 0.2048, Accuracy: 90.62%)
# Train epoch: 14 [10/375]	Accuracy: 89.06%	Loss: 0.224280
# Train epoch: 14 [20/375]	Accuracy: 88.75%	Loss: 0.281156
# Train epoch: 14 [30/375]	Accuracy: 88.12%	Loss: 0.246504
# Train epoch: 14 [40/375]	Accuracy: 90.94%	Loss: 0.240246
# Train epoch: 14 [50/375]	Accuracy: 86.88%	Loss: 0.257837
# Train epoch: 14 [60/375]	Accuracy: 83.75%	Loss: 0.304449
# Train epoch: 14 [70/375]	Accuracy: 87.81%	Loss: 0.268059
# Train epoch: 14 [80/375]	Accuracy: 89.38%	Loss: 0.252253
# Train epoch: 14 [90/375]	Accuracy: 87.50%	Loss: 0.259607
# Train epoch: 14 [100/375]	Accuracy: 91.56%	Loss: 0.200640
# Train epoch: 14 [110/375]	Accuracy: 88.12%	Loss: 0.243602
# Train epoch: 14 [120/375]	Accuracy: 87.81%	Loss: 0.238002
# Train epoch: 14 [130/375]	Accuracy: 85.00%	Loss: 0.320089
# Train epoch: 14 [140/375]	Accuracy: 88.12%	Loss: 0.274523
# Train epoch: 14 [150/375]	Accuracy: 88.12%	Loss: 0.237572
# Train epoch: 14 [160/375]	Accuracy: 91.56%	Loss: 0.211430
# Train epoch: 14 [170/375]	Accuracy: 92.19%	Loss: 0.225881
# Train epoch: 14 [180/375]	Accuracy: 87.50%	Loss: 0.267757
# Train epoch: 14 [190/375]	Accuracy: 88.75%	Loss: 0.245214
# Train epoch: 14 [200/375]	Accuracy: 89.06%	Loss: 0.247703
# Train epoch: 14 [210/375]	Accuracy: 84.38%	Loss: 0.330831
# Train epoch: 14 [220/375]	Accuracy: 88.44%	Loss: 0.256941
# Train epoch: 14 [230/375]	Accuracy: 88.44%	Loss: 0.233251
# Train epoch: 14 [240/375]	Accuracy: 89.38%	Loss: 0.240796
# Train epoch: 14 [250/375]	Accuracy: 91.56%	Loss: 0.212111
# Train epoch: 14 [260/375]	Accuracy: 89.69%	Loss: 0.244344
# Train epoch: 14 [270/375]	Accuracy: 83.75%	Loss: 0.344747
# Train epoch: 14 [280/375]	Accuracy: 89.06%	Loss: 0.256684
# Train epoch: 14 [290/375]	Accuracy: 89.06%	Loss: 0.221607
# Train epoch: 14 [300/375]	Accuracy: 88.75%	Loss: 0.241775
# Train epoch: 14 [310/375]	Accuracy: 87.81%	Loss: 0.256803
# Train epoch: 14 [320/375]	Accuracy: 89.69%	Loss: 0.240870
# Train epoch: 14 [330/375]	Accuracy: 89.69%	Loss: 0.230584
# Train epoch: 14 [340/375]	Accuracy: 85.94%	Loss: 0.283804
# Train epoch: 14 [350/375]	Accuracy: 86.88%	Loss: 0.274225
# Train epoch: 14 [360/375]	Accuracy: 89.06%	Loss: 0.272039
# Train epoch: 14 [370/375]	Accuracy: 89.69%	Loss: 0.222969
# Test set: Loss: 0.2231, Accuracy: 90.23%)
# Train epoch: 15 [10/375]	Accuracy: 85.00%	Loss: 0.263358
# Train epoch: 15 [20/375]	Accuracy: 86.88%	Loss: 0.238462
# Train epoch: 15 [30/375]	Accuracy: 87.19%	Loss: 0.253229
# Train epoch: 15 [40/375]	Accuracy: 88.12%	Loss: 0.275047
# Train epoch: 15 [50/375]	Accuracy: 90.94%	Loss: 0.206244
# Train epoch: 15 [60/375]	Accuracy: 88.75%	Loss: 0.268600
# Train epoch: 15 [70/375]	Accuracy: 86.25%	Loss: 0.300010
# Train epoch: 15 [80/375]	Accuracy: 87.81%	Loss: 0.269767
# Train epoch: 15 [90/375]	Accuracy: 90.62%	Loss: 0.259689
# Train epoch: 15 [100/375]	Accuracy: 91.56%	Loss: 0.222592
# Train epoch: 15 [110/375]	Accuracy: 85.31%	Loss: 0.310548
# Train epoch: 15 [120/375]	Accuracy: 89.69%	Loss: 0.244412
# Train epoch: 15 [130/375]	Accuracy: 90.62%	Loss: 0.229975
# Train epoch: 15 [140/375]	Accuracy: 90.00%	Loss: 0.254186
# Train epoch: 15 [150/375]	Accuracy: 90.00%	Loss: 0.205845
# Train epoch: 15 [160/375]	Accuracy: 86.25%	Loss: 0.279444
# Train epoch: 15 [170/375]	Accuracy: 87.19%	Loss: 0.243526
# Train epoch: 15 [180/375]	Accuracy: 90.94%	Loss: 0.206418
# Train epoch: 15 [190/375]	Accuracy: 86.88%	Loss: 0.273954
# Train epoch: 15 [200/375]	Accuracy: 89.69%	Loss: 0.239271
# Train epoch: 15 [210/375]	Accuracy: 87.19%	Loss: 0.266639
# Train epoch: 15 [220/375]	Accuracy: 89.38%	Loss: 0.242211
# Train epoch: 15 [230/375]	Accuracy: 87.81%	Loss: 0.256370
# Train epoch: 15 [240/375]	Accuracy: 90.00%	Loss: 0.232387
# Train epoch: 15 [250/375]	Accuracy: 90.00%	Loss: 0.230581
# Train epoch: 15 [260/375]	Accuracy: 89.69%	Loss: 0.256922
# Train epoch: 15 [270/375]	Accuracy: 84.38%	Loss: 0.333668
# Train epoch: 15 [280/375]	Accuracy: 85.31%	Loss: 0.319135
# Train epoch: 15 [290/375]	Accuracy: 85.00%	Loss: 0.286719
# Train epoch: 15 [300/375]	Accuracy: 87.50%	Loss: 0.243094
# Train epoch: 15 [310/375]	Accuracy: 88.12%	Loss: 0.254778
# Train epoch: 15 [320/375]	Accuracy: 89.06%	Loss: 0.243526
# Train epoch: 15 [330/375]	Accuracy: 89.06%	Loss: 0.228891
# Train epoch: 15 [340/375]	Accuracy: 88.44%	Loss: 0.261089
# Train epoch: 15 [350/375]	Accuracy: 89.38%	Loss: 0.243914
# Train epoch: 15 [360/375]	Accuracy: 89.06%	Loss: 0.255779
# Train epoch: 15 [370/375]	Accuracy: 87.50%	Loss: 0.247022
# Test set: Loss: 0.1899, Accuracy: 91.67%)
# Train epoch: 16 [10/375]	Accuracy: 87.81%	Loss: 0.276729
# Train epoch: 16 [20/375]	Accuracy: 88.44%	Loss: 0.245964
# Train epoch: 16 [30/375]	Accuracy: 87.50%	Loss: 0.237913
# Train epoch: 16 [40/375]	Accuracy: 90.00%	Loss: 0.229233
# Train epoch: 16 [50/375]	Accuracy: 86.25%	Loss: 0.283317
# Train epoch: 16 [60/375]	Accuracy: 87.50%	Loss: 0.279486
# Train epoch: 16 [70/375]	Accuracy: 91.56%	Loss: 0.200462
# Train epoch: 16 [80/375]	Accuracy: 87.19%	Loss: 0.264130
# Train epoch: 16 [90/375]	Accuracy: 88.75%	Loss: 0.244289
# Train epoch: 16 [100/375]	Accuracy: 84.38%	Loss: 0.303022
# Train epoch: 16 [110/375]	Accuracy: 91.25%	Loss: 0.246546
# Train epoch: 16 [120/375]	Accuracy: 89.06%	Loss: 0.285617
# Train epoch: 16 [130/375]	Accuracy: 87.50%	Loss: 0.262122
# Train epoch: 16 [140/375]	Accuracy: 89.06%	Loss: 0.244312
# Train epoch: 16 [150/375]	Accuracy: 88.12%	Loss: 0.273485
# Train epoch: 16 [160/375]	Accuracy: 90.00%	Loss: 0.238249
# Train epoch: 16 [170/375]	Accuracy: 86.25%	Loss: 0.253725
# Train epoch: 16 [180/375]	Accuracy: 85.94%	Loss: 0.271246
# Train epoch: 16 [190/375]	Accuracy: 88.12%	Loss: 0.250165
# Train epoch: 16 [200/375]	Accuracy: 88.12%	Loss: 0.275130
# Train epoch: 16 [210/375]	Accuracy: 87.19%	Loss: 0.236033
# Train epoch: 16 [220/375]	Accuracy: 88.44%	Loss: 0.282411
# Train epoch: 16 [230/375]	Accuracy: 89.38%	Loss: 0.248327
# Train epoch: 16 [240/375]	Accuracy: 87.19%	Loss: 0.279488
# Train epoch: 16 [250/375]	Accuracy: 87.19%	Loss: 0.323609
# Train epoch: 16 [260/375]	Accuracy: 91.88%	Loss: 0.195495
# Train epoch: 16 [270/375]	Accuracy: 90.62%	Loss: 0.217289
# Train epoch: 16 [280/375]	Accuracy: 90.94%	Loss: 0.222748
# Train epoch: 16 [290/375]	Accuracy: 90.00%	Loss: 0.234925
# Train epoch: 16 [300/375]	Accuracy: 88.12%	Loss: 0.249178
# Train epoch: 16 [310/375]	Accuracy: 91.88%	Loss: 0.223113
# Train epoch: 16 [320/375]	Accuracy: 90.31%	Loss: 0.228401
# Train epoch: 16 [330/375]	Accuracy: 89.06%	Loss: 0.252451
# Train epoch: 16 [340/375]	Accuracy: 85.62%	Loss: 0.303674
# Train epoch: 16 [350/375]	Accuracy: 87.19%	Loss: 0.277393
# Train epoch: 16 [360/375]	Accuracy: 86.56%	Loss: 0.275105
# Train epoch: 16 [370/375]	Accuracy: 88.12%	Loss: 0.245998
# Test set: Loss: 0.2447, Accuracy: 88.44%)
# Train epoch: 17 [10/375]	Accuracy: 91.56%	Loss: 0.211060
# Train epoch: 17 [20/375]	Accuracy: 88.75%	Loss: 0.278275
# Train epoch: 17 [30/375]	Accuracy: 88.12%	Loss: 0.251440
# Train epoch: 17 [40/375]	Accuracy: 87.81%	Loss: 0.262444
# Train epoch: 17 [50/375]	Accuracy: 86.56%	Loss: 0.257914
# Train epoch: 17 [60/375]	Accuracy: 89.69%	Loss: 0.225987
# Train epoch: 17 [70/375]	Accuracy: 90.00%	Loss: 0.242744
# Train epoch: 17 [80/375]	Accuracy: 89.38%	Loss: 0.231116
# Train epoch: 17 [90/375]	Accuracy: 88.12%	Loss: 0.222908
# Train epoch: 17 [100/375]	Accuracy: 87.81%	Loss: 0.303567
# Train epoch: 17 [110/375]	Accuracy: 86.25%	Loss: 0.285500
# Train epoch: 17 [120/375]	Accuracy: 89.69%	Loss: 0.258480
# Train epoch: 17 [130/375]	Accuracy: 85.94%	Loss: 0.274251
# Train epoch: 17 [140/375]	Accuracy: 84.06%	Loss: 0.308657
# Train epoch: 17 [150/375]	Accuracy: 88.12%	Loss: 0.247706
# Train epoch: 17 [160/375]	Accuracy: 86.56%	Loss: 0.271336
# Train epoch: 17 [170/375]	Accuracy: 87.50%	Loss: 0.291925
# Train epoch: 17 [180/375]	Accuracy: 88.12%	Loss: 0.230108
# Train epoch: 17 [190/375]	Accuracy: 86.56%	Loss: 0.276917
# Train epoch: 17 [200/375]	Accuracy: 87.50%	Loss: 0.253832
# Train epoch: 17 [210/375]	Accuracy: 89.06%	Loss: 0.230098
# Train epoch: 17 [220/375]	Accuracy: 87.50%	Loss: 0.263884
# Train epoch: 17 [230/375]	Accuracy: 90.62%	Loss: 0.234396
# Train epoch: 17 [240/375]	Accuracy: 87.81%	Loss: 0.239392
# Train epoch: 17 [250/375]	Accuracy: 87.19%	Loss: 0.267862
# Train epoch: 17 [260/375]	Accuracy: 87.50%	Loss: 0.268946
# Train epoch: 17 [270/375]	Accuracy: 90.62%	Loss: 0.233446
# Train epoch: 17 [280/375]	Accuracy: 89.69%	Loss: 0.232632
# Train epoch: 17 [290/375]	Accuracy: 88.75%	Loss: 0.241793
# Train epoch: 17 [300/375]	Accuracy: 86.88%	Loss: 0.303490
# Train epoch: 17 [310/375]	Accuracy: 87.50%	Loss: 0.314206
# Train epoch: 17 [320/375]	Accuracy: 86.56%	Loss: 0.271806
# Train epoch: 17 [330/375]	Accuracy: 86.25%	Loss: 0.319231
# Train epoch: 17 [340/375]	Accuracy: 84.38%	Loss: 0.287676
# Train epoch: 17 [350/375]	Accuracy: 85.94%	Loss: 0.274085
# Train epoch: 17 [360/375]	Accuracy: 89.69%	Loss: 0.236547
# Train epoch: 17 [370/375]	Accuracy: 90.94%	Loss: 0.240820
# Test set: Loss: 0.2891, Accuracy: 86.01%)
# Epoch    17: reducing learning rate of group 0 to 3.0000e-04.
# Train epoch: 18 [10/375]	Accuracy: 90.62%	Loss: 0.211625
# Train epoch: 18 [20/375]	Accuracy: 89.69%	Loss: 0.241498
# Train epoch: 18 [30/375]	Accuracy: 89.38%	Loss: 0.265356
# Train epoch: 18 [40/375]	Accuracy: 88.75%	Loss: 0.230526
# Train epoch: 18 [50/375]	Accuracy: 87.50%	Loss: 0.287374
# Train epoch: 18 [60/375]	Accuracy: 89.38%	Loss: 0.229876
# Train epoch: 18 [70/375]	Accuracy: 90.31%	Loss: 0.228088
# Train epoch: 18 [80/375]	Accuracy: 91.88%	Loss: 0.200559
# Train epoch: 18 [90/375]	Accuracy: 91.25%	Loss: 0.198188
# Train epoch: 18 [100/375]	Accuracy: 90.00%	Loss: 0.220520
# Train epoch: 18 [110/375]	Accuracy: 90.62%	Loss: 0.220405
# Train epoch: 18 [120/375]	Accuracy: 90.94%	Loss: 0.213441
# Train epoch: 18 [130/375]	Accuracy: 87.81%	Loss: 0.256635
# Train epoch: 18 [140/375]	Accuracy: 87.50%	Loss: 0.275361
# Train epoch: 18 [150/375]	Accuracy: 86.25%	Loss: 0.273866
# Train epoch: 18 [160/375]	Accuracy: 91.25%	Loss: 0.199895
# Train epoch: 18 [170/375]	Accuracy: 87.81%	Loss: 0.239670
# Train epoch: 18 [180/375]	Accuracy: 92.50%	Loss: 0.200931
# Train epoch: 18 [190/375]	Accuracy: 91.25%	Loss: 0.205846
# Train epoch: 18 [200/375]	Accuracy: 93.44%	Loss: 0.168372
# Train epoch: 18 [210/375]	Accuracy: 90.62%	Loss: 0.227643
# Train epoch: 18 [220/375]	Accuracy: 90.00%	Loss: 0.212963
# Train epoch: 18 [230/375]	Accuracy: 90.94%	Loss: 0.206147
# Train epoch: 18 [240/375]	Accuracy: 86.88%	Loss: 0.265925
# Train epoch: 18 [250/375]	Accuracy: 93.12%	Loss: 0.200581
# Train epoch: 18 [260/375]	Accuracy: 87.50%	Loss: 0.274848
# Train epoch: 18 [270/375]	Accuracy: 90.62%	Loss: 0.235288
# Train epoch: 18 [280/375]	Accuracy: 89.38%	Loss: 0.265499
# Train epoch: 18 [290/375]	Accuracy: 90.62%	Loss: 0.216157
# Train epoch: 18 [300/375]	Accuracy: 89.69%	Loss: 0.223317
# Train epoch: 18 [310/375]	Accuracy: 89.06%	Loss: 0.226361
# Train epoch: 18 [320/375]	Accuracy: 89.38%	Loss: 0.235217
# Train epoch: 18 [330/375]	Accuracy: 89.38%	Loss: 0.227731
# Train epoch: 18 [340/375]	Accuracy: 90.00%	Loss: 0.233070
# Train epoch: 18 [350/375]	Accuracy: 90.94%	Loss: 0.220601
# Train epoch: 18 [360/375]	Accuracy: 89.06%	Loss: 0.223754
# Train epoch: 18 [370/375]	Accuracy: 90.94%	Loss: 0.232547
# Test set: Loss: 0.1974, Accuracy: 90.72%)
# Train epoch: 19 [10/375]	Accuracy: 86.88%	Loss: 0.245167
# Train epoch: 19 [20/375]	Accuracy: 91.88%	Loss: 0.221368
# Train epoch: 19 [30/375]	Accuracy: 90.31%	Loss: 0.225207
# Train epoch: 19 [40/375]	Accuracy: 90.94%	Loss: 0.200859
# Train epoch: 19 [50/375]	Accuracy: 90.31%	Loss: 0.203151
# Train epoch: 19 [60/375]	Accuracy: 88.12%	Loss: 0.243070
# Train epoch: 19 [70/375]	Accuracy: 88.75%	Loss: 0.225183
# Train epoch: 19 [80/375]	Accuracy: 90.62%	Loss: 0.213460
# Train epoch: 19 [90/375]	Accuracy: 91.88%	Loss: 0.208239
# Train epoch: 19 [100/375]	Accuracy: 91.25%	Loss: 0.218608
# Train epoch: 19 [110/375]	Accuracy: 89.38%	Loss: 0.236106
# Train epoch: 19 [120/375]	Accuracy: 90.31%	Loss: 0.203241
# Train epoch: 19 [130/375]	Accuracy: 89.06%	Loss: 0.244025
# Train epoch: 19 [140/375]	Accuracy: 88.75%	Loss: 0.286592
# Train epoch: 19 [150/375]	Accuracy: 89.38%	Loss: 0.219131
# Train epoch: 19 [160/375]	Accuracy: 92.19%	Loss: 0.210009
# Train epoch: 19 [170/375]	Accuracy: 93.12%	Loss: 0.195668
# Train epoch: 19 [180/375]	Accuracy: 95.00%	Loss: 0.179119
# Train epoch: 19 [190/375]	Accuracy: 88.12%	Loss: 0.257639
# Train epoch: 19 [200/375]	Accuracy: 87.19%	Loss: 0.279732
# Train epoch: 19 [210/375]	Accuracy: 92.81%	Loss: 0.194728
# Train epoch: 19 [220/375]	Accuracy: 89.38%	Loss: 0.244732
# Train epoch: 19 [230/375]	Accuracy: 90.31%	Loss: 0.218897
# Train epoch: 19 [240/375]	Accuracy: 90.62%	Loss: 0.226364
# Train epoch: 19 [250/375]	Accuracy: 88.75%	Loss: 0.240739
# Train epoch: 19 [260/375]	Accuracy: 90.31%	Loss: 0.213192
# Train epoch: 19 [270/375]	Accuracy: 89.69%	Loss: 0.226036
# Train epoch: 19 [280/375]	Accuracy: 90.62%	Loss: 0.212421
# Train epoch: 19 [290/375]	Accuracy: 86.88%	Loss: 0.269082
# Train epoch: 19 [300/375]	Accuracy: 88.12%	Loss: 0.245027
# Train epoch: 19 [310/375]	Accuracy: 92.50%	Loss: 0.191309
# Train epoch: 19 [320/375]	Accuracy: 92.81%	Loss: 0.182635
# Train epoch: 19 [330/375]	Accuracy: 89.69%	Loss: 0.218036
# Train epoch: 19 [340/375]	Accuracy: 90.94%	Loss: 0.210921
# Train epoch: 19 [350/375]	Accuracy: 90.62%	Loss: 0.208953
# Train epoch: 19 [360/375]	Accuracy: 89.69%	Loss: 0.245492
# Train epoch: 19 [370/375]	Accuracy: 90.94%	Loss: 0.209291
# Test set: Loss: 0.1592, Accuracy: 92.81%)
# Train epoch: 20 [10/375]	Accuracy: 90.00%	Loss: 0.249051
# Train epoch: 20 [20/375]	Accuracy: 89.69%	Loss: 0.220834
# Train epoch: 20 [30/375]	Accuracy: 91.88%	Loss: 0.202993
# Train epoch: 20 [40/375]	Accuracy: 90.62%	Loss: 0.221155
# Train epoch: 20 [50/375]	Accuracy: 90.31%	Loss: 0.223932
# Train epoch: 20 [60/375]	Accuracy: 88.12%	Loss: 0.237493
# Train epoch: 20 [70/375]	Accuracy: 89.06%	Loss: 0.259392
# Train epoch: 20 [80/375]	Accuracy: 90.62%	Loss: 0.210444
# Train epoch: 20 [90/375]	Accuracy: 90.94%	Loss: 0.218678
# Train epoch: 20 [100/375]	Accuracy: 87.19%	Loss: 0.244527
# Train epoch: 20 [110/375]	Accuracy: 92.19%	Loss: 0.195011
# Train epoch: 20 [120/375]	Accuracy: 90.94%	Loss: 0.222908
# Train epoch: 20 [130/375]	Accuracy: 92.81%	Loss: 0.195829
# Train epoch: 20 [140/375]	Accuracy: 90.00%	Loss: 0.213630
# Train epoch: 20 [150/375]	Accuracy: 89.38%	Loss: 0.247492
# Train epoch: 20 [160/375]	Accuracy: 90.62%	Loss: 0.198400
# Train epoch: 20 [170/375]	Accuracy: 90.62%	Loss: 0.210771
# Train epoch: 20 [180/375]	Accuracy: 88.44%	Loss: 0.237683
# Train epoch: 20 [190/375]	Accuracy: 91.25%	Loss: 0.227503
# Train epoch: 20 [200/375]	Accuracy: 87.50%	Loss: 0.263983
# Train epoch: 20 [210/375]	Accuracy: 88.75%	Loss: 0.223017
# Train epoch: 20 [220/375]	Accuracy: 88.44%	Loss: 0.268700
# Train epoch: 20 [230/375]	Accuracy: 87.50%	Loss: 0.241287
# Train epoch: 20 [240/375]	Accuracy: 89.69%	Loss: 0.229450
# Train epoch: 20 [250/375]	Accuracy: 89.38%	Loss: 0.247690
# Train epoch: 20 [260/375]	Accuracy: 90.94%	Loss: 0.216652
# Train epoch: 20 [270/375]	Accuracy: 88.75%	Loss: 0.254570
# Train epoch: 20 [280/375]	Accuracy: 90.31%	Loss: 0.234998
# Train epoch: 20 [290/375]	Accuracy: 90.62%	Loss: 0.208764
# Train epoch: 20 [300/375]	Accuracy: 89.38%	Loss: 0.228000
# Train epoch: 20 [310/375]	Accuracy: 90.00%	Loss: 0.219706
# Train epoch: 20 [320/375]	Accuracy: 91.56%	Loss: 0.203110
# Train epoch: 20 [330/375]	Accuracy: 94.06%	Loss: 0.174374
# Train epoch: 20 [340/375]	Accuracy: 91.88%	Loss: 0.202283
# Train epoch: 20 [350/375]	Accuracy: 91.25%	Loss: 0.221902
# Train epoch: 20 [360/375]	Accuracy: 89.69%	Loss: 0.226936
# Train epoch: 20 [370/375]	Accuracy: 91.56%	Loss: 0.221199
# Test set: Loss: 0.1907, Accuracy: 91.91%)
# Train epoch: 21 [10/375]	Accuracy: 93.44%	Loss: 0.191886
# Train epoch: 21 [20/375]	Accuracy: 90.94%	Loss: 0.208973
# Train epoch: 21 [30/375]	Accuracy: 89.69%	Loss: 0.212983
# Train epoch: 21 [40/375]	Accuracy: 88.75%	Loss: 0.223108
# Train epoch: 21 [50/375]	Accuracy: 90.94%	Loss: 0.240809
# Train epoch: 21 [60/375]	Accuracy: 90.94%	Loss: 0.200517
# Train epoch: 21 [70/375]	Accuracy: 90.31%	Loss: 0.220393
# Train epoch: 21 [80/375]	Accuracy: 88.44%	Loss: 0.259362
# Train epoch: 21 [90/375]	Accuracy: 86.88%	Loss: 0.260608
# Train epoch: 21 [100/375]	Accuracy: 88.75%	Loss: 0.246726
# Train epoch: 21 [110/375]	Accuracy: 90.00%	Loss: 0.217827
# Train epoch: 21 [120/375]	Accuracy: 89.38%	Loss: 0.231853
# Train epoch: 21 [130/375]	Accuracy: 90.00%	Loss: 0.211798
# Train epoch: 21 [140/375]	Accuracy: 88.44%	Loss: 0.228792
# Train epoch: 21 [150/375]	Accuracy: 89.38%	Loss: 0.203685
# Train epoch: 21 [160/375]	Accuracy: 89.38%	Loss: 0.220171
# Train epoch: 21 [170/375]	Accuracy: 90.62%	Loss: 0.221059
# Train epoch: 21 [180/375]	Accuracy: 90.94%	Loss: 0.193618
# Train epoch: 21 [190/375]	Accuracy: 88.44%	Loss: 0.224457
# Train epoch: 21 [200/375]	Accuracy: 90.00%	Loss: 0.221221
# Train epoch: 21 [210/375]	Accuracy: 88.12%	Loss: 0.253437
# Train epoch: 21 [220/375]	Accuracy: 88.12%	Loss: 0.234384
# Train epoch: 21 [230/375]	Accuracy: 87.81%	Loss: 0.251360
# Train epoch: 21 [240/375]	Accuracy: 90.94%	Loss: 0.205769
# Train epoch: 21 [250/375]	Accuracy: 90.00%	Loss: 0.208816
# Train epoch: 21 [260/375]	Accuracy: 89.69%	Loss: 0.231939
# Train epoch: 21 [270/375]	Accuracy: 93.75%	Loss: 0.163313
# Train epoch: 21 [280/375]	Accuracy: 88.75%	Loss: 0.218271
# Train epoch: 21 [290/375]	Accuracy: 89.38%	Loss: 0.230710
# Train epoch: 21 [300/375]	Accuracy: 90.31%	Loss: 0.259576
# Train epoch: 21 [310/375]	Accuracy: 89.69%	Loss: 0.216152
# Train epoch: 21 [320/375]	Accuracy: 91.25%	Loss: 0.204883
# Train epoch: 21 [330/375]	Accuracy: 92.19%	Loss: 0.213280
# Train epoch: 21 [340/375]	Accuracy: 90.94%	Loss: 0.212685
# Train epoch: 21 [350/375]	Accuracy: 89.38%	Loss: 0.202128
# Train epoch: 21 [360/375]	Accuracy: 89.38%	Loss: 0.232568
# Train epoch: 21 [370/375]	Accuracy: 90.94%	Loss: 0.227211
# Test set: Loss: 0.2365, Accuracy: 89.53%)
# Train epoch: 22 [10/375]	Accuracy: 92.50%	Loss: 0.176736
# Train epoch: 22 [20/375]	Accuracy: 91.56%	Loss: 0.203050
# Train epoch: 22 [30/375]	Accuracy: 91.88%	Loss: 0.232433
# Train epoch: 22 [40/375]	Accuracy: 88.44%	Loss: 0.260854
# Train epoch: 22 [50/375]	Accuracy: 92.50%	Loss: 0.176701
# Train epoch: 22 [60/375]	Accuracy: 90.31%	Loss: 0.207094
# Train epoch: 22 [70/375]	Accuracy: 91.25%	Loss: 0.220347
# Train epoch: 22 [80/375]	Accuracy: 90.00%	Loss: 0.207974
# Train epoch: 22 [90/375]	Accuracy: 90.94%	Loss: 0.214835
# Train epoch: 22 [100/375]	Accuracy: 90.62%	Loss: 0.207104
# Train epoch: 22 [110/375]	Accuracy: 89.06%	Loss: 0.214003
# Train epoch: 22 [120/375]	Accuracy: 88.44%	Loss: 0.268344
# Train epoch: 22 [130/375]	Accuracy: 94.38%	Loss: 0.164964
# Train epoch: 22 [140/375]	Accuracy: 90.00%	Loss: 0.202145
# Train epoch: 22 [150/375]	Accuracy: 91.88%	Loss: 0.184930
# Train epoch: 22 [160/375]	Accuracy: 90.00%	Loss: 0.235408
# Train epoch: 22 [170/375]	Accuracy: 89.38%	Loss: 0.222395
# Train epoch: 22 [180/375]	Accuracy: 90.94%	Loss: 0.214987
# Train epoch: 22 [190/375]	Accuracy: 90.31%	Loss: 0.207068
# Train epoch: 22 [200/375]	Accuracy: 90.00%	Loss: 0.215063
# Train epoch: 22 [210/375]	Accuracy: 93.44%	Loss: 0.184504
# Train epoch: 22 [220/375]	Accuracy: 92.19%	Loss: 0.221433
# Train epoch: 22 [230/375]	Accuracy: 91.56%	Loss: 0.203323
# Train epoch: 22 [240/375]	Accuracy: 89.06%	Loss: 0.227559
# Train epoch: 22 [250/375]	Accuracy: 91.25%	Loss: 0.211980
# Train epoch: 22 [260/375]	Accuracy: 89.06%	Loss: 0.235993
# Train epoch: 22 [270/375]	Accuracy: 90.00%	Loss: 0.230971
# Train epoch: 22 [280/375]	Accuracy: 87.19%	Loss: 0.266340
# Train epoch: 22 [290/375]	Accuracy: 90.31%	Loss: 0.207291
# Train epoch: 22 [300/375]	Accuracy: 90.00%	Loss: 0.240936
# Train epoch: 22 [310/375]	Accuracy: 89.69%	Loss: 0.207600
# Train epoch: 22 [320/375]	Accuracy: 89.06%	Loss: 0.243001
# Train epoch: 22 [330/375]	Accuracy: 88.12%	Loss: 0.227941
# Train epoch: 22 [340/375]	Accuracy: 89.38%	Loss: 0.209142
# Train epoch: 22 [350/375]	Accuracy: 88.75%	Loss: 0.247910
# Train epoch: 22 [360/375]	Accuracy: 89.69%	Loss: 0.206985
# Train epoch: 22 [370/375]	Accuracy: 89.38%	Loss: 0.211175
# Test set: Loss: 0.2125, Accuracy: 90.82%)
# Train epoch: 23 [10/375]	Accuracy: 87.50%	Loss: 0.255510
# Train epoch: 23 [20/375]	Accuracy: 88.44%	Loss: 0.268020
# Train epoch: 23 [30/375]	Accuracy: 90.31%	Loss: 0.242809
# Train epoch: 23 [40/375]	Accuracy: 86.56%	Loss: 0.276289
# Train epoch: 23 [50/375]	Accuracy: 91.25%	Loss: 0.212782
# Train epoch: 23 [60/375]	Accuracy: 92.19%	Loss: 0.204321
# Train epoch: 23 [70/375]	Accuracy: 86.88%	Loss: 0.260935
# Train epoch: 23 [80/375]	Accuracy: 92.19%	Loss: 0.192118
# Train epoch: 23 [90/375]	Accuracy: 89.38%	Loss: 0.229574
# Train epoch: 23 [100/375]	Accuracy: 92.50%	Loss: 0.198200
# Train epoch: 23 [110/375]	Accuracy: 91.56%	Loss: 0.192010
# Train epoch: 23 [120/375]	Accuracy: 89.69%	Loss: 0.225330
# Train epoch: 23 [130/375]	Accuracy: 91.56%	Loss: 0.206825
# Train epoch: 23 [140/375]	Accuracy: 88.12%	Loss: 0.233998
# Train epoch: 23 [150/375]	Accuracy: 91.88%	Loss: 0.191125
# Train epoch: 23 [160/375]	Accuracy: 90.31%	Loss: 0.232073
# Train epoch: 23 [170/375]	Accuracy: 90.00%	Loss: 0.211340
# Train epoch: 23 [180/375]	Accuracy: 90.00%	Loss: 0.180447
# Train epoch: 23 [190/375]	Accuracy: 90.62%	Loss: 0.201472
# Train epoch: 23 [200/375]	Accuracy: 89.38%	Loss: 0.241143
# Train epoch: 23 [210/375]	Accuracy: 88.75%	Loss: 0.244775
# Train epoch: 23 [220/375]	Accuracy: 90.94%	Loss: 0.193881
# Train epoch: 23 [230/375]	Accuracy: 89.38%	Loss: 0.232702
# Train epoch: 23 [240/375]	Accuracy: 90.31%	Loss: 0.235946
# Train epoch: 23 [250/375]	Accuracy: 91.56%	Loss: 0.191448
# Train epoch: 23 [260/375]	Accuracy: 90.62%	Loss: 0.212589
# Train epoch: 23 [270/375]	Accuracy: 85.62%	Loss: 0.250828
# Train epoch: 23 [280/375]	Accuracy: 88.75%	Loss: 0.239017
# Train epoch: 23 [290/375]	Accuracy: 86.56%	Loss: 0.254172
# Train epoch: 23 [300/375]	Accuracy: 89.69%	Loss: 0.232710
# Train epoch: 23 [310/375]	Accuracy: 89.38%	Loss: 0.235159
# Train epoch: 23 [320/375]	Accuracy: 90.00%	Loss: 0.209501
# Train epoch: 23 [330/375]	Accuracy: 91.25%	Loss: 0.196063
# Train epoch: 23 [340/375]	Accuracy: 91.88%	Loss: 0.205867
# Train epoch: 23 [350/375]	Accuracy: 90.62%	Loss: 0.218290
# Train epoch: 23 [360/375]	Accuracy: 90.31%	Loss: 0.198554
# Train epoch: 23 [370/375]	Accuracy: 89.06%	Loss: 0.249907
# Test set: Loss: 0.2088, Accuracy: 91.27%)
# Train epoch: 24 [10/375]	Accuracy: 89.38%	Loss: 0.258055
# Train epoch: 24 [20/375]	Accuracy: 92.50%	Loss: 0.198839
# Train epoch: 24 [30/375]	Accuracy: 90.94%	Loss: 0.206986
# Train epoch: 24 [40/375]	Accuracy: 89.69%	Loss: 0.223565
# Train epoch: 24 [50/375]	Accuracy: 92.50%	Loss: 0.181896
# Train epoch: 24 [60/375]	Accuracy: 92.81%	Loss: 0.199881
# Train epoch: 24 [70/375]	Accuracy: 90.31%	Loss: 0.207060
# Train epoch: 24 [80/375]	Accuracy: 90.00%	Loss: 0.232275
# Train epoch: 24 [90/375]	Accuracy: 90.00%	Loss: 0.230077
# Train epoch: 24 [100/375]	Accuracy: 91.56%	Loss: 0.198358
# Train epoch: 24 [110/375]	Accuracy: 90.31%	Loss: 0.240385
# Train epoch: 24 [120/375]	Accuracy: 89.38%	Loss: 0.252622
