# %% [markdown]
# <a href="https://colab.research.google.com/github/jithinraj9895/steganalysis/blob/second/Image_steagnalysis_SiaNET_MYMODEL_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
import logging
import os
import random
from PIL import Image
import cv2
import numpy as np
import torch
import random
import os
import os.path as osp

def set_random_seed(seed=None):
    """Sets random seed for reproducibility.

    Args:
        seed (int, optional): Random seed.
    """
    if seed is None:
        seed = (
                os.getpid()
                + int(datetime.now().strftime("%S%f"))
                + int.from_bytes(os.urandom(2), "big")
        )
        logger = logging.getLogger(__name__)
        logger.info('Using a generated random seed {}'.format(seed))
    random.seed(seed)
    np.random.seed(seed)
    torch.set_rng_state(torch.manual_seed(seed).get_state())


def get_random_seed():
    return np.random.randint(2 ** 31)

# %%
class RandomRot(object):

    def __call__(self, sample):
        rot = random.randint(0, 3)
        return {
            'image': np.rot90(sample['image'], rot, axes=[-3, -2]).copy(),
            'label': sample['label'],
        }


class RandomFlip(object):

    def __init__(self, p=0.5):
        self._p = p

    def __call__(self, sample):
        if random.random() < self._p:
            return {
                'image': np.flip(sample['image'], axis=-2).copy(),
                'label': sample['label'],
            }
        else:
            return sample


class ToTensor(object):

    def __call__(self, sample):
        image, label = sample['image'], sample['label']
        if image.ndim == 3:  # HxWxC
            image = image.transpose(2, 0, 1)
        else:  # NxHxWxC
            image = image.transpose(0, 3, 1, 2)
        return {
            'image': torch.from_numpy(image).type(torch.FloatTensor),
            'label': torch.tensor(label).long()
        }

# %%
from torch.utils.data import Dataset


class CoverStegoDataset(Dataset):

    def __init__(self, cover_dir, stego_dir, transform=None):
        self._transform = transform

        self.images, self.labels = self.get_items(cover_dir, stego_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = np.array(Image.open(self.images[idx]))
        image = np.expand_dims(image, 2)  # (H, W, C)
        assert image.ndim == 3

        sample = {
            'image': image,
            'label': self.labels[idx]
        }

        if self._transform:
            sample = self._transform(sample)
        return sample

    @staticmethod
    def get_items(cover_dir, stego_dir):
        images, labels = [], []

        cover_names = sorted(os.listdir(cover_dir))
        if stego_dir is not None:
            stego_names = sorted(os.listdir(stego_dir))
            assert cover_names == stego_names

        file_names = cover_names
        if stego_dir is None:
            dir_to_label = [(cover_dir, 0), ]
        else:
            dir_to_label = [(cover_dir, 0), (stego_dir, 1)]
        for image_dir, label in dir_to_label:
            for file_name in file_names:
                image_path = osp.join(image_dir, file_name)
                if not osp.isfile(image_path):
                    raise FileNotFoundError('{} not exists'.format(image_path))
                images.append(image_path)
                labels.append(label)

        return images, labels

# %%
import torchvision
from torch.utils.data import BatchSampler
from torch.utils.data import DataLoader
from torch.utils.data import Sampler
from torch.utils.data import SequentialSampler
import itertools
import logging
import math

class TrainingSampler(Sampler):

    def __init__(self, size, seed=None, shuffle=True):
        self._size = size
        self._shuffle = shuffle

        if seed is None:
            seed = get_random_seed()
        self._seed = seed

    def __iter__(self):
        yield from itertools.islice(self._infinite_indices(), 0, None, 1)

    def _infinite_indices(self):
        g = torch.Generator()
        g.manual_seed(self._seed)
        while True:
            if self._shuffle:
                yield from torch.randperm(self._size, generator=g)
            else:
                yield from torch.arange(self._size)




class BalancedBatchSampler(BatchSampler):

    def __init__(self, sampler, group_ids, batch_size):
        """
        Args:
            sampler (Sampler): Base sampler.
            group_ids (list[int]): If the sampler produces indices in range [0, N),
                `group_ids` must be a list of `N` ints which contains the group id of each
                sample. The group ids must be a set of integers in [0, num_groups).
            batch_size (int): Size of mini-batch.
        """
        if not isinstance(sampler, Sampler):
            raise ValueError("sampler should be an instance of torch.utils.data.Sampler, "
                             "but got sampler={}".format(sampler))

        self._sampler = sampler
        self._group_ids = np.asarray(group_ids)
        assert self._group_ids.ndim == 1
        self._batch_size = batch_size
        groups = np.unique(self._group_ids).tolist()
        assert batch_size % len(groups) == 0

        # buffer the indices of each group until batch size is reached
        self._buffer_per_group = {k: [] for k in groups}
        self._group_size = batch_size // len(groups)

    def __iter__(self):
        for idx in self._sampler:
            group_id = self._group_ids[idx]
            self._buffer_per_group[group_id].append(idx)
            if all(len(v) >= self._group_size for k, v in self._buffer_per_group.items()):
                idxs = []
                # Collect across all groups
                for k, v in self._buffer_per_group.items():
                    idxs.extend(v[:self._group_size])
                    del v[:self._group_size]

                idxs = np.random.permutation(idxs)
                yield idxs

    def __len__(self):
        raise NotImplementedError("len() of GroupedBatchSampler is not well-defined.")


def build_train_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        RandomRot(),
        RandomFlip(),
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    size = len(dataset)
    sampler = TrainingSampler(size)
    if stego_dir is not None:
        batch_sampler = BalancedBatchSampler(sampler, dataset.labels, batch_size)
    else:
        batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)
    epoch_length = math.ceil(size / batch_size)


    train_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
        worker_init_fn=worker_init_reset_seed,
    )
    return train_loader, epoch_length




def build_val_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    sampler = SequentialSampler(dataset)
    batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)


    test_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
    )
    return test_loader

def worker_init_reset_seed(worker_id):
    set_random_seed(np.random.randint(2 ** 31) + worker_id)

# %%
set_random_seed()

# %%
 train_cover_dir = "/content/drive/MyDrive/real_boss_256/train/cover"
 train_stego_dir = "/content/drive/MyDrive/real_boss_256/train/stego"
 val_cover_dir = "/content/drive/MyDrive/real_boss_256/validation/cover"
 val_stego_dir = "/content/drive/MyDrive/real_boss_256/validation/stego"
 
 
 train_loader, epoch_length = build_train_loader(
        train_cover_dir, train_stego_dir, batch_size=32,
        num_workers=0)

# %%
print(epoch_length)
# Out:
# 375

# %%
val_loader = build_val_loader(
    val_cover_dir, val_stego_dir, batch_size=32,
    num_workers=0
)

# %%
train_loader_iter = iter(train_loader)

# %%
def activation(x):
    a = torch.ones(x.shape).cuda()
    a = torch.mul(a, -3).cuda()
    b = torch.ones(x.shape).cuda()
    b = torch.mul(b, 3).cuda()
    c = torch.where(x > -3,x,a).cuda()
    d = torch.where(c < 3,c,b).cuda()
    return d     


class the_tlu(nn.Module):
    def __init__(self):
        super(the_tlu, self).__init__()
    def forward(self, x):
        return activation(x)

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.nn import Parameter


srm_dir = "/content/drive/MyDrive"
SRM_npy = np.load(os.path.join(srm_dir,"SRM_Kernels.npy"))


def accuracy(outputs, labels):
    _, argmax = torch.max(outputs, 1)
    return (labels == argmax.squeeze()).float().mean()


def conv3x3(in_planes, out_planes, stride=1, groups=1, dilation=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                     padding=dilation, groups=groups, bias=False, dilation=dilation)


def conv1x1(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


class SRMConv2d(nn.Module):

    def __init__(self, stride=1, padding=0):
        super(SRMConv2d, self).__init__()
        self.in_channels = 1
        self.out_channels = 30
        self.kernel_size = (5, 5)
        if isinstance(stride, int):
            self.stride = (stride, stride)
        else:
            self.stride = stride
        if isinstance(padding, int):
            self.padding = (padding, padding)
        else:
            self.padding = padding
        self.dilation = (1, 1)
        self.transpose = False
        self.output_padding = (0,)
        self.groups = 1
        self.weight = Parameter(torch.Tensor(30, 1, 5, 5), requires_grad=True)
        self.bias = Parameter(torch.Tensor(30), requires_grad=True)
        self.reset_parameters()

    def reset_parameters(self):
        self.weight.data.numpy()[:] = SRM_npy
        self.bias.data.zero_()

    def forward(self, input):
        return F.conv2d(input, self.weight, self.bias, self.stride, self.padding,
                        self.dilation, self.groups)


class BlockA(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockA, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += identity
        out = self.relu(out)

        return out


class BlockB(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockB, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes, stride=2)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)
        # self.pool = nn.AvgPool2d(3, stride=2, padding=1)

        self.shortcut_conv = conv1x1(in_planes, out_planes, stride=2)
        self.shortcut_bn = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        # out = self.pool(out)

        identity = self.shortcut_conv(identity)
        identity = self.shortcut_bn(identity)

        out += identity
        out = self.relu(out)

        return out

# %%
class KeNet(nn.Module):

    def __init__(self, norm_layer=None, zero_init_residual=True, p=0.5):
        super(KeNet, self).__init__()

        self.zero_init_residual = zero_init_residual

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.srm = SRMConv2d(1, 0)
        self.bn1 = norm_layer(30)
        self.tlu = the_tlu()

        self.A1 = BlockA(30, 30, norm_layer=norm_layer)
        self.A2 = BlockA(30, 30, norm_layer=norm_layer)
        self.AA = BlockA(30, 30, norm_layer=norm_layer)

        # self.B1 = BlockB(30, 30, norm_layer=norm_layer)
        # self.B2 = BlockB(30, 64, norm_layer=norm_layer)

        self.B3 = BlockB(30, 64, norm_layer=norm_layer)
        self.A3 = BlockA(64, 64, norm_layer=norm_layer)

        self.B4 = BlockB(64, 128, norm_layer=norm_layer)
        self.A4 = BlockA(128, 128, norm_layer=norm_layer)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # self.bnfc = nn.BatchNorm1d(128)
        self.relu = nn.ReLU(inplace=True)
        # self.fcfusion = nn.Linear(128, 128) #4
        self.fc = nn.Linear(128 * 4 + 1, 2)
        self.dropout = nn.Dropout(p=p)

        self.reset_parameters()

    def reset_parameters(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # nn.init.xavier_uniform_(m.weight)
                # nn.init.constant_(m.bias, 0.2)
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, std=0.01)

        if self.zero_init_residual:
            for m in self.modules():
                if isinstance(m, (BlockA, BlockB)):
                    nn.init.constant_(m.bn2.weight, 0)

    def extract_feat(self, x):
        x = x.float()
        out = self.srm(x)
        out = self.bn1(out)
        out = self.tlu(out)
    #    out = self.relu(out)

        out = self.A1(out)
        out = self.A2(out)
        out = self.AA(out)

        # out = self.B1(out)
        # out = self.B2(out)

        out = self.B3(out)
        out = self.A3(out)

        out = self.B4(out)
        out = self.A4(out)

        out = self.avgpool(out)
        out = out.view(out.size(0), out.size(1))

        # out = self.relu(out)
        # out = self.bnfc(out)

        return out

    def forward(self, *args):
        ############# statistics fusion start #############
        feats = torch.stack(
            [self.extract_feat(subarea) for subarea in args], dim=0
        )

        euclidean_distance = F.pairwise_distance(feats[0], feats[1], eps=1e-6,
                                                 keepdim=True)

        if feats.shape[0] == 1:
            final_feat = feats.squeeze(dim=0)
        else:
            # feats_sum = feats.sum(dim=0)
            # feats_sub = feats[0] - feats[1]
            feats_mean = feats.mean(dim=0)
            feats_var = feats.var(dim=0)
            feats_min, _ = feats.min(dim=0)
            feats_max, _ = feats.max(dim=0)

            '''feats_sum = feats.sum(dim=0)
            feats_sub = abs(feats[0] - feats[1])
            feats_prod = feats.prod(dim=0)
            feats_max, _ = feats.max(dim=0)'''
            
            #final_feat = torch.cat(
            #    [feats[0], feats[1], feats[0], feats[1]], dim=-1
            #    #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            #)

            final_feat = torch.cat(
                [euclidean_distance, feats_mean, feats_var, feats_min, feats_max], dim=-1
                #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            )

        out = self.dropout(final_feat)
        # out = self.fcfusion(out)
        # out = self.relu(out)
        out = self.fc(out)

        return out, feats[0], feats[1]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ContrastiveLoss(nn.Module):

    def __init__(self, margin=1.25):  # margin=2
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        label = label.to(torch.float32)
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean(
            (1 - label) * torch.pow(euclidean_distance, 2) +
            label * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2)
        )

        return loss_contrastive

# %%
criterion_1 = nn.CrossEntropyLoss()
criterion_2 = ContrastiveLoss(margin=1)

# %%
net = KeNet();

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

device = get_default_device()


if device.type == "cuda":
    net.cuda()
    criterion_1.cuda()
    criterion_2.cuda()

# %%
from torch.optim.adamax import Adamax

optimizer = Adamax(net.parameters(), lr=0.001, eps=1e-08, weight_decay=0.0001)

# %%
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', factor=0.3,
                                                           patience=10, verbose=True, min_lr=0,
                                                           eps=1e-08)

# %%
import logging
import time
import shutil
logger = logging.getLogger(__name__)


def preprocess_data(images, labels, random_crop,gpu):
    # images of shape: NxCxHxW
    if images.ndim == 5:  # 1xNxCxHxW
        images = images.squeeze(0)
        labels = labels.squeeze(0)
    h, w = images.shape[-2:]

    if random_crop:
        ch = random.randint(h * 3 // 4, h)  # h // 2      #256
        cw = random.randint(w * 3 // 4, w)  # square ch   #256

        h0 = random.randint(0, h - ch)  # 128
        w0 = random.randint(0, w - cw)  # 128
    else:
        ch, cw, h0, w0 = h, w, 0, 0


    cw = cw & ~1
    inputs = [
            images[..., h0:h0 + ch, w0:w0 + cw // 2],
            images[..., h0:h0 + ch, w0 + cw // 2:w0 + cw]
        ]

    if gpu:
        inputs = [x.cuda() for x in inputs]
        labels = labels.cuda()
    return inputs, labels

# %%
def train(epoch):
    net.train()
    running_loss, running_accuracy = 0., 0.

    for batch_idx in range(epoch_length):
        data = next(train_loader_iter)
        inputs, labels = preprocess_data(data['image'], data['label'], False,gpu=True)

        optimizer.zero_grad()
   
        outputs, feats_0, feats_1 = net(*inputs)

            # count parameters start
            # print('parameters_count: {}'.format(sum(p.numel() for p in net.parameters() if p.requires_grad)))
            # count parameters end

        loss = criterion_1(outputs, labels) + \
                   0.1 * criterion_2(feats_0, feats_1, labels)

        accuracy1 = accuracy(outputs, labels).item()
        running_accuracy += accuracy1
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        if (batch_idx + 1) % 10 == 0:
            running_accuracy /= 10
            running_loss /= 10
            
            print(
                'Train epoch: {} [{}/{}]\tAccuracy: {:.2f}%\tLoss: {:.6f}'.format(
                    epoch, batch_idx + 1, epoch_length, 100 * running_accuracy,
                    running_loss))
                    
            ###############################log per log_interval start
            is_best=False
            save_checkpoint(
                {
                    'iteration': batch_idx + 1,
                    'state_dict': net.state_dict(),
                    'best_prec1': running_accuracy,
                    'optimizer': optimizer.state_dict(),
                },
                is_best,
                filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
                best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
            ###############################
            running_loss = 0.
            running_accuracy = 0.
            net.train()

# %%
def valid():
    net.eval()
    valid_loss = 0.
    valid_accuracy = 0.
    with torch.no_grad():
        for data in val_loader:
            inputs, labels = preprocess_data(data['image'], data['label'], False,gpu = True)

            outputs, feats_0, feats_1 = net(*inputs)
            valid_loss += criterion_1(outputs, labels).item() + \
                              0.01 * criterion_2(feats_0, feats_1, labels)
            valid_accuracy += accuracy(outputs, labels).item()
    valid_loss /= len(val_loader)
    valid_accuracy /= len(val_loader)
    print('Test set: Loss: {:.4f}, Accuracy: {:.2f}%)'.format(
        valid_loss, 100 * valid_accuracy))
    return valid_loss, valid_accuracy

# %%
fine_tune = "/content/drive/MyDrive/dataset/checkpoint.pth.tar"

if fine_tune is not None:
    net.load_state_dict(torch.load(fine_tune)['state_dict'], strict=False)
    e = torch.load(fine_tune)['iteration']

# %%
print(e)
# Out:
# 430

# %%
def save_checkpoint(state, is_best, filename, best_name):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, best_name)


_time = time.time()
best_accuracy = 0.
for e in range(1, 500 + 1):
    logger.info('Epoch: {}'.format(e))
    logger.info('Train')
    train(e)
    logger.info('Time: {}'.format(time.time() - _time))
    logger.info('Test')
    _, accuracy1 = valid()
    if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
        scheduler.step(accuracy1)
    else:
        scheduler.step()
    if accuracy1 > best_accuracy:
        best_accuracy = accuracy1
        is_best = True
    else:
        is_best = False
    logger.info('Best accuracy: {}'.format(best_accuracy))
    logger.info('Time: {}'.format(time.time() - _time))
    save_checkpoint(
        {
            'epoch': e,
            'state_dict': net.state_dict(),
            'best_prec1': accuracy1,
            'optimizer': optimizer.state_dict(),
        },
        is_best,
        filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
        best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
# Out:
# Train epoch: 1 [10/375]	Accuracy: 47.81%	Loss: 0.798852
# Train epoch: 1 [20/375]	Accuracy: 49.38%	Loss: 0.753677
# Train epoch: 1 [30/375]	Accuracy: 49.69%	Loss: 0.755620
# Train epoch: 1 [40/375]	Accuracy: 51.56%	Loss: 0.740197
# Train epoch: 1 [50/375]	Accuracy: 53.44%	Loss: 0.726227
# Train epoch: 1 [60/375]	Accuracy: 47.19%	Loss: 0.728326
# Train epoch: 1 [70/375]	Accuracy: 49.06%	Loss: 0.726461
# Train epoch: 1 [80/375]	Accuracy: 56.25%	Loss: 0.722203
# Train epoch: 1 [90/375]	Accuracy: 51.88%	Loss: 0.725162
# Train epoch: 1 [100/375]	Accuracy: 45.62%	Loss: 0.729622
# Train epoch: 1 [110/375]	Accuracy: 49.38%	Loss: 0.728570
# Train epoch: 1 [120/375]	Accuracy: 51.56%	Loss: 0.723312
# Train epoch: 1 [130/375]	Accuracy: 52.50%	Loss: 0.721978
# Train epoch: 1 [140/375]	Accuracy: 52.81%	Loss: 0.721002
# Train epoch: 1 [150/375]	Accuracy: 50.31%	Loss: 0.721050
# Train epoch: 1 [160/375]	Accuracy: 52.81%	Loss: 0.724792
# Train epoch: 1 [170/375]	Accuracy: 49.06%	Loss: 0.728729
# Train epoch: 1 [180/375]	Accuracy: 50.00%	Loss: 0.723994
# Train epoch: 1 [190/375]	Accuracy: 53.12%	Loss: 0.719952
# Train epoch: 1 [200/375]	Accuracy: 51.56%	Loss: 0.718771
# Train epoch: 1 [210/375]	Accuracy: 51.56%	Loss: 0.722877
# Train epoch: 1 [220/375]	Accuracy: 50.00%	Loss: 0.723600
# Train epoch: 1 [230/375]	Accuracy: 47.81%	Loss: 0.730708
# Train epoch: 1 [240/375]	Accuracy: 48.12%	Loss: 0.725929
# Train epoch: 1 [250/375]	Accuracy: 52.19%	Loss: 0.719170
# Train epoch: 1 [260/375]	Accuracy: 52.19%	Loss: 0.721241
# Train epoch: 1 [270/375]	Accuracy: 49.06%	Loss: 0.726390
# Train epoch: 1 [280/375]	Accuracy: 53.44%	Loss: 0.719970
# Train epoch: 1 [290/375]	Accuracy: 51.56%	Loss: 0.721512
# Train epoch: 1 [300/375]	Accuracy: 55.31%	Loss: 0.720102
# Train epoch: 1 [310/375]	Accuracy: 53.44%	Loss: 0.721452
# Train epoch: 1 [320/375]	Accuracy: 54.06%	Loss: 0.716448
# Train epoch: 1 [330/375]	Accuracy: 53.44%	Loss: 0.722208
# Train epoch: 1 [340/375]	Accuracy: 50.31%	Loss: 0.714897
# Train epoch: 1 [350/375]	Accuracy: 56.88%	Loss: 0.715609
# Train epoch: 1 [360/375]	Accuracy: 56.25%	Loss: 0.716511
# Train epoch: 1 [370/375]	Accuracy: 51.88%	Loss: 0.724500
# Test set: Loss: 0.6907, Accuracy: 54.76%)
# Train epoch: 2 [10/375]	Accuracy: 50.62%	Loss: 0.721336
# Train epoch: 2 [20/375]	Accuracy: 54.37%	Loss: 0.717969
# Train epoch: 2 [30/375]	Accuracy: 54.37%	Loss: 0.718591
# Train epoch: 2 [40/375]	Accuracy: 53.44%	Loss: 0.717388
# Train epoch: 2 [50/375]	Accuracy: 50.31%	Loss: 0.721001
# Train epoch: 2 [60/375]	Accuracy: 53.75%	Loss: 0.716670
# Train epoch: 2 [70/375]	Accuracy: 56.88%	Loss: 0.717206
# Train epoch: 2 [80/375]	Accuracy: 55.94%	Loss: 0.709781
# Train epoch: 2 [90/375]	Accuracy: 59.06%	Loss: 0.702678
# Train epoch: 2 [100/375]	Accuracy: 54.69%	Loss: 0.711537
# Train epoch: 2 [110/375]	Accuracy: 55.00%	Loss: 0.711404
# Train epoch: 2 [120/375]	Accuracy: 50.00%	Loss: 0.720613
# Train epoch: 2 [130/375]	Accuracy: 54.69%	Loss: 0.711127
# Train epoch: 2 [140/375]	Accuracy: 56.56%	Loss: 0.710326
# Train epoch: 2 [150/375]	Accuracy: 56.56%	Loss: 0.711496
# Train epoch: 2 [160/375]	Accuracy: 57.19%	Loss: 0.702490
# Train epoch: 2 [170/375]	Accuracy: 55.94%	Loss: 0.708363
# Train epoch: 2 [180/375]	Accuracy: 56.88%	Loss: 0.707920
# Train epoch: 2 [190/375]	Accuracy: 61.56%	Loss: 0.695637
# Train epoch: 2 [200/375]	Accuracy: 56.88%	Loss: 0.706433
# Train epoch: 2 [210/375]	Accuracy: 58.44%	Loss: 0.706964
# Train epoch: 2 [220/375]	Accuracy: 59.06%	Loss: 0.691592
# Train epoch: 2 [230/375]	Accuracy: 55.62%	Loss: 0.707592
# Train epoch: 2 [240/375]	Accuracy: 58.13%	Loss: 0.698682
# Train epoch: 2 [250/375]	Accuracy: 61.88%	Loss: 0.691786
# Train epoch: 2 [260/375]	Accuracy: 60.94%	Loss: 0.688008
# Train epoch: 2 [270/375]	Accuracy: 62.50%	Loss: 0.686833
# Train epoch: 2 [280/375]	Accuracy: 63.75%	Loss: 0.677187
# Train epoch: 2 [290/375]	Accuracy: 57.81%	Loss: 0.694992
# Train epoch: 2 [300/375]	Accuracy: 63.44%	Loss: 0.673112
# Train epoch: 2 [310/375]	Accuracy: 58.75%	Loss: 0.708391
# Train epoch: 2 [320/375]	Accuracy: 58.75%	Loss: 0.691572
# Train epoch: 2 [330/375]	Accuracy: 61.56%	Loss: 0.674645
# Train epoch: 2 [340/375]	Accuracy: 64.38%	Loss: 0.666967
# Train epoch: 2 [350/375]	Accuracy: 59.69%	Loss: 0.691032
# Train epoch: 2 [360/375]	Accuracy: 65.00%	Loss: 0.653876
# Train epoch: 2 [370/375]	Accuracy: 61.25%	Loss: 0.680261
# Test set: Loss: 0.6255, Accuracy: 66.22%)
# Train epoch: 3 [10/375]	Accuracy: 63.12%	Loss: 0.662818
# Train epoch: 3 [20/375]	Accuracy: 60.62%	Loss: 0.698412
# Train epoch: 3 [30/375]	Accuracy: 61.25%	Loss: 0.673887
# Train epoch: 3 [40/375]	Accuracy: 59.69%	Loss: 0.674291
# Train epoch: 3 [50/375]	Accuracy: 64.06%	Loss: 0.659029
# Train epoch: 3 [60/375]	Accuracy: 68.44%	Loss: 0.635184
# Train epoch: 3 [70/375]	Accuracy: 61.56%	Loss: 0.668133
# Train epoch: 3 [80/375]	Accuracy: 65.00%	Loss: 0.665092
# Train epoch: 3 [90/375]	Accuracy: 67.81%	Loss: 0.640758
# Train epoch: 3 [100/375]	Accuracy: 60.00%	Loss: 0.674666
# Train epoch: 3 [110/375]	Accuracy: 61.88%	Loss: 0.669500
# Train epoch: 3 [120/375]	Accuracy: 63.12%	Loss: 0.649476
# Train epoch: 3 [130/375]	Accuracy: 67.50%	Loss: 0.628032
# Train epoch: 3 [140/375]	Accuracy: 63.75%	Loss: 0.660626
# Train epoch: 3 [150/375]	Accuracy: 62.19%	Loss: 0.658357
# Train epoch: 3 [160/375]	Accuracy: 63.75%	Loss: 0.648897
# Train epoch: 3 [170/375]	Accuracy: 64.06%	Loss: 0.644803
# Train epoch: 3 [180/375]	Accuracy: 65.94%	Loss: 0.649810
# Train epoch: 3 [190/375]	Accuracy: 62.81%	Loss: 0.668893
# Train epoch: 3 [200/375]	Accuracy: 68.12%	Loss: 0.622002
# Train epoch: 3 [210/375]	Accuracy: 61.88%	Loss: 0.666314
# Train epoch: 3 [220/375]	Accuracy: 65.00%	Loss: 0.629973
# Train epoch: 3 [230/375]	Accuracy: 67.19%	Loss: 0.623847
# Train epoch: 3 [240/375]	Accuracy: 61.25%	Loss: 0.652310
# Train epoch: 3 [250/375]	Accuracy: 68.44%	Loss: 0.626485
# Train epoch: 3 [260/375]	Accuracy: 65.00%	Loss: 0.620785
# Train epoch: 3 [270/375]	Accuracy: 65.31%	Loss: 0.634345
# Train epoch: 3 [280/375]	Accuracy: 62.81%	Loss: 0.666645
# Train epoch: 3 [290/375]	Accuracy: 62.81%	Loss: 0.629543
# Train epoch: 3 [300/375]	Accuracy: 61.88%	Loss: 0.674052
# Train epoch: 3 [310/375]	Accuracy: 63.44%	Loss: 0.635510
# Train epoch: 3 [320/375]	Accuracy: 65.62%	Loss: 0.618488
# Train epoch: 3 [330/375]	Accuracy: 71.56%	Loss: 0.598576
# Train epoch: 3 [340/375]	Accuracy: 67.81%	Loss: 0.607987
# Train epoch: 3 [350/375]	Accuracy: 66.56%	Loss: 0.632723
# Train epoch: 3 [360/375]	Accuracy: 65.94%	Loss: 0.612349
# Train epoch: 3 [370/375]	Accuracy: 63.44%	Loss: 0.618862
# Test set: Loss: 0.5508, Accuracy: 71.28%)
# Train epoch: 4 [10/375]	Accuracy: 68.75%	Loss: 0.614493
# Train epoch: 4 [20/375]	Accuracy: 69.38%	Loss: 0.566498
# Train epoch: 4 [30/375]	Accuracy: 65.94%	Loss: 0.629964
# Train epoch: 4 [40/375]	Accuracy: 67.50%	Loss: 0.633956
# Train epoch: 4 [50/375]	Accuracy: 64.38%	Loss: 0.628008
# Train epoch: 4 [60/375]	Accuracy: 65.31%	Loss: 0.621458
# Train epoch: 4 [70/375]	Accuracy: 68.12%	Loss: 0.595970
# Train epoch: 4 [80/375]	Accuracy: 66.56%	Loss: 0.629319
# Train epoch: 4 [90/375]	Accuracy: 68.12%	Loss: 0.614241
# Train epoch: 4 [100/375]	Accuracy: 72.81%	Loss: 0.566098
# Train epoch: 4 [110/375]	Accuracy: 66.88%	Loss: 0.599788
# Train epoch: 4 [120/375]	Accuracy: 64.38%	Loss: 0.636287
# Train epoch: 4 [130/375]	Accuracy: 69.06%	Loss: 0.590557
# Train epoch: 4 [140/375]	Accuracy: 67.19%	Loss: 0.604803
# Train epoch: 4 [150/375]	Accuracy: 68.12%	Loss: 0.583311
# Train epoch: 4 [160/375]	Accuracy: 67.81%	Loss: 0.602792
# Train epoch: 4 [170/375]	Accuracy: 72.81%	Loss: 0.589493
# Train epoch: 4 [180/375]	Accuracy: 68.75%	Loss: 0.596511
# Train epoch: 4 [190/375]	Accuracy: 65.62%	Loss: 0.625367
# Train epoch: 4 [200/375]	Accuracy: 69.38%	Loss: 0.591137
# Train epoch: 4 [210/375]	Accuracy: 66.56%	Loss: 0.616984
# Train epoch: 4 [220/375]	Accuracy: 73.44%	Loss: 0.576242
# Train epoch: 4 [230/375]	Accuracy: 65.94%	Loss: 0.600798
# Train epoch: 4 [240/375]	Accuracy: 68.44%	Loss: 0.563550
# Train epoch: 4 [250/375]	Accuracy: 69.69%	Loss: 0.574561
# Train epoch: 4 [260/375]	Accuracy: 69.69%	Loss: 0.598060
# Train epoch: 4 [270/375]	Accuracy: 67.19%	Loss: 0.589360
# Train epoch: 4 [280/375]	Accuracy: 64.38%	Loss: 0.641093
# Train epoch: 4 [290/375]	Accuracy: 62.50%	Loss: 0.624480
# Train epoch: 4 [300/375]	Accuracy: 72.81%	Loss: 0.565026
# Train epoch: 4 [310/375]	Accuracy: 72.81%	Loss: 0.549133
# Train epoch: 4 [320/375]	Accuracy: 68.44%	Loss: 0.600052
# Train epoch: 4 [330/375]	Accuracy: 69.06%	Loss: 0.575132
# Train epoch: 4 [340/375]	Accuracy: 70.94%	Loss: 0.574785
# Train epoch: 4 [350/375]	Accuracy: 70.31%	Loss: 0.622690
# Train epoch: 4 [360/375]	Accuracy: 71.56%	Loss: 0.579286
# Train epoch: 4 [370/375]	Accuracy: 68.12%	Loss: 0.608980
# Test set: Loss: 0.5561, Accuracy: 68.55%)
# Train epoch: 5 [10/375]	Accuracy: 76.25%	Loss: 0.524007
# Train epoch: 5 [20/375]	Accuracy: 74.69%	Loss: 0.522248
# Train epoch: 5 [30/375]	Accuracy: 67.19%	Loss: 0.596383
# Train epoch: 5 [40/375]	Accuracy: 77.19%	Loss: 0.525152
# Train epoch: 5 [50/375]	Accuracy: 67.50%	Loss: 0.598248
# Train epoch: 5 [60/375]	Accuracy: 73.12%	Loss: 0.556025
# Train epoch: 5 [70/375]	Accuracy: 72.50%	Loss: 0.564473
# Train epoch: 5 [80/375]	Accuracy: 65.62%	Loss: 0.632589
# Train epoch: 5 [90/375]	Accuracy: 64.69%	Loss: 0.627717
# Train epoch: 5 [100/375]	Accuracy: 71.56%	Loss: 0.553679
# Train epoch: 5 [110/375]	Accuracy: 67.50%	Loss: 0.573621
# Train epoch: 5 [120/375]	Accuracy: 68.75%	Loss: 0.574907
# Train epoch: 5 [130/375]	Accuracy: 73.12%	Loss: 0.551257
# Train epoch: 5 [140/375]	Accuracy: 65.31%	Loss: 0.644235
# Train epoch: 5 [150/375]	Accuracy: 71.25%	Loss: 0.597514
# Train epoch: 5 [160/375]	Accuracy: 71.56%	Loss: 0.561391
# Train epoch: 5 [170/375]	Accuracy: 72.19%	Loss: 0.567293
# Train epoch: 5 [180/375]	Accuracy: 68.75%	Loss: 0.601368
# Train epoch: 5 [190/375]	Accuracy: 71.25%	Loss: 0.534154
# Train epoch: 5 [200/375]	Accuracy: 71.56%	Loss: 0.568038
# Train epoch: 5 [210/375]	Accuracy: 74.06%	Loss: 0.541287
# Train epoch: 5 [220/375]	Accuracy: 73.44%	Loss: 0.564021
# Train epoch: 5 [230/375]	Accuracy: 72.50%	Loss: 0.541029
# Train epoch: 5 [240/375]	Accuracy: 73.12%	Loss: 0.534652
# Train epoch: 5 [250/375]	Accuracy: 73.75%	Loss: 0.549531
# Train epoch: 5 [260/375]	Accuracy: 68.75%	Loss: 0.590513
# Train epoch: 5 [270/375]	Accuracy: 67.19%	Loss: 0.583940
# Train epoch: 5 [280/375]	Accuracy: 75.94%	Loss: 0.519143
# Train epoch: 5 [290/375]	Accuracy: 72.19%	Loss: 0.544195
# Train epoch: 5 [300/375]	Accuracy: 68.75%	Loss: 0.559311
# Train epoch: 5 [310/375]	Accuracy: 74.38%	Loss: 0.551953
# Train epoch: 5 [320/375]	Accuracy: 70.94%	Loss: 0.567939
# Train epoch: 5 [330/375]	Accuracy: 70.94%	Loss: 0.559173
# Train epoch: 5 [340/375]	Accuracy: 72.50%	Loss: 0.537833
# Train epoch: 5 [350/375]	Accuracy: 71.25%	Loss: 0.555213
# Train epoch: 5 [360/375]	Accuracy: 75.00%	Loss: 0.561587
# Train epoch: 5 [370/375]	Accuracy: 71.56%	Loss: 0.572018
# Test set: Loss: 0.4651, Accuracy: 77.43%)
# Train epoch: 6 [10/375]	Accuracy: 74.38%	Loss: 0.558175
# Train epoch: 6 [20/375]	Accuracy: 74.38%	Loss: 0.527076
# Train epoch: 6 [30/375]	Accuracy: 74.38%	Loss: 0.515104
# Train epoch: 6 [40/375]	Accuracy: 68.75%	Loss: 0.577003
# Train epoch: 6 [50/375]	Accuracy: 70.62%	Loss: 0.553543
# Train epoch: 6 [60/375]	Accuracy: 68.12%	Loss: 0.590500
# Train epoch: 6 [70/375]	Accuracy: 71.25%	Loss: 0.578086
# Train epoch: 6 [80/375]	Accuracy: 70.94%	Loss: 0.554839
# Train epoch: 6 [90/375]	Accuracy: 71.25%	Loss: 0.571043
# Train epoch: 6 [100/375]	Accuracy: 71.25%	Loss: 0.558597
# Train epoch: 6 [110/375]	Accuracy: 69.69%	Loss: 0.604979
# Train epoch: 6 [120/375]	Accuracy: 72.19%	Loss: 0.548233
# Train epoch: 6 [130/375]	Accuracy: 69.06%	Loss: 0.543286
# Train epoch: 6 [140/375]	Accuracy: 73.44%	Loss: 0.530222
# Train epoch: 6 [150/375]	Accuracy: 73.75%	Loss: 0.517371
# Train epoch: 6 [160/375]	Accuracy: 75.00%	Loss: 0.522518
# Train epoch: 6 [170/375]	Accuracy: 70.31%	Loss: 0.556823
# Train epoch: 6 [180/375]	Accuracy: 74.69%	Loss: 0.542576
# Train epoch: 6 [190/375]	Accuracy: 75.31%	Loss: 0.518219
# Train epoch: 6 [200/375]	Accuracy: 71.56%	Loss: 0.562935
# Train epoch: 6 [210/375]	Accuracy: 72.81%	Loss: 0.525922
# Train epoch: 6 [220/375]	Accuracy: 69.69%	Loss: 0.545339
# Train epoch: 6 [230/375]	Accuracy: 72.50%	Loss: 0.538758
# Train epoch: 6 [240/375]	Accuracy: 68.75%	Loss: 0.563551
# Train epoch: 6 [250/375]	Accuracy: 67.19%	Loss: 0.584672
# Train epoch: 6 [260/375]	Accuracy: 73.44%	Loss: 0.545410
# Train epoch: 6 [270/375]	Accuracy: 75.62%	Loss: 0.536119
# Train epoch: 6 [280/375]	Accuracy: 72.19%	Loss: 0.528572
# Train epoch: 6 [290/375]	Accuracy: 72.50%	Loss: 0.569416
# Train epoch: 6 [300/375]	Accuracy: 72.19%	Loss: 0.525081
# Train epoch: 6 [310/375]	Accuracy: 73.75%	Loss: 0.536103
# Train epoch: 6 [320/375]	Accuracy: 70.62%	Loss: 0.550462
# Train epoch: 6 [330/375]	Accuracy: 71.25%	Loss: 0.511861
# Train epoch: 6 [340/375]	Accuracy: 70.94%	Loss: 0.541973
# Train epoch: 6 [350/375]	Accuracy: 74.38%	Loss: 0.547960
# Train epoch: 6 [360/375]	Accuracy: 77.50%	Loss: 0.517783
# Train epoch: 6 [370/375]	Accuracy: 73.12%	Loss: 0.534032
# Test set: Loss: 0.7389, Accuracy: 58.43%)
# Train epoch: 7 [10/375]	Accuracy: 76.56%	Loss: 0.490970
# Train epoch: 7 [20/375]	Accuracy: 72.81%	Loss: 0.525632
# Train epoch: 7 [30/375]	Accuracy: 71.25%	Loss: 0.554759
# Train epoch: 7 [40/375]	Accuracy: 72.50%	Loss: 0.528145
# Train epoch: 7 [50/375]	Accuracy: 74.38%	Loss: 0.525079
# Train epoch: 7 [60/375]	Accuracy: 72.81%	Loss: 0.558485
# Train epoch: 7 [70/375]	Accuracy: 74.06%	Loss: 0.537899
# Train epoch: 7 [80/375]	Accuracy: 71.88%	Loss: 0.578646
# Train epoch: 7 [90/375]	Accuracy: 69.69%	Loss: 0.579883
# Train epoch: 7 [100/375]	Accuracy: 75.31%	Loss: 0.518204
# Train epoch: 7 [110/375]	Accuracy: 71.25%	Loss: 0.558997
# Train epoch: 7 [120/375]	Accuracy: 74.06%	Loss: 0.485733
# Train epoch: 7 [130/375]	Accuracy: 77.19%	Loss: 0.476614
# Train epoch: 7 [140/375]	Accuracy: 76.88%	Loss: 0.501252
# Train epoch: 7 [150/375]	Accuracy: 73.12%	Loss: 0.520623
# Train epoch: 7 [160/375]	Accuracy: 72.81%	Loss: 0.535703
# Train epoch: 7 [170/375]	Accuracy: 74.06%	Loss: 0.544720
# Train epoch: 7 [180/375]	Accuracy: 73.44%	Loss: 0.526430
# Train epoch: 7 [190/375]	Accuracy: 74.69%	Loss: 0.483484
# Train epoch: 7 [200/375]	Accuracy: 76.25%	Loss: 0.482530
# Train epoch: 7 [210/375]	Accuracy: 75.31%	Loss: 0.528935
# Train epoch: 7 [220/375]	Accuracy: 74.69%	Loss: 0.520994
# Train epoch: 7 [230/375]	Accuracy: 67.81%	Loss: 0.614833
# Train epoch: 7 [240/375]	Accuracy: 71.88%	Loss: 0.550139
# Train epoch: 7 [250/375]	Accuracy: 76.88%	Loss: 0.510366
# Train epoch: 7 [260/375]	Accuracy: 71.56%	Loss: 0.553243
# Train epoch: 7 [270/375]	Accuracy: 74.69%	Loss: 0.529917
# Train epoch: 7 [280/375]	Accuracy: 71.25%	Loss: 0.544884
# Train epoch: 7 [290/375]	Accuracy: 75.62%	Loss: 0.524401
# Train epoch: 7 [300/375]	Accuracy: 71.88%	Loss: 0.547115
# Train epoch: 7 [310/375]	Accuracy: 72.50%	Loss: 0.529502
# Train epoch: 7 [320/375]	Accuracy: 76.56%	Loss: 0.531992
# Train epoch: 7 [330/375]	Accuracy: 72.81%	Loss: 0.548665
# Train epoch: 7 [340/375]	Accuracy: 73.75%	Loss: 0.521384
# Train epoch: 7 [350/375]	Accuracy: 72.50%	Loss: 0.539357
# Train epoch: 7 [360/375]	Accuracy: 75.94%	Loss: 0.481485
# Train epoch: 7 [370/375]	Accuracy: 72.81%	Loss: 0.549704
# Test set: Loss: 0.5475, Accuracy: 68.85%)
# Train epoch: 8 [10/375]	Accuracy: 75.31%	Loss: 0.519030
# Train epoch: 8 [20/375]	Accuracy: 76.88%	Loss: 0.483677
# Train epoch: 8 [30/375]	Accuracy: 74.06%	Loss: 0.489057
# Train epoch: 8 [40/375]	Accuracy: 68.44%	Loss: 0.559072
# Train epoch: 8 [50/375]	Accuracy: 72.19%	Loss: 0.511357
# Train epoch: 8 [60/375]	Accuracy: 77.19%	Loss: 0.502153
# Train epoch: 8 [70/375]	Accuracy: 71.25%	Loss: 0.545736
# Train epoch: 8 [80/375]	Accuracy: 74.06%	Loss: 0.489787
# Train epoch: 8 [90/375]	Accuracy: 78.12%	Loss: 0.483552
# Train epoch: 8 [100/375]	Accuracy: 72.19%	Loss: 0.552536
# Train epoch: 8 [110/375]	Accuracy: 71.25%	Loss: 0.562600
# Train epoch: 8 [120/375]	Accuracy: 75.31%	Loss: 0.517526
# Train epoch: 8 [130/375]	Accuracy: 71.88%	Loss: 0.565412
# Train epoch: 8 [140/375]	Accuracy: 76.88%	Loss: 0.500755
# Train epoch: 8 [150/375]	Accuracy: 74.38%	Loss: 0.531963
# Train epoch: 8 [160/375]	Accuracy: 75.00%	Loss: 0.490557
# Train epoch: 8 [170/375]	Accuracy: 74.38%	Loss: 0.514880
# Train epoch: 8 [180/375]	Accuracy: 68.44%	Loss: 0.558317
# Train epoch: 8 [190/375]	Accuracy: 77.19%	Loss: 0.480541
# Train epoch: 8 [200/375]	Accuracy: 74.06%	Loss: 0.486686
# Train epoch: 8 [210/375]	Accuracy: 78.75%	Loss: 0.499450
# Train epoch: 8 [220/375]	Accuracy: 77.19%	Loss: 0.500673
# Train epoch: 8 [230/375]	Accuracy: 77.50%	Loss: 0.477865
# Train epoch: 8 [240/375]	Accuracy: 74.38%	Loss: 0.563742
# Train epoch: 8 [250/375]	Accuracy: 75.31%	Loss: 0.509967
# Train epoch: 8 [260/375]	Accuracy: 75.31%	Loss: 0.501217
# Train epoch: 8 [270/375]	Accuracy: 73.44%	Loss: 0.523891
# Train epoch: 8 [280/375]	Accuracy: 76.88%	Loss: 0.475154
# Train epoch: 8 [290/375]	Accuracy: 75.62%	Loss: 0.519938
# Train epoch: 8 [300/375]	Accuracy: 73.44%	Loss: 0.515632
# Train epoch: 8 [310/375]	Accuracy: 75.31%	Loss: 0.495764
# Train epoch: 8 [320/375]	Accuracy: 70.62%	Loss: 0.573460
# Train epoch: 8 [330/375]	Accuracy: 75.62%	Loss: 0.520121
# Train epoch: 8 [340/375]	Accuracy: 79.06%	Loss: 0.469057
# Train epoch: 8 [350/375]	Accuracy: 72.81%	Loss: 0.548557
# Train epoch: 8 [360/375]	Accuracy: 72.81%	Loss: 0.565018
# Train epoch: 8 [370/375]	Accuracy: 77.19%	Loss: 0.492278
# Test set: Loss: 0.4488, Accuracy: 76.14%)
# Train epoch: 9 [10/375]	Accuracy: 71.25%	Loss: 0.518122
# Train epoch: 9 [20/375]	Accuracy: 70.31%	Loss: 0.564325
# Train epoch: 9 [30/375]	Accuracy: 79.69%	Loss: 0.448708
# Train epoch: 9 [40/375]	Accuracy: 75.31%	Loss: 0.509590
# Train epoch: 9 [50/375]	Accuracy: 75.94%	Loss: 0.495175
# Train epoch: 9 [60/375]	Accuracy: 71.88%	Loss: 0.543566
# Train epoch: 9 [70/375]	Accuracy: 77.50%	Loss: 0.462672
# Train epoch: 9 [80/375]	Accuracy: 72.81%	Loss: 0.522215
# Train epoch: 9 [90/375]	Accuracy: 77.19%	Loss: 0.488348
# Train epoch: 9 [100/375]	Accuracy: 75.94%	Loss: 0.553759
# Train epoch: 9 [110/375]	Accuracy: 75.94%	Loss: 0.477199
# Train epoch: 9 [120/375]	Accuracy: 77.19%	Loss: 0.482755
# Train epoch: 9 [130/375]	Accuracy: 76.25%	Loss: 0.520375
# Train epoch: 9 [140/375]	Accuracy: 72.19%	Loss: 0.530067
# Train epoch: 9 [150/375]	Accuracy: 72.81%	Loss: 0.510024
# Train epoch: 9 [160/375]	Accuracy: 73.75%	Loss: 0.496597
# Train epoch: 9 [170/375]	Accuracy: 73.75%	Loss: 0.528388
# Train epoch: 9 [180/375]	Accuracy: 75.00%	Loss: 0.511941
# Train epoch: 9 [190/375]	Accuracy: 78.12%	Loss: 0.481408
# Train epoch: 9 [200/375]	Accuracy: 78.12%	Loss: 0.477383
# Train epoch: 9 [210/375]	Accuracy: 76.25%	Loss: 0.530766
# Train epoch: 9 [220/375]	Accuracy: 75.00%	Loss: 0.513441
# Train epoch: 9 [230/375]	Accuracy: 73.44%	Loss: 0.490580
# Train epoch: 9 [240/375]	Accuracy: 73.44%	Loss: 0.527220
# Train epoch: 9 [250/375]	Accuracy: 74.38%	Loss: 0.527640
# Train epoch: 9 [260/375]	Accuracy: 70.94%	Loss: 0.552032
# Train epoch: 9 [270/375]	Accuracy: 74.06%	Loss: 0.534188
# Train epoch: 9 [280/375]	Accuracy: 75.31%	Loss: 0.497147
# Train epoch: 9 [290/375]	Accuracy: 78.44%	Loss: 0.473683
# Train epoch: 9 [300/375]	Accuracy: 76.88%	Loss: 0.488080
# Train epoch: 9 [310/375]	Accuracy: 77.81%	Loss: 0.512843
# Train epoch: 9 [320/375]	Accuracy: 72.19%	Loss: 0.529207
# Train epoch: 9 [330/375]	Accuracy: 73.75%	Loss: 0.523487
# Train epoch: 9 [340/375]	Accuracy: 74.69%	Loss: 0.515033
# Train epoch: 9 [350/375]	Accuracy: 75.94%	Loss: 0.515781
# Train epoch: 9 [360/375]	Accuracy: 78.75%	Loss: 0.476741
# Train epoch: 9 [370/375]	Accuracy: 68.75%	Loss: 0.567363
# Test set: Loss: 0.4849, Accuracy: 74.36%)
# Train epoch: 10 [10/375]	Accuracy: 76.56%	Loss: 0.493139
# Train epoch: 10 [20/375]	Accuracy: 70.31%	Loss: 0.529859
# Train epoch: 10 [30/375]	Accuracy: 75.94%	Loss: 0.497573
# Train epoch: 10 [40/375]	Accuracy: 74.69%	Loss: 0.497465
# Train epoch: 10 [50/375]	Accuracy: 78.44%	Loss: 0.475564
# Train epoch: 10 [60/375]	Accuracy: 80.31%	Loss: 0.488758
# Train epoch: 10 [70/375]	Accuracy: 79.06%	Loss: 0.479926
# Train epoch: 10 [80/375]	Accuracy: 79.38%	Loss: 0.465095
# Train epoch: 10 [90/375]	Accuracy: 72.81%	Loss: 0.541174
# Train epoch: 10 [100/375]	Accuracy: 75.94%	Loss: 0.492646
# Train epoch: 10 [110/375]	Accuracy: 74.38%	Loss: 0.533878
# Train epoch: 10 [120/375]	Accuracy: 74.06%	Loss: 0.542028
# Train epoch: 10 [130/375]	Accuracy: 74.06%	Loss: 0.500900
# Train epoch: 10 [140/375]	Accuracy: 71.88%	Loss: 0.518848
# Train epoch: 10 [150/375]	Accuracy: 76.56%	Loss: 0.484409
# Train epoch: 10 [160/375]	Accuracy: 76.56%	Loss: 0.483947
# Train epoch: 10 [170/375]	Accuracy: 75.00%	Loss: 0.505839
# Train epoch: 10 [180/375]	Accuracy: 81.88%	Loss: 0.434388
# Train epoch: 10 [190/375]	Accuracy: 74.69%	Loss: 0.525058
# Train epoch: 10 [200/375]	Accuracy: 73.12%	Loss: 0.499954
# Train epoch: 10 [210/375]	Accuracy: 77.50%	Loss: 0.477589
# Train epoch: 10 [220/375]	Accuracy: 76.25%	Loss: 0.498198
# Train epoch: 10 [230/375]	Accuracy: 77.81%	Loss: 0.474337
# Train epoch: 10 [240/375]	Accuracy: 74.69%	Loss: 0.494639
# Train epoch: 10 [250/375]	Accuracy: 72.81%	Loss: 0.531087
# Train epoch: 10 [260/375]	Accuracy: 74.69%	Loss: 0.506241
# Train epoch: 10 [270/375]	Accuracy: 73.44%	Loss: 0.519207
# Train epoch: 10 [280/375]	Accuracy: 75.31%	Loss: 0.473842
# Train epoch: 10 [290/375]	Accuracy: 76.88%	Loss: 0.479819
# Train epoch: 10 [300/375]	Accuracy: 77.19%	Loss: 0.501919
# Train epoch: 10 [310/375]	Accuracy: 76.25%	Loss: 0.511457
# Train epoch: 10 [320/375]	Accuracy: 71.56%	Loss: 0.542335
# Train epoch: 10 [330/375]	Accuracy: 75.62%	Loss: 0.521355
# Train epoch: 10 [340/375]	Accuracy: 76.25%	Loss: 0.485390
# Train epoch: 10 [350/375]	Accuracy: 72.81%	Loss: 0.514968
# Train epoch: 10 [360/375]	Accuracy: 77.81%	Loss: 0.486309
# Train epoch: 10 [370/375]	Accuracy: 77.19%	Loss: 0.447653
# Test set: Loss: 0.7715, Accuracy: 63.79%)
# Train epoch: 11 [10/375]	Accuracy: 78.12%	Loss: 0.496067
# Train epoch: 11 [20/375]	Accuracy: 75.31%	Loss: 0.502669
# Train epoch: 11 [30/375]	Accuracy: 75.94%	Loss: 0.522166
# Train epoch: 11 [40/375]	Accuracy: 74.38%	Loss: 0.539656
# Train epoch: 11 [50/375]	Accuracy: 80.31%	Loss: 0.468187
# Train epoch: 11 [60/375]	Accuracy: 75.62%	Loss: 0.495811
# Train epoch: 11 [70/375]	Accuracy: 78.75%	Loss: 0.447482
# Train epoch: 11 [80/375]	Accuracy: 73.44%	Loss: 0.498391
# Train epoch: 11 [90/375]	Accuracy: 73.44%	Loss: 0.537920
# Train epoch: 11 [100/375]	Accuracy: 76.88%	Loss: 0.492995
# Train epoch: 11 [110/375]	Accuracy: 75.00%	Loss: 0.507918
# Train epoch: 11 [120/375]	Accuracy: 75.31%	Loss: 0.530116
# Train epoch: 11 [130/375]	Accuracy: 77.50%	Loss: 0.486755
# Train epoch: 11 [140/375]	Accuracy: 76.56%	Loss: 0.476350
# Train epoch: 11 [150/375]	Accuracy: 78.44%	Loss: 0.473717
# Train epoch: 11 [160/375]	Accuracy: 79.38%	Loss: 0.439323
# Train epoch: 11 [170/375]	Accuracy: 79.69%	Loss: 0.440609
# Train epoch: 11 [180/375]	Accuracy: 71.88%	Loss: 0.507841
# Train epoch: 11 [190/375]	Accuracy: 69.38%	Loss: 0.571123
# Train epoch: 11 [200/375]	Accuracy: 77.19%	Loss: 0.480979
# Train epoch: 11 [210/375]	Accuracy: 79.06%	Loss: 0.469490
# Train epoch: 11 [220/375]	Accuracy: 76.88%	Loss: 0.477061
# Train epoch: 11 [230/375]	Accuracy: 81.25%	Loss: 0.436147
# Train epoch: 11 [240/375]	Accuracy: 75.31%	Loss: 0.518591
# Train epoch: 11 [250/375]	Accuracy: 75.31%	Loss: 0.486100
# Train epoch: 11 [260/375]	Accuracy: 73.44%	Loss: 0.509949
# Train epoch: 11 [270/375]	Accuracy: 74.38%	Loss: 0.503764
# Train epoch: 11 [280/375]	Accuracy: 80.31%	Loss: 0.448359
# Train epoch: 11 [290/375]	Accuracy: 81.56%	Loss: 0.450182
# Train epoch: 11 [300/375]	Accuracy: 75.94%	Loss: 0.505850
# Train epoch: 11 [310/375]	Accuracy: 76.56%	Loss: 0.456964
# Train epoch: 11 [320/375]	Accuracy: 72.19%	Loss: 0.531648
# Train epoch: 11 [330/375]	Accuracy: 74.38%	Loss: 0.484983
# Train epoch: 11 [340/375]	Accuracy: 71.56%	Loss: 0.542535
# Train epoch: 11 [350/375]	Accuracy: 75.31%	Loss: 0.475030
# Train epoch: 11 [360/375]	Accuracy: 78.75%	Loss: 0.452486
# Train epoch: 11 [370/375]	Accuracy: 75.31%	Loss: 0.459776
# Test set: Loss: 0.4704, Accuracy: 74.65%)
# Train epoch: 12 [10/375]	Accuracy: 77.50%	Loss: 0.462685
# Train epoch: 12 [20/375]	Accuracy: 75.94%	Loss: 0.500387
# Train epoch: 12 [30/375]	Accuracy: 74.06%	Loss: 0.477249
# Train epoch: 12 [40/375]	Accuracy: 78.12%	Loss: 0.464518
# Train epoch: 12 [50/375]	Accuracy: 75.00%	Loss: 0.503392
# Train epoch: 12 [60/375]	Accuracy: 80.00%	Loss: 0.439086
# Train epoch: 12 [70/375]	Accuracy: 79.69%	Loss: 0.451529
# Train epoch: 12 [80/375]	Accuracy: 78.44%	Loss: 0.428498
# Train epoch: 12 [90/375]	Accuracy: 75.62%	Loss: 0.491067
# Train epoch: 12 [100/375]	Accuracy: 72.81%	Loss: 0.538602
# Train epoch: 12 [110/375]	Accuracy: 76.56%	Loss: 0.519056
# Train epoch: 12 [120/375]	Accuracy: 73.12%	Loss: 0.510156
# Train epoch: 12 [130/375]	Accuracy: 75.31%	Loss: 0.519747
# Train epoch: 12 [140/375]	Accuracy: 80.00%	Loss: 0.466212
# Train epoch: 12 [150/375]	Accuracy: 75.62%	Loss: 0.488832
# Train epoch: 12 [160/375]	Accuracy: 73.12%	Loss: 0.510518
# Train epoch: 12 [170/375]	Accuracy: 78.12%	Loss: 0.509604
# Train epoch: 12 [180/375]	Accuracy: 76.56%	Loss: 0.488288
# Train epoch: 12 [190/375]	Accuracy: 74.06%	Loss: 0.569690
# Train epoch: 12 [200/375]	Accuracy: 73.44%	Loss: 0.493793
# Train epoch: 12 [210/375]	Accuracy: 77.19%	Loss: 0.460084
# Train epoch: 12 [220/375]	Accuracy: 76.25%	Loss: 0.495831
# Train epoch: 12 [230/375]	Accuracy: 74.06%	Loss: 0.504224
# Train epoch: 12 [240/375]	Accuracy: 79.69%	Loss: 0.448787
# Train epoch: 12 [250/375]	Accuracy: 75.94%	Loss: 0.476241
# Train epoch: 12 [260/375]	Accuracy: 81.88%	Loss: 0.452433
# Train epoch: 12 [270/375]	Accuracy: 77.81%	Loss: 0.465406
# Train epoch: 12 [280/375]	Accuracy: 76.56%	Loss: 0.447286
# Train epoch: 12 [290/375]	Accuracy: 79.69%	Loss: 0.443059
# Train epoch: 12 [300/375]	Accuracy: 75.62%	Loss: 0.502248
# Train epoch: 12 [310/375]	Accuracy: 77.50%	Loss: 0.498695
# Train epoch: 12 [320/375]	Accuracy: 74.06%	Loss: 0.502897
# Train epoch: 12 [330/375]	Accuracy: 77.50%	Loss: 0.498672
# Train epoch: 12 [340/375]	Accuracy: 77.19%	Loss: 0.450902
# Train epoch: 12 [350/375]	Accuracy: 75.31%	Loss: 0.505656
# Train epoch: 12 [360/375]	Accuracy: 75.94%	Loss: 0.482147
# Train epoch: 12 [370/375]	Accuracy: 75.94%	Loss: 0.463684
# Test set: Loss: 0.3970, Accuracy: 80.31%)
# Train epoch: 13 [10/375]	Accuracy: 80.94%	Loss: 0.445092
# Train epoch: 13 [20/375]	Accuracy: 75.94%	Loss: 0.480432
# Train epoch: 13 [30/375]	Accuracy: 79.06%	Loss: 0.451320
# Train epoch: 13 [40/375]	Accuracy: 74.69%	Loss: 0.508114
# Train epoch: 13 [50/375]	Accuracy: 80.00%	Loss: 0.420508
# Train epoch: 13 [60/375]	Accuracy: 77.81%	Loss: 0.461644
# Train epoch: 13 [70/375]	Accuracy: 77.81%	Loss: 0.475412
# Train epoch: 13 [80/375]	Accuracy: 76.88%	Loss: 0.496442
# Train epoch: 13 [90/375]	Accuracy: 77.81%	Loss: 0.497865
# Train epoch: 13 [100/375]	Accuracy: 75.62%	Loss: 0.473400
# Train epoch: 13 [110/375]	Accuracy: 82.19%	Loss: 0.427336
# Train epoch: 13 [120/375]	Accuracy: 75.62%	Loss: 0.477713
# Train epoch: 13 [130/375]	Accuracy: 76.25%	Loss: 0.470240
# Train epoch: 13 [140/375]	Accuracy: 73.44%	Loss: 0.500800
# Train epoch: 13 [150/375]	Accuracy: 81.56%	Loss: 0.416703
# Train epoch: 13 [160/375]	Accuracy: 76.88%	Loss: 0.452688
# Train epoch: 13 [170/375]	Accuracy: 78.12%	Loss: 0.440376
# Train epoch: 13 [180/375]	Accuracy: 76.56%	Loss: 0.477771
# Train epoch: 13 [190/375]	Accuracy: 74.38%	Loss: 0.519084
# Train epoch: 13 [200/375]	Accuracy: 77.19%	Loss: 0.478551
# Train epoch: 13 [210/375]	Accuracy: 81.56%	Loss: 0.428824
# Train epoch: 13 [220/375]	Accuracy: 76.25%	Loss: 0.477434
# Train epoch: 13 [230/375]	Accuracy: 79.69%	Loss: 0.492518
# Train epoch: 13 [240/375]	Accuracy: 78.12%	Loss: 0.458663
# Train epoch: 13 [250/375]	Accuracy: 77.81%	Loss: 0.434165
# Train epoch: 13 [260/375]	Accuracy: 78.44%	Loss: 0.435467
# Train epoch: 13 [270/375]	Accuracy: 76.88%	Loss: 0.451433
# Train epoch: 13 [280/375]	Accuracy: 78.44%	Loss: 0.456068
# Train epoch: 13 [290/375]	Accuracy: 79.69%	Loss: 0.427774
# Train epoch: 13 [300/375]	Accuracy: 79.38%	Loss: 0.459275
# Train epoch: 13 [310/375]	Accuracy: 78.44%	Loss: 0.459523
# Train epoch: 13 [320/375]	Accuracy: 78.75%	Loss: 0.421004
# Train epoch: 13 [330/375]	Accuracy: 73.12%	Loss: 0.516764
# Train epoch: 13 [340/375]	Accuracy: 72.19%	Loss: 0.499400
# Train epoch: 13 [350/375]	Accuracy: 82.50%	Loss: 0.383534
# Train epoch: 13 [360/375]	Accuracy: 78.44%	Loss: 0.448733
# Train epoch: 13 [370/375]	Accuracy: 76.88%	Loss: 0.469632
# Test set: Loss: 0.4079, Accuracy: 80.70%)
# Train epoch: 14 [10/375]	Accuracy: 79.06%	Loss: 0.481759
# Train epoch: 14 [20/375]	Accuracy: 77.50%	Loss: 0.479304
# Train epoch: 14 [30/375]	Accuracy: 77.50%	Loss: 0.459725
# Train epoch: 14 [40/375]	Accuracy: 75.94%	Loss: 0.456234
# Train epoch: 14 [50/375]	Accuracy: 79.38%	Loss: 0.469752
# Train epoch: 14 [60/375]	Accuracy: 78.44%	Loss: 0.481421
# Train epoch: 14 [70/375]	Accuracy: 78.75%	Loss: 0.440007
# Train epoch: 14 [80/375]	Accuracy: 77.81%	Loss: 0.493950
# Train epoch: 14 [90/375]	Accuracy: 74.38%	Loss: 0.502250
# Train epoch: 14 [100/375]	Accuracy: 73.12%	Loss: 0.509351
# Train epoch: 14 [110/375]	Accuracy: 76.56%	Loss: 0.495094
# Train epoch: 14 [120/375]	Accuracy: 75.00%	Loss: 0.491524
# Train epoch: 14 [130/375]	Accuracy: 76.56%	Loss: 0.468310
# Train epoch: 14 [140/375]	Accuracy: 79.06%	Loss: 0.482954
# Train epoch: 14 [150/375]	Accuracy: 80.00%	Loss: 0.446380
# Train epoch: 14 [160/375]	Accuracy: 79.06%	Loss: 0.452534
# Train epoch: 14 [170/375]	Accuracy: 76.56%	Loss: 0.462945
# Train epoch: 14 [180/375]	Accuracy: 80.31%	Loss: 0.431473
# Train epoch: 14 [190/375]	Accuracy: 79.69%	Loss: 0.448782
# Train epoch: 14 [200/375]	Accuracy: 77.81%	Loss: 0.457406
# Train epoch: 14 [210/375]	Accuracy: 75.31%	Loss: 0.481206
# Train epoch: 14 [220/375]	Accuracy: 79.06%	Loss: 0.420347
# Train epoch: 14 [230/375]	Accuracy: 78.44%	Loss: 0.458226
# Train epoch: 14 [240/375]	Accuracy: 81.56%	Loss: 0.435968
# Train epoch: 14 [250/375]	Accuracy: 80.62%	Loss: 0.453509
# Train epoch: 14 [260/375]	Accuracy: 81.25%	Loss: 0.398791
# Train epoch: 14 [270/375]	Accuracy: 81.25%	Loss: 0.408975
# Train epoch: 14 [280/375]	Accuracy: 77.81%	Loss: 0.443220
# Train epoch: 14 [290/375]	Accuracy: 72.81%	Loss: 0.506023
# Train epoch: 14 [300/375]	Accuracy: 79.69%	Loss: 0.451868
# Train epoch: 14 [310/375]	Accuracy: 80.31%	Loss: 0.433142
# Train epoch: 14 [320/375]	Accuracy: 77.19%	Loss: 0.489788
# Train epoch: 14 [330/375]	Accuracy: 80.94%	Loss: 0.436460
# Train epoch: 14 [340/375]	Accuracy: 80.00%	Loss: 0.428178
# Train epoch: 14 [350/375]	Accuracy: 78.44%	Loss: 0.488465
# Train epoch: 14 [360/375]	Accuracy: 80.94%	Loss: 0.424902
# Train epoch: 14 [370/375]	Accuracy: 76.88%	Loss: 0.471208
# Test set: Loss: 0.4953, Accuracy: 74.40%)
# Train epoch: 15 [10/375]	Accuracy: 79.06%	Loss: 0.435693
# Train epoch: 15 [20/375]	Accuracy: 76.56%	Loss: 0.446045
# Train epoch: 15 [30/375]	Accuracy: 79.38%	Loss: 0.432171
# Train epoch: 15 [40/375]	Accuracy: 79.38%	Loss: 0.416405
# Train epoch: 15 [50/375]	Accuracy: 80.00%	Loss: 0.432806
# Train epoch: 15 [60/375]	Accuracy: 75.31%	Loss: 0.459842
# Train epoch: 15 [70/375]	Accuracy: 78.44%	Loss: 0.438302
# Train epoch: 15 [80/375]	Accuracy: 79.06%	Loss: 0.433871
# Train epoch: 15 [90/375]	Accuracy: 83.75%	Loss: 0.396888
# Train epoch: 15 [100/375]	Accuracy: 81.56%	Loss: 0.445872
# Train epoch: 15 [110/375]	Accuracy: 75.31%	Loss: 0.505645
# Train epoch: 15 [120/375]	Accuracy: 79.06%	Loss: 0.439336
# Train epoch: 15 [130/375]	Accuracy: 76.56%	Loss: 0.495919
# Train epoch: 15 [140/375]	Accuracy: 73.44%	Loss: 0.520508
# Train epoch: 15 [150/375]	Accuracy: 81.56%	Loss: 0.416263
# Train epoch: 15 [160/375]	Accuracy: 81.25%	Loss: 0.420131
# Train epoch: 15 [170/375]	Accuracy: 80.62%	Loss: 0.443433
# Train epoch: 15 [180/375]	Accuracy: 77.81%	Loss: 0.440117
# Train epoch: 15 [190/375]	Accuracy: 80.94%	Loss: 0.442035
# Train epoch: 15 [200/375]	Accuracy: 80.00%	Loss: 0.450513
# Train epoch: 15 [210/375]	Accuracy: 81.25%	Loss: 0.435792
# Train epoch: 15 [220/375]	Accuracy: 77.50%	Loss: 0.464656
# Train epoch: 15 [230/375]	Accuracy: 79.69%	Loss: 0.418818
# Train epoch: 15 [240/375]	Accuracy: 80.94%	Loss: 0.447553
# Train epoch: 15 [250/375]	Accuracy: 75.31%	Loss: 0.492961
# Train epoch: 15 [260/375]	Accuracy: 76.56%	Loss: 0.469239
# Train epoch: 15 [270/375]	Accuracy: 80.00%	Loss: 0.422531
# Train epoch: 15 [280/375]	Accuracy: 79.06%	Loss: 0.421747
# Train epoch: 15 [290/375]	Accuracy: 75.94%	Loss: 0.508282
# Train epoch: 15 [300/375]	Accuracy: 76.88%	Loss: 0.506459
# Train epoch: 15 [310/375]	Accuracy: 81.56%	Loss: 0.430510
# Train epoch: 15 [320/375]	Accuracy: 74.38%	Loss: 0.456339
# Train epoch: 15 [330/375]	Accuracy: 76.56%	Loss: 0.474101
# Train epoch: 15 [340/375]	Accuracy: 78.12%	Loss: 0.468905
# Train epoch: 15 [350/375]	Accuracy: 79.38%	Loss: 0.402383
# Train epoch: 15 [360/375]	Accuracy: 79.38%	Loss: 0.407782
# Train epoch: 15 [370/375]	Accuracy: 79.06%	Loss: 0.422394
# Test set: Loss: 0.4919, Accuracy: 75.30%)
# Train epoch: 16 [10/375]	Accuracy: 80.31%	Loss: 0.412708
# Train epoch: 16 [20/375]	Accuracy: 81.25%	Loss: 0.429988
# Train epoch: 16 [30/375]	Accuracy: 82.81%	Loss: 0.394142
# Train epoch: 16 [40/375]	Accuracy: 76.88%	Loss: 0.491390
# Train epoch: 16 [50/375]	Accuracy: 78.75%	Loss: 0.426250
# Train epoch: 16 [60/375]	Accuracy: 75.00%	Loss: 0.480248
# Train epoch: 16 [70/375]	Accuracy: 80.00%	Loss: 0.432747
# Train epoch: 16 [80/375]	Accuracy: 79.38%	Loss: 0.466240
# Train epoch: 16 [90/375]	Accuracy: 80.00%	Loss: 0.414161
# Train epoch: 16 [100/375]	Accuracy: 80.94%	Loss: 0.445213
# Train epoch: 16 [110/375]	Accuracy: 79.38%	Loss: 0.439491
# Train epoch: 16 [120/375]	Accuracy: 77.19%	Loss: 0.427027
# Train epoch: 16 [130/375]	Accuracy: 80.31%	Loss: 0.426144
# Train epoch: 16 [140/375]	Accuracy: 78.12%	Loss: 0.451371
# Train epoch: 16 [150/375]	Accuracy: 79.06%	Loss: 0.432735
# Train epoch: 16 [160/375]	Accuracy: 77.50%	Loss: 0.425527
# Train epoch: 16 [170/375]	Accuracy: 72.19%	Loss: 0.492656
# Train epoch: 16 [180/375]	Accuracy: 81.25%	Loss: 0.412254
# Train epoch: 16 [190/375]	Accuracy: 82.19%	Loss: 0.403956
# Train epoch: 16 [200/375]	Accuracy: 80.62%	Loss: 0.464658
# Train epoch: 16 [210/375]	Accuracy: 77.50%	Loss: 0.447727
# Train epoch: 16 [220/375]	Accuracy: 79.06%	Loss: 0.456086
# Train epoch: 16 [230/375]	Accuracy: 78.75%	Loss: 0.468828
# Train epoch: 16 [240/375]	Accuracy: 75.62%	Loss: 0.459291
# Train epoch: 16 [250/375]	Accuracy: 80.94%	Loss: 0.405564
# Train epoch: 16 [260/375]	Accuracy: 82.19%	Loss: 0.405107
# Train epoch: 16 [270/375]	Accuracy: 78.75%	Loss: 0.465388
# Train epoch: 16 [280/375]	Accuracy: 77.81%	Loss: 0.459266
# Train epoch: 16 [290/375]	Accuracy: 78.44%	Loss: 0.478730
# Train epoch: 16 [300/375]	Accuracy: 79.06%	Loss: 0.435330
# Train epoch: 16 [310/375]	Accuracy: 80.94%	Loss: 0.401593
# Train epoch: 16 [320/375]	Accuracy: 78.44%	Loss: 0.450421
# Train epoch: 16 [330/375]	Accuracy: 79.06%	Loss: 0.449239
# Train epoch: 16 [340/375]	Accuracy: 79.69%	Loss: 0.434719
# Train epoch: 16 [350/375]	Accuracy: 77.19%	Loss: 0.461687
# Train epoch: 16 [360/375]	Accuracy: 77.19%	Loss: 0.452300
# Train epoch: 16 [370/375]	Accuracy: 80.31%	Loss: 0.448284
# Test set: Loss: 0.3625, Accuracy: 83.04%)
# Train epoch: 17 [10/375]	Accuracy: 78.75%	Loss: 0.434658
# Train epoch: 17 [20/375]	Accuracy: 75.62%	Loss: 0.493570
# Train epoch: 17 [30/375]	Accuracy: 78.75%	Loss: 0.432150
# Train epoch: 17 [40/375]	Accuracy: 78.75%	Loss: 0.448069
# Train epoch: 17 [50/375]	Accuracy: 81.25%	Loss: 0.403231
# Train epoch: 17 [60/375]	Accuracy: 83.44%	Loss: 0.390373
# Train epoch: 17 [70/375]	Accuracy: 79.69%	Loss: 0.445628
# Train epoch: 17 [80/375]	Accuracy: 78.75%	Loss: 0.419186
# Train epoch: 17 [90/375]	Accuracy: 69.38%	Loss: 0.531676
# Train epoch: 17 [100/375]	Accuracy: 78.75%	Loss: 0.491659
# Train epoch: 17 [110/375]	Accuracy: 79.69%	Loss: 0.435344
# Train epoch: 17 [120/375]	Accuracy: 79.06%	Loss: 0.438399
# Train epoch: 17 [130/375]	Accuracy: 80.31%	Loss: 0.417617
# Train epoch: 17 [140/375]	Accuracy: 79.69%	Loss: 0.414141
# Train epoch: 17 [150/375]	Accuracy: 80.62%	Loss: 0.435677
# Train epoch: 17 [160/375]	Accuracy: 81.25%	Loss: 0.425318
# Train epoch: 17 [170/375]	Accuracy: 77.19%	Loss: 0.439965
# Train epoch: 17 [180/375]	Accuracy: 81.25%	Loss: 0.384198
# Train epoch: 17 [190/375]	Accuracy: 75.31%	Loss: 0.516771
# Train epoch: 17 [200/375]	Accuracy: 82.19%	Loss: 0.450291
# Train epoch: 17 [210/375]	Accuracy: 77.81%	Loss: 0.455958
# Train epoch: 17 [220/375]	Accuracy: 80.31%	Loss: 0.413194
# Train epoch: 17 [230/375]	Accuracy: 78.44%	Loss: 0.461360
# Train epoch: 17 [240/375]	Accuracy: 81.88%	Loss: 0.421739
# Train epoch: 17 [250/375]	Accuracy: 82.19%	Loss: 0.420509
# Train epoch: 17 [260/375]	Accuracy: 79.06%	Loss: 0.441684
# Train epoch: 17 [270/375]	Accuracy: 78.12%	Loss: 0.422281
# Train epoch: 17 [280/375]	Accuracy: 78.12%	Loss: 0.463646
# Train epoch: 17 [290/375]	Accuracy: 81.25%	Loss: 0.400930
# Train epoch: 17 [300/375]	Accuracy: 79.06%	Loss: 0.405587
# Train epoch: 17 [310/375]	Accuracy: 81.25%	Loss: 0.372464
# Train epoch: 17 [320/375]	Accuracy: 81.56%	Loss: 0.452919
# Train epoch: 17 [330/375]	Accuracy: 76.25%	Loss: 0.472261
# Train epoch: 17 [340/375]	Accuracy: 80.94%	Loss: 0.436588
# Train epoch: 17 [350/375]	Accuracy: 77.81%	Loss: 0.433820
# Train epoch: 17 [360/375]	Accuracy: 83.44%	Loss: 0.399151
# Train epoch: 17 [370/375]	Accuracy: 83.44%	Loss: 0.382440
# Test set: Loss: 0.3323, Accuracy: 83.88%)
# Train epoch: 18 [10/375]	Accuracy: 81.56%	Loss: 0.367678
# Train epoch: 18 [20/375]	Accuracy: 80.94%	Loss: 0.382591
# Train epoch: 18 [30/375]	Accuracy: 78.75%	Loss: 0.446884
# Train epoch: 18 [40/375]	Accuracy: 78.75%	Loss: 0.437392
# Train epoch: 18 [50/375]	Accuracy: 81.88%	Loss: 0.401379
# Train epoch: 18 [60/375]	Accuracy: 78.75%	Loss: 0.440437
# Train epoch: 18 [70/375]	Accuracy: 78.44%	Loss: 0.439036
# Train epoch: 18 [80/375]	Accuracy: 81.25%	Loss: 0.401832
# Train epoch: 18 [90/375]	Accuracy: 79.69%	Loss: 0.429047
# Train epoch: 18 [100/375]	Accuracy: 78.12%	Loss: 0.428738
# Train epoch: 18 [110/375]	Accuracy: 80.31%	Loss: 0.424462
# Train epoch: 18 [120/375]	Accuracy: 82.81%	Loss: 0.407141
# Train epoch: 18 [130/375]	Accuracy: 75.94%	Loss: 0.418566
# Train epoch: 18 [140/375]	Accuracy: 79.38%	Loss: 0.416865
# Train epoch: 18 [150/375]	Accuracy: 78.44%	Loss: 0.453379
# Train epoch: 18 [160/375]	Accuracy: 76.56%	Loss: 0.447657
# Train epoch: 18 [170/375]	Accuracy: 83.75%	Loss: 0.362900
# Train epoch: 18 [180/375]	Accuracy: 80.00%	Loss: 0.434792
# Train epoch: 18 [190/375]	Accuracy: 77.19%	Loss: 0.458590
# Train epoch: 18 [200/375]	Accuracy: 83.12%	Loss: 0.386522
# Train epoch: 18 [210/375]	Accuracy: 77.50%	Loss: 0.455127
# Train epoch: 18 [220/375]	Accuracy: 81.56%	Loss: 0.393354
# Train epoch: 18 [230/375]	Accuracy: 83.44%	Loss: 0.372503
# Train epoch: 18 [240/375]	Accuracy: 79.38%	Loss: 0.414308
# Train epoch: 18 [250/375]	Accuracy: 80.62%	Loss: 0.401027
# Train epoch: 18 [260/375]	Accuracy: 80.00%	Loss: 0.405451
# Train epoch: 18 [270/375]	Accuracy: 76.25%	Loss: 0.457340
# Train epoch: 18 [280/375]	Accuracy: 77.50%	Loss: 0.474462
# Train epoch: 18 [290/375]	Accuracy: 77.50%	Loss: 0.479588
# Train epoch: 18 [300/375]	Accuracy: 79.38%	Loss: 0.453241
# Train epoch: 18 [310/375]	Accuracy: 79.06%	Loss: 0.460739
# Train epoch: 18 [320/375]	Accuracy: 78.44%	Loss: 0.419532
# Train epoch: 18 [330/375]	Accuracy: 84.69%	Loss: 0.383953
# Train epoch: 18 [340/375]	Accuracy: 81.25%	Loss: 0.408351
# Train epoch: 18 [350/375]	Accuracy: 80.31%	Loss: 0.428152
# Train epoch: 18 [360/375]	Accuracy: 77.50%	Loss: 0.424232
# Train epoch: 18 [370/375]	Accuracy: 75.94%	Loss: 0.486635
# Test set: Loss: 0.3859, Accuracy: 82.44%)
# Train epoch: 19 [10/375]	Accuracy: 84.06%	Loss: 0.396531
# Train epoch: 19 [20/375]	Accuracy: 81.25%	Loss: 0.448965
# Train epoch: 19 [30/375]	Accuracy: 76.88%	Loss: 0.437081
# Train epoch: 19 [40/375]	Accuracy: 81.88%	Loss: 0.383254
# Train epoch: 19 [50/375]	Accuracy: 80.00%	Loss: 0.423264
# Train epoch: 19 [60/375]	Accuracy: 76.56%	Loss: 0.433774
# Train epoch: 19 [70/375]	Accuracy: 83.44%	Loss: 0.415769
# Train epoch: 19 [80/375]	Accuracy: 76.88%	Loss: 0.471367
# Train epoch: 19 [90/375]	Accuracy: 83.12%	Loss: 0.386251
# Train epoch: 19 [100/375]	Accuracy: 83.12%	Loss: 0.378911
# Train epoch: 19 [110/375]	Accuracy: 78.12%	Loss: 0.447770
# Train epoch: 19 [120/375]	Accuracy: 79.06%	Loss: 0.433156
# Train epoch: 19 [130/375]	Accuracy: 80.31%	Loss: 0.419830
# Train epoch: 19 [140/375]	Accuracy: 80.62%	Loss: 0.412383
# Train epoch: 19 [150/375]	Accuracy: 79.06%	Loss: 0.446208
# Train epoch: 19 [160/375]	Accuracy: 78.75%	Loss: 0.434614
# Train epoch: 19 [170/375]	Accuracy: 81.88%	Loss: 0.384678
# Train epoch: 19 [180/375]	Accuracy: 80.94%	Loss: 0.399031
# Train epoch: 19 [190/375]	Accuracy: 77.81%	Loss: 0.427144
# Train epoch: 19 [200/375]	Accuracy: 80.00%	Loss: 0.411345
# Train epoch: 19 [210/375]	Accuracy: 83.44%	Loss: 0.355548
# Train epoch: 19 [220/375]	Accuracy: 79.06%	Loss: 0.441359
# Train epoch: 19 [230/375]	Accuracy: 80.00%	Loss: 0.395747
# Train epoch: 19 [240/375]	Accuracy: 77.19%	Loss: 0.443306
# Train epoch: 19 [250/375]	Accuracy: 80.00%	Loss: 0.401564
# Train epoch: 19 [260/375]	Accuracy: 80.31%	Loss: 0.413189
# Train epoch: 19 [270/375]	Accuracy: 81.25%	Loss: 0.402787
# Train epoch: 19 [280/375]	Accuracy: 82.50%	Loss: 0.380449
# Train epoch: 19 [290/375]	Accuracy: 80.94%	Loss: 0.422430
# Train epoch: 19 [300/375]	Accuracy: 75.62%	Loss: 0.441337
# Train epoch: 19 [310/375]	Accuracy: 79.38%	Loss: 0.511794
# Train epoch: 19 [320/375]	Accuracy: 77.81%	Loss: 0.454834
# Train epoch: 19 [330/375]	Accuracy: 80.62%	Loss: 0.434250
# Train epoch: 19 [340/375]	Accuracy: 84.69%	Loss: 0.355528
# Train epoch: 19 [350/375]	Accuracy: 79.38%	Loss: 0.450901
# Train epoch: 19 [360/375]	Accuracy: 78.12%	Loss: 0.460619
# Train epoch: 19 [370/375]	Accuracy: 79.69%	Loss: 0.423459
# Test set: Loss: 0.3807, Accuracy: 79.81%)
# Train epoch: 20 [10/375]	Accuracy: 85.00%	Loss: 0.348488
# Train epoch: 20 [20/375]	Accuracy: 77.50%	Loss: 0.438638
# Train epoch: 20 [30/375]	Accuracy: 78.75%	Loss: 0.424698
# Train epoch: 20 [40/375]	Accuracy: 75.00%	Loss: 0.451403
# Train epoch: 20 [50/375]	Accuracy: 79.06%	Loss: 0.430469
# Train epoch: 20 [60/375]	Accuracy: 79.69%	Loss: 0.411341
# Train epoch: 20 [70/375]	Accuracy: 80.94%	Loss: 0.448914
# Train epoch: 20 [80/375]	Accuracy: 81.56%	Loss: 0.406485
# Train epoch: 20 [90/375]	Accuracy: 84.69%	Loss: 0.368009
# Train epoch: 20 [100/375]	Accuracy: 82.19%	Loss: 0.388725
# Train epoch: 20 [110/375]	Accuracy: 79.69%	Loss: 0.429307
# Train epoch: 20 [120/375]	Accuracy: 78.12%	Loss: 0.436529
# Train epoch: 20 [130/375]	Accuracy: 78.44%	Loss: 0.441646
# Train epoch: 20 [140/375]	Accuracy: 81.88%	Loss: 0.397071
# Train epoch: 20 [150/375]	Accuracy: 80.00%	Loss: 0.381892
# Train epoch: 20 [160/375]	Accuracy: 79.38%	Loss: 0.400515
# Train epoch: 20 [170/375]	Accuracy: 79.69%	Loss: 0.394570
# Train epoch: 20 [180/375]	Accuracy: 84.69%	Loss: 0.362154
# Train epoch: 20 [190/375]	Accuracy: 78.44%	Loss: 0.452020
# Train epoch: 20 [200/375]	Accuracy: 77.81%	Loss: 0.508077
# Train epoch: 20 [210/375]	Accuracy: 77.50%	Loss: 0.438428
# Train epoch: 20 [220/375]	Accuracy: 79.06%	Loss: 0.414507
# Train epoch: 20 [230/375]	Accuracy: 80.94%	Loss: 0.418277
# Train epoch: 20 [240/375]	Accuracy: 78.44%	Loss: 0.447376
# Train epoch: 20 [250/375]	Accuracy: 83.44%	Loss: 0.371225
# Train epoch: 20 [260/375]	Accuracy: 76.25%	Loss: 0.464298
# Train epoch: 20 [270/375]	Accuracy: 82.50%	Loss: 0.394973
# Train epoch: 20 [280/375]	Accuracy: 80.62%	Loss: 0.422395
# Train epoch: 20 [290/375]	Accuracy: 82.19%	Loss: 0.381337
# Train epoch: 20 [300/375]	Accuracy: 80.00%	Loss: 0.388488
# Train epoch: 20 [310/375]	Accuracy: 77.19%	Loss: 0.422217
# Train epoch: 20 [320/375]	Accuracy: 80.94%	Loss: 0.415291
# Train epoch: 20 [330/375]	Accuracy: 83.75%	Loss: 0.383000
# Train epoch: 20 [340/375]	Accuracy: 83.44%	Loss: 0.405781
# Train epoch: 20 [350/375]	Accuracy: 78.12%	Loss: 0.469940
# Train epoch: 20 [360/375]	Accuracy: 83.44%	Loss: 0.400748
# Train epoch: 20 [370/375]	Accuracy: 82.19%	Loss: 0.393989
# Test set: Loss: 0.4126, Accuracy: 78.72%)
# Train epoch: 21 [10/375]	Accuracy: 76.56%	Loss: 0.421171
# Train epoch: 21 [20/375]	Accuracy: 80.62%	Loss: 0.426520
# Train epoch: 21 [30/375]	Accuracy: 77.50%	Loss: 0.444829
# Train epoch: 21 [40/375]	Accuracy: 81.88%	Loss: 0.406704
# Train epoch: 21 [50/375]	Accuracy: 80.94%	Loss: 0.406364
# Train epoch: 21 [60/375]	Accuracy: 82.81%	Loss: 0.390047
# Train epoch: 21 [70/375]	Accuracy: 79.69%	Loss: 0.427575
# Train epoch: 21 [80/375]	Accuracy: 79.38%	Loss: 0.443594
# Train epoch: 21 [90/375]	Accuracy: 82.19%	Loss: 0.396695
# Train epoch: 21 [100/375]	Accuracy: 80.62%	Loss: 0.432932
# Train epoch: 21 [110/375]	Accuracy: 80.62%	Loss: 0.399449
# Train epoch: 21 [120/375]	Accuracy: 79.69%	Loss: 0.423577
# Train epoch: 21 [130/375]	Accuracy: 81.88%	Loss: 0.384352
# Train epoch: 21 [140/375]	Accuracy: 81.56%	Loss: 0.404620
# Train epoch: 21 [150/375]	Accuracy: 82.19%	Loss: 0.410977
# Train epoch: 21 [160/375]	Accuracy: 80.62%	Loss: 0.411482
# Train epoch: 21 [170/375]	Accuracy: 82.81%	Loss: 0.383504
# Train epoch: 21 [180/375]	Accuracy: 81.25%	Loss: 0.420460
# Train epoch: 21 [190/375]	Accuracy: 80.00%	Loss: 0.469812
# Train epoch: 21 [200/375]	Accuracy: 79.69%	Loss: 0.410693
# Train epoch: 21 [210/375]	Accuracy: 78.12%	Loss: 0.437324
# Train epoch: 21 [220/375]	Accuracy: 81.56%	Loss: 0.404416
# Train epoch: 21 [230/375]	Accuracy: 84.38%	Loss: 0.377458
# Train epoch: 21 [240/375]	Accuracy: 80.94%	Loss: 0.411783
# Train epoch: 21 [250/375]	Accuracy: 80.00%	Loss: 0.448702
# Train epoch: 21 [260/375]	Accuracy: 82.81%	Loss: 0.399219
# Train epoch: 21 [270/375]	Accuracy: 79.69%	Loss: 0.412672
# Train epoch: 21 [280/375]	Accuracy: 81.56%	Loss: 0.386366
# Train epoch: 21 [290/375]	Accuracy: 77.19%	Loss: 0.435898
# Train epoch: 21 [300/375]	Accuracy: 80.94%	Loss: 0.376891
# Train epoch: 21 [310/375]	Accuracy: 77.50%	Loss: 0.437561
# Train epoch: 21 [320/375]	Accuracy: 79.69%	Loss: 0.408300
# Train epoch: 21 [330/375]	Accuracy: 77.50%	Loss: 0.422174
# Train epoch: 21 [340/375]	Accuracy: 85.62%	Loss: 0.360611
# Train epoch: 21 [350/375]	Accuracy: 85.00%	Loss: 0.349153
# Train epoch: 21 [360/375]	Accuracy: 80.00%	Loss: 0.391696
# Train epoch: 21 [370/375]	Accuracy: 81.56%	Loss: 0.409607
# Test set: Loss: 0.6096, Accuracy: 71.68%)
# Train epoch: 22 [10/375]	Accuracy: 81.56%	Loss: 0.438863
# Train epoch: 22 [20/375]	Accuracy: 81.25%	Loss: 0.401132
# Train epoch: 22 [30/375]	Accuracy: 80.62%	Loss: 0.397080
# Train epoch: 22 [40/375]	Accuracy: 81.25%	Loss: 0.411715
# Train epoch: 22 [50/375]	Accuracy: 74.69%	Loss: 0.432345
# Train epoch: 22 [60/375]	Accuracy: 81.56%	Loss: 0.372822
# Train epoch: 22 [70/375]	Accuracy: 80.00%	Loss: 0.399031
# Train epoch: 22 [80/375]	Accuracy: 85.62%	Loss: 0.367265
# Train epoch: 22 [90/375]	Accuracy: 80.94%	Loss: 0.420506
# Train epoch: 22 [100/375]	Accuracy: 81.56%	Loss: 0.419147
# Train epoch: 22 [110/375]	Accuracy: 79.38%	Loss: 0.436904
# Train epoch: 22 [120/375]	Accuracy: 77.81%	Loss: 0.453718
# Train epoch: 22 [130/375]	Accuracy: 80.31%	Loss: 0.393268
# Train epoch: 22 [140/375]	Accuracy: 77.19%	Loss: 0.444465
# Train epoch: 22 [150/375]	Accuracy: 80.00%	Loss: 0.423077
# Train epoch: 22 [160/375]	Accuracy: 82.50%	Loss: 0.368990
# Train epoch: 22 [170/375]	Accuracy: 82.50%	Loss: 0.427726
# Train epoch: 22 [180/375]	Accuracy: 79.06%	Loss: 0.419032
# Train epoch: 22 [190/375]	Accuracy: 84.06%	Loss: 0.366918
# Train epoch: 22 [200/375]	Accuracy: 81.56%	Loss: 0.406884
# Train epoch: 22 [210/375]	Accuracy: 83.75%	Loss: 0.362129
# Train epoch: 22 [220/375]	Accuracy: 82.50%	Loss: 0.372048
# Train epoch: 22 [230/375]	Accuracy: 84.69%	Loss: 0.362318
# Train epoch: 22 [240/375]	Accuracy: 81.88%	Loss: 0.379084
# Train epoch: 22 [250/375]	Accuracy: 81.56%	Loss: 0.369326
# Train epoch: 22 [260/375]	Accuracy: 84.06%	Loss: 0.404647
# Train epoch: 22 [270/375]	Accuracy: 80.31%	Loss: 0.407510
# Train epoch: 22 [280/375]	Accuracy: 81.88%	Loss: 0.351475
# Train epoch: 22 [290/375]	Accuracy: 83.44%	Loss: 0.362323
# Train epoch: 22 [300/375]	Accuracy: 82.81%	Loss: 0.365961
# Train epoch: 22 [310/375]	Accuracy: 81.25%	Loss: 0.436621
# Train epoch: 22 [320/375]	Accuracy: 85.00%	Loss: 0.355762
# Train epoch: 22 [330/375]	Accuracy: 80.31%	Loss: 0.426359
# Train epoch: 22 [340/375]	Accuracy: 79.69%	Loss: 0.391423
# Train epoch: 22 [350/375]	Accuracy: 75.94%	Loss: 0.452732
# Train epoch: 22 [360/375]	Accuracy: 82.50%	Loss: 0.364579
# Train epoch: 22 [370/375]	Accuracy: 83.12%	Loss: 0.365350
# Test set: Loss: 0.4842, Accuracy: 76.59%)
# Train epoch: 23 [10/375]	Accuracy: 75.00%	Loss: 0.489549
# Train epoch: 23 [20/375]	Accuracy: 75.62%	Loss: 0.434497
# Train epoch: 23 [30/375]	Accuracy: 81.88%	Loss: 0.401831
# Train epoch: 23 [40/375]	Accuracy: 82.50%	Loss: 0.386183
# Train epoch: 23 [50/375]	Accuracy: 81.56%	Loss: 0.370408
# Train epoch: 23 [60/375]	Accuracy: 82.19%	Loss: 0.367002
# Train epoch: 23 [70/375]	Accuracy: 80.94%	Loss: 0.374686
# Train epoch: 23 [80/375]	Accuracy: 82.50%	Loss: 0.397412
# Train epoch: 23 [90/375]	Accuracy: 80.00%	Loss: 0.425841
# Train epoch: 23 [100/375]	Accuracy: 85.94%	Loss: 0.353530
# Train epoch: 23 [110/375]	Accuracy: 82.81%	Loss: 0.368202
# Train epoch: 23 [120/375]	Accuracy: 78.12%	Loss: 0.403079
# Train epoch: 23 [130/375]	Accuracy: 80.00%	Loss: 0.444191
# Train epoch: 23 [140/375]	Accuracy: 80.94%	Loss: 0.402330
# Train epoch: 23 [150/375]	Accuracy: 84.69%	Loss: 0.332225
# Train epoch: 23 [160/375]	Accuracy: 81.56%	Loss: 0.409658
# Train epoch: 23 [170/375]	Accuracy: 76.88%	Loss: 0.442067
# Train epoch: 23 [180/375]	Accuracy: 78.44%	Loss: 0.494880
# Train epoch: 23 [190/375]	Accuracy: 80.31%	Loss: 0.395677
# Train epoch: 23 [200/375]	Accuracy: 83.12%	Loss: 0.366979
# Train epoch: 23 [210/375]	Accuracy: 84.69%	Loss: 0.343759
# Train epoch: 23 [220/375]	Accuracy: 80.31%	Loss: 0.402490
# Train epoch: 23 [230/375]	Accuracy: 84.69%	Loss: 0.362936
# Train epoch: 23 [240/375]	Accuracy: 83.75%	Loss: 0.347463
# Train epoch: 23 [250/375]	Accuracy: 83.44%	Loss: 0.377761
# Train epoch: 23 [260/375]	Accuracy: 78.12%	Loss: 0.401005
# Train epoch: 23 [270/375]	Accuracy: 78.75%	Loss: 0.425892
# Train epoch: 23 [280/375]	Accuracy: 79.06%	Loss: 0.427677
# Train epoch: 23 [290/375]	Accuracy: 80.31%	Loss: 0.420334
# Train epoch: 23 [300/375]	Accuracy: 80.62%	Loss: 0.393579
# Train epoch: 23 [310/375]	Accuracy: 82.19%	Loss: 0.422761
# Train epoch: 23 [320/375]	Accuracy: 76.88%	Loss: 0.475522
# Train epoch: 23 [330/375]	Accuracy: 78.12%	Loss: 0.428669
# Train epoch: 23 [340/375]	Accuracy: 78.12%	Loss: 0.424806
# Train epoch: 23 [350/375]	Accuracy: 83.44%	Loss: 0.367020
# Train epoch: 23 [360/375]	Accuracy: 84.38%	Loss: 0.387339
# Train epoch: 23 [370/375]	Accuracy: 81.88%	Loss: 0.384582
# Test set: Loss: 0.5157, Accuracy: 73.41%)
# Train epoch: 24 [10/375]	Accuracy: 78.44%	Loss: 0.430848
# Train epoch: 24 [20/375]	Accuracy: 81.25%	Loss: 0.398581
# Train epoch: 24 [30/375]	Accuracy: 84.06%	Loss: 0.368015
# Train epoch: 24 [40/375]	Accuracy: 84.38%	Loss: 0.362843
# Train epoch: 24 [50/375]	Accuracy: 81.88%	Loss: 0.342985
# Train epoch: 24 [60/375]	Accuracy: 80.00%	Loss: 0.401980
# Train epoch: 24 [70/375]	Accuracy: 80.94%	Loss: 0.425252
# Train epoch: 24 [80/375]	Accuracy: 79.06%	Loss: 0.435095
# Train epoch: 24 [90/375]	Accuracy: 81.56%	Loss: 0.384342
# Train epoch: 24 [100/375]	Accuracy: 82.50%	Loss: 0.362575
# Train epoch: 24 [110/375]	Accuracy: 80.62%	Loss: 0.429048
# Train epoch: 24 [120/375]	Accuracy: 80.00%	Loss: 0.436368
# Train epoch: 24 [130/375]	Accuracy: 78.75%	Loss: 0.417948
# Train epoch: 24 [140/375]	Accuracy: 81.25%	Loss: 0.390198
# Train epoch: 24 [150/375]	Accuracy: 80.00%	Loss: 0.428748
# Train epoch: 24 [160/375]	Accuracy: 86.25%	Loss: 0.342447
# Train epoch: 24 [170/375]	Accuracy: 90.31%	Loss: 0.319831
# Train epoch: 24 [180/375]	Accuracy: 84.69%	Loss: 0.335734
# Train epoch: 24 [190/375]	Accuracy: 82.50%	Loss: 0.406725
# Train epoch: 24 [200/375]	Accuracy: 80.00%	Loss: 0.403265
# Train epoch: 24 [210/375]	Accuracy: 79.69%	Loss: 0.422692
# Train epoch: 24 [220/375]	Accuracy: 80.94%	Loss: 0.412685
# Train epoch: 24 [230/375]	Accuracy: 81.25%	Loss: 0.384267
# Train epoch: 24 [240/375]	Accuracy: 79.69%	Loss: 0.431483
# Train epoch: 24 [250/375]	Accuracy: 78.12%	Loss: 0.429916
# Train epoch: 24 [260/375]	Accuracy: 83.12%	Loss: 0.374166
# Train epoch: 24 [270/375]	Accuracy: 79.69%	Loss: 0.430776
# Train epoch: 24 [280/375]	Accuracy: 84.06%	Loss: 0.331439
# Train epoch: 24 [290/375]	Accuracy: 81.88%	Loss: 0.427169
# Train epoch: 24 [300/375]	Accuracy: 83.44%	Loss: 0.362050
# Train epoch: 24 [310/375]	Accuracy: 80.62%	Loss: 0.392825
# Train epoch: 24 [320/375]	Accuracy: 85.31%	Loss: 0.325258
# Train epoch: 24 [330/375]	Accuracy: 80.00%	Loss: 0.390219
# Train epoch: 24 [340/375]	Accuracy: 83.75%	Loss: 0.321757
# Train epoch: 24 [350/375]	Accuracy: 82.50%	Loss: 0.383627
# Train epoch: 24 [360/375]	Accuracy: 80.31%	Loss: 0.396715
# Train epoch: 24 [370/375]	Accuracy: 79.69%	Loss: 0.433403
# Test set: Loss: 0.3012, Accuracy: 85.52%)
# Train epoch: 25 [10/375]	Accuracy: 80.31%	Loss: 0.408724
# Train epoch: 25 [20/375]	Accuracy: 84.38%	Loss: 0.361502
# Train epoch: 25 [30/375]	Accuracy: 81.88%	Loss: 0.381759
# Train epoch: 25 [40/375]	Accuracy: 82.81%	Loss: 0.392131
# Train epoch: 25 [50/375]	Accuracy: 81.88%	Loss: 0.396763
# Train epoch: 25 [60/375]	Accuracy: 81.25%	Loss: 0.405745
# Train epoch: 25 [70/375]	Accuracy: 84.06%	Loss: 0.349990
# Train epoch: 25 [80/375]	Accuracy: 82.50%	Loss: 0.404779
# Train epoch: 25 [90/375]	Accuracy: 80.00%	Loss: 0.411883
# Train epoch: 25 [100/375]	Accuracy: 80.31%	Loss: 0.375941
# Train epoch: 25 [110/375]	Accuracy: 85.00%	Loss: 0.344544
# Train epoch: 25 [120/375]	Accuracy: 80.62%	Loss: 0.384233
# Train epoch: 25 [130/375]	Accuracy: 81.25%	Loss: 0.386970
# Train epoch: 25 [140/375]	Accuracy: 80.62%	Loss: 0.397013
# Train epoch: 25 [150/375]	Accuracy: 85.31%	Loss: 0.377922
# Train epoch: 25 [160/375]	Accuracy: 78.75%	Loss: 0.402703
# Train epoch: 25 [170/375]	Accuracy: 84.38%	Loss: 0.382404
# Train epoch: 25 [180/375]	Accuracy: 80.31%	Loss: 0.396580
# Train epoch: 25 [190/375]	Accuracy: 81.88%	Loss: 0.364038
# Train epoch: 25 [200/375]	Accuracy: 83.12%	Loss: 0.359275
# Train epoch: 25 [210/375]	Accuracy: 84.38%	Loss: 0.331708
# Train epoch: 25 [220/375]	Accuracy: 80.00%	Loss: 0.445946
# Train epoch: 25 [230/375]	Accuracy: 80.31%	Loss: 0.379934
# Train epoch: 25 [240/375]	Accuracy: 79.06%	Loss: 0.417077
# Train epoch: 25 [250/375]	Accuracy: 81.88%	Loss: 0.398570
# Train epoch: 25 [260/375]	Accuracy: 80.94%	Loss: 0.391349
# Train epoch: 25 [270/375]	Accuracy: 84.38%	Loss: 0.379280
# Train epoch: 25 [280/375]	Accuracy: 81.25%	Loss: 0.388381
# Train epoch: 25 [290/375]	Accuracy: 79.38%	Loss: 0.387777
# Train epoch: 25 [300/375]	Accuracy: 78.12%	Loss: 0.437672
# Train epoch: 25 [310/375]	Accuracy: 83.75%	Loss: 0.365831
# Train epoch: 25 [320/375]	Accuracy: 81.56%	Loss: 0.414725
# Train epoch: 25 [330/375]	Accuracy: 82.81%	Loss: 0.407706
# Train epoch: 25 [340/375]	Accuracy: 80.31%	Loss: 0.426470
# Train epoch: 25 [350/375]	Accuracy: 80.31%	Loss: 0.381421
# Train epoch: 25 [360/375]	Accuracy: 76.88%	Loss: 0.411515
# Train epoch: 25 [370/375]	Accuracy: 85.31%	Loss: 0.342071
# Test set: Loss: 0.3676, Accuracy: 81.55%)
# Train epoch: 26 [10/375]	Accuracy: 77.19%	Loss: 0.433268
# Train epoch: 26 [20/375]	Accuracy: 75.94%	Loss: 0.470927
# Train epoch: 26 [30/375]	Accuracy: 86.56%	Loss: 0.329567
# Train epoch: 26 [40/375]	Accuracy: 84.38%	Loss: 0.356193
# Train epoch: 26 [50/375]	Accuracy: 81.88%	Loss: 0.372342
# Train epoch: 26 [60/375]	Accuracy: 85.00%	Loss: 0.355434
# Train epoch: 26 [70/375]	Accuracy: 82.81%	Loss: 0.341852
# Train epoch: 26 [80/375]	Accuracy: 83.75%	Loss: 0.373042
# Train epoch: 26 [90/375]	Accuracy: 83.75%	Loss: 0.341547
# Train epoch: 26 [100/375]	Accuracy: 83.12%	Loss: 0.371125
# Train epoch: 26 [110/375]	Accuracy: 79.06%	Loss: 0.400885
# Train epoch: 26 [120/375]	Accuracy: 82.50%	Loss: 0.379517
# Train epoch: 26 [130/375]	Accuracy: 78.44%	Loss: 0.373661
# Train epoch: 26 [140/375]	Accuracy: 81.56%	Loss: 0.382823
# Train epoch: 26 [150/375]	Accuracy: 80.94%	Loss: 0.408038
# Train epoch: 26 [160/375]	Accuracy: 81.56%	Loss: 0.380366
# Train epoch: 26 [170/375]	Accuracy: 77.81%	Loss: 0.385463
# Train epoch: 26 [180/375]	Accuracy: 83.12%	Loss: 0.342177
# Train epoch: 26 [190/375]	Accuracy: 79.38%	Loss: 0.409715
# Train epoch: 26 [200/375]	Accuracy: 85.00%	Loss: 0.349596
# Train epoch: 26 [210/375]	Accuracy: 80.31%	Loss: 0.412278
# Train epoch: 26 [220/375]	Accuracy: 77.50%	Loss: 0.432404
# Train epoch: 26 [230/375]	Accuracy: 78.75%	Loss: 0.433725
# Train epoch: 26 [240/375]	Accuracy: 83.75%	Loss: 0.407408
# Train epoch: 26 [250/375]	Accuracy: 86.88%	Loss: 0.331422
# Train epoch: 26 [260/375]	Accuracy: 85.00%	Loss: 0.343934
# Train epoch: 26 [270/375]	Accuracy: 81.88%	Loss: 0.366692
# Train epoch: 26 [280/375]	Accuracy: 84.38%	Loss: 0.352364
# Train epoch: 26 [290/375]	Accuracy: 78.44%	Loss: 0.403814
# Train epoch: 26 [300/375]	Accuracy: 83.75%	Loss: 0.336623
# Train epoch: 26 [310/375]	Accuracy: 84.06%	Loss: 0.332040
# Train epoch: 26 [320/375]	Accuracy: 83.44%	Loss: 0.387610
# Train epoch: 26 [330/375]	Accuracy: 84.69%	Loss: 0.334039
# Train epoch: 26 [340/375]	Accuracy: 77.19%	Loss: 0.437436
# Train epoch: 26 [350/375]	Accuracy: 77.81%	Loss: 0.414590
# Train epoch: 26 [360/375]	Accuracy: 81.25%	Loss: 0.373002
# Train epoch: 26 [370/375]	Accuracy: 78.44%	Loss: 0.431877
# Test set: Loss: 0.6117, Accuracy: 72.42%)
# Train epoch: 27 [10/375]	Accuracy: 84.06%	Loss: 0.370204
# Train epoch: 27 [20/375]	Accuracy: 82.81%	Loss: 0.369413
# Train epoch: 27 [30/375]	Accuracy: 82.81%	Loss: 0.375971
# Train epoch: 27 [40/375]	Accuracy: 82.81%	Loss: 0.375798
# Train epoch: 27 [50/375]	Accuracy: 82.50%	Loss: 0.363426
# Train epoch: 27 [60/375]	Accuracy: 84.69%	Loss: 0.372123
# Train epoch: 27 [70/375]	Accuracy: 82.81%	Loss: 0.363450
# Train epoch: 27 [80/375]	Accuracy: 83.44%	Loss: 0.352000
# Train epoch: 27 [90/375]	Accuracy: 84.06%	Loss: 0.354367
# Train epoch: 27 [100/375]	Accuracy: 81.88%	Loss: 0.379706
# Train epoch: 27 [110/375]	Accuracy: 84.06%	Loss: 0.339564
# Train epoch: 27 [120/375]	Accuracy: 83.75%	Loss: 0.349658
# Train epoch: 27 [130/375]	Accuracy: 86.25%	Loss: 0.322384
# Train epoch: 27 [140/375]	Accuracy: 81.88%	Loss: 0.391316
# Train epoch: 27 [150/375]	Accuracy: 84.38%	Loss: 0.376389
# Train epoch: 27 [160/375]	Accuracy: 80.94%	Loss: 0.400263
# Train epoch: 27 [170/375]	Accuracy: 84.06%	Loss: 0.338247
# Train epoch: 27 [180/375]	Accuracy: 81.56%	Loss: 0.396315
# Train epoch: 27 [190/375]	Accuracy: 83.44%	Loss: 0.351315
# Train epoch: 27 [200/375]	Accuracy: 82.19%	Loss: 0.402189
# Train epoch: 27 [210/375]	Accuracy: 83.44%	Loss: 0.344852
# Train epoch: 27 [220/375]	Accuracy: 85.31%	Loss: 0.341401
# Train epoch: 27 [230/375]	Accuracy: 81.56%	Loss: 0.415207
# Train epoch: 27 [240/375]	Accuracy: 80.62%	Loss: 0.387793
# Train epoch: 27 [250/375]	Accuracy: 83.44%	Loss: 0.380866
# Train epoch: 27 [260/375]	Accuracy: 84.38%	Loss: 0.331476
# Train epoch: 27 [270/375]	Accuracy: 84.06%	Loss: 0.332366
# Train epoch: 27 [280/375]	Accuracy: 80.31%	Loss: 0.412063
# Train epoch: 27 [290/375]	Accuracy: 80.31%	Loss: 0.375659
# Train epoch: 27 [300/375]	Accuracy: 81.56%	Loss: 0.380698
# Train epoch: 27 [310/375]	Accuracy: 84.69%	Loss: 0.343725
# Train epoch: 27 [320/375]	Accuracy: 83.12%	Loss: 0.354285
# Train epoch: 27 [330/375]	Accuracy: 80.31%	Loss: 0.420849
# Train epoch: 27 [340/375]	Accuracy: 81.88%	Loss: 0.337647
# Train epoch: 27 [350/375]	Accuracy: 83.44%	Loss: 0.384436
# Train epoch: 27 [360/375]	Accuracy: 83.75%	Loss: 0.345019
# Train epoch: 27 [370/375]	Accuracy: 79.69%	Loss: 0.446608
# Test set: Loss: 0.6660, Accuracy: 71.43%)
# Train epoch: 28 [10/375]	Accuracy: 81.88%	Loss: 0.394567
# Train epoch: 28 [20/375]	Accuracy: 84.06%	Loss: 0.335530
# Train epoch: 28 [30/375]	Accuracy: 87.19%	Loss: 0.329491
# Train epoch: 28 [40/375]	Accuracy: 85.62%	Loss: 0.330730
# Train epoch: 28 [50/375]	Accuracy: 84.06%	Loss: 0.386224
# Train epoch: 28 [60/375]	Accuracy: 79.38%	Loss: 0.457863
# Train epoch: 28 [70/375]	Accuracy: 86.25%	Loss: 0.315900
# Train epoch: 28 [80/375]	Accuracy: 81.25%	Loss: 0.393703
# Train epoch: 28 [90/375]	Accuracy: 82.81%	Loss: 0.379826
# Train epoch: 28 [100/375]	Accuracy: 86.88%	Loss: 0.345132
# Train epoch: 28 [110/375]	Accuracy: 79.69%	Loss: 0.409744
# Train epoch: 28 [120/375]	Accuracy: 83.75%	Loss: 0.391887
# Train epoch: 28 [130/375]	Accuracy: 84.69%	Loss: 0.345193
# Train epoch: 28 [140/375]	Accuracy: 84.69%	Loss: 0.360643
# Train epoch: 28 [150/375]	Accuracy: 80.62%	Loss: 0.381851
# Train epoch: 28 [160/375]	Accuracy: 83.75%	Loss: 0.342097
# Train epoch: 28 [170/375]	Accuracy: 80.94%	Loss: 0.381924
# Train epoch: 28 [180/375]	Accuracy: 84.38%	Loss: 0.360875
# Train epoch: 28 [190/375]	Accuracy: 83.75%	Loss: 0.372402
# Train epoch: 28 [200/375]	Accuracy: 85.00%	Loss: 0.360991
# Train epoch: 28 [210/375]	Accuracy: 80.62%	Loss: 0.353570
# Train epoch: 28 [220/375]	Accuracy: 83.75%	Loss: 0.384834
# Train epoch: 28 [230/375]	Accuracy: 84.38%	Loss: 0.354049
# Train epoch: 28 [240/375]	Accuracy: 82.19%	Loss: 0.402958
# Train epoch: 28 [250/375]	Accuracy: 82.19%	Loss: 0.395104
# Train epoch: 28 [260/375]	Accuracy: 82.19%	Loss: 0.362315
# Train epoch: 28 [270/375]	Accuracy: 82.50%	Loss: 0.360805
# Train epoch: 28 [280/375]	Accuracy: 81.25%	Loss: 0.397820
# Train epoch: 28 [290/375]	Accuracy: 82.81%	Loss: 0.401207
# Train epoch: 28 [300/375]	Accuracy: 86.25%	Loss: 0.350927
# Train epoch: 28 [310/375]	Accuracy: 85.62%	Loss: 0.363621
# Train epoch: 28 [320/375]	Accuracy: 79.69%	Loss: 0.392793
# Train epoch: 28 [330/375]	Accuracy: 84.38%	Loss: 0.367900
# Train epoch: 28 [340/375]	Accuracy: 80.94%	Loss: 0.364212
# Train epoch: 28 [350/375]	Accuracy: 79.06%	Loss: 0.430365
# Train epoch: 28 [360/375]	Accuracy: 80.62%	Loss: 0.416931
# Train epoch: 28 [370/375]	Accuracy: 84.38%	Loss: 0.368784
# Test set: Loss: 0.4315, Accuracy: 80.01%)
# Train epoch: 29 [10/375]	Accuracy: 84.38%	Loss: 0.357620
# Train epoch: 29 [20/375]	Accuracy: 84.69%	Loss: 0.327655
# Train epoch: 29 [30/375]	Accuracy: 80.62%	Loss: 0.362446
# Train epoch: 29 [40/375]	Accuracy: 85.94%	Loss: 0.354890
# Train epoch: 29 [50/375]	Accuracy: 81.25%	Loss: 0.378486
# Train epoch: 29 [60/375]	Accuracy: 82.50%	Loss: 0.392835
# Train epoch: 29 [70/375]	Accuracy: 81.25%	Loss: 0.394084
# Train epoch: 29 [80/375]	Accuracy: 84.06%	Loss: 0.372276
# Train epoch: 29 [90/375]	Accuracy: 84.38%	Loss: 0.358920
# Train epoch: 29 [100/375]	Accuracy: 84.38%	Loss: 0.359544
# Train epoch: 29 [110/375]	Accuracy: 81.25%	Loss: 0.380187
# Train epoch: 29 [120/375]	Accuracy: 80.00%	Loss: 0.411757
# Train epoch: 29 [130/375]	Accuracy: 80.31%	Loss: 0.390583
# Train epoch: 29 [140/375]	Accuracy: 82.50%	Loss: 0.370797
# Train epoch: 29 [150/375]	Accuracy: 84.69%	Loss: 0.363525
# Train epoch: 29 [160/375]	Accuracy: 82.81%	Loss: 0.345540
# Train epoch: 29 [170/375]	Accuracy: 85.00%	Loss: 0.322597
# Train epoch: 29 [180/375]	Accuracy: 80.00%	Loss: 0.354582
# Train epoch: 29 [190/375]	Accuracy: 84.69%	Loss: 0.356822
# Train epoch: 29 [200/375]	Accuracy: 85.94%	Loss: 0.322847
# Train epoch: 29 [210/375]	Accuracy: 80.94%	Loss: 0.338079
# Train epoch: 29 [220/375]	Accuracy: 82.81%	Loss: 0.367384
# Train epoch: 29 [230/375]	Accuracy: 80.62%	Loss: 0.424221
# Train epoch: 29 [240/375]	Accuracy: 82.50%	Loss: 0.342944
# Train epoch: 29 [250/375]	Accuracy: 84.38%	Loss: 0.374389
# Train epoch: 29 [260/375]	Accuracy: 80.62%	Loss: 0.418312
# Train epoch: 29 [270/375]	Accuracy: 81.88%	Loss: 0.383896
# Train epoch: 29 [280/375]	Accuracy: 78.44%	Loss: 0.410333
# Train epoch: 29 [290/375]	Accuracy: 83.75%	Loss: 0.334296
# Train epoch: 29 [300/375]	Accuracy: 85.62%	Loss: 0.350265
# Train epoch: 29 [310/375]	Accuracy: 83.12%	Loss: 0.346966
# Train epoch: 29 [320/375]	Accuracy: 84.69%	Loss: 0.335366
# Train epoch: 29 [330/375]	Accuracy: 85.62%	Loss: 0.356831
# Train epoch: 29 [340/375]	Accuracy: 83.44%	Loss: 0.365974
# Train epoch: 29 [350/375]	Accuracy: 81.56%	Loss: 0.397405
# Train epoch: 29 [360/375]	Accuracy: 80.62%	Loss: 0.382663
# Train epoch: 29 [370/375]	Accuracy: 80.00%	Loss: 0.462619
# Test set: Loss: 0.2756, Accuracy: 86.81%)
# Train epoch: 30 [10/375]	Accuracy: 85.62%	Loss: 0.337060
# Train epoch: 30 [20/375]	Accuracy: 84.38%	Loss: 0.333623
# Train epoch: 30 [30/375]	Accuracy: 80.62%	Loss: 0.386414
# Train epoch: 30 [40/375]	Accuracy: 79.69%	Loss: 0.409931
# Train epoch: 30 [50/375]	Accuracy: 82.81%	Loss: 0.365975
# Train epoch: 30 [60/375]	Accuracy: 82.50%	Loss: 0.387690
# Train epoch: 30 [70/375]	Accuracy: 82.19%	Loss: 0.416903
# Train epoch: 30 [80/375]	Accuracy: 84.69%	Loss: 0.387870
# Train epoch: 30 [90/375]	Accuracy: 80.31%	Loss: 0.376179
# Train epoch: 30 [100/375]	Accuracy: 82.19%	Loss: 0.362913
# Train epoch: 30 [110/375]	Accuracy: 86.25%	Loss: 0.306198
# Train epoch: 30 [120/375]	Accuracy: 85.94%	Loss: 0.317962
# Train epoch: 30 [130/375]	Accuracy: 81.88%	Loss: 0.367649
