# %% [markdown]
# <a href="https://colab.research.google.com/github/jithinraj9895/steganalysis/blob/main/Image_steagnalysis_SiaNET_21ep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
import logging
import os
import random
from PIL import Image
import cv2
import numpy as np
import torch
import random
import os
import os.path as osp

def set_random_seed(seed=None):
    """Sets random seed for reproducibility.

    Args:
        seed (int, optional): Random seed.
    """
    if seed is None:
        seed = (
                os.getpid()
                + int(datetime.now().strftime("%S%f"))
                + int.from_bytes(os.urandom(2), "big")
        )
        logger = logging.getLogger(__name__)
        logger.info('Using a generated random seed {}'.format(seed))
    random.seed(seed)
    np.random.seed(seed)
    torch.set_rng_state(torch.manual_seed(seed).get_state())


def get_random_seed():
    return np.random.randint(2 ** 31)

# %%
class RandomRot(object):

    def __call__(self, sample):
        rot = random.randint(0, 3)
        return {
            'image': np.rot90(sample['image'], rot, axes=[-3, -2]).copy(),
            'label': sample['label'],
        }


class RandomFlip(object):

    def __init__(self, p=0.5):
        self._p = p

    def __call__(self, sample):
        if random.random() < self._p:
            return {
                'image': np.flip(sample['image'], axis=-2).copy(),
                'label': sample['label'],
            }
        else:
            return sample


class ToTensor(object):

    def __call__(self, sample):
        image, label = sample['image'], sample['label']
        if image.ndim == 3:  # HxWxC
            image = image.transpose(2, 0, 1)
        else:  # NxHxWxC
            image = image.transpose(0, 3, 1, 2)
        return {
            'image': torch.from_numpy(image).type(torch.FloatTensor),
            'label': torch.tensor(label).long()
        }

# %%
from torch.utils.data import Dataset


class CoverStegoDataset(Dataset):

    def __init__(self, cover_dir, stego_dir, transform=None):
        self._transform = transform

        self.images, self.labels = self.get_items(cover_dir, stego_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = np.array(Image.open(self.images[idx]))
        image = np.expand_dims(image, 2)  # (H, W, C)
        assert image.ndim == 3

        sample = {
            'image': image,
            'label': self.labels[idx]
        }

        if self._transform:
            sample = self._transform(sample)
        return sample

    @staticmethod
    def get_items(cover_dir, stego_dir):
        images, labels = [], []

        cover_names = sorted(os.listdir(cover_dir))
        if stego_dir is not None:
            stego_names = sorted(os.listdir(stego_dir))
            assert cover_names == stego_names

        file_names = cover_names
        if stego_dir is None:
            dir_to_label = [(cover_dir, 0), ]
        else:
            dir_to_label = [(cover_dir, 0), (stego_dir, 1)]
        for image_dir, label in dir_to_label:
            for file_name in file_names:
                image_path = osp.join(image_dir, file_name)
                if not osp.isfile(image_path):
                    raise FileNotFoundError('{} not exists'.format(image_path))
                images.append(image_path)
                labels.append(label)

        return images, labels

# %%
import torchvision
from torch.utils.data import BatchSampler
from torch.utils.data import DataLoader
from torch.utils.data import Sampler
from torch.utils.data import SequentialSampler
import itertools
import logging
import math

class TrainingSampler(Sampler):

    def __init__(self, size, seed=None, shuffle=True):
        self._size = size
        self._shuffle = shuffle

        if seed is None:
            seed = get_random_seed()
        self._seed = seed

    def __iter__(self):
        yield from itertools.islice(self._infinite_indices(), 0, None, 1)

    def _infinite_indices(self):
        g = torch.Generator()
        g.manual_seed(self._seed)
        while True:
            if self._shuffle:
                yield from torch.randperm(self._size, generator=g)
            else:
                yield from torch.arange(self._size)




class BalancedBatchSampler(BatchSampler):

    def __init__(self, sampler, group_ids, batch_size):
        """
        Args:
            sampler (Sampler): Base sampler.
            group_ids (list[int]): If the sampler produces indices in range [0, N),
                `group_ids` must be a list of `N` ints which contains the group id of each
                sample. The group ids must be a set of integers in [0, num_groups).
            batch_size (int): Size of mini-batch.
        """
        if not isinstance(sampler, Sampler):
            raise ValueError("sampler should be an instance of torch.utils.data.Sampler, "
                             "but got sampler={}".format(sampler))

        self._sampler = sampler
        self._group_ids = np.asarray(group_ids)
        assert self._group_ids.ndim == 1
        self._batch_size = batch_size
        groups = np.unique(self._group_ids).tolist()
        assert batch_size % len(groups) == 0

        # buffer the indices of each group until batch size is reached
        self._buffer_per_group = {k: [] for k in groups}
        self._group_size = batch_size // len(groups)

    def __iter__(self):
        for idx in self._sampler:
            group_id = self._group_ids[idx]
            self._buffer_per_group[group_id].append(idx)
            if all(len(v) >= self._group_size for k, v in self._buffer_per_group.items()):
                idxs = []
                # Collect across all groups
                for k, v in self._buffer_per_group.items():
                    idxs.extend(v[:self._group_size])
                    del v[:self._group_size]

                idxs = np.random.permutation(idxs)
                yield idxs

    def __len__(self):
        raise NotImplementedError("len() of GroupedBatchSampler is not well-defined.")


def build_train_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        RandomRot(),
        RandomFlip(),
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    size = len(dataset)
    sampler = TrainingSampler(size)
    if stego_dir is not None:
        batch_sampler = BalancedBatchSampler(sampler, dataset.labels, batch_size)
    else:
        batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)
    epoch_length = math.ceil(size / batch_size)


    train_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
        worker_init_fn=worker_init_reset_seed,
    )
    return train_loader, epoch_length




def build_val_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    sampler = SequentialSampler(dataset)
    batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)


    test_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
    )
    return test_loader

def worker_init_reset_seed(worker_id):
    set_random_seed(np.random.randint(2 ** 31) + worker_id)

# %%
set_random_seed()

# %%
 train_cover_dir = "/content/drive/MyDrive/boss_256/256_cropped_train/cover"
 train_stego_dir = "/content/drive/MyDrive/boss_256/256_cropped_train/stego"
 val_cover_dir = "/content/drive/MyDrive/boss_256/train/cover"
 val_stego_dir = "/content/drive/MyDrive/boss_256/train/stego"
 
 
 train_loader, epoch_length = build_train_loader(
        val_cover_dir, val_stego_dir, batch_size=32,
        num_workers=0)

# %%
val_loader = build_val_loader(
    train_cover_dir, train_stego_dir, batch_size=32,
    num_workers=0
)

# %%
train_loader_iter = iter(train_loader)

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.nn import Parameter


srm_dir = "/content/drive/MyDrive"
SRM_npy = np.load(os.path.join(srm_dir,"SRM_Kernels.npy"))


def accuracy(outputs, labels):
    _, argmax = torch.max(outputs, 1)
    return (labels == argmax.squeeze()).float().mean()


def conv3x3(in_planes, out_planes, stride=1, groups=1, dilation=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                     padding=dilation, groups=groups, bias=False, dilation=dilation)


def conv1x1(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


class SRMConv2d(nn.Module):

    def __init__(self, stride=1, padding=0):
        super(SRMConv2d, self).__init__()
        self.in_channels = 1
        self.out_channels = 30
        self.kernel_size = (5, 5)
        if isinstance(stride, int):
            self.stride = (stride, stride)
        else:
            self.stride = stride
        if isinstance(padding, int):
            self.padding = (padding, padding)
        else:
            self.padding = padding
        self.dilation = (1, 1)
        self.transpose = False
        self.output_padding = (0,)
        self.groups = 1
        self.weight = Parameter(torch.Tensor(30, 1, 5, 5), requires_grad=True)
        self.bias = Parameter(torch.Tensor(30), requires_grad=True)
        self.reset_parameters()

    def reset_parameters(self):
        self.weight.data.numpy()[:] = SRM_npy
        self.bias.data.zero_()

    def forward(self, input):
        return F.conv2d(input, self.weight, self.bias, self.stride, self.padding,
                        self.dilation, self.groups)


class BlockA(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockA, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += identity
        out = self.relu(out)

        return out


class BlockB(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockB, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes, stride=2)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)
        # self.pool = nn.AvgPool2d(3, stride=2, padding=1)

        self.shortcut_conv = conv1x1(in_planes, out_planes, stride=2)
        self.shortcut_bn = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        # out = self.pool(out)

        identity = self.shortcut_conv(identity)
        identity = self.shortcut_bn(identity)

        out += identity
        out = self.relu(out)

        return out

# %%
class KeNet(nn.Module):

    def __init__(self, norm_layer=None, zero_init_residual=True, p=0.5):
        super(KeNet, self).__init__()

        self.zero_init_residual = zero_init_residual

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.srm = SRMConv2d(1, 0)
        self.bn1 = norm_layer(30)

        self.A1 = BlockA(30, 30, norm_layer=norm_layer)
        self.A2 = BlockA(30, 30, norm_layer=norm_layer)
        self.AA = BlockA(30, 30, norm_layer=norm_layer)

        # self.B1 = BlockB(30, 30, norm_layer=norm_layer)
        # self.B2 = BlockB(30, 64, norm_layer=norm_layer)

        self.B3 = BlockB(30, 64, norm_layer=norm_layer)
        self.A3 = BlockA(64, 64, norm_layer=norm_layer)

        self.B4 = BlockB(64, 128, norm_layer=norm_layer)
        self.A4 = BlockA(128, 128, norm_layer=norm_layer)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # self.bnfc = nn.BatchNorm1d(128)
        self.relu = nn.ReLU(inplace=True)
        # self.fcfusion = nn.Linear(128, 128) #4
        self.fc = nn.Linear(128 * 4 + 1, 2)
        self.dropout = nn.Dropout(p=p)

        self.reset_parameters()

    def reset_parameters(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # nn.init.xavier_uniform_(m.weight)
                # nn.init.constant_(m.bias, 0.2)
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, std=0.01)

        if self.zero_init_residual:
            for m in self.modules():
                if isinstance(m, (BlockA, BlockB)):
                    nn.init.constant_(m.bn2.weight, 0)

    def extract_feat(self, x):
        x = x.float()
        out = self.srm(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.A1(out)
        out = self.A2(out)
        out = self.AA(out)

        # out = self.B1(out)
        # out = self.B2(out)

        out = self.B3(out)
        out = self.A3(out)

        out = self.B4(out)
        out = self.A4(out)

        out = self.avgpool(out)
        out = out.view(out.size(0), out.size(1))

        # out = self.relu(out)
        # out = self.bnfc(out)

        return out

    def forward(self, *args):
        ############# statistics fusion start #############
        feats = torch.stack(
            [self.extract_feat(subarea) for subarea in args], dim=0
        )

        euclidean_distance = F.pairwise_distance(feats[0], feats[1], eps=1e-6,
                                                 keepdim=True)

        if feats.shape[0] == 1:
            final_feat = feats.squeeze(dim=0)
        else:
            # feats_sum = feats.sum(dim=0)
            # feats_sub = feats[0] - feats[1]
            feats_mean = feats.mean(dim=0)
            feats_var = feats.var(dim=0)
            feats_min, _ = feats.min(dim=0)
            feats_max, _ = feats.max(dim=0)

            '''feats_sum = feats.sum(dim=0)
            feats_sub = abs(feats[0] - feats[1])
            feats_prod = feats.prod(dim=0)
            feats_max, _ = feats.max(dim=0)'''
            
            #final_feat = torch.cat(
            #    [feats[0], feats[1], feats[0], feats[1]], dim=-1
            #    #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            #)

            final_feat = torch.cat(
                [euclidean_distance, feats_mean, feats_var, feats_min, feats_max], dim=-1
                #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            )

        out = self.dropout(final_feat)
        # out = self.fcfusion(out)
        # out = self.relu(out)
        out = self.fc(out)

        return out, feats[0], feats[1]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ContrastiveLoss(nn.Module):

    def __init__(self, margin=1.25):  # margin=2
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        label = label.to(torch.float32)
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean(
            (1 - label) * torch.pow(euclidean_distance, 2) +
            label * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2)
        )

        return loss_contrastive

# %%
criterion_1 = nn.CrossEntropyLoss()
criterion_2 = ContrastiveLoss(margin=1)

# %%
net = KeNet();

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

device = get_default_device()


if device.type == "cuda":
    net.cuda()
    criterion_1.cuda()
    criterion_2.cuda()

# %%
from torch.optim.adamax import Adamax

optimizer = Adamax(net.parameters(), lr=0.001, eps=1e-08, weight_decay=0.0001)

# %%
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', factor=0.3,
                                                           patience=10, verbose=True, min_lr=0,
                                                           eps=1e-08)

# %%
import logging
import time
import shutil
logger = logging.getLogger(__name__)


def preprocess_data(images, labels, random_crop,gpu):
    # images of shape: NxCxHxW
    if images.ndim == 5:  # 1xNxCxHxW
        images = images.squeeze(0)
        labels = labels.squeeze(0)
    h, w = images.shape[-2:]

    if random_crop:
        ch = random.randint(h * 3 // 4, h)  # h // 2      #256
        cw = random.randint(w * 3 // 4, w)  # square ch   #256

        h0 = random.randint(0, h - ch)  # 128
        w0 = random.randint(0, w - cw)  # 128
    else:
        ch, cw, h0, w0 = h, w, 0, 0


    cw = cw & ~1
    inputs = [
            images[..., h0:h0 + ch, w0:w0 + cw // 2],
            images[..., h0:h0 + ch, w0 + cw // 2:w0 + cw]
        ]

    if gpu:
        inputs = [x.cuda() for x in inputs]
        labels = labels.cuda()
    return inputs, labels

# %%
def train(epoch):
    net.train()
    running_loss, running_accuracy = 0., 0.

    for batch_idx in range(epoch_length):
        data = next(train_loader_iter)
        inputs, labels = preprocess_data(data['image'], data['label'], False,gpu=True)

        optimizer.zero_grad()
   
        outputs, feats_0, feats_1 = net(*inputs)

            # count parameters start
            # print('parameters_count: {}'.format(sum(p.numel() for p in net.parameters() if p.requires_grad)))
            # count parameters end

        loss = criterion_1(outputs, labels) + \
                   0.1 * criterion_2(feats_0, feats_1, labels)

        accuracy1 = accuracy(outputs, labels).item()
        running_accuracy += accuracy1
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        if (batch_idx + 1) % 10 == 0:
            running_accuracy /= 10
            running_loss /= 10
            
            print(
                'Train epoch: {} [{}/{}]\tAccuracy: {:.2f}%\tLoss: {:.6f}'.format(
                    epoch, batch_idx + 1, epoch_length, 100 * running_accuracy,
                    running_loss))
                    
            ###############################log per log_interval start
            is_best=False
            save_checkpoint(
                {
                    'iteration': batch_idx + 1,
                    'state_dict': net.state_dict(),
                    'best_prec1': running_accuracy,
                    'optimizer': optimizer.state_dict(),
                },
                is_best,
                filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
                best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
            ###############################
            running_loss = 0.
            running_accuracy = 0.
            net.train()

# %%
def valid():
    net.eval()
    valid_loss = 0.
    valid_accuracy = 0.
    with torch.no_grad():
        for data in val_loader:
            inputs, labels = preprocess_data(data['image'], data['label'], False,gpu = True)

            outputs, feats_0, feats_1 = net(*inputs)
            valid_loss += criterion_1(outputs, labels).item() + \
                              0.01 * criterion_2(feats_0, feats_1, labels)
            valid_accuracy += accuracy(outputs, labels).item()
    valid_loss /= len(val_loader)
    valid_accuracy /= len(val_loader)
    print('Test set: Loss: {:.4f}, Accuracy: {:.2f}%)'.format(
        valid_loss, 100 * valid_accuracy))
    return valid_loss, valid_accuracy

# %%
epoch = 50

# %%
def save_checkpoint(state, is_best, filename, best_name):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, best_name)


_time = time.time()
best_accuracy = 0.
for e in range(1, 500 + 1):
    logger.info('Epoch: {}'.format(e))
    logger.info('Train')
    train(e)
    logger.info('Time: {}'.format(time.time() - _time))
    logger.info('Test')
    _, accuracy1 = valid()
    if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
        scheduler.step(accuracy1)
    else:
        scheduler.step()
    if accuracy1 > best_accuracy:
        best_accuracy = accuracy1
        is_best = True
    else:
        is_best = False
    logger.info('Best accuracy: {}'.format(best_accuracy))
    logger.info('Time: {}'.format(time.time() - _time))
    save_checkpoint(
        {
            'epoch': e,
            'state_dict': net.state_dict(),
            'best_prec1': accuracy1,
            'optimizer': optimizer.state_dict(),
        },
        is_best,
        filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
        best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
# Out:
# Train epoch: 1 [10/625]	Accuracy: 50.62%	Loss: 0.801101
# Train epoch: 1 [20/625]	Accuracy: 48.44%	Loss: 0.766061
# Train epoch: 1 [30/625]	Accuracy: 48.44%	Loss: 0.749577
# Train epoch: 1 [40/625]	Accuracy: 48.44%	Loss: 0.741399
# Train epoch: 1 [50/625]	Accuracy: 46.56%	Loss: 0.740086
# Train epoch: 1 [60/625]	Accuracy: 50.00%	Loss: 0.736760
# Train epoch: 1 [70/625]	Accuracy: 55.31%	Loss: 0.721185
# Train epoch: 1 [80/625]	Accuracy: 46.56%	Loss: 0.731034
# Train epoch: 1 [90/625]	Accuracy: 50.94%	Loss: 0.723395
# Train epoch: 1 [100/625]	Accuracy: 48.75%	Loss: 0.724830
# Train epoch: 1 [110/625]	Accuracy: 51.88%	Loss: 0.719682
# Train epoch: 1 [120/625]	Accuracy: 44.38%	Loss: 0.728448
# Train epoch: 1 [130/625]	Accuracy: 46.56%	Loss: 0.726463
# Train epoch: 1 [140/625]	Accuracy: 50.31%	Loss: 0.725087
# Train epoch: 1 [150/625]	Accuracy: 49.38%	Loss: 0.727295
# Train epoch: 1 [160/625]	Accuracy: 47.81%	Loss: 0.728210
# Train epoch: 1 [170/625]	Accuracy: 53.12%	Loss: 0.720917
# Train epoch: 1 [180/625]	Accuracy: 53.75%	Loss: 0.720080
# Train epoch: 1 [190/625]	Accuracy: 52.81%	Loss: 0.722164
# Train epoch: 1 [200/625]	Accuracy: 50.00%	Loss: 0.719628
# Train epoch: 1 [210/625]	Accuracy: 51.25%	Loss: 0.719973
# Train epoch: 1 [220/625]	Accuracy: 50.31%	Loss: 0.723483
# Train epoch: 1 [230/625]	Accuracy: 52.19%	Loss: 0.721325
# Train epoch: 1 [240/625]	Accuracy: 50.94%	Loss: 0.723451
# Train epoch: 1 [250/625]	Accuracy: 54.06%	Loss: 0.721840
# Train epoch: 1 [260/625]	Accuracy: 46.56%	Loss: 0.723384
# Train epoch: 1 [270/625]	Accuracy: 52.50%	Loss: 0.720272
# Train epoch: 1 [280/625]	Accuracy: 49.69%	Loss: 0.725004
# Train epoch: 1 [290/625]	Accuracy: 57.81%	Loss: 0.714853
# Train epoch: 1 [300/625]	Accuracy: 52.81%	Loss: 0.718407
# Train epoch: 1 [310/625]	Accuracy: 48.12%	Loss: 0.726804
# Train epoch: 1 [320/625]	Accuracy: 53.12%	Loss: 0.722330
# Train epoch: 1 [330/625]	Accuracy: 50.94%	Loss: 0.720900
# Train epoch: 1 [340/625]	Accuracy: 58.75%	Loss: 0.718924
# Train epoch: 1 [350/625]	Accuracy: 45.94%	Loss: 0.729210
# Train epoch: 1 [360/625]	Accuracy: 48.75%	Loss: 0.725381
# Train epoch: 1 [370/625]	Accuracy: 49.69%	Loss: 0.723761
# Train epoch: 1 [380/625]	Accuracy: 56.25%	Loss: 0.715493
# Train epoch: 1 [390/625]	Accuracy: 58.75%	Loss: 0.714841
# Train epoch: 1 [400/625]	Accuracy: 55.94%	Loss: 0.721778
# Train epoch: 1 [410/625]	Accuracy: 56.25%	Loss: 0.714989
# Train epoch: 1 [420/625]	Accuracy: 54.69%	Loss: 0.722572
# Train epoch: 1 [430/625]	Accuracy: 56.25%	Loss: 0.715666
# Train epoch: 1 [440/625]	Accuracy: 48.75%	Loss: 0.726878
# Train epoch: 1 [450/625]	Accuracy: 55.62%	Loss: 0.714447
# Train epoch: 1 [460/625]	Accuracy: 50.94%	Loss: 0.722920
# Train epoch: 1 [470/625]	Accuracy: 55.31%	Loss: 0.713854
# Train epoch: 1 [480/625]	Accuracy: 55.00%	Loss: 0.716807
# Train epoch: 1 [490/625]	Accuracy: 55.00%	Loss: 0.712626
# Train epoch: 1 [500/625]	Accuracy: 57.50%	Loss: 0.717150
# Train epoch: 1 [510/625]	Accuracy: 52.50%	Loss: 0.724181
# Train epoch: 1 [520/625]	Accuracy: 58.44%	Loss: 0.715339
# Train epoch: 1 [530/625]	Accuracy: 58.13%	Loss: 0.706412
# Train epoch: 1 [540/625]	Accuracy: 54.69%	Loss: 0.707471
# Train epoch: 1 [550/625]	Accuracy: 55.31%	Loss: 0.720941
# Train epoch: 1 [560/625]	Accuracy: 53.75%	Loss: 0.715892
# Train epoch: 1 [570/625]	Accuracy: 59.69%	Loss: 0.708757
# Train epoch: 1 [580/625]	Accuracy: 55.62%	Loss: 0.705829
# Train epoch: 1 [590/625]	Accuracy: 57.50%	Loss: 0.702832
# Train epoch: 1 [600/625]	Accuracy: 56.88%	Loss: 0.700761
# Train epoch: 1 [610/625]	Accuracy: 56.88%	Loss: 0.712328
# Train epoch: 1 [620/625]	Accuracy: 59.69%	Loss: 0.692661
# Test set: Loss: 0.7168, Accuracy: 54.54%)
# Train epoch: 2 [10/625]	Accuracy: 62.81%	Loss: 0.679276
# Train epoch: 2 [20/625]	Accuracy: 54.69%	Loss: 0.720503
# Train epoch: 2 [30/625]	Accuracy: 55.94%	Loss: 0.719971
# Train epoch: 2 [40/625]	Accuracy: 58.13%	Loss: 0.686351
# Train epoch: 2 [50/625]	Accuracy: 58.44%	Loss: 0.705783
# Train epoch: 2 [60/625]	Accuracy: 62.19%	Loss: 0.688805
# Train epoch: 2 [70/625]	Accuracy: 58.75%	Loss: 0.697768
# Train epoch: 2 [80/625]	Accuracy: 59.38%	Loss: 0.693653
# Train epoch: 2 [90/625]	Accuracy: 65.94%	Loss: 0.672717
# Train epoch: 2 [100/625]	Accuracy: 58.13%	Loss: 0.683885
# Train epoch: 2 [110/625]	Accuracy: 59.06%	Loss: 0.706060
# Train epoch: 2 [120/625]	Accuracy: 60.00%	Loss: 0.677377
# Train epoch: 2 [130/625]	Accuracy: 59.06%	Loss: 0.695523
# Train epoch: 2 [140/625]	Accuracy: 58.13%	Loss: 0.692692
# Train epoch: 2 [150/625]	Accuracy: 59.06%	Loss: 0.681686
# Train epoch: 2 [160/625]	Accuracy: 62.50%	Loss: 0.665547
# Train epoch: 2 [170/625]	Accuracy: 62.81%	Loss: 0.668346
# Train epoch: 2 [180/625]	Accuracy: 63.75%	Loss: 0.654283
# Train epoch: 2 [190/625]	Accuracy: 65.31%	Loss: 0.661041
# Train epoch: 2 [200/625]	Accuracy: 62.50%	Loss: 0.681487
# Train epoch: 2 [210/625]	Accuracy: 60.62%	Loss: 0.690506
# Train epoch: 2 [220/625]	Accuracy: 65.94%	Loss: 0.649695
# Train epoch: 2 [230/625]	Accuracy: 65.31%	Loss: 0.637875
# Train epoch: 2 [240/625]	Accuracy: 53.12%	Loss: 0.702053
# Train epoch: 2 [250/625]	Accuracy: 63.75%	Loss: 0.659631
# Train epoch: 2 [260/625]	Accuracy: 61.56%	Loss: 0.666883
# Train epoch: 2 [270/625]	Accuracy: 64.06%	Loss: 0.660800
# Train epoch: 2 [280/625]	Accuracy: 64.38%	Loss: 0.658529
# Train epoch: 2 [290/625]	Accuracy: 62.50%	Loss: 0.666237
# Train epoch: 2 [300/625]	Accuracy: 65.94%	Loss: 0.648188
# Train epoch: 2 [310/625]	Accuracy: 65.94%	Loss: 0.646417
# Train epoch: 2 [320/625]	Accuracy: 63.75%	Loss: 0.645513
# Train epoch: 2 [330/625]	Accuracy: 64.38%	Loss: 0.629131
# Train epoch: 2 [340/625]	Accuracy: 65.31%	Loss: 0.625691
# Train epoch: 2 [350/625]	Accuracy: 63.75%	Loss: 0.658481
# Train epoch: 2 [360/625]	Accuracy: 66.56%	Loss: 0.638133
# Train epoch: 2 [370/625]	Accuracy: 66.25%	Loss: 0.633617
# Train epoch: 2 [380/625]	Accuracy: 66.56%	Loss: 0.649269
# Train epoch: 2 [390/625]	Accuracy: 65.31%	Loss: 0.649641
# Train epoch: 2 [400/625]	Accuracy: 63.75%	Loss: 0.665308
# Train epoch: 2 [410/625]	Accuracy: 64.69%	Loss: 0.639466
# Train epoch: 2 [420/625]	Accuracy: 65.62%	Loss: 0.630898
# Train epoch: 2 [430/625]	Accuracy: 65.62%	Loss: 0.625927
# Train epoch: 2 [440/625]	Accuracy: 63.75%	Loss: 0.633131
# Train epoch: 2 [450/625]	Accuracy: 66.25%	Loss: 0.629094
# Train epoch: 2 [460/625]	Accuracy: 68.75%	Loss: 0.597520
# Train epoch: 2 [470/625]	Accuracy: 69.06%	Loss: 0.592783
# Train epoch: 2 [480/625]	Accuracy: 66.88%	Loss: 0.623446
# Train epoch: 2 [490/625]	Accuracy: 65.62%	Loss: 0.630343
# Train epoch: 2 [500/625]	Accuracy: 63.12%	Loss: 0.642659
# Train epoch: 2 [510/625]	Accuracy: 69.06%	Loss: 0.621134
# Train epoch: 2 [520/625]	Accuracy: 66.25%	Loss: 0.602138
# Train epoch: 2 [530/625]	Accuracy: 70.31%	Loss: 0.597419
# Train epoch: 2 [540/625]	Accuracy: 68.12%	Loss: 0.615404
# Train epoch: 2 [550/625]	Accuracy: 66.88%	Loss: 0.594649
# Train epoch: 2 [560/625]	Accuracy: 64.69%	Loss: 0.642166
# Train epoch: 2 [570/625]	Accuracy: 70.00%	Loss: 0.593492
# Train epoch: 2 [580/625]	Accuracy: 69.06%	Loss: 0.608976
# Train epoch: 2 [590/625]	Accuracy: 65.00%	Loss: 0.630150
# Train epoch: 2 [600/625]	Accuracy: 66.88%	Loss: 0.623722
# Train epoch: 2 [610/625]	Accuracy: 68.44%	Loss: 0.603657
# Train epoch: 2 [620/625]	Accuracy: 70.62%	Loss: 0.596465
# Test set: Loss: 0.7442, Accuracy: 58.72%)
# Train epoch: 3 [10/625]	Accuracy: 71.25%	Loss: 0.607984
# Train epoch: 3 [20/625]	Accuracy: 65.62%	Loss: 0.609843
# Train epoch: 3 [30/625]	Accuracy: 63.75%	Loss: 0.638809
# Train epoch: 3 [40/625]	Accuracy: 70.62%	Loss: 0.568263
# Train epoch: 3 [50/625]	Accuracy: 70.62%	Loss: 0.584984
# Train epoch: 3 [60/625]	Accuracy: 65.62%	Loss: 0.595046
# Train epoch: 3 [70/625]	Accuracy: 66.56%	Loss: 0.585594
# Train epoch: 3 [80/625]	Accuracy: 72.19%	Loss: 0.568299
# Train epoch: 3 [90/625]	Accuracy: 64.69%	Loss: 0.578984
# Train epoch: 3 [100/625]	Accuracy: 71.25%	Loss: 0.596038
# Train epoch: 3 [110/625]	Accuracy: 73.12%	Loss: 0.566357
# Train epoch: 3 [120/625]	Accuracy: 72.81%	Loss: 0.550914
# Train epoch: 3 [130/625]	Accuracy: 68.12%	Loss: 0.568843
# Train epoch: 3 [140/625]	Accuracy: 70.94%	Loss: 0.560348
# Train epoch: 3 [150/625]	Accuracy: 70.31%	Loss: 0.568779
# Train epoch: 3 [160/625]	Accuracy: 69.06%	Loss: 0.598660
# Train epoch: 3 [170/625]	Accuracy: 71.88%	Loss: 0.571889
# Train epoch: 3 [180/625]	Accuracy: 70.94%	Loss: 0.549409
# Train epoch: 3 [190/625]	Accuracy: 72.19%	Loss: 0.551442
# Train epoch: 3 [200/625]	Accuracy: 66.88%	Loss: 0.619853
# Train epoch: 3 [210/625]	Accuracy: 65.00%	Loss: 0.599948
# Train epoch: 3 [220/625]	Accuracy: 67.19%	Loss: 0.603123
# Train epoch: 3 [230/625]	Accuracy: 70.94%	Loss: 0.555694
# Train epoch: 3 [240/625]	Accuracy: 68.12%	Loss: 0.569825
# Train epoch: 3 [250/625]	Accuracy: 73.12%	Loss: 0.548665
# Train epoch: 3 [260/625]	Accuracy: 70.00%	Loss: 0.555521
# Train epoch: 3 [270/625]	Accuracy: 69.06%	Loss: 0.568962
# Train epoch: 3 [280/625]	Accuracy: 71.88%	Loss: 0.553907
# Train epoch: 3 [290/625]	Accuracy: 73.44%	Loss: 0.514110
# Train epoch: 3 [300/625]	Accuracy: 74.06%	Loss: 0.543913
# Train epoch: 3 [310/625]	Accuracy: 68.44%	Loss: 0.570709
# Train epoch: 3 [320/625]	Accuracy: 70.94%	Loss: 0.556748
# Train epoch: 3 [330/625]	Accuracy: 70.94%	Loss: 0.583672
# Train epoch: 3 [340/625]	Accuracy: 74.38%	Loss: 0.535828
# Train epoch: 3 [350/625]	Accuracy: 69.69%	Loss: 0.590507
# Train epoch: 3 [360/625]	Accuracy: 72.81%	Loss: 0.526366
# Train epoch: 3 [370/625]	Accuracy: 70.00%	Loss: 0.596140
# Train epoch: 3 [380/625]	Accuracy: 75.00%	Loss: 0.550621
# Train epoch: 3 [390/625]	Accuracy: 69.38%	Loss: 0.591872
# Train epoch: 3 [400/625]	Accuracy: 70.94%	Loss: 0.556370
# Train epoch: 3 [410/625]	Accuracy: 71.56%	Loss: 0.540439
# Train epoch: 3 [420/625]	Accuracy: 75.94%	Loss: 0.515688
# Train epoch: 3 [430/625]	Accuracy: 72.50%	Loss: 0.568545
# Train epoch: 3 [440/625]	Accuracy: 75.94%	Loss: 0.540248
# Train epoch: 3 [450/625]	Accuracy: 74.38%	Loss: 0.522206
# Train epoch: 3 [460/625]	Accuracy: 71.88%	Loss: 0.559110
# Train epoch: 3 [470/625]	Accuracy: 73.12%	Loss: 0.498241
# Train epoch: 3 [480/625]	Accuracy: 71.88%	Loss: 0.547821
# Train epoch: 3 [490/625]	Accuracy: 70.94%	Loss: 0.555494
# Train epoch: 3 [500/625]	Accuracy: 73.44%	Loss: 0.545027
# Train epoch: 3 [510/625]	Accuracy: 76.88%	Loss: 0.535326
# Train epoch: 3 [520/625]	Accuracy: 75.62%	Loss: 0.503500
# Train epoch: 3 [530/625]	Accuracy: 70.62%	Loss: 0.586708
# Train epoch: 3 [540/625]	Accuracy: 72.19%	Loss: 0.517308
# Train epoch: 3 [550/625]	Accuracy: 70.94%	Loss: 0.539522
# Train epoch: 3 [560/625]	Accuracy: 72.19%	Loss: 0.538004
# Train epoch: 3 [570/625]	Accuracy: 74.38%	Loss: 0.499530
# Train epoch: 3 [580/625]	Accuracy: 72.81%	Loss: 0.533679
# Train epoch: 3 [590/625]	Accuracy: 77.50%	Loss: 0.498492
# Train epoch: 3 [600/625]	Accuracy: 69.06%	Loss: 0.563274
# Train epoch: 3 [610/625]	Accuracy: 76.25%	Loss: 0.526267
# Train epoch: 3 [620/625]	Accuracy: 76.56%	Loss: 0.513261
# Test set: Loss: 0.9100, Accuracy: 61.11%)
# Train epoch: 4 [10/625]	Accuracy: 70.00%	Loss: 0.555656
# Train epoch: 4 [20/625]	Accuracy: 77.81%	Loss: 0.476665
# Train epoch: 4 [30/625]	Accuracy: 75.62%	Loss: 0.512393
# Train epoch: 4 [40/625]	Accuracy: 70.31%	Loss: 0.550077
# Train epoch: 4 [50/625]	Accuracy: 73.75%	Loss: 0.537068
# Train epoch: 4 [60/625]	Accuracy: 73.75%	Loss: 0.533351
# Train epoch: 4 [70/625]	Accuracy: 72.19%	Loss: 0.556923
# Train epoch: 4 [80/625]	Accuracy: 69.06%	Loss: 0.571242
# Train epoch: 4 [90/625]	Accuracy: 76.56%	Loss: 0.488004
# Train epoch: 4 [100/625]	Accuracy: 72.81%	Loss: 0.549364
# Train epoch: 4 [110/625]	Accuracy: 75.62%	Loss: 0.495853
# Train epoch: 4 [120/625]	Accuracy: 76.88%	Loss: 0.492658
# Train epoch: 4 [130/625]	Accuracy: 74.06%	Loss: 0.541535
# Train epoch: 4 [140/625]	Accuracy: 75.62%	Loss: 0.519792
# Train epoch: 4 [150/625]	Accuracy: 79.38%	Loss: 0.484740
# Train epoch: 4 [160/625]	Accuracy: 75.31%	Loss: 0.521394
# Train epoch: 4 [170/625]	Accuracy: 74.06%	Loss: 0.499600
# Train epoch: 4 [180/625]	Accuracy: 74.06%	Loss: 0.562157
# Train epoch: 4 [190/625]	Accuracy: 73.44%	Loss: 0.519466
# Train epoch: 4 [200/625]	Accuracy: 74.38%	Loss: 0.529952
# Train epoch: 4 [210/625]	Accuracy: 69.69%	Loss: 0.562516
# Train epoch: 4 [220/625]	Accuracy: 74.69%	Loss: 0.511228
# Train epoch: 4 [230/625]	Accuracy: 79.38%	Loss: 0.453373
# Train epoch: 4 [240/625]	Accuracy: 74.69%	Loss: 0.495241
# Train epoch: 4 [250/625]	Accuracy: 73.75%	Loss: 0.528293
# Train epoch: 4 [260/625]	Accuracy: 75.31%	Loss: 0.519148
# Train epoch: 4 [270/625]	Accuracy: 74.38%	Loss: 0.513294
# Train epoch: 4 [280/625]	Accuracy: 73.12%	Loss: 0.517748
# Train epoch: 4 [290/625]	Accuracy: 75.00%	Loss: 0.521591
# Train epoch: 4 [300/625]	Accuracy: 74.38%	Loss: 0.492950
# Train epoch: 4 [310/625]	Accuracy: 72.19%	Loss: 0.516984
# Train epoch: 4 [320/625]	Accuracy: 79.69%	Loss: 0.467604
# Train epoch: 4 [330/625]	Accuracy: 75.31%	Loss: 0.498424
# Train epoch: 4 [340/625]	Accuracy: 76.56%	Loss: 0.501340
# Train epoch: 4 [350/625]	Accuracy: 75.94%	Loss: 0.502861
# Train epoch: 4 [360/625]	Accuracy: 78.75%	Loss: 0.472477
# Train epoch: 4 [370/625]	Accuracy: 75.00%	Loss: 0.524345
# Train epoch: 4 [380/625]	Accuracy: 71.25%	Loss: 0.546986
# Train epoch: 4 [390/625]	Accuracy: 74.38%	Loss: 0.555799
# Train epoch: 4 [400/625]	Accuracy: 73.12%	Loss: 0.516428
# Train epoch: 4 [410/625]	Accuracy: 75.94%	Loss: 0.516712
# Train epoch: 4 [420/625]	Accuracy: 78.75%	Loss: 0.477788
# Train epoch: 4 [430/625]	Accuracy: 76.25%	Loss: 0.484789
# Train epoch: 4 [440/625]	Accuracy: 75.62%	Loss: 0.512597
# Train epoch: 4 [450/625]	Accuracy: 78.12%	Loss: 0.457546
# Train epoch: 4 [460/625]	Accuracy: 78.44%	Loss: 0.490959
# Train epoch: 4 [470/625]	Accuracy: 79.69%	Loss: 0.459586
# Train epoch: 4 [480/625]	Accuracy: 76.88%	Loss: 0.492833
# Train epoch: 4 [490/625]	Accuracy: 78.12%	Loss: 0.484587
# Train epoch: 4 [500/625]	Accuracy: 74.38%	Loss: 0.486521
# Train epoch: 4 [510/625]	Accuracy: 71.56%	Loss: 0.540893
# Train epoch: 4 [520/625]	Accuracy: 75.00%	Loss: 0.486154
# Train epoch: 4 [530/625]	Accuracy: 73.12%	Loss: 0.508727
# Train epoch: 4 [540/625]	Accuracy: 75.00%	Loss: 0.513007
# Train epoch: 4 [550/625]	Accuracy: 77.19%	Loss: 0.488752
# Train epoch: 4 [560/625]	Accuracy: 77.50%	Loss: 0.503901
# Train epoch: 4 [570/625]	Accuracy: 71.56%	Loss: 0.538964
# Train epoch: 4 [580/625]	Accuracy: 76.88%	Loss: 0.497480
# Train epoch: 4 [590/625]	Accuracy: 76.56%	Loss: 0.458814
# Train epoch: 4 [600/625]	Accuracy: 77.19%	Loss: 0.462531
# Train epoch: 4 [610/625]	Accuracy: 74.06%	Loss: 0.481464
# Train epoch: 4 [620/625]	Accuracy: 73.44%	Loss: 0.550467
# Test set: Loss: 1.1992, Accuracy: 53.58%)
# Train epoch: 5 [10/625]	Accuracy: 76.25%	Loss: 0.494681
# Train epoch: 5 [20/625]	Accuracy: 75.62%	Loss: 0.488888
# Train epoch: 5 [30/625]	Accuracy: 77.81%	Loss: 0.478958
# Train epoch: 5 [40/625]	Accuracy: 77.81%	Loss: 0.493804
# Train epoch: 5 [50/625]	Accuracy: 75.00%	Loss: 0.488609
# Train epoch: 5 [60/625]	Accuracy: 75.94%	Loss: 0.483119
# Train epoch: 5 [70/625]	Accuracy: 77.50%	Loss: 0.457803
# Train epoch: 5 [80/625]	Accuracy: 78.12%	Loss: 0.473349
# Train epoch: 5 [90/625]	Accuracy: 73.75%	Loss: 0.515681
# Train epoch: 5 [100/625]	Accuracy: 78.12%	Loss: 0.496182
# Train epoch: 5 [110/625]	Accuracy: 73.44%	Loss: 0.504864
# Train epoch: 5 [120/625]	Accuracy: 71.25%	Loss: 0.515747
# Train epoch: 5 [130/625]	Accuracy: 74.38%	Loss: 0.493558
# Train epoch: 5 [140/625]	Accuracy: 75.94%	Loss: 0.490984
# Train epoch: 5 [150/625]	Accuracy: 74.69%	Loss: 0.504556
# Train epoch: 5 [160/625]	Accuracy: 75.94%	Loss: 0.483620
# Train epoch: 5 [170/625]	Accuracy: 77.50%	Loss: 0.444520
# Train epoch: 5 [180/625]	Accuracy: 75.94%	Loss: 0.494393
# Train epoch: 5 [190/625]	Accuracy: 76.88%	Loss: 0.476198
# Train epoch: 5 [200/625]	Accuracy: 75.94%	Loss: 0.456608
# Train epoch: 5 [210/625]	Accuracy: 80.94%	Loss: 0.439748
# Train epoch: 5 [220/625]	Accuracy: 75.62%	Loss: 0.463292
# Train epoch: 5 [230/625]	Accuracy: 76.88%	Loss: 0.481387
# Train epoch: 5 [240/625]	Accuracy: 74.69%	Loss: 0.491413
# Train epoch: 5 [250/625]	Accuracy: 75.94%	Loss: 0.473959
# Train epoch: 5 [260/625]	Accuracy: 71.25%	Loss: 0.548636
# Train epoch: 5 [270/625]	Accuracy: 78.12%	Loss: 0.470780
# Train epoch: 5 [280/625]	Accuracy: 75.00%	Loss: 0.481953
# Train epoch: 5 [290/625]	Accuracy: 77.50%	Loss: 0.492874
# Train epoch: 5 [300/625]	Accuracy: 72.50%	Loss: 0.550419
# Train epoch: 5 [310/625]	Accuracy: 71.56%	Loss: 0.542927
# Train epoch: 5 [320/625]	Accuracy: 75.00%	Loss: 0.516818
# Train epoch: 5 [330/625]	Accuracy: 76.56%	Loss: 0.491658
# Train epoch: 5 [340/625]	Accuracy: 75.62%	Loss: 0.484340
# Train epoch: 5 [350/625]	Accuracy: 80.94%	Loss: 0.439191
# Train epoch: 5 [360/625]	Accuracy: 79.69%	Loss: 0.432034
# Train epoch: 5 [370/625]	Accuracy: 76.25%	Loss: 0.470270
# Train epoch: 5 [380/625]	Accuracy: 71.88%	Loss: 0.513483
# Train epoch: 5 [390/625]	Accuracy: 72.19%	Loss: 0.530378
# Train epoch: 5 [400/625]	Accuracy: 77.81%	Loss: 0.448229
# Train epoch: 5 [410/625]	Accuracy: 79.69%	Loss: 0.455940
# Train epoch: 5 [420/625]	Accuracy: 78.12%	Loss: 0.466018
# Train epoch: 5 [430/625]	Accuracy: 77.50%	Loss: 0.475097
# Train epoch: 5 [440/625]	Accuracy: 77.19%	Loss: 0.500398
# Train epoch: 5 [450/625]	Accuracy: 75.31%	Loss: 0.510101
# Train epoch: 5 [460/625]	Accuracy: 73.75%	Loss: 0.514588
# Train epoch: 5 [470/625]	Accuracy: 71.88%	Loss: 0.530573
# Train epoch: 5 [480/625]	Accuracy: 74.69%	Loss: 0.497623
# Train epoch: 5 [490/625]	Accuracy: 77.50%	Loss: 0.455916
# Train epoch: 5 [500/625]	Accuracy: 79.69%	Loss: 0.415662
# Train epoch: 5 [510/625]	Accuracy: 82.50%	Loss: 0.411900
# Train epoch: 5 [520/625]	Accuracy: 81.25%	Loss: 0.438742
# Train epoch: 5 [530/625]	Accuracy: 74.06%	Loss: 0.502337
# Train epoch: 5 [540/625]	Accuracy: 77.81%	Loss: 0.458040
# Train epoch: 5 [550/625]	Accuracy: 75.00%	Loss: 0.481525
# Train epoch: 5 [560/625]	Accuracy: 73.12%	Loss: 0.479685
# Train epoch: 5 [570/625]	Accuracy: 75.00%	Loss: 0.500472
# Train epoch: 5 [580/625]	Accuracy: 75.62%	Loss: 0.500477
# Train epoch: 5 [590/625]	Accuracy: 75.94%	Loss: 0.478333
# Train epoch: 5 [600/625]	Accuracy: 75.62%	Loss: 0.503072
# Train epoch: 5 [610/625]	Accuracy: 78.12%	Loss: 0.456864
# Train epoch: 5 [620/625]	Accuracy: 80.00%	Loss: 0.472128
# Test set: Loss: 1.5082, Accuracy: 58.96%)
# Train epoch: 6 [10/625]	Accuracy: 75.00%	Loss: 0.478943
# Train epoch: 6 [20/625]	Accuracy: 76.25%	Loss: 0.462528
# Train epoch: 6 [30/625]	Accuracy: 79.06%	Loss: 0.449304
# Train epoch: 6 [40/625]	Accuracy: 80.62%	Loss: 0.428802
# Train epoch: 6 [50/625]	Accuracy: 78.12%	Loss: 0.475266
# Train epoch: 6 [60/625]	Accuracy: 83.12%	Loss: 0.399896
# Train epoch: 6 [70/625]	Accuracy: 74.06%	Loss: 0.484908
# Train epoch: 6 [80/625]	Accuracy: 80.62%	Loss: 0.451639
# Train epoch: 6 [90/625]	Accuracy: 76.88%	Loss: 0.482504
# Train epoch: 6 [100/625]	Accuracy: 71.25%	Loss: 0.551972
# Train epoch: 6 [110/625]	Accuracy: 71.25%	Loss: 0.524198
# Train epoch: 6 [120/625]	Accuracy: 75.94%	Loss: 0.484219
# Train epoch: 6 [130/625]	Accuracy: 78.12%	Loss: 0.447023
# Train epoch: 6 [140/625]	Accuracy: 79.69%	Loss: 0.453887
# Train epoch: 6 [150/625]	Accuracy: 79.38%	Loss: 0.436436
# Train epoch: 6 [160/625]	Accuracy: 78.75%	Loss: 0.444844
# Train epoch: 6 [170/625]	Accuracy: 78.75%	Loss: 0.426389
# Train epoch: 6 [180/625]	Accuracy: 76.88%	Loss: 0.463784
# Train epoch: 6 [190/625]	Accuracy: 76.56%	Loss: 0.473115
# Train epoch: 6 [200/625]	Accuracy: 76.88%	Loss: 0.442677
# Train epoch: 6 [210/625]	Accuracy: 77.19%	Loss: 0.476002
# Train epoch: 6 [220/625]	Accuracy: 76.56%	Loss: 0.486004
# Train epoch: 6 [230/625]	Accuracy: 79.06%	Loss: 0.432260
# Train epoch: 6 [240/625]	Accuracy: 79.06%	Loss: 0.472073
# Train epoch: 6 [250/625]	Accuracy: 76.56%	Loss: 0.451622
# Train epoch: 6 [260/625]	Accuracy: 81.56%	Loss: 0.412088
# Train epoch: 6 [270/625]	Accuracy: 79.69%	Loss: 0.477216
# Train epoch: 6 [280/625]	Accuracy: 84.38%	Loss: 0.391692
# Train epoch: 6 [290/625]	Accuracy: 78.75%	Loss: 0.475671
# Train epoch: 6 [300/625]	Accuracy: 80.62%	Loss: 0.403212
# Train epoch: 6 [310/625]	Accuracy: 83.12%	Loss: 0.419844
# Train epoch: 6 [320/625]	Accuracy: 82.50%	Loss: 0.451018
# Train epoch: 6 [330/625]	Accuracy: 77.81%	Loss: 0.493851
# Train epoch: 6 [340/625]	Accuracy: 77.19%	Loss: 0.462580
# Train epoch: 6 [350/625]	Accuracy: 76.56%	Loss: 0.455078
# Train epoch: 6 [360/625]	Accuracy: 78.44%	Loss: 0.469740
# Train epoch: 6 [370/625]	Accuracy: 76.25%	Loss: 0.446853
# Train epoch: 6 [380/625]	Accuracy: 80.31%	Loss: 0.401239
# Train epoch: 6 [390/625]	Accuracy: 80.94%	Loss: 0.414592
# Train epoch: 6 [400/625]	Accuracy: 77.50%	Loss: 0.481136
# Train epoch: 6 [410/625]	Accuracy: 78.75%	Loss: 0.434735
# Train epoch: 6 [420/625]	Accuracy: 78.12%	Loss: 0.442395
# Train epoch: 6 [430/625]	Accuracy: 82.81%	Loss: 0.377855
# Train epoch: 6 [440/625]	Accuracy: 80.31%	Loss: 0.409316
# Train epoch: 6 [450/625]	Accuracy: 75.00%	Loss: 0.458710
# Train epoch: 6 [460/625]	Accuracy: 81.88%	Loss: 0.424278
# Train epoch: 6 [470/625]	Accuracy: 80.94%	Loss: 0.404947
# Train epoch: 6 [480/625]	Accuracy: 76.88%	Loss: 0.468533
# Train epoch: 6 [490/625]	Accuracy: 77.19%	Loss: 0.416035
# Train epoch: 6 [500/625]	Accuracy: 79.06%	Loss: 0.421911
# Train epoch: 6 [510/625]	Accuracy: 79.69%	Loss: 0.434914
# Train epoch: 6 [520/625]	Accuracy: 80.62%	Loss: 0.457678
# Train epoch: 6 [530/625]	Accuracy: 74.38%	Loss: 0.522358
# Train epoch: 6 [540/625]	Accuracy: 80.00%	Loss: 0.444099
# Train epoch: 6 [550/625]	Accuracy: 80.62%	Loss: 0.425658
# Train epoch: 6 [560/625]	Accuracy: 79.06%	Loss: 0.475993
# Train epoch: 6 [570/625]	Accuracy: 73.75%	Loss: 0.496195
# Train epoch: 6 [580/625]	Accuracy: 77.50%	Loss: 0.448968
# Train epoch: 6 [590/625]	Accuracy: 77.81%	Loss: 0.460967
# Train epoch: 6 [600/625]	Accuracy: 78.44%	Loss: 0.466517
# Train epoch: 6 [610/625]	Accuracy: 80.00%	Loss: 0.447057
# Train epoch: 6 [620/625]	Accuracy: 78.75%	Loss: 0.421065
# Test set: Loss: 0.8684, Accuracy: 55.75%)
# Train epoch: 7 [10/625]	Accuracy: 79.38%	Loss: 0.502658
# Train epoch: 7 [20/625]	Accuracy: 76.88%	Loss: 0.501177
# Train epoch: 7 [30/625]	Accuracy: 78.44%	Loss: 0.442738
# Train epoch: 7 [40/625]	Accuracy: 83.12%	Loss: 0.406014
# Train epoch: 7 [50/625]	Accuracy: 78.44%	Loss: 0.469668
# Train epoch: 7 [60/625]	Accuracy: 78.75%	Loss: 0.440359
# Train epoch: 7 [70/625]	Accuracy: 78.12%	Loss: 0.431220
# Train epoch: 7 [80/625]	Accuracy: 83.12%	Loss: 0.375874
# Train epoch: 7 [90/625]	Accuracy: 80.31%	Loss: 0.437620
# Train epoch: 7 [100/625]	Accuracy: 80.00%	Loss: 0.449755
# Train epoch: 7 [110/625]	Accuracy: 77.81%	Loss: 0.474745
# Train epoch: 7 [120/625]	Accuracy: 78.12%	Loss: 0.442305
# Train epoch: 7 [130/625]	Accuracy: 73.12%	Loss: 0.484182
# Train epoch: 7 [140/625]	Accuracy: 80.62%	Loss: 0.432067
# Train epoch: 7 [150/625]	Accuracy: 78.12%	Loss: 0.453967
# Train epoch: 7 [160/625]	Accuracy: 80.00%	Loss: 0.409672
# Train epoch: 7 [170/625]	Accuracy: 80.31%	Loss: 0.414529
# Train epoch: 7 [180/625]	Accuracy: 79.06%	Loss: 0.404655
# Train epoch: 7 [190/625]	Accuracy: 79.06%	Loss: 0.405556
# Train epoch: 7 [200/625]	Accuracy: 82.81%	Loss: 0.415048
# Train epoch: 7 [210/625]	Accuracy: 81.56%	Loss: 0.438789
# Train epoch: 7 [220/625]	Accuracy: 76.88%	Loss: 0.477071
# Train epoch: 7 [230/625]	Accuracy: 79.06%	Loss: 0.459118
# Train epoch: 7 [240/625]	Accuracy: 80.00%	Loss: 0.422276
# Train epoch: 7 [250/625]	Accuracy: 77.81%	Loss: 0.418781
# Train epoch: 7 [260/625]	Accuracy: 77.19%	Loss: 0.429320
# Train epoch: 7 [270/625]	Accuracy: 79.06%	Loss: 0.422597
# Train epoch: 7 [280/625]	Accuracy: 83.12%	Loss: 0.413487
# Train epoch: 7 [290/625]	Accuracy: 78.75%	Loss: 0.454247
# Train epoch: 7 [300/625]	Accuracy: 79.38%	Loss: 0.427460
# Train epoch: 7 [310/625]	Accuracy: 81.25%	Loss: 0.412469
# Train epoch: 7 [320/625]	Accuracy: 78.44%	Loss: 0.459695
# Train epoch: 7 [330/625]	Accuracy: 78.12%	Loss: 0.465440
# Train epoch: 7 [340/625]	Accuracy: 81.88%	Loss: 0.413370
# Train epoch: 7 [350/625]	Accuracy: 79.38%	Loss: 0.449970
# Train epoch: 7 [360/625]	Accuracy: 80.62%	Loss: 0.404506
# Train epoch: 7 [370/625]	Accuracy: 81.25%	Loss: 0.424913
# Train epoch: 7 [380/625]	Accuracy: 80.00%	Loss: 0.448879
# Train epoch: 7 [390/625]	Accuracy: 77.19%	Loss: 0.455727
# Train epoch: 7 [400/625]	Accuracy: 81.56%	Loss: 0.447473
# Train epoch: 7 [410/625]	Accuracy: 74.38%	Loss: 0.481144
# Train epoch: 7 [420/625]	Accuracy: 79.69%	Loss: 0.420122
# Train epoch: 7 [430/625]	Accuracy: 81.88%	Loss: 0.379458
# Train epoch: 7 [440/625]	Accuracy: 82.81%	Loss: 0.381325
# Train epoch: 7 [450/625]	Accuracy: 79.38%	Loss: 0.419117
# Train epoch: 7 [460/625]	Accuracy: 81.88%	Loss: 0.401465
# Train epoch: 7 [470/625]	Accuracy: 84.06%	Loss: 0.346069
# Train epoch: 7 [480/625]	Accuracy: 80.62%	Loss: 0.425851
# Train epoch: 7 [490/625]	Accuracy: 80.31%	Loss: 0.442828
# Train epoch: 7 [500/625]	Accuracy: 78.12%	Loss: 0.441261
# Train epoch: 7 [510/625]	Accuracy: 81.56%	Loss: 0.412802
# Train epoch: 7 [520/625]	Accuracy: 82.50%	Loss: 0.390596
# Train epoch: 7 [530/625]	Accuracy: 82.19%	Loss: 0.428949
# Train epoch: 7 [540/625]	Accuracy: 77.50%	Loss: 0.442366
# Train epoch: 7 [550/625]	Accuracy: 80.62%	Loss: 0.416376
# Train epoch: 7 [560/625]	Accuracy: 79.69%	Loss: 0.441338
# Train epoch: 7 [570/625]	Accuracy: 80.62%	Loss: 0.446566
# Train epoch: 7 [580/625]	Accuracy: 82.19%	Loss: 0.394741
# Train epoch: 7 [590/625]	Accuracy: 82.50%	Loss: 0.393297
# Train epoch: 7 [600/625]	Accuracy: 84.06%	Loss: 0.376800
# Train epoch: 7 [610/625]	Accuracy: 81.56%	Loss: 0.405419
# Train epoch: 7 [620/625]	Accuracy: 87.81%	Loss: 0.360405
# Test set: Loss: 0.7171, Accuracy: 65.68%)
# Train epoch: 8 [10/625]	Accuracy: 79.69%	Loss: 0.435736
# Train epoch: 8 [20/625]	Accuracy: 80.94%	Loss: 0.416234
# Train epoch: 8 [30/625]	Accuracy: 76.25%	Loss: 0.463550
# Train epoch: 8 [40/625]	Accuracy: 80.31%	Loss: 0.451871
# Train epoch: 8 [50/625]	Accuracy: 83.75%	Loss: 0.406481
# Train epoch: 8 [60/625]	Accuracy: 77.50%	Loss: 0.450564
# Train epoch: 8 [70/625]	Accuracy: 81.56%	Loss: 0.407162
# Train epoch: 8 [80/625]	Accuracy: 81.25%	Loss: 0.394768
# Train epoch: 8 [90/625]	Accuracy: 76.25%	Loss: 0.445350
# Train epoch: 8 [100/625]	Accuracy: 80.31%	Loss: 0.434523
# Train epoch: 8 [110/625]	Accuracy: 86.25%	Loss: 0.341139
# Train epoch: 8 [120/625]	Accuracy: 78.75%	Loss: 0.442106
# Train epoch: 8 [130/625]	Accuracy: 78.44%	Loss: 0.415098
# Train epoch: 8 [140/625]	Accuracy: 76.25%	Loss: 0.496920
# Train epoch: 8 [150/625]	Accuracy: 82.19%	Loss: 0.408163
# Train epoch: 8 [160/625]	Accuracy: 78.12%	Loss: 0.419344
# Train epoch: 8 [170/625]	Accuracy: 76.56%	Loss: 0.463799
# Train epoch: 8 [180/625]	Accuracy: 80.94%	Loss: 0.418261
# Train epoch: 8 [190/625]	Accuracy: 81.25%	Loss: 0.413359
# Train epoch: 8 [200/625]	Accuracy: 76.88%	Loss: 0.456638
# Train epoch: 8 [210/625]	Accuracy: 80.94%	Loss: 0.409545
# Train epoch: 8 [220/625]	Accuracy: 82.50%	Loss: 0.398791
# Train epoch: 8 [230/625]	Accuracy: 80.94%	Loss: 0.425413
# Train epoch: 8 [240/625]	Accuracy: 83.44%	Loss: 0.376366
# Train epoch: 8 [250/625]	Accuracy: 78.44%	Loss: 0.401997
# Train epoch: 8 [260/625]	Accuracy: 88.12%	Loss: 0.344529
# Train epoch: 8 [270/625]	Accuracy: 80.31%	Loss: 0.427391
# Train epoch: 8 [280/625]	Accuracy: 78.75%	Loss: 0.459976
# Train epoch: 8 [290/625]	Accuracy: 81.25%	Loss: 0.399813
# Train epoch: 8 [300/625]	Accuracy: 74.69%	Loss: 0.462946
# Train epoch: 8 [310/625]	Accuracy: 82.50%	Loss: 0.360652
# Train epoch: 8 [320/625]	Accuracy: 81.25%	Loss: 0.400204
# Train epoch: 8 [330/625]	Accuracy: 82.19%	Loss: 0.414438
# Train epoch: 8 [340/625]	Accuracy: 80.00%	Loss: 0.439648
# Train epoch: 8 [350/625]	Accuracy: 80.94%	Loss: 0.409029
# Train epoch: 8 [360/625]	Accuracy: 83.44%	Loss: 0.388259
# Train epoch: 8 [370/625]	Accuracy: 82.81%	Loss: 0.358883
# Train epoch: 8 [380/625]	Accuracy: 82.19%	Loss: 0.396057
# Train epoch: 8 [390/625]	Accuracy: 80.94%	Loss: 0.427360
# Train epoch: 8 [400/625]	Accuracy: 79.06%	Loss: 0.437084
# Train epoch: 8 [410/625]	Accuracy: 79.38%	Loss: 0.418805
# Train epoch: 8 [420/625]	Accuracy: 81.25%	Loss: 0.410350
# Train epoch: 8 [430/625]	Accuracy: 79.38%	Loss: 0.422845
# Train epoch: 8 [440/625]	Accuracy: 86.88%	Loss: 0.340728
# Train epoch: 8 [450/625]	Accuracy: 82.81%	Loss: 0.372612
# Train epoch: 8 [460/625]	Accuracy: 81.88%	Loss: 0.396205
# Train epoch: 8 [470/625]	Accuracy: 81.88%	Loss: 0.406173
# Train epoch: 8 [480/625]	Accuracy: 76.88%	Loss: 0.428537
# Train epoch: 8 [490/625]	Accuracy: 81.88%	Loss: 0.407281
# Train epoch: 8 [500/625]	Accuracy: 81.56%	Loss: 0.382877
# Train epoch: 8 [510/625]	Accuracy: 80.31%	Loss: 0.412315
# Train epoch: 8 [520/625]	Accuracy: 80.94%	Loss: 0.414227
# Train epoch: 8 [530/625]	Accuracy: 82.81%	Loss: 0.406587
# Train epoch: 8 [540/625]	Accuracy: 76.56%	Loss: 0.494344
# Train epoch: 8 [550/625]	Accuracy: 78.75%	Loss: 0.456131
# Train epoch: 8 [560/625]	Accuracy: 84.38%	Loss: 0.368141
# Train epoch: 8 [570/625]	Accuracy: 83.12%	Loss: 0.380634
# Train epoch: 8 [580/625]	Accuracy: 80.31%	Loss: 0.368574
# Train epoch: 8 [590/625]	Accuracy: 84.38%	Loss: 0.344301
# Train epoch: 8 [600/625]	Accuracy: 85.31%	Loss: 0.334916
# Train epoch: 8 [610/625]	Accuracy: 79.38%	Loss: 0.398522
# Train epoch: 8 [620/625]	Accuracy: 79.38%	Loss: 0.397314
# Test set: Loss: 0.6920, Accuracy: 64.55%)
# Train epoch: 9 [10/625]	Accuracy: 80.62%	Loss: 0.394712
# Train epoch: 9 [20/625]	Accuracy: 78.12%	Loss: 0.427083
# Train epoch: 9 [30/625]	Accuracy: 84.06%	Loss: 0.364776
# Train epoch: 9 [40/625]	Accuracy: 81.25%	Loss: 0.383171
# Train epoch: 9 [50/625]	Accuracy: 78.44%	Loss: 0.440931
# Train epoch: 9 [60/625]	Accuracy: 76.56%	Loss: 0.479267
# Train epoch: 9 [70/625]	Accuracy: 81.56%	Loss: 0.384388
# Train epoch: 9 [80/625]	Accuracy: 81.56%	Loss: 0.419660
# Train epoch: 9 [90/625]	Accuracy: 82.19%	Loss: 0.354283
# Train epoch: 9 [100/625]	Accuracy: 80.00%	Loss: 0.427412
# Train epoch: 9 [110/625]	Accuracy: 84.38%	Loss: 0.375318
# Train epoch: 9 [120/625]	Accuracy: 80.62%	Loss: 0.398646
# Train epoch: 9 [130/625]	Accuracy: 80.62%	Loss: 0.420845
# Train epoch: 9 [140/625]	Accuracy: 80.62%	Loss: 0.411597
# Train epoch: 9 [150/625]	Accuracy: 79.06%	Loss: 0.397519
# Train epoch: 9 [160/625]	Accuracy: 83.75%	Loss: 0.360905
# Train epoch: 9 [170/625]	Accuracy: 80.31%	Loss: 0.417653
# Train epoch: 9 [180/625]	Accuracy: 81.88%	Loss: 0.412072
# Train epoch: 9 [190/625]	Accuracy: 80.94%	Loss: 0.398995
# Train epoch: 9 [200/625]	Accuracy: 82.19%	Loss: 0.430288
# Train epoch: 9 [210/625]	Accuracy: 79.69%	Loss: 0.386759
# Train epoch: 9 [220/625]	Accuracy: 85.00%	Loss: 0.351396
# Train epoch: 9 [230/625]	Accuracy: 80.00%	Loss: 0.438571
# Train epoch: 9 [240/625]	Accuracy: 81.25%	Loss: 0.358518
# Train epoch: 9 [250/625]	Accuracy: 80.62%	Loss: 0.412008
# Train epoch: 9 [260/625]	Accuracy: 85.62%	Loss: 0.339197
# Train epoch: 9 [270/625]	Accuracy: 84.38%	Loss: 0.353979
# Train epoch: 9 [280/625]	Accuracy: 83.12%	Loss: 0.383026
# Train epoch: 9 [290/625]	Accuracy: 80.94%	Loss: 0.423778
# Train epoch: 9 [300/625]	Accuracy: 83.12%	Loss: 0.367568
# Train epoch: 9 [310/625]	Accuracy: 86.25%	Loss: 0.362481
# Train epoch: 9 [320/625]	Accuracy: 82.19%	Loss: 0.377717
# Train epoch: 9 [330/625]	Accuracy: 80.94%	Loss: 0.410925
# Train epoch: 9 [340/625]	Accuracy: 81.25%	Loss: 0.423525
# Train epoch: 9 [350/625]	Accuracy: 82.50%	Loss: 0.373939
# Train epoch: 9 [360/625]	Accuracy: 84.06%	Loss: 0.394242
# Train epoch: 9 [370/625]	Accuracy: 84.69%	Loss: 0.361194
# Train epoch: 9 [380/625]	Accuracy: 78.12%	Loss: 0.414451
# Train epoch: 9 [390/625]	Accuracy: 83.44%	Loss: 0.382781
# Train epoch: 9 [400/625]	Accuracy: 82.50%	Loss: 0.391995
# Train epoch: 9 [410/625]	Accuracy: 80.31%	Loss: 0.380055
# Train epoch: 9 [420/625]	Accuracy: 78.12%	Loss: 0.441403
# Train epoch: 9 [430/625]	Accuracy: 80.62%	Loss: 0.375166
# Train epoch: 9 [440/625]	Accuracy: 80.94%	Loss: 0.410460
# Train epoch: 9 [450/625]	Accuracy: 81.88%	Loss: 0.380355
# Train epoch: 9 [460/625]	Accuracy: 80.31%	Loss: 0.403205
# Train epoch: 9 [470/625]	Accuracy: 79.06%	Loss: 0.421387
# Train epoch: 9 [480/625]	Accuracy: 86.88%	Loss: 0.350119
# Train epoch: 9 [490/625]	Accuracy: 83.75%	Loss: 0.377278
# Train epoch: 9 [500/625]	Accuracy: 80.31%	Loss: 0.401215
# Train epoch: 9 [510/625]	Accuracy: 85.00%	Loss: 0.347491
# Train epoch: 9 [520/625]	Accuracy: 82.19%	Loss: 0.381402
# Train epoch: 9 [530/625]	Accuracy: 82.19%	Loss: 0.379811
# Train epoch: 9 [540/625]	Accuracy: 84.06%	Loss: 0.362395
# Train epoch: 9 [550/625]	Accuracy: 78.44%	Loss: 0.431390
# Train epoch: 9 [560/625]	Accuracy: 80.31%	Loss: 0.435453
# Train epoch: 9 [570/625]	Accuracy: 85.31%	Loss: 0.356597
# Train epoch: 9 [580/625]	Accuracy: 81.56%	Loss: 0.393256
# Train epoch: 9 [590/625]	Accuracy: 82.81%	Loss: 0.360485
# Train epoch: 9 [600/625]	Accuracy: 84.69%	Loss: 0.373680
# Train epoch: 9 [610/625]	Accuracy: 87.19%	Loss: 0.312586
# Train epoch: 9 [620/625]	Accuracy: 84.38%	Loss: 0.353469
# Test set: Loss: 0.7622, Accuracy: 65.23%)
# Train epoch: 10 [10/625]	Accuracy: 81.25%	Loss: 0.386845
# Train epoch: 10 [20/625]	Accuracy: 80.62%	Loss: 0.404602
# Train epoch: 10 [30/625]	Accuracy: 77.19%	Loss: 0.473155
# Train epoch: 10 [40/625]	Accuracy: 75.62%	Loss: 0.478511
# Train epoch: 10 [50/625]	Accuracy: 79.06%	Loss: 0.439398
# Train epoch: 10 [60/625]	Accuracy: 80.62%	Loss: 0.435252
# Train epoch: 10 [70/625]	Accuracy: 82.19%	Loss: 0.382478
# Train epoch: 10 [80/625]	Accuracy: 83.44%	Loss: 0.362632
# Train epoch: 10 [90/625]	Accuracy: 87.19%	Loss: 0.328806
# Train epoch: 10 [100/625]	Accuracy: 80.31%	Loss: 0.409756
# Train epoch: 10 [110/625]	Accuracy: 85.94%	Loss: 0.351865
# Train epoch: 10 [120/625]	Accuracy: 84.69%	Loss: 0.349924
# Train epoch: 10 [130/625]	Accuracy: 83.44%	Loss: 0.351998
# Train epoch: 10 [140/625]	Accuracy: 82.81%	Loss: 0.400671
# Train epoch: 10 [150/625]	Accuracy: 80.31%	Loss: 0.379088
# Train epoch: 10 [160/625]	Accuracy: 80.31%	Loss: 0.411961
# Train epoch: 10 [170/625]	Accuracy: 80.62%	Loss: 0.369975
# Train epoch: 10 [180/625]	Accuracy: 81.56%	Loss: 0.397321
# Train epoch: 10 [190/625]	Accuracy: 80.31%	Loss: 0.413104
# Train epoch: 10 [200/625]	Accuracy: 81.88%	Loss: 0.395647
# Train epoch: 10 [210/625]	Accuracy: 83.44%	Loss: 0.369477
# Train epoch: 10 [220/625]	Accuracy: 79.69%	Loss: 0.417316
# Train epoch: 10 [230/625]	Accuracy: 82.81%	Loss: 0.374304
# Train epoch: 10 [240/625]	Accuracy: 84.38%	Loss: 0.361672
# Train epoch: 10 [250/625]	Accuracy: 81.88%	Loss: 0.363895
# Train epoch: 10 [260/625]	Accuracy: 83.12%	Loss: 0.368036
# Train epoch: 10 [270/625]	Accuracy: 82.19%	Loss: 0.402574
# Train epoch: 10 [280/625]	Accuracy: 84.38%	Loss: 0.354754
# Train epoch: 10 [290/625]	Accuracy: 87.50%	Loss: 0.331998
# Train epoch: 10 [300/625]	Accuracy: 83.12%	Loss: 0.400012
# Train epoch: 10 [310/625]	Accuracy: 85.94%	Loss: 0.355891
# Train epoch: 10 [320/625]	Accuracy: 83.44%	Loss: 0.367509
# Train epoch: 10 [330/625]	Accuracy: 82.19%	Loss: 0.371390
# Train epoch: 10 [340/625]	Accuracy: 82.81%	Loss: 0.428595
# Train epoch: 10 [350/625]	Accuracy: 84.38%	Loss: 0.375396
# Train epoch: 10 [360/625]	Accuracy: 83.12%	Loss: 0.377251
# Train epoch: 10 [370/625]	Accuracy: 82.81%	Loss: 0.386742
# Train epoch: 10 [380/625]	Accuracy: 83.12%	Loss: 0.376335
# Train epoch: 10 [390/625]	Accuracy: 83.44%	Loss: 0.394679
# Train epoch: 10 [400/625]	Accuracy: 83.44%	Loss: 0.358774
# Train epoch: 10 [410/625]	Accuracy: 81.56%	Loss: 0.366426
# Train epoch: 10 [420/625]	Accuracy: 80.62%	Loss: 0.376037
# Train epoch: 10 [430/625]	Accuracy: 81.88%	Loss: 0.398827
# Train epoch: 10 [440/625]	Accuracy: 79.38%	Loss: 0.410547
# Train epoch: 10 [450/625]	Accuracy: 81.25%	Loss: 0.400348
# Train epoch: 10 [460/625]	Accuracy: 81.88%	Loss: 0.405074
# Train epoch: 10 [470/625]	Accuracy: 83.75%	Loss: 0.363084
# Train epoch: 10 [480/625]	Accuracy: 83.12%	Loss: 0.344230
# Train epoch: 10 [490/625]	Accuracy: 85.00%	Loss: 0.341739
# Train epoch: 10 [500/625]	Accuracy: 83.44%	Loss: 0.371363
# Train epoch: 10 [510/625]	Accuracy: 83.44%	Loss: 0.391475
# Train epoch: 10 [520/625]	Accuracy: 83.12%	Loss: 0.362275
# Train epoch: 10 [530/625]	Accuracy: 85.94%	Loss: 0.355980
# Train epoch: 10 [540/625]	Accuracy: 81.25%	Loss: 0.394193
# Train epoch: 10 [550/625]	Accuracy: 82.50%	Loss: 0.387126
# Train epoch: 10 [560/625]	Accuracy: 84.69%	Loss: 0.347873
# Train epoch: 10 [570/625]	Accuracy: 84.38%	Loss: 0.359924
# Train epoch: 10 [580/625]	Accuracy: 84.69%	Loss: 0.361371
# Train epoch: 10 [590/625]	Accuracy: 82.50%	Loss: 0.400609
# Train epoch: 10 [600/625]	Accuracy: 83.44%	Loss: 0.349775
# Train epoch: 10 [610/625]	Accuracy: 84.06%	Loss: 0.333544
# Train epoch: 10 [620/625]	Accuracy: 85.94%	Loss: 0.365958
# Test set: Loss: 0.7420, Accuracy: 61.21%)
# Train epoch: 11 [10/625]	Accuracy: 80.31%	Loss: 0.378121
# Train epoch: 11 [20/625]	Accuracy: 87.81%	Loss: 0.297507
# Train epoch: 11 [30/625]	Accuracy: 85.31%	Loss: 0.333771
# Train epoch: 11 [40/625]	Accuracy: 83.44%	Loss: 0.379870
# Train epoch: 11 [50/625]	Accuracy: 85.94%	Loss: 0.315091
# Train epoch: 11 [60/625]	Accuracy: 85.94%	Loss: 0.319176
# Train epoch: 11 [70/625]	Accuracy: 82.81%	Loss: 0.371596
# Train epoch: 11 [80/625]	Accuracy: 83.44%	Loss: 0.370690
# Train epoch: 11 [90/625]	Accuracy: 80.31%	Loss: 0.387436
# Train epoch: 11 [100/625]	Accuracy: 81.88%	Loss: 0.364990
# Train epoch: 11 [110/625]	Accuracy: 85.31%	Loss: 0.339323
# Train epoch: 11 [120/625]	Accuracy: 82.50%	Loss: 0.346910
# Train epoch: 11 [130/625]	Accuracy: 82.81%	Loss: 0.357474
# Train epoch: 11 [140/625]	Accuracy: 82.19%	Loss: 0.365987
# Train epoch: 11 [150/625]	Accuracy: 82.19%	Loss: 0.361195
# Train epoch: 11 [160/625]	Accuracy: 83.75%	Loss: 0.366470
# Train epoch: 11 [170/625]	Accuracy: 83.75%	Loss: 0.364021
# Train epoch: 11 [180/625]	Accuracy: 81.56%	Loss: 0.405870
# Train epoch: 11 [190/625]	Accuracy: 85.62%	Loss: 0.371021
# Train epoch: 11 [200/625]	Accuracy: 81.25%	Loss: 0.413839
# Train epoch: 11 [210/625]	Accuracy: 84.06%	Loss: 0.359066
# Train epoch: 11 [220/625]	Accuracy: 87.50%	Loss: 0.330108
# Train epoch: 11 [230/625]	Accuracy: 82.50%	Loss: 0.366131
# Train epoch: 11 [240/625]	Accuracy: 86.25%	Loss: 0.323577
# Train epoch: 11 [250/625]	Accuracy: 86.88%	Loss: 0.322706
# Train epoch: 11 [260/625]	Accuracy: 83.12%	Loss: 0.418565
# Train epoch: 11 [270/625]	Accuracy: 83.12%	Loss: 0.372192
# Train epoch: 11 [280/625]	Accuracy: 83.75%	Loss: 0.367254
# Train epoch: 11 [290/625]	Accuracy: 82.81%	Loss: 0.350297
# Train epoch: 11 [300/625]	Accuracy: 82.19%	Loss: 0.393104
# Train epoch: 11 [310/625]	Accuracy: 81.88%	Loss: 0.361357
# Train epoch: 11 [320/625]	Accuracy: 86.25%	Loss: 0.372418
# Train epoch: 11 [330/625]	Accuracy: 82.81%	Loss: 0.397253
# Train epoch: 11 [340/625]	Accuracy: 80.94%	Loss: 0.394322
# Train epoch: 11 [350/625]	Accuracy: 84.06%	Loss: 0.353450
# Train epoch: 11 [360/625]	Accuracy: 85.00%	Loss: 0.356174
# Train epoch: 11 [370/625]	Accuracy: 76.88%	Loss: 0.428890
# Train epoch: 11 [380/625]	Accuracy: 81.88%	Loss: 0.381853
# Train epoch: 11 [390/625]	Accuracy: 82.81%	Loss: 0.359084
# Train epoch: 11 [400/625]	Accuracy: 83.75%	Loss: 0.364910
# Train epoch: 11 [410/625]	Accuracy: 86.56%	Loss: 0.332896
# Train epoch: 11 [420/625]	Accuracy: 83.44%	Loss: 0.344139
# Train epoch: 11 [430/625]	Accuracy: 86.88%	Loss: 0.315739
# Train epoch: 11 [440/625]	Accuracy: 82.19%	Loss: 0.378915
# Train epoch: 11 [450/625]	Accuracy: 82.81%	Loss: 0.377793
# Train epoch: 11 [460/625]	Accuracy: 84.06%	Loss: 0.333704
# Train epoch: 11 [470/625]	Accuracy: 84.06%	Loss: 0.327871
# Train epoch: 11 [480/625]	Accuracy: 83.12%	Loss: 0.341577
# Train epoch: 11 [490/625]	Accuracy: 80.94%	Loss: 0.389265
# Train epoch: 11 [500/625]	Accuracy: 80.00%	Loss: 0.393653
# Train epoch: 11 [510/625]	Accuracy: 80.31%	Loss: 0.400833
# Train epoch: 11 [520/625]	Accuracy: 81.88%	Loss: 0.384860
# Train epoch: 11 [530/625]	Accuracy: 80.00%	Loss: 0.427039
# Train epoch: 11 [540/625]	Accuracy: 82.50%	Loss: 0.361453
# Train epoch: 11 [550/625]	Accuracy: 81.88%	Loss: 0.404558
# Train epoch: 11 [560/625]	Accuracy: 85.94%	Loss: 0.339224
# Train epoch: 11 [570/625]	Accuracy: 84.38%	Loss: 0.335741
# Train epoch: 11 [580/625]	Accuracy: 82.50%	Loss: 0.361705
# Train epoch: 11 [590/625]	Accuracy: 81.88%	Loss: 0.375261
# Train epoch: 11 [600/625]	Accuracy: 81.25%	Loss: 0.391002
# Train epoch: 11 [610/625]	Accuracy: 84.69%	Loss: 0.323066
# Train epoch: 11 [620/625]	Accuracy: 85.94%	Loss: 0.348856
# Test set: Loss: 0.6479, Accuracy: 66.08%)
# Train epoch: 12 [10/625]	Accuracy: 85.00%	Loss: 0.342110
# Train epoch: 12 [20/625]	Accuracy: 80.31%	Loss: 0.388947
# Train epoch: 12 [30/625]	Accuracy: 86.25%	Loss: 0.339565
# Train epoch: 12 [40/625]	Accuracy: 85.00%	Loss: 0.346847
# Train epoch: 12 [50/625]	Accuracy: 83.44%	Loss: 0.341937
# Train epoch: 12 [60/625]	Accuracy: 85.62%	Loss: 0.323140
# Train epoch: 12 [70/625]	Accuracy: 82.81%	Loss: 0.342473
# Train epoch: 12 [80/625]	Accuracy: 85.62%	Loss: 0.337253
# Train epoch: 12 [90/625]	Accuracy: 83.44%	Loss: 0.357345
# Train epoch: 12 [100/625]	Accuracy: 81.88%	Loss: 0.376449
# Train epoch: 12 [110/625]	Accuracy: 86.56%	Loss: 0.328248
# Train epoch: 12 [120/625]	Accuracy: 86.56%	Loss: 0.310461
# Train epoch: 12 [130/625]	Accuracy: 83.75%	Loss: 0.356520
# Train epoch: 12 [140/625]	Accuracy: 84.69%	Loss: 0.337383
# Train epoch: 12 [150/625]	Accuracy: 84.06%	Loss: 0.376300
# Train epoch: 12 [160/625]	Accuracy: 84.38%	Loss: 0.340619
# Train epoch: 12 [170/625]	Accuracy: 80.31%	Loss: 0.393938
# Train epoch: 12 [180/625]	Accuracy: 79.06%	Loss: 0.397831
# Train epoch: 12 [190/625]	Accuracy: 82.19%	Loss: 0.377245
# Train epoch: 12 [200/625]	Accuracy: 85.62%	Loss: 0.360676
# Train epoch: 12 [210/625]	Accuracy: 87.81%	Loss: 0.313907
# Train epoch: 12 [220/625]	Accuracy: 82.81%	Loss: 0.364930
# Train epoch: 12 [230/625]	Accuracy: 85.31%	Loss: 0.344923
# Train epoch: 12 [240/625]	Accuracy: 83.12%	Loss: 0.403035
# Train epoch: 12 [250/625]	Accuracy: 82.81%	Loss: 0.370538
# Train epoch: 12 [260/625]	Accuracy: 85.94%	Loss: 0.367747
# Train epoch: 12 [270/625]	Accuracy: 82.50%	Loss: 0.405056
# Train epoch: 12 [280/625]	Accuracy: 85.94%	Loss: 0.331425
# Train epoch: 12 [290/625]	Accuracy: 79.06%	Loss: 0.429597
# Train epoch: 12 [300/625]	Accuracy: 84.69%	Loss: 0.328786
# Train epoch: 12 [310/625]	Accuracy: 84.69%	Loss: 0.326163
# Train epoch: 12 [320/625]	Accuracy: 83.44%	Loss: 0.368076
# Train epoch: 12 [330/625]	Accuracy: 82.50%	Loss: 0.385810
# Train epoch: 12 [340/625]	Accuracy: 82.50%	Loss: 0.369418
# Train epoch: 12 [350/625]	Accuracy: 87.81%	Loss: 0.309221
# Train epoch: 12 [360/625]	Accuracy: 83.75%	Loss: 0.382185
# Train epoch: 12 [370/625]	Accuracy: 85.00%	Loss: 0.348367
# Train epoch: 12 [380/625]	Accuracy: 82.50%	Loss: 0.325894
# Train epoch: 12 [390/625]	Accuracy: 80.94%	Loss: 0.373566
# Train epoch: 12 [400/625]	Accuracy: 84.38%	Loss: 0.394213
# Train epoch: 12 [410/625]	Accuracy: 81.88%	Loss: 0.368296
# Train epoch: 12 [420/625]	Accuracy: 84.38%	Loss: 0.343690
# Train epoch: 12 [430/625]	Accuracy: 86.88%	Loss: 0.321067
# Train epoch: 12 [440/625]	Accuracy: 87.81%	Loss: 0.308323
# Train epoch: 12 [450/625]	Accuracy: 85.94%	Loss: 0.306113
# Train epoch: 12 [460/625]	Accuracy: 87.19%	Loss: 0.291048
# Train epoch: 12 [470/625]	Accuracy: 84.06%	Loss: 0.365000
# Train epoch: 12 [480/625]	Accuracy: 85.94%	Loss: 0.316630
# Train epoch: 12 [490/625]	Accuracy: 85.94%	Loss: 0.316395
# Train epoch: 12 [500/625]	Accuracy: 84.06%	Loss: 0.330898
# Train epoch: 12 [510/625]	Accuracy: 85.31%	Loss: 0.366440
# Train epoch: 12 [520/625]	Accuracy: 83.75%	Loss: 0.357746
# Train epoch: 12 [530/625]	Accuracy: 85.94%	Loss: 0.355820
# Train epoch: 12 [540/625]	Accuracy: 84.69%	Loss: 0.359827
# Train epoch: 12 [550/625]	Accuracy: 85.00%	Loss: 0.325159
# Train epoch: 12 [560/625]	Accuracy: 84.38%	Loss: 0.362300
# Train epoch: 12 [570/625]	Accuracy: 82.50%	Loss: 0.377878
# Train epoch: 12 [580/625]	Accuracy: 84.06%	Loss: 0.337927
# Train epoch: 12 [590/625]	Accuracy: 82.50%	Loss: 0.419092
# Train epoch: 12 [600/625]	Accuracy: 85.94%	Loss: 0.377196
# Train epoch: 12 [610/625]	Accuracy: 85.00%	Loss: 0.362796
# Train epoch: 12 [620/625]	Accuracy: 81.56%	Loss: 0.393845
# Test set: Loss: 0.9731, Accuracy: 56.77%)
# Train epoch: 13 [10/625]	Accuracy: 80.94%	Loss: 0.357270
# Train epoch: 13 [20/625]	Accuracy: 82.81%	Loss: 0.338430
# Train epoch: 13 [30/625]	Accuracy: 84.38%	Loss: 0.365915
# Train epoch: 13 [40/625]	Accuracy: 83.44%	Loss: 0.366433
# Train epoch: 13 [50/625]	Accuracy: 86.88%	Loss: 0.329057
# Train epoch: 13 [60/625]	Accuracy: 84.06%	Loss: 0.343767
# Train epoch: 13 [70/625]	Accuracy: 81.88%	Loss: 0.391986
# Train epoch: 13 [80/625]	Accuracy: 82.81%	Loss: 0.336736
# Train epoch: 13 [90/625]	Accuracy: 86.25%	Loss: 0.354059
# Train epoch: 13 [100/625]	Accuracy: 81.25%	Loss: 0.408616
# Train epoch: 13 [110/625]	Accuracy: 88.44%	Loss: 0.281718
# Train epoch: 13 [120/625]	Accuracy: 84.38%	Loss: 0.333085
# Train epoch: 13 [130/625]	Accuracy: 82.19%	Loss: 0.386512
# Train epoch: 13 [140/625]	Accuracy: 85.31%	Loss: 0.319462
# Train epoch: 13 [150/625]	Accuracy: 80.94%	Loss: 0.364712
# Train epoch: 13 [160/625]	Accuracy: 80.62%	Loss: 0.366471
# Train epoch: 13 [170/625]	Accuracy: 85.00%	Loss: 0.323329
# Train epoch: 13 [180/625]	Accuracy: 82.50%	Loss: 0.341294
# Train epoch: 13 [190/625]	Accuracy: 82.19%	Loss: 0.367478
# Train epoch: 13 [200/625]	Accuracy: 85.00%	Loss: 0.332187
# Train epoch: 13 [210/625]	Accuracy: 83.44%	Loss: 0.352170
# Train epoch: 13 [220/625]	Accuracy: 82.81%	Loss: 0.346285
# Train epoch: 13 [230/625]	Accuracy: 83.44%	Loss: 0.374884
# Train epoch: 13 [240/625]	Accuracy: 81.56%	Loss: 0.392144
# Train epoch: 13 [250/625]	Accuracy: 82.50%	Loss: 0.365101
# Train epoch: 13 [260/625]	Accuracy: 89.69%	Loss: 0.300457
# Train epoch: 13 [270/625]	Accuracy: 86.25%	Loss: 0.310957
# Train epoch: 13 [280/625]	Accuracy: 82.81%	Loss: 0.348702
# Train epoch: 13 [290/625]	Accuracy: 83.75%	Loss: 0.359833
# Train epoch: 13 [300/625]	Accuracy: 81.25%	Loss: 0.395611
# Train epoch: 13 [310/625]	Accuracy: 83.12%	Loss: 0.372105
# Train epoch: 13 [320/625]	Accuracy: 87.50%	Loss: 0.320662
# Train epoch: 13 [330/625]	Accuracy: 84.06%	Loss: 0.355637
# Train epoch: 13 [340/625]	Accuracy: 85.00%	Loss: 0.345098
# Train epoch: 13 [350/625]	Accuracy: 81.56%	Loss: 0.356094
# Train epoch: 13 [360/625]	Accuracy: 82.50%	Loss: 0.339938
# Train epoch: 13 [370/625]	Accuracy: 79.69%	Loss: 0.429418
# Train epoch: 13 [380/625]	Accuracy: 83.12%	Loss: 0.356106
# Train epoch: 13 [390/625]	Accuracy: 84.69%	Loss: 0.335100
# Train epoch: 13 [400/625]	Accuracy: 82.81%	Loss: 0.353671
# Train epoch: 13 [410/625]	Accuracy: 85.62%	Loss: 0.331398
# Train epoch: 13 [420/625]	Accuracy: 85.31%	Loss: 0.343849
# Train epoch: 13 [430/625]	Accuracy: 87.19%	Loss: 0.317593
# Train epoch: 13 [440/625]	Accuracy: 82.19%	Loss: 0.356568
# Train epoch: 13 [450/625]	Accuracy: 84.38%	Loss: 0.322109
# Train epoch: 13 [460/625]	Accuracy: 85.31%	Loss: 0.322137
# Train epoch: 13 [470/625]	Accuracy: 86.88%	Loss: 0.291262
# Train epoch: 13 [480/625]	Accuracy: 82.81%	Loss: 0.368207
# Train epoch: 13 [490/625]	Accuracy: 86.88%	Loss: 0.330902
# Train epoch: 13 [500/625]	Accuracy: 84.69%	Loss: 0.337817
# Train epoch: 13 [510/625]	Accuracy: 87.50%	Loss: 0.309191
# Train epoch: 13 [520/625]	Accuracy: 82.81%	Loss: 0.361950
# Train epoch: 13 [530/625]	Accuracy: 85.62%	Loss: 0.327040
# Train epoch: 13 [540/625]	Accuracy: 87.81%	Loss: 0.306556
# Train epoch: 13 [550/625]	Accuracy: 86.88%	Loss: 0.304950
# Train epoch: 13 [560/625]	Accuracy: 85.62%	Loss: 0.319052
# Train epoch: 13 [570/625]	Accuracy: 86.56%	Loss: 0.327401
# Train epoch: 13 [580/625]	Accuracy: 83.75%	Loss: 0.405567
# Train epoch: 13 [590/625]	Accuracy: 86.88%	Loss: 0.299314
# Train epoch: 13 [600/625]	Accuracy: 81.88%	Loss: 0.416720
# Train epoch: 13 [610/625]	Accuracy: 88.12%	Loss: 0.323182
# Train epoch: 13 [620/625]	Accuracy: 84.69%	Loss: 0.338152
# Test set: Loss: 0.6321, Accuracy: 65.68%)
# Train epoch: 14 [10/625]	Accuracy: 86.56%	Loss: 0.321294
# Train epoch: 14 [20/625]	Accuracy: 86.25%	Loss: 0.308188
# Train epoch: 14 [30/625]	Accuracy: 88.44%	Loss: 0.294231
# Train epoch: 14 [40/625]	Accuracy: 84.06%	Loss: 0.364302
# Train epoch: 14 [50/625]	Accuracy: 81.56%	Loss: 0.394739
# Train epoch: 14 [60/625]	Accuracy: 85.62%	Loss: 0.345452
# Train epoch: 14 [70/625]	Accuracy: 82.81%	Loss: 0.357038
# Train epoch: 14 [80/625]	Accuracy: 83.44%	Loss: 0.321701
# Train epoch: 14 [90/625]	Accuracy: 87.81%	Loss: 0.317688
# Train epoch: 14 [100/625]	Accuracy: 88.44%	Loss: 0.299444
# Train epoch: 14 [110/625]	Accuracy: 85.94%	Loss: 0.311093
# Train epoch: 14 [120/625]	Accuracy: 87.50%	Loss: 0.285454
# Train epoch: 14 [130/625]	Accuracy: 83.44%	Loss: 0.372584
# Train epoch: 14 [140/625]	Accuracy: 85.62%	Loss: 0.333884
# Train epoch: 14 [150/625]	Accuracy: 83.44%	Loss: 0.379379
# Train epoch: 14 [160/625]	Accuracy: 82.81%	Loss: 0.365967
# Train epoch: 14 [170/625]	Accuracy: 83.44%	Loss: 0.335879
# Train epoch: 14 [180/625]	Accuracy: 86.88%	Loss: 0.362477
# Train epoch: 14 [190/625]	Accuracy: 83.12%	Loss: 0.356175
# Train epoch: 14 [200/625]	Accuracy: 84.69%	Loss: 0.406317
# Train epoch: 14 [210/625]	Accuracy: 79.69%	Loss: 0.439675
# Train epoch: 14 [220/625]	Accuracy: 80.94%	Loss: 0.423124
# Train epoch: 14 [230/625]	Accuracy: 86.25%	Loss: 0.336399
# ...
# Train epoch: 16 [510/625]	Accuracy: 86.56%	Loss: 0.310081
# Train epoch: 16 [520/625]	Accuracy: 85.00%	Loss: 0.325265
# Train epoch: 16 [530/625]	Accuracy: 85.31%	Loss: 0.324210
# Train epoch: 16 [540/625]	Accuracy: 84.69%	Loss: 0.327794
# Train epoch: 16 [550/625]	Accuracy: 87.19%	Loss: 0.296524
# Train epoch: 16 [560/625]	Accuracy: 86.25%	Loss: 0.286475
# Train epoch: 16 [570/625]	Accuracy: 83.75%	Loss: 0.342264
# Train epoch: 16 [580/625]	Accuracy: 88.44%	Loss: 0.275224
# Train epoch: 16 [590/625]	Accuracy: 87.50%	Loss: 0.312057
# Train epoch: 16 [600/625]	Accuracy: 88.44%	Loss: 0.272552
# Train epoch: 16 [610/625]	Accuracy: 86.88%	Loss: 0.264078
# Train epoch: 16 [620/625]	Accuracy: 87.19%	Loss: 0.317621
# Test set: Loss: 0.7201, Accuracy: 64.71%)
# Train epoch: 17 [10/625]	Accuracy: 85.62%	Loss: 0.302986
# Train epoch: 17 [20/625]	Accuracy: 87.19%	Loss: 0.286379
# Train epoch: 17 [30/625]	Accuracy: 81.88%	Loss: 0.358676
# Train epoch: 17 [40/625]	Accuracy: 85.31%	Loss: 0.330689
# Train epoch: 17 [50/625]	Accuracy: 84.06%	Loss: 0.351597
# Train epoch: 17 [60/625]	Accuracy: 82.19%	Loss: 0.356622
# Train epoch: 17 [70/625]	Accuracy: 86.25%	Loss: 0.306847
# Train epoch: 17 [80/625]	Accuracy: 87.50%	Loss: 0.289990
# Train epoch: 17 [90/625]	Accuracy: 86.56%	Loss: 0.318242
# Train epoch: 17 [100/625]	Accuracy: 85.94%	Loss: 0.313082
# Train epoch: 17 [110/625]	Accuracy: 86.25%	Loss: 0.274879
# Train epoch: 17 [120/625]	Accuracy: 87.19%	Loss: 0.298770
# Train epoch: 17 [130/625]	Accuracy: 82.19%	Loss: 0.356569
# Train epoch: 17 [140/625]	Accuracy: 85.62%	Loss: 0.308464
# Train epoch: 17 [150/625]	Accuracy: 83.44%	Loss: 0.329438
# Train epoch: 17 [160/625]	Accuracy: 86.25%	Loss: 0.344519
# Train epoch: 17 [170/625]	Accuracy: 85.62%	Loss: 0.322624
# Train epoch: 17 [180/625]	Accuracy: 85.31%	Loss: 0.339430
# Train epoch: 17 [190/625]	Accuracy: 85.94%	Loss: 0.345347
# Train epoch: 17 [200/625]	Accuracy: 86.25%	Loss: 0.296650
# Train epoch: 17 [210/625]	Accuracy: 87.19%	Loss: 0.311647
# Train epoch: 17 [220/625]	Accuracy: 85.62%	Loss: 0.310024
# Train epoch: 17 [230/625]	Accuracy: 88.44%	Loss: 0.259341
# Train epoch: 17 [240/625]	Accuracy: 88.44%	Loss: 0.272835
# Train epoch: 17 [250/625]	Accuracy: 86.25%	Loss: 0.312274
# Train epoch: 17 [260/625]	Accuracy: 86.25%	Loss: 0.301680
# Train epoch: 17 [270/625]	Accuracy: 89.38%	Loss: 0.290479
# Train epoch: 17 [280/625]	Accuracy: 80.94%	Loss: 0.352941
# Train epoch: 17 [290/625]	Accuracy: 87.50%	Loss: 0.304693
# Train epoch: 17 [300/625]	Accuracy: 87.19%	Loss: 0.287503
# Train epoch: 17 [310/625]	Accuracy: 87.50%	Loss: 0.309011
# Train epoch: 17 [320/625]	Accuracy: 85.62%	Loss: 0.307306
# Train epoch: 17 [330/625]	Accuracy: 84.06%	Loss: 0.339951
# Train epoch: 17 [340/625]	Accuracy: 86.88%	Loss: 0.286150
# Train epoch: 17 [350/625]	Accuracy: 86.25%	Loss: 0.334887
# Train epoch: 17 [360/625]	Accuracy: 89.38%	Loss: 0.257295
# Train epoch: 17 [370/625]	Accuracy: 87.50%	Loss: 0.301269
# Train epoch: 17 [380/625]	Accuracy: 85.00%	Loss: 0.330711
# Train epoch: 17 [390/625]	Accuracy: 86.88%	Loss: 0.275450
# Train epoch: 17 [400/625]	Accuracy: 85.00%	Loss: 0.323695
# Train epoch: 17 [410/625]	Accuracy: 89.38%	Loss: 0.277419
# Train epoch: 17 [420/625]	Accuracy: 85.31%	Loss: 0.294147
# Train epoch: 17 [430/625]	Accuracy: 86.25%	Loss: 0.303900
# Train epoch: 17 [440/625]	Accuracy: 87.50%	Loss: 0.338609
# Train epoch: 17 [450/625]	Accuracy: 86.88%	Loss: 0.337426
# Train epoch: 17 [460/625]	Accuracy: 87.19%	Loss: 0.288642
# Train epoch: 17 [470/625]	Accuracy: 85.94%	Loss: 0.301928
# Train epoch: 17 [480/625]	Accuracy: 83.75%	Loss: 0.325618
# Train epoch: 17 [490/625]	Accuracy: 86.88%	Loss: 0.302270
# Train epoch: 17 [500/625]	Accuracy: 88.12%	Loss: 0.300007
# Train epoch: 17 [510/625]	Accuracy: 84.38%	Loss: 0.331988
# Train epoch: 17 [520/625]	Accuracy: 82.50%	Loss: 0.355495
# Train epoch: 17 [530/625]	Accuracy: 85.62%	Loss: 0.307764
# Train epoch: 17 [540/625]	Accuracy: 84.38%	Loss: 0.363556
# Train epoch: 17 [550/625]	Accuracy: 85.31%	Loss: 0.316372
# Train epoch: 17 [560/625]	Accuracy: 85.31%	Loss: 0.325784
# Train epoch: 17 [570/625]	Accuracy: 87.19%	Loss: 0.280584
# Train epoch: 17 [580/625]	Accuracy: 87.81%	Loss: 0.298900
# Train epoch: 17 [590/625]	Accuracy: 89.06%	Loss: 0.285696
# Train epoch: 17 [600/625]	Accuracy: 85.94%	Loss: 0.311247
# Train epoch: 17 [610/625]	Accuracy: 84.38%	Loss: 0.339424
# Train epoch: 17 [620/625]	Accuracy: 80.62%	Loss: 0.377270
# Test set: Loss: 1.1509, Accuracy: 59.18%)
# Train epoch: 18 [10/625]	Accuracy: 82.81%	Loss: 0.347815
# Train epoch: 18 [20/625]	Accuracy: 85.94%	Loss: 0.320441
# Train epoch: 18 [30/625]	Accuracy: 86.88%	Loss: 0.311399
# Train epoch: 18 [40/625]	Accuracy: 84.69%	Loss: 0.315171
# Train epoch: 18 [50/625]	Accuracy: 90.31%	Loss: 0.254576
# Train epoch: 18 [60/625]	Accuracy: 85.31%	Loss: 0.305659
# Train epoch: 18 [70/625]	Accuracy: 87.81%	Loss: 0.287294
# Train epoch: 18 [80/625]	Accuracy: 88.12%	Loss: 0.303801
# Train epoch: 18 [90/625]	Accuracy: 85.31%	Loss: 0.330991
# Train epoch: 18 [100/625]	Accuracy: 88.44%	Loss: 0.279048
# Train epoch: 18 [110/625]	Accuracy: 84.69%	Loss: 0.349663
# Train epoch: 18 [120/625]	Accuracy: 86.56%	Loss: 0.306883
# Train epoch: 18 [130/625]	Accuracy: 86.88%	Loss: 0.316863
# Train epoch: 18 [140/625]	Accuracy: 87.19%	Loss: 0.314753
# Train epoch: 18 [150/625]	Accuracy: 85.62%	Loss: 0.310482
# Train epoch: 18 [160/625]	Accuracy: 84.06%	Loss: 0.330476
# Train epoch: 18 [170/625]	Accuracy: 87.50%	Loss: 0.303484
# Train epoch: 18 [180/625]	Accuracy: 83.12%	Loss: 0.351471
# Train epoch: 18 [190/625]	Accuracy: 85.62%	Loss: 0.331010
# Train epoch: 18 [200/625]	Accuracy: 83.12%	Loss: 0.353026
# Train epoch: 18 [210/625]	Accuracy: 88.12%	Loss: 0.303716
# Train epoch: 18 [220/625]	Accuracy: 86.56%	Loss: 0.300369
# Train epoch: 18 [230/625]	Accuracy: 85.31%	Loss: 0.288449
# Train epoch: 18 [240/625]	Accuracy: 87.19%	Loss: 0.286000
# Train epoch: 18 [250/625]	Accuracy: 87.81%	Loss: 0.299723
# Train epoch: 18 [260/625]	Accuracy: 86.25%	Loss: 0.356676
# Train epoch: 18 [270/625]	Accuracy: 83.75%	Loss: 0.333722
# Train epoch: 18 [280/625]	Accuracy: 83.12%	Loss: 0.360998
# Train epoch: 18 [290/625]	Accuracy: 82.50%	Loss: 0.372621
# Train epoch: 18 [300/625]	Accuracy: 83.75%	Loss: 0.322794
# Train epoch: 18 [310/625]	Accuracy: 83.12%	Loss: 0.348460
# Train epoch: 18 [320/625]	Accuracy: 88.12%	Loss: 0.311119
# Train epoch: 18 [330/625]	Accuracy: 86.88%	Loss: 0.295100
# Train epoch: 18 [340/625]	Accuracy: 82.81%	Loss: 0.326745
# Train epoch: 18 [350/625]	Accuracy: 89.38%	Loss: 0.281368
# Train epoch: 18 [360/625]	Accuracy: 84.06%	Loss: 0.330677
# Train epoch: 18 [370/625]	Accuracy: 87.50%	Loss: 0.287222
# Train epoch: 18 [380/625]	Accuracy: 86.56%	Loss: 0.310242
# Train epoch: 18 [390/625]	Accuracy: 88.12%	Loss: 0.278904
# Train epoch: 18 [400/625]	Accuracy: 91.25%	Loss: 0.237741
# Train epoch: 18 [410/625]	Accuracy: 88.44%	Loss: 0.303671
# Train epoch: 18 [420/625]	Accuracy: 90.31%	Loss: 0.252998
# Train epoch: 18 [430/625]	Accuracy: 87.19%	Loss: 0.320697
# Train epoch: 18 [440/625]	Accuracy: 83.44%	Loss: 0.325566
# Train epoch: 18 [450/625]	Accuracy: 85.94%	Loss: 0.304912
# Train epoch: 18 [460/625]	Accuracy: 86.56%	Loss: 0.320098
# Train epoch: 18 [470/625]	Accuracy: 90.94%	Loss: 0.258421
# Train epoch: 18 [480/625]	Accuracy: 82.19%	Loss: 0.336351
# Train epoch: 18 [490/625]	Accuracy: 86.88%	Loss: 0.309015
# Train epoch: 18 [500/625]	Accuracy: 87.19%	Loss: 0.302295
# Train epoch: 18 [510/625]	Accuracy: 88.12%	Loss: 0.292319
# Train epoch: 18 [520/625]	Accuracy: 89.69%	Loss: 0.267978
# Train epoch: 18 [530/625]	Accuracy: 86.25%	Loss: 0.324453
# Train epoch: 18 [540/625]	Accuracy: 86.56%	Loss: 0.324096
# Train epoch: 18 [550/625]	Accuracy: 87.81%	Loss: 0.305398
# Train epoch: 18 [560/625]	Accuracy: 87.81%	Loss: 0.309342
# Train epoch: 18 [570/625]	Accuracy: 88.75%	Loss: 0.268404
# Train epoch: 18 [580/625]	Accuracy: 86.88%	Loss: 0.279421
# Train epoch: 18 [590/625]	Accuracy: 82.19%	Loss: 0.354686
# Train epoch: 18 [600/625]	Accuracy: 87.50%	Loss: 0.316479
# Train epoch: 18 [610/625]	Accuracy: 89.38%	Loss: 0.276520
# Train epoch: 18 [620/625]	Accuracy: 86.25%	Loss: 0.305812
# Test set: Loss: 0.9292, Accuracy: 61.45%)
# Train epoch: 19 [10/625]	Accuracy: 87.19%	Loss: 0.301908
# Train epoch: 19 [20/625]	Accuracy: 85.94%	Loss: 0.318536
# Train epoch: 19 [30/625]	Accuracy: 81.25%	Loss: 0.370848
# Train epoch: 19 [40/625]	Accuracy: 86.56%	Loss: 0.292707
# Train epoch: 19 [50/625]	Accuracy: 87.19%	Loss: 0.267131
# Train epoch: 19 [60/625]	Accuracy: 87.19%	Loss: 0.289826
# Train epoch: 19 [70/625]	Accuracy: 87.19%	Loss: 0.304300
# Train epoch: 19 [80/625]	Accuracy: 88.12%	Loss: 0.269859
# Train epoch: 19 [90/625]	Accuracy: 88.12%	Loss: 0.279960
# Train epoch: 19 [100/625]	Accuracy: 84.38%	Loss: 0.320948
# Train epoch: 19 [110/625]	Accuracy: 87.81%	Loss: 0.281047
# Train epoch: 19 [120/625]	Accuracy: 84.38%	Loss: 0.316554
# Train epoch: 19 [130/625]	Accuracy: 86.25%	Loss: 0.317688
# Train epoch: 19 [140/625]	Accuracy: 85.31%	Loss: 0.323501
# Train epoch: 19 [150/625]	Accuracy: 85.62%	Loss: 0.312441
# Train epoch: 19 [160/625]	Accuracy: 87.19%	Loss: 0.330047
# Train epoch: 19 [170/625]	Accuracy: 84.69%	Loss: 0.327279
# Train epoch: 19 [180/625]	Accuracy: 87.81%	Loss: 0.272597
# Train epoch: 19 [190/625]	Accuracy: 87.81%	Loss: 0.271384
# Train epoch: 19 [200/625]	Accuracy: 88.44%	Loss: 0.266051
# Train epoch: 19 [210/625]	Accuracy: 87.81%	Loss: 0.305130
# Train epoch: 19 [220/625]	Accuracy: 88.75%	Loss: 0.269422
# Train epoch: 19 [230/625]	Accuracy: 84.06%	Loss: 0.329652
# Train epoch: 19 [240/625]	Accuracy: 84.38%	Loss: 0.349618
# Train epoch: 19 [250/625]	Accuracy: 87.81%	Loss: 0.303905
# Train epoch: 19 [260/625]	Accuracy: 84.38%	Loss: 0.361729
# Train epoch: 19 [270/625]	Accuracy: 86.56%	Loss: 0.294186
# Train epoch: 19 [280/625]	Accuracy: 87.19%	Loss: 0.299464
# Train epoch: 19 [290/625]	Accuracy: 86.56%	Loss: 0.298973
# Train epoch: 19 [300/625]	Accuracy: 90.62%	Loss: 0.248102
# Train epoch: 19 [310/625]	Accuracy: 87.19%	Loss: 0.327928
# Train epoch: 19 [320/625]	Accuracy: 87.19%	Loss: 0.313561
# Train epoch: 19 [330/625]	Accuracy: 85.31%	Loss: 0.310158
# Train epoch: 19 [340/625]	Accuracy: 88.44%	Loss: 0.265968
# Train epoch: 19 [350/625]	Accuracy: 87.81%	Loss: 0.272830
# Train epoch: 19 [360/625]	Accuracy: 89.69%	Loss: 0.236726
# Train epoch: 19 [370/625]	Accuracy: 89.38%	Loss: 0.294224
# Train epoch: 19 [380/625]	Accuracy: 89.38%	Loss: 0.288770
# Train epoch: 19 [390/625]	Accuracy: 87.50%	Loss: 0.300652
# Train epoch: 19 [400/625]	Accuracy: 85.62%	Loss: 0.338137
# Train epoch: 19 [410/625]	Accuracy: 84.38%	Loss: 0.335591
# Train epoch: 19 [420/625]	Accuracy: 86.25%	Loss: 0.301762
# Train epoch: 19 [430/625]	Accuracy: 87.81%	Loss: 0.299160
# Train epoch: 19 [440/625]	Accuracy: 85.62%	Loss: 0.298780
# Train epoch: 19 [450/625]	Accuracy: 89.06%	Loss: 0.264128
# Train epoch: 19 [460/625]	Accuracy: 91.25%	Loss: 0.236311
# Train epoch: 19 [470/625]	Accuracy: 82.19%	Loss: 0.321922
# Train epoch: 19 [480/625]	Accuracy: 86.88%	Loss: 0.279885
# Train epoch: 19 [490/625]	Accuracy: 87.19%	Loss: 0.297086
# Train epoch: 19 [500/625]	Accuracy: 83.44%	Loss: 0.315460
# Train epoch: 19 [510/625]	Accuracy: 87.50%	Loss: 0.299230
# Train epoch: 19 [520/625]	Accuracy: 89.06%	Loss: 0.262905
# Train epoch: 19 [530/625]	Accuracy: 84.38%	Loss: 0.358440
# Train epoch: 19 [540/625]	Accuracy: 86.25%	Loss: 0.330129
# Train epoch: 19 [550/625]	Accuracy: 89.06%	Loss: 0.241827
# Train epoch: 19 [560/625]	Accuracy: 86.25%	Loss: 0.339227
# Train epoch: 19 [570/625]	Accuracy: 84.06%	Loss: 0.306478
# Train epoch: 19 [580/625]	Accuracy: 84.06%	Loss: 0.298003
# Train epoch: 19 [590/625]	Accuracy: 85.00%	Loss: 0.304548
# Train epoch: 19 [600/625]	Accuracy: 85.94%	Loss: 0.293657
# Train epoch: 19 [610/625]	Accuracy: 87.81%	Loss: 0.279813
# Train epoch: 19 [620/625]	Accuracy: 88.44%	Loss: 0.264484
# Test set: Loss: 0.7842, Accuracy: 65.51%)
# Train epoch: 20 [10/625]	Accuracy: 86.56%	Loss: 0.281012
# Train epoch: 20 [20/625]	Accuracy: 87.50%	Loss: 0.309062
# Train epoch: 20 [30/625]	Accuracy: 85.00%	Loss: 0.353285
# Train epoch: 20 [40/625]	Accuracy: 89.38%	Loss: 0.258934
# Train epoch: 20 [50/625]	Accuracy: 87.50%	Loss: 0.300812
# Train epoch: 20 [60/625]	Accuracy: 86.88%	Loss: 0.296262
# Train epoch: 20 [70/625]	Accuracy: 81.25%	Loss: 0.386908
# Train epoch: 20 [80/625]	Accuracy: 85.00%	Loss: 0.303432
# Train epoch: 20 [90/625]	Accuracy: 85.62%	Loss: 0.317232
# Train epoch: 20 [100/625]	Accuracy: 87.50%	Loss: 0.287447
# Train epoch: 20 [110/625]	Accuracy: 89.38%	Loss: 0.273661
# Train epoch: 20 [120/625]	Accuracy: 86.88%	Loss: 0.303884
# Train epoch: 20 [130/625]	Accuracy: 88.44%	Loss: 0.288416
# Train epoch: 20 [140/625]	Accuracy: 85.94%	Loss: 0.301380
# Train epoch: 20 [150/625]	Accuracy: 84.69%	Loss: 0.321388
# Train epoch: 20 [160/625]	Accuracy: 85.62%	Loss: 0.293594
# Train epoch: 20 [170/625]	Accuracy: 90.62%	Loss: 0.264057
# Train epoch: 20 [180/625]	Accuracy: 87.50%	Loss: 0.289378
# Train epoch: 20 [190/625]	Accuracy: 87.81%	Loss: 0.277158
# Train epoch: 20 [200/625]	Accuracy: 86.88%	Loss: 0.297560
# Train epoch: 20 [210/625]	Accuracy: 89.06%	Loss: 0.271489
# Train epoch: 20 [220/625]	Accuracy: 87.19%	Loss: 0.294986
# Train epoch: 20 [230/625]	Accuracy: 86.25%	Loss: 0.297080
# Train epoch: 20 [240/625]	Accuracy: 85.31%	Loss: 0.317556
# Train epoch: 20 [250/625]	Accuracy: 88.75%	Loss: 0.261925
# Train epoch: 20 [260/625]	Accuracy: 85.00%	Loss: 0.311667
# Train epoch: 20 [270/625]	Accuracy: 84.38%	Loss: 0.325840
# Train epoch: 20 [280/625]	Accuracy: 86.25%	Loss: 0.308569
# Train epoch: 20 [290/625]	Accuracy: 85.31%	Loss: 0.314002
# Train epoch: 20 [300/625]	Accuracy: 86.25%	Loss: 0.291976
# Train epoch: 20 [310/625]	Accuracy: 86.25%	Loss: 0.293647
# Train epoch: 20 [320/625]	Accuracy: 83.44%	Loss: 0.354649
# Train epoch: 20 [330/625]	Accuracy: 86.25%	Loss: 0.301458
# Train epoch: 20 [340/625]	Accuracy: 86.56%	Loss: 0.284888
# Train epoch: 20 [350/625]	Accuracy: 84.69%	Loss: 0.347240
# Train epoch: 20 [360/625]	Accuracy: 88.44%	Loss: 0.291407
# Train epoch: 20 [370/625]	Accuracy: 87.50%	Loss: 0.283519
# Train epoch: 20 [380/625]	Accuracy: 88.75%	Loss: 0.270143
# Train epoch: 20 [390/625]	Accuracy: 87.19%	Loss: 0.319104
# Train epoch: 20 [400/625]	Accuracy: 84.38%	Loss: 0.341024
# Train epoch: 20 [410/625]	Accuracy: 85.00%	Loss: 0.301318
# Train epoch: 20 [420/625]	Accuracy: 84.69%	Loss: 0.342747
# Train epoch: 20 [430/625]	Accuracy: 88.44%	Loss: 0.289810
# Train epoch: 20 [440/625]	Accuracy: 87.19%	Loss: 0.294715
# Train epoch: 20 [450/625]	Accuracy: 86.88%	Loss: 0.293869
# Train epoch: 20 [460/625]	Accuracy: 83.12%	Loss: 0.315963
# Train epoch: 20 [470/625]	Accuracy: 82.81%	Loss: 0.346853
# Train epoch: 20 [480/625]	Accuracy: 88.44%	Loss: 0.270573
# Train epoch: 20 [490/625]	Accuracy: 85.00%	Loss: 0.304682
# Train epoch: 20 [500/625]	Accuracy: 85.62%	Loss: 0.328758
# Train epoch: 20 [510/625]	Accuracy: 86.56%	Loss: 0.310981
# Train epoch: 20 [520/625]	Accuracy: 87.19%	Loss: 0.303997
# Train epoch: 20 [530/625]	Accuracy: 88.44%	Loss: 0.283907
# Train epoch: 20 [540/625]	Accuracy: 85.94%	Loss: 0.291164
# Train epoch: 20 [550/625]	Accuracy: 85.94%	Loss: 0.332547
# Train epoch: 20 [560/625]	Accuracy: 87.81%	Loss: 0.299397
# Train epoch: 20 [570/625]	Accuracy: 90.62%	Loss: 0.237070
# Train epoch: 20 [580/625]	Accuracy: 86.88%	Loss: 0.284249
# Train epoch: 20 [590/625]	Accuracy: 86.56%	Loss: 0.261197
# Train epoch: 20 [600/625]	Accuracy: 86.25%	Loss: 0.283307
# Train epoch: 20 [610/625]	Accuracy: 85.31%	Loss: 0.316022
# Train epoch: 20 [620/625]	Accuracy: 88.12%	Loss: 0.275124
# Test set: Loss: 0.6706, Accuracy: 63.12%)
# Train epoch: 21 [10/625]	Accuracy: 89.06%	Loss: 0.279152
# Train epoch: 21 [20/625]	Accuracy: 84.69%	Loss: 0.306944
# Train epoch: 21 [30/625]	Accuracy: 88.12%	Loss: 0.279681
# Train epoch: 21 [40/625]	Accuracy: 87.81%	Loss: 0.280166
# Train epoch: 21 [50/625]	Accuracy: 87.50%	Loss: 0.284315
# Train epoch: 21 [60/625]	Accuracy: 84.06%	Loss: 0.324080
# Train epoch: 21 [70/625]	Accuracy: 85.94%	Loss: 0.301038
# Train epoch: 21 [80/625]	Accuracy: 84.06%	Loss: 0.316154
# Train epoch: 21 [90/625]	Accuracy: 83.75%	Loss: 0.321078
# Train epoch: 21 [100/625]	Accuracy: 86.25%	Loss: 0.310824
# Train epoch: 21 [110/625]	Accuracy: 86.88%	Loss: 0.300041
# Train epoch: 21 [120/625]	Accuracy: 89.69%	Loss: 0.263107
# Train epoch: 21 [130/625]	Accuracy: 86.88%	Loss: 0.293406
