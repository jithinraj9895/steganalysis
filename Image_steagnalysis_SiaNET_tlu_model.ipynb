# %% [markdown]
# <a href="https://colab.research.google.com/github/jithinraj9895/steganalysis/blob/main/Image_steagnalysis_SiaNET_tlu_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
import logging
import os
import random
from PIL import Image
import cv2
import numpy as np
import torch
import random
import os
import os.path as osp

def set_random_seed(seed=None):
    """Sets random seed for reproducibility.

    Args:
        seed (int, optional): Random seed.
    """
    if seed is None:
        seed = (
                os.getpid()
                + int(datetime.now().strftime("%S%f"))
                + int.from_bytes(os.urandom(2), "big")
        )
        logger = logging.getLogger(__name__)
        logger.info('Using a generated random seed {}'.format(seed))
    random.seed(seed)
    np.random.seed(seed)
    torch.set_rng_state(torch.manual_seed(seed).get_state())


def get_random_seed():
    return np.random.randint(2 ** 31)

# %%
class RandomRot(object):

    def __call__(self, sample):
        rot = random.randint(0, 3)
        return {
            'image': np.rot90(sample['image'], rot, axes=[-3, -2]).copy(),
            'label': sample['label'],
        }


class RandomFlip(object):

    def __init__(self, p=0.5):
        self._p = p

    def __call__(self, sample):
        if random.random() < self._p:
            return {
                'image': np.flip(sample['image'], axis=-2).copy(),
                'label': sample['label'],
            }
        else:
            return sample


class ToTensor(object):

    def __call__(self, sample):
        image, label = sample['image'], sample['label']
        if image.ndim == 3:  # HxWxC
            image = image.transpose(2, 0, 1)
        else:  # NxHxWxC
            image = image.transpose(0, 3, 1, 2)
        return {
            'image': torch.from_numpy(image).type(torch.FloatTensor),
            'label': torch.tensor(label).long()
        }

# %%
from torch.utils.data import Dataset


class CoverStegoDataset(Dataset):

    def __init__(self, cover_dir, stego_dir, transform=None):
        self._transform = transform

        self.images, self.labels = self.get_items(cover_dir, stego_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = np.array(Image.open(self.images[idx]))
        image = np.expand_dims(image, 2)  # (H, W, C)
        assert image.ndim == 3

        sample = {
            'image': image,
            'label': self.labels[idx]
        }

        if self._transform:
            sample = self._transform(sample)
        return sample

    @staticmethod
    def get_items(cover_dir, stego_dir):
        images, labels = [], []

        cover_names = sorted(os.listdir(cover_dir))
        if stego_dir is not None:
            stego_names = sorted(os.listdir(stego_dir))
            assert cover_names == stego_names

        file_names = cover_names
        if stego_dir is None:
            dir_to_label = [(cover_dir, 0), ]
        else:
            dir_to_label = [(cover_dir, 0), (stego_dir, 1)]
        for image_dir, label in dir_to_label:
            for file_name in file_names:
                image_path = osp.join(image_dir, file_name)
                if not osp.isfile(image_path):
                    raise FileNotFoundError('{} not exists'.format(image_path))
                images.append(image_path)
                labels.append(label)

        return images, labels

# %%
import torchvision
from torch.utils.data import BatchSampler
from torch.utils.data import DataLoader
from torch.utils.data import Sampler
from torch.utils.data import SequentialSampler
import itertools
import logging
import math

class TrainingSampler(Sampler):

    def __init__(self, size, seed=None, shuffle=True):
        self._size = size
        self._shuffle = shuffle

        if seed is None:
            seed = get_random_seed()
        self._seed = seed

    def __iter__(self):
        yield from itertools.islice(self._infinite_indices(), 0, None, 1)

    def _infinite_indices(self):
        g = torch.Generator()
        g.manual_seed(self._seed)
        while True:
            if self._shuffle:
                yield from torch.randperm(self._size, generator=g)
            else:
                yield from torch.arange(self._size)




class BalancedBatchSampler(BatchSampler):

    def __init__(self, sampler, group_ids, batch_size):
        """
        Args:
            sampler (Sampler): Base sampler.
            group_ids (list[int]): If the sampler produces indices in range [0, N),
                `group_ids` must be a list of `N` ints which contains the group id of each
                sample. The group ids must be a set of integers in [0, num_groups).
            batch_size (int): Size of mini-batch.
        """
        if not isinstance(sampler, Sampler):
            raise ValueError("sampler should be an instance of torch.utils.data.Sampler, "
                             "but got sampler={}".format(sampler))

        self._sampler = sampler
        self._group_ids = np.asarray(group_ids)
        assert self._group_ids.ndim == 1
        self._batch_size = batch_size
        groups = np.unique(self._group_ids).tolist()
        assert batch_size % len(groups) == 0

        # buffer the indices of each group until batch size is reached
        self._buffer_per_group = {k: [] for k in groups}
        self._group_size = batch_size // len(groups)

    def __iter__(self):
        for idx in self._sampler:
            group_id = self._group_ids[idx]
            self._buffer_per_group[group_id].append(idx)
            if all(len(v) >= self._group_size for k, v in self._buffer_per_group.items()):
                idxs = []
                # Collect across all groups
                for k, v in self._buffer_per_group.items():
                    idxs.extend(v[:self._group_size])
                    del v[:self._group_size]

                idxs = np.random.permutation(idxs)
                yield idxs

    def __len__(self):
        raise NotImplementedError("len() of GroupedBatchSampler is not well-defined.")


def build_train_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        RandomRot(),
        RandomFlip(),
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    size = len(dataset)
    sampler = TrainingSampler(size)
    if stego_dir is not None:
        batch_sampler = BalancedBatchSampler(sampler, dataset.labels, batch_size)
    else:
        batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)
    epoch_length = math.ceil(size / batch_size)


    train_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
        worker_init_fn=worker_init_reset_seed,
    )
    return train_loader, epoch_length




def build_val_loader(cover_dir, stego_dir, batch_size=32, num_workers=0):
    transform = torchvision.transforms.Compose([
        ToTensor(),
    ])
    dataset = CoverStegoDataset(cover_dir, stego_dir, transform)

    sampler = SequentialSampler(dataset)
    batch_sampler = BatchSampler(sampler, batch_size, drop_last=False)


    test_loader = DataLoader(
        dataset,
        batch_sampler=batch_sampler,
        num_workers=num_workers,
    )
    return test_loader

def worker_init_reset_seed(worker_id):
    set_random_seed(np.random.randint(2 ** 31) + worker_id)

# %%
set_random_seed()

# %%
 train_cover_dir = "/content/drive/MyDrive/boss_256/256_cropped_train/cover"
 train_stego_dir = "/content/drive/MyDrive/boss_256/256_cropped_train/stego"
 val_cover_dir = "/content/drive/MyDrive/boss_256/train/cover"
 val_stego_dir = "/content/drive/MyDrive/boss_256/train/stego"
 
 
 train_loader, epoch_length = build_train_loader(
        val_cover_dir, val_stego_dir, batch_size=32,
        num_workers=0)

# %%
val_loader = build_val_loader(
    train_cover_dir, train_stego_dir, batch_size=32,
    num_workers=0
)

# %%
train_loader_iter = iter(train_loader)

# %%
def activation(x):
    a = torch.ones(x.shape).cuda()
    a = torch.mul(a, -3).cuda()
    b = torch.ones(x.shape).cuda()
    b = torch.mul(b, 3).cuda()
    c = torch.where(x > -3,x,a).cuda()
    d = torch.where(c < 3,c,b).cuda()
    return d     


class the_tlu(nn.Module):
    def __init__(self):
        super(the_tlu, self).__init__()
    def forward(self, x):
        return activation(x)

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.nn import Parameter


srm_dir = "/content/drive/MyDrive"
SRM_npy = np.load(os.path.join(srm_dir,"SRM_Kernels.npy"))


def accuracy(outputs, labels):
    _, argmax = torch.max(outputs, 1)
    return (labels == argmax.squeeze()).float().mean()


def conv3x3(in_planes, out_planes, stride=1, groups=1, dilation=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                     padding=dilation, groups=groups, bias=False, dilation=dilation)


def conv1x1(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


class SRMConv2d(nn.Module):

    def __init__(self, stride=1, padding=0):
        super(SRMConv2d, self).__init__()
        self.in_channels = 1
        self.out_channels = 30
        self.kernel_size = (5, 5)
        if isinstance(stride, int):
            self.stride = (stride, stride)
        else:
            self.stride = stride
        if isinstance(padding, int):
            self.padding = (padding, padding)
        else:
            self.padding = padding
        self.dilation = (1, 1)
        self.transpose = False
        self.output_padding = (0,)
        self.groups = 1
        self.weight = Parameter(torch.Tensor(30, 1, 5, 5), requires_grad=True)
        self.bias = Parameter(torch.Tensor(30), requires_grad=True)
        self.reset_parameters()

    def reset_parameters(self):
        self.weight.data.numpy()[:] = SRM_npy
        self.bias.data.zero_()

    def forward(self, input):
        return F.conv2d(input, self.weight, self.bias, self.stride, self.padding,
                        self.dilation, self.groups)


class BlockA(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockA, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += identity
        out = self.relu(out)

        return out


class BlockB(nn.Module):

    def __init__(self, in_planes, out_planes, norm_layer=None):
        super(BlockB, self).__init__()

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.conv1 = conv3x3(in_planes, out_planes, stride=2)
        self.bn1 = norm_layer(out_planes)
        self.conv2 = conv3x3(out_planes, out_planes)
        self.bn2 = norm_layer(out_planes)
        # self.pool = nn.AvgPool2d(3, stride=2, padding=1)

        self.shortcut_conv = conv1x1(in_planes, out_planes, stride=2)
        self.shortcut_bn = norm_layer(out_planes)

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        # out = self.pool(out)

        identity = self.shortcut_conv(identity)
        identity = self.shortcut_bn(identity)

        out += identity
        out = self.relu(out)

        return out

# %%
class KeNet(nn.Module):

    def __init__(self, norm_layer=None, zero_init_residual=True, p=0.5):
        super(KeNet, self).__init__()

        self.zero_init_residual = zero_init_residual

        if norm_layer is None:
            norm_layer = nn.BatchNorm2d

        self.srm = SRMConv2d(1, 0)
        self.bn1 = norm_layer(30)
        self.tlu = the_tlu()

        self.A1 = BlockA(30, 30, norm_layer=norm_layer)
        self.A2 = BlockA(30, 30, norm_layer=norm_layer)
        self.AA = BlockA(30, 30, norm_layer=norm_layer)

        # self.B1 = BlockB(30, 30, norm_layer=norm_layer)
        # self.B2 = BlockB(30, 64, norm_layer=norm_layer)

        self.B3 = BlockB(30, 64, norm_layer=norm_layer)
        self.A3 = BlockA(64, 64, norm_layer=norm_layer)

        self.B4 = BlockB(64, 128, norm_layer=norm_layer)
        self.A4 = BlockA(128, 128, norm_layer=norm_layer)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # self.bnfc = nn.BatchNorm1d(128)
        self.relu = nn.ReLU(inplace=True)
        # self.fcfusion = nn.Linear(128, 128) #4
        self.fc = nn.Linear(128 * 4 + 1, 2)
        self.dropout = nn.Dropout(p=p)

        self.reset_parameters()

    def reset_parameters(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # nn.init.xavier_uniform_(m.weight)
                # nn.init.constant_(m.bias, 0.2)
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, std=0.01)

        if self.zero_init_residual:
            for m in self.modules():
                if isinstance(m, (BlockA, BlockB)):
                    nn.init.constant_(m.bn2.weight, 0)

    def extract_feat(self, x):
        x = x.float()
        out = self.srm(x)
        out = self.bn1(out)
        out = self.tlu(out)
    #    out = self.relu(out)

        out = self.A1(out)
        out = self.A2(out)
        out = self.AA(out)

        # out = self.B1(out)
        # out = self.B2(out)

        out = self.B3(out)
        out = self.A3(out)

        out = self.B4(out)
        out = self.A4(out)

        out = self.avgpool(out)
        out = out.view(out.size(0), out.size(1))

        # out = self.relu(out)
        # out = self.bnfc(out)

        return out

    def forward(self, *args):
        ############# statistics fusion start #############
        feats = torch.stack(
            [self.extract_feat(subarea) for subarea in args], dim=0
        )

        euclidean_distance = F.pairwise_distance(feats[0], feats[1], eps=1e-6,
                                                 keepdim=True)

        if feats.shape[0] == 1:
            final_feat = feats.squeeze(dim=0)
        else:
            # feats_sum = feats.sum(dim=0)
            # feats_sub = feats[0] - feats[1]
            feats_mean = feats.mean(dim=0)
            feats_var = feats.var(dim=0)
            feats_min, _ = feats.min(dim=0)
            feats_max, _ = feats.max(dim=0)

            '''feats_sum = feats.sum(dim=0)
            feats_sub = abs(feats[0] - feats[1])
            feats_prod = feats.prod(dim=0)
            feats_max, _ = feats.max(dim=0)'''
            
            #final_feat = torch.cat(
            #    [feats[0], feats[1], feats[0], feats[1]], dim=-1
            #    #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            #)

            final_feat = torch.cat(
                [euclidean_distance, feats_mean, feats_var, feats_min, feats_max], dim=-1
                #[euclidean_distance, feats_sum, feats_sub, feats_prod, feats_max], dim=-1
            )

        out = self.dropout(final_feat)
        # out = self.fcfusion(out)
        # out = self.relu(out)
        out = self.fc(out)

        return out, feats[0], feats[1]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ContrastiveLoss(nn.Module):

    def __init__(self, margin=1.25):  # margin=2
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        label = label.to(torch.float32)
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean(
            (1 - label) * torch.pow(euclidean_distance, 2) +
            label * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2)
        )

        return loss_contrastive

# %%
criterion_1 = nn.CrossEntropyLoss()
criterion_2 = ContrastiveLoss(margin=1)

# %%
net = KeNet();

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

device = get_default_device()


if device.type == "cuda":
    net.cuda()
    criterion_1.cuda()
    criterion_2.cuda()

# %%
from torch.optim.adamax import Adamax

optimizer = Adamax(net.parameters(), lr=0.001, eps=1e-08, weight_decay=0.0001)

# %%
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', factor=0.3,
                                                           patience=10, verbose=True, min_lr=0,
                                                           eps=1e-08)

# %%
import logging
import time
import shutil
logger = logging.getLogger(__name__)


def preprocess_data(images, labels, random_crop,gpu):
    # images of shape: NxCxHxW
    if images.ndim == 5:  # 1xNxCxHxW
        images = images.squeeze(0)
        labels = labels.squeeze(0)
    h, w = images.shape[-2:]

    if random_crop:
        ch = random.randint(h * 3 // 4, h)  # h // 2      #256
        cw = random.randint(w * 3 // 4, w)  # square ch   #256

        h0 = random.randint(0, h - ch)  # 128
        w0 = random.randint(0, w - cw)  # 128
    else:
        ch, cw, h0, w0 = h, w, 0, 0


    cw = cw & ~1
    inputs = [
            images[..., h0:h0 + ch, w0:w0 + cw // 2],
            images[..., h0:h0 + ch, w0 + cw // 2:w0 + cw]
        ]

    if gpu:
        inputs = [x.cuda() for x in inputs]
        labels = labels.cuda()
    return inputs, labels

# %%
def train(epoch):
    net.train()
    running_loss, running_accuracy = 0., 0.

    for batch_idx in range(epoch_length):
        data = next(train_loader_iter)
        inputs, labels = preprocess_data(data['image'], data['label'], False,gpu=True)

        optimizer.zero_grad()
   
        outputs, feats_0, feats_1 = net(*inputs)

            # count parameters start
            # print('parameters_count: {}'.format(sum(p.numel() for p in net.parameters() if p.requires_grad)))
            # count parameters end

        loss = criterion_1(outputs, labels) + \
                   0.1 * criterion_2(feats_0, feats_1, labels)

        accuracy1 = accuracy(outputs, labels).item()
        running_accuracy += accuracy1
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        if (batch_idx + 1) % 10 == 0:
            running_accuracy /= 10
            running_loss /= 10
            
            print(
                'Train epoch: {} [{}/{}]\tAccuracy: {:.2f}%\tLoss: {:.6f}'.format(
                    epoch, batch_idx + 1, epoch_length, 100 * running_accuracy,
                    running_loss))
                    
            ###############################log per log_interval start
            is_best=False
            save_checkpoint(
                {
                    'iteration': batch_idx + 1,
                    'state_dict': net.state_dict(),
                    'best_prec1': running_accuracy,
                    'optimizer': optimizer.state_dict(),
                },
                is_best,
                filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
                best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
            ###############################
            running_loss = 0.
            running_accuracy = 0.
            net.train()

# %%
def valid():
    net.eval()
    valid_loss = 0.
    valid_accuracy = 0.
    with torch.no_grad():
        for data in val_loader:
            inputs, labels = preprocess_data(data['image'], data['label'], False,gpu = True)

            outputs, feats_0, feats_1 = net(*inputs)
            valid_loss += criterion_1(outputs, labels).item() + \
                              0.01 * criterion_2(feats_0, feats_1, labels)
            valid_accuracy += accuracy(outputs, labels).item()
    valid_loss /= len(val_loader)
    valid_accuracy /= len(val_loader)
    print('Test set: Loss: {:.4f}, Accuracy: {:.2f}%)'.format(
        valid_loss, 100 * valid_accuracy))
    return valid_loss, valid_accuracy

# %%
fine_tune = "/content/drive/MyDrive/dataset/checkpoint.pth.tar"

if fine_tune is not None:
    net.load_state_dict(torch.load(fine_tune)['state_dict'], strict=False)
    e = torch.load(fine_tune)['iteration']

# %%
print(e)
# Out:
# 430

# %%
def save_checkpoint(state, is_best, filename, best_name):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, best_name)


_time = time.time()
best_accuracy = 0.
for e in range(1, 30 + 1):
    logger.info('Epoch: {}'.format(e))
    logger.info('Train')
    train(e)
    logger.info('Time: {}'.format(time.time() - _time))
    logger.info('Test')
    _, accuracy1 = valid()
    if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
        scheduler.step(accuracy1)
    else:
        scheduler.step()
    if accuracy1 > best_accuracy:
        best_accuracy = accuracy1
        is_best = True
    else:
        is_best = False
    logger.info('Best accuracy: {}'.format(best_accuracy))
    logger.info('Time: {}'.format(time.time() - _time))
    save_checkpoint(
        {
            'epoch': e,
            'state_dict': net.state_dict(),
            'best_prec1': accuracy1,
            'optimizer': optimizer.state_dict(),
        },
        is_best,
        filename=os.path.join("/content/drive/MyDrive/dataset", 'checkpoint.pth.tar'),
        best_name=os.path.join("/content/drive/MyDrive/dataset", 'model_best.pth.tar'))
# Out:
# Train epoch: 1 [10/625]	Accuracy: 49.06%	Loss: 0.793049
# Train epoch: 1 [20/625]	Accuracy: 48.44%	Loss: 0.780421
# Train epoch: 1 [30/625]	Accuracy: 52.81%	Loss: 0.776009
# Train epoch: 1 [40/625]	Accuracy: 51.88%	Loss: 0.757353
# Train epoch: 1 [50/625]	Accuracy: 52.81%	Loss: 0.750252
# Train epoch: 1 [60/625]	Accuracy: 54.06%	Loss: 0.728953
# Train epoch: 1 [70/625]	Accuracy: 52.50%	Loss: 0.734247
# Train epoch: 1 [80/625]	Accuracy: 51.25%	Loss: 0.728685
# Train epoch: 1 [90/625]	Accuracy: 50.31%	Loss: 0.725557
# Train epoch: 1 [100/625]	Accuracy: 47.19%	Loss: 0.724548
# Train epoch: 1 [110/625]	Accuracy: 51.25%	Loss: 0.720015
# Train epoch: 1 [120/625]	Accuracy: 53.75%	Loss: 0.722426
# Train epoch: 1 [130/625]	Accuracy: 45.94%	Loss: 0.728700
# Train epoch: 1 [140/625]	Accuracy: 45.00%	Loss: 0.729656
# Train epoch: 1 [150/625]	Accuracy: 49.06%	Loss: 0.726866
# Train epoch: 1 [160/625]	Accuracy: 53.75%	Loss: 0.720387
# Train epoch: 1 [170/625]	Accuracy: 49.69%	Loss: 0.721671
# Train epoch: 1 [180/625]	Accuracy: 48.75%	Loss: 0.723913
# Train epoch: 1 [190/625]	Accuracy: 53.75%	Loss: 0.723054
# Train epoch: 1 [200/625]	Accuracy: 53.12%	Loss: 0.721449
# Train epoch: 1 [210/625]	Accuracy: 54.06%	Loss: 0.724328
# Train epoch: 1 [220/625]	Accuracy: 49.38%	Loss: 0.726158
# Train epoch: 1 [230/625]	Accuracy: 50.62%	Loss: 0.725767
# Train epoch: 1 [240/625]	Accuracy: 53.12%	Loss: 0.717807
# Train epoch: 1 [250/625]	Accuracy: 52.81%	Loss: 0.722154
# Train epoch: 1 [260/625]	Accuracy: 56.88%	Loss: 0.719732
# Train epoch: 1 [270/625]	Accuracy: 54.06%	Loss: 0.714713
# Train epoch: 1 [280/625]	Accuracy: 51.25%	Loss: 0.721104
# Train epoch: 1 [290/625]	Accuracy: 57.19%	Loss: 0.711073
# Train epoch: 1 [300/625]	Accuracy: 56.25%	Loss: 0.715131
# Train epoch: 1 [310/625]	Accuracy: 54.69%	Loss: 0.715820
# Train epoch: 1 [320/625]	Accuracy: 56.25%	Loss: 0.726398
# Train epoch: 1 [330/625]	Accuracy: 54.06%	Loss: 0.716208
# Train epoch: 1 [340/625]	Accuracy: 58.44%	Loss: 0.710647
# Train epoch: 1 [350/625]	Accuracy: 57.19%	Loss: 0.710637
# Train epoch: 1 [360/625]	Accuracy: 54.69%	Loss: 0.715398
# Train epoch: 1 [370/625]	Accuracy: 59.38%	Loss: 0.708748
# Train epoch: 1 [380/625]	Accuracy: 56.56%	Loss: 0.712661
# Train epoch: 1 [390/625]	Accuracy: 61.88%	Loss: 0.706394
# Train epoch: 1 [400/625]	Accuracy: 52.19%	Loss: 0.724564
# Train epoch: 1 [410/625]	Accuracy: 52.81%	Loss: 0.723023
# Train epoch: 1 [420/625]	Accuracy: 55.31%	Loss: 0.705759
# Train epoch: 1 [430/625]	Accuracy: 55.31%	Loss: 0.707101
# Train epoch: 1 [440/625]	Accuracy: 54.37%	Loss: 0.722683
# Train epoch: 1 [450/625]	Accuracy: 55.00%	Loss: 0.715715
# Train epoch: 1 [460/625]	Accuracy: 56.56%	Loss: 0.709154
# Train epoch: 1 [470/625]	Accuracy: 53.44%	Loss: 0.714638
# Train epoch: 1 [480/625]	Accuracy: 61.56%	Loss: 0.696401
# Train epoch: 1 [490/625]	Accuracy: 53.75%	Loss: 0.704407
# Train epoch: 1 [500/625]	Accuracy: 64.38%	Loss: 0.691054
# Train epoch: 1 [510/625]	Accuracy: 61.56%	Loss: 0.681157
# Train epoch: 1 [520/625]	Accuracy: 60.62%	Loss: 0.684652
# Train epoch: 1 [530/625]	Accuracy: 58.13%	Loss: 0.693842
# Train epoch: 1 [540/625]	Accuracy: 57.19%	Loss: 0.690408
# Train epoch: 1 [550/625]	Accuracy: 58.75%	Loss: 0.697084
# Train epoch: 1 [560/625]	Accuracy: 65.00%	Loss: 0.683809
# Train epoch: 1 [570/625]	Accuracy: 60.31%	Loss: 0.686383
# Train epoch: 1 [580/625]	Accuracy: 56.88%	Loss: 0.682587
# Train epoch: 1 [590/625]	Accuracy: 61.56%	Loss: 0.683237
# Train epoch: 1 [600/625]	Accuracy: 63.44%	Loss: 0.661716
# Train epoch: 1 [610/625]	Accuracy: 59.06%	Loss: 0.675309
# Train epoch: 1 [620/625]	Accuracy: 56.56%	Loss: 0.692805
# Test set: Loss: 0.8173, Accuracy: 51.79%)
# Train epoch: 2 [10/625]	Accuracy: 63.12%	Loss: 0.662991
# Train epoch: 2 [20/625]	Accuracy: 60.62%	Loss: 0.668016
# Train epoch: 2 [30/625]	Accuracy: 59.69%	Loss: 0.684794
# Train epoch: 2 [40/625]	Accuracy: 62.19%	Loss: 0.671760
# Train epoch: 2 [50/625]	Accuracy: 60.31%	Loss: 0.681461
# Train epoch: 2 [60/625]	Accuracy: 65.94%	Loss: 0.660824
# Train epoch: 2 [70/625]	Accuracy: 62.50%	Loss: 0.677530
# Train epoch: 2 [80/625]	Accuracy: 60.00%	Loss: 0.682589
# Train epoch: 2 [90/625]	Accuracy: 57.81%	Loss: 0.687748
# Train epoch: 2 [100/625]	Accuracy: 64.38%	Loss: 0.663246
# Train epoch: 2 [110/625]	Accuracy: 61.88%	Loss: 0.659692
# Train epoch: 2 [120/625]	Accuracy: 62.19%	Loss: 0.658410
# Train epoch: 2 [130/625]	Accuracy: 60.94%	Loss: 0.664568
# Train epoch: 2 [140/625]	Accuracy: 66.25%	Loss: 0.638048
# Train epoch: 2 [150/625]	Accuracy: 64.38%	Loss: 0.636658
# Train epoch: 2 [160/625]	Accuracy: 61.25%	Loss: 0.654104
# Train epoch: 2 [170/625]	Accuracy: 65.94%	Loss: 0.648000
# Train epoch: 2 [180/625]	Accuracy: 65.31%	Loss: 0.643986
# Train epoch: 2 [190/625]	Accuracy: 56.88%	Loss: 0.689530
# Train epoch: 2 [200/625]	Accuracy: 65.62%	Loss: 0.656700
# Train epoch: 2 [210/625]	Accuracy: 65.31%	Loss: 0.632781
# Train epoch: 2 [220/625]	Accuracy: 68.12%	Loss: 0.619336
# Train epoch: 2 [230/625]	Accuracy: 65.00%	Loss: 0.636421
# Train epoch: 2 [240/625]	Accuracy: 64.38%	Loss: 0.652389
# Train epoch: 2 [250/625]	Accuracy: 69.38%	Loss: 0.595926
# Train epoch: 2 [260/625]	Accuracy: 71.88%	Loss: 0.587210
# Train epoch: 2 [270/625]	Accuracy: 68.44%	Loss: 0.635251
# Train epoch: 2 [280/625]	Accuracy: 67.19%	Loss: 0.644491
# Train epoch: 2 [290/625]	Accuracy: 65.31%	Loss: 0.656433
# Train epoch: 2 [300/625]	Accuracy: 71.25%	Loss: 0.587442
# Train epoch: 2 [310/625]	Accuracy: 72.19%	Loss: 0.625197
# Train epoch: 2 [320/625]	Accuracy: 65.62%	Loss: 0.646185
# Train epoch: 2 [330/625]	Accuracy: 66.25%	Loss: 0.641272
# Train epoch: 2 [340/625]	Accuracy: 65.62%	Loss: 0.630998
# Train epoch: 2 [350/625]	Accuracy: 68.12%	Loss: 0.613120
# Train epoch: 2 [360/625]	Accuracy: 62.50%	Loss: 0.637501
# Train epoch: 2 [370/625]	Accuracy: 69.38%	Loss: 0.613101
# Train epoch: 2 [380/625]	Accuracy: 67.19%	Loss: 0.603354
# Train epoch: 2 [390/625]	Accuracy: 73.12%	Loss: 0.565689
# Train epoch: 2 [400/625]	Accuracy: 64.69%	Loss: 0.629135
# Train epoch: 2 [410/625]	Accuracy: 67.19%	Loss: 0.619401
# Train epoch: 2 [420/625]	Accuracy: 68.12%	Loss: 0.611746
# Train epoch: 2 [430/625]	Accuracy: 71.56%	Loss: 0.588253
# Train epoch: 2 [440/625]	Accuracy: 67.50%	Loss: 0.590494
# Train epoch: 2 [450/625]	Accuracy: 69.69%	Loss: 0.602487
# Train epoch: 2 [460/625]	Accuracy: 66.25%	Loss: 0.596155
# Train epoch: 2 [470/625]	Accuracy: 69.06%	Loss: 0.609911
# Train epoch: 2 [480/625]	Accuracy: 64.06%	Loss: 0.671330
# Train epoch: 2 [490/625]	Accuracy: 64.06%	Loss: 0.638503
# Train epoch: 2 [500/625]	Accuracy: 72.50%	Loss: 0.583199
# Train epoch: 2 [510/625]	Accuracy: 72.19%	Loss: 0.566128
# Train epoch: 2 [520/625]	Accuracy: 71.56%	Loss: 0.604277
# Train epoch: 2 [530/625]	Accuracy: 67.81%	Loss: 0.574432
# Train epoch: 2 [540/625]	Accuracy: 69.38%	Loss: 0.609732
# Train epoch: 2 [550/625]	Accuracy: 68.75%	Loss: 0.597335
# Train epoch: 2 [560/625]	Accuracy: 70.31%	Loss: 0.592800
# Train epoch: 2 [570/625]	Accuracy: 71.25%	Loss: 0.572132
# Train epoch: 2 [580/625]	Accuracy: 69.38%	Loss: 0.598452
# Train epoch: 2 [590/625]	Accuracy: 63.75%	Loss: 0.636672
# Train epoch: 2 [600/625]	Accuracy: 64.38%	Loss: 0.621151
# Train epoch: 2 [610/625]	Accuracy: 69.06%	Loss: 0.569519
# Train epoch: 2 [620/625]	Accuracy: 71.88%	Loss: 0.561362
# Test set: Loss: 0.8544, Accuracy: 59.43%)
# Train epoch: 3 [10/625]	Accuracy: 69.06%	Loss: 0.595166
# Train epoch: 3 [20/625]	Accuracy: 68.75%	Loss: 0.590246
# Train epoch: 3 [30/625]	Accuracy: 72.50%	Loss: 0.553859
# Train epoch: 3 [40/625]	Accuracy: 73.12%	Loss: 0.587188
# Train epoch: 3 [50/625]	Accuracy: 72.81%	Loss: 0.551372
# Train epoch: 3 [60/625]	Accuracy: 70.31%	Loss: 0.593822
# Train epoch: 3 [70/625]	Accuracy: 71.88%	Loss: 0.561843
# Train epoch: 3 [80/625]	Accuracy: 73.75%	Loss: 0.561658
# Train epoch: 3 [90/625]	Accuracy: 70.94%	Loss: 0.549365
# Train epoch: 3 [100/625]	Accuracy: 66.88%	Loss: 0.616225
# Train epoch: 3 [110/625]	Accuracy: 71.25%	Loss: 0.543501
# Train epoch: 3 [120/625]	Accuracy: 72.19%	Loss: 0.539491
# Train epoch: 3 [130/625]	Accuracy: 69.69%	Loss: 0.551646
# Train epoch: 3 [140/625]	Accuracy: 69.69%	Loss: 0.582365
# Train epoch: 3 [150/625]	Accuracy: 73.75%	Loss: 0.548035
# Train epoch: 3 [160/625]	Accuracy: 69.06%	Loss: 0.592378
# Train epoch: 3 [170/625]	Accuracy: 67.50%	Loss: 0.602896
# Train epoch: 3 [180/625]	Accuracy: 74.38%	Loss: 0.559577
# Train epoch: 3 [190/625]	Accuracy: 70.00%	Loss: 0.578979
# Train epoch: 3 [200/625]	Accuracy: 68.12%	Loss: 0.585608
# Train epoch: 3 [210/625]	Accuracy: 70.31%	Loss: 0.557529
# Train epoch: 3 [220/625]	Accuracy: 72.50%	Loss: 0.577068
# Train epoch: 3 [230/625]	Accuracy: 70.31%	Loss: 0.569660
# Train epoch: 3 [240/625]	Accuracy: 64.69%	Loss: 0.591647
# Train epoch: 3 [250/625]	Accuracy: 70.62%	Loss: 0.575162
# Train epoch: 3 [260/625]	Accuracy: 73.44%	Loss: 0.550474
# Train epoch: 3 [270/625]	Accuracy: 71.88%	Loss: 0.580562
# Train epoch: 3 [280/625]	Accuracy: 65.94%	Loss: 0.604744
# Train epoch: 3 [290/625]	Accuracy: 72.50%	Loss: 0.545869
# Train epoch: 3 [300/625]	Accuracy: 67.19%	Loss: 0.581014
# Train epoch: 3 [310/625]	Accuracy: 71.25%	Loss: 0.548567
# Train epoch: 3 [320/625]	Accuracy: 73.44%	Loss: 0.553046
# Train epoch: 3 [330/625]	Accuracy: 73.75%	Loss: 0.520339
# Train epoch: 3 [340/625]	Accuracy: 74.69%	Loss: 0.510747
# Train epoch: 3 [350/625]	Accuracy: 70.00%	Loss: 0.544877
# Train epoch: 3 [360/625]	Accuracy: 74.38%	Loss: 0.546211
# Train epoch: 3 [370/625]	Accuracy: 73.44%	Loss: 0.540640
# Train epoch: 3 [380/625]	Accuracy: 69.38%	Loss: 0.603098
# Train epoch: 3 [390/625]	Accuracy: 72.19%	Loss: 0.542129
# Train epoch: 3 [400/625]	Accuracy: 71.88%	Loss: 0.554598
# Train epoch: 3 [410/625]	Accuracy: 70.00%	Loss: 0.573969
# Train epoch: 3 [420/625]	Accuracy: 75.94%	Loss: 0.506149
# Train epoch: 3 [430/625]	Accuracy: 72.50%	Loss: 0.540267
# Train epoch: 3 [440/625]	Accuracy: 70.94%	Loss: 0.554943
# Train epoch: 3 [450/625]	Accuracy: 74.69%	Loss: 0.530840
# Train epoch: 3 [460/625]	Accuracy: 70.62%	Loss: 0.575979
# Train epoch: 3 [470/625]	Accuracy: 74.69%	Loss: 0.516655
# Train epoch: 3 [480/625]	Accuracy: 75.94%	Loss: 0.511777
# Train epoch: 3 [490/625]	Accuracy: 71.25%	Loss: 0.578705
# Train epoch: 3 [500/625]	Accuracy: 72.19%	Loss: 0.524178
# Train epoch: 3 [510/625]	Accuracy: 74.38%	Loss: 0.521219
# Train epoch: 3 [520/625]	Accuracy: 71.56%	Loss: 0.526136
# Train epoch: 3 [530/625]	Accuracy: 73.12%	Loss: 0.514785
# Train epoch: 3 [540/625]	Accuracy: 74.69%	Loss: 0.555815
# Train epoch: 3 [550/625]	Accuracy: 70.94%	Loss: 0.565499
# Train epoch: 3 [560/625]	Accuracy: 76.25%	Loss: 0.508700
# Train epoch: 3 [570/625]	Accuracy: 77.19%	Loss: 0.504722
# Train epoch: 3 [580/625]	Accuracy: 74.69%	Loss: 0.517081
# Train epoch: 3 [590/625]	Accuracy: 69.06%	Loss: 0.544403
# Train epoch: 3 [600/625]	Accuracy: 72.19%	Loss: 0.539423
# Train epoch: 3 [610/625]	Accuracy: 74.38%	Loss: 0.529976
# Train epoch: 3 [620/625]	Accuracy: 68.75%	Loss: 0.566583
# Test set: Loss: 0.8676, Accuracy: 58.10%)
# Train epoch: 4 [10/625]	Accuracy: 72.19%	Loss: 0.542873
# Train epoch: 4 [20/625]	Accuracy: 77.19%	Loss: 0.506857
# Train epoch: 4 [30/625]	Accuracy: 76.56%	Loss: 0.520267
# Train epoch: 4 [40/625]	Accuracy: 75.62%	Loss: 0.523545
# Train epoch: 4 [50/625]	Accuracy: 70.31%	Loss: 0.566215
# Train epoch: 4 [60/625]	Accuracy: 74.06%	Loss: 0.522814
# Train epoch: 4 [70/625]	Accuracy: 69.69%	Loss: 0.543216
# Train epoch: 4 [80/625]	Accuracy: 75.62%	Loss: 0.525692
# Train epoch: 4 [90/625]	Accuracy: 76.25%	Loss: 0.508963
# Train epoch: 4 [100/625]	Accuracy: 73.75%	Loss: 0.545921
# Train epoch: 4 [110/625]	Accuracy: 72.19%	Loss: 0.548127
# Train epoch: 4 [120/625]	Accuracy: 74.69%	Loss: 0.500002
# Train epoch: 4 [130/625]	Accuracy: 70.62%	Loss: 0.571146
# Train epoch: 4 [140/625]	Accuracy: 75.94%	Loss: 0.510780
# Train epoch: 4 [150/625]	Accuracy: 76.25%	Loss: 0.513597
# Train epoch: 4 [160/625]	Accuracy: 72.81%	Loss: 0.540131
# Train epoch: 4 [170/625]	Accuracy: 75.31%	Loss: 0.507239
# Train epoch: 4 [180/625]	Accuracy: 72.81%	Loss: 0.519034
# Train epoch: 4 [190/625]	Accuracy: 69.38%	Loss: 0.526491
# Train epoch: 4 [200/625]	Accuracy: 75.62%	Loss: 0.510704
# Train epoch: 4 [210/625]	Accuracy: 75.31%	Loss: 0.521104
# Train epoch: 4 [220/625]	Accuracy: 74.69%	Loss: 0.539990
# Train epoch: 4 [230/625]	Accuracy: 76.56%	Loss: 0.535717
# Train epoch: 4 [240/625]	Accuracy: 71.56%	Loss: 0.553015
# Train epoch: 4 [250/625]	Accuracy: 73.12%	Loss: 0.524845
# Train epoch: 4 [260/625]	Accuracy: 76.25%	Loss: 0.475369
# Train epoch: 4 [270/625]	Accuracy: 78.44%	Loss: 0.504554
# Train epoch: 4 [280/625]	Accuracy: 73.12%	Loss: 0.503244
# Train epoch: 4 [290/625]	Accuracy: 73.75%	Loss: 0.485631
# Train epoch: 4 [300/625]	Accuracy: 76.56%	Loss: 0.498446
# Train epoch: 4 [310/625]	Accuracy: 76.88%	Loss: 0.461091
# Train epoch: 4 [320/625]	Accuracy: 73.12%	Loss: 0.537197
# Train epoch: 4 [330/625]	Accuracy: 76.25%	Loss: 0.504849
# Train epoch: 4 [340/625]	Accuracy: 68.12%	Loss: 0.564300
# Train epoch: 4 [350/625]	Accuracy: 74.38%	Loss: 0.521922
# Train epoch: 4 [360/625]	Accuracy: 70.31%	Loss: 0.542754
# Train epoch: 4 [370/625]	Accuracy: 76.25%	Loss: 0.495166
# Train epoch: 4 [380/625]	Accuracy: 74.38%	Loss: 0.485690
# Train epoch: 4 [390/625]	Accuracy: 76.25%	Loss: 0.493935
# Train epoch: 4 [400/625]	Accuracy: 75.94%	Loss: 0.503766
# Train epoch: 4 [410/625]	Accuracy: 78.44%	Loss: 0.478139
# Train epoch: 4 [420/625]	Accuracy: 71.25%	Loss: 0.525163
# Train epoch: 4 [430/625]	Accuracy: 73.44%	Loss: 0.556466
# Train epoch: 4 [440/625]	Accuracy: 72.81%	Loss: 0.515468
# Train epoch: 4 [450/625]	Accuracy: 76.56%	Loss: 0.505066
# Train epoch: 4 [460/625]	Accuracy: 75.62%	Loss: 0.483517
# Train epoch: 4 [470/625]	Accuracy: 75.31%	Loss: 0.513315
# Train epoch: 4 [480/625]	Accuracy: 80.31%	Loss: 0.480703
# Train epoch: 4 [490/625]	Accuracy: 78.44%	Loss: 0.485325
# Train epoch: 4 [500/625]	Accuracy: 77.19%	Loss: 0.498626
# Train epoch: 4 [510/625]	Accuracy: 71.88%	Loss: 0.517821
# Train epoch: 4 [520/625]	Accuracy: 75.31%	Loss: 0.494406
# Train epoch: 4 [530/625]	Accuracy: 72.81%	Loss: 0.509793
# Train epoch: 4 [540/625]	Accuracy: 76.88%	Loss: 0.509736
# Train epoch: 4 [550/625]	Accuracy: 81.56%	Loss: 0.431969
# Train epoch: 4 [560/625]	Accuracy: 74.38%	Loss: 0.515610
# Train epoch: 4 [570/625]	Accuracy: 80.62%	Loss: 0.445803
# Train epoch: 4 [580/625]	Accuracy: 78.12%	Loss: 0.454779
# Train epoch: 4 [590/625]	Accuracy: 77.81%	Loss: 0.488395
# Train epoch: 4 [600/625]	Accuracy: 71.56%	Loss: 0.523126
# Train epoch: 4 [610/625]	Accuracy: 78.12%	Loss: 0.461973
# Train epoch: 4 [620/625]	Accuracy: 77.81%	Loss: 0.469766
# Test set: Loss: 1.1035, Accuracy: 61.76%)
# Train epoch: 5 [10/625]	Accuracy: 78.44%	Loss: 0.496820
# Train epoch: 5 [20/625]	Accuracy: 76.25%	Loss: 0.478158
# Train epoch: 5 [30/625]	Accuracy: 75.00%	Loss: 0.482815
# Train epoch: 5 [40/625]	Accuracy: 75.94%	Loss: 0.470521
# Train epoch: 5 [50/625]	Accuracy: 74.69%	Loss: 0.491393
# Train epoch: 5 [60/625]	Accuracy: 75.31%	Loss: 0.524486
# Train epoch: 5 [70/625]	Accuracy: 76.25%	Loss: 0.475470
# Train epoch: 5 [80/625]	Accuracy: 75.62%	Loss: 0.506698
# Train epoch: 5 [90/625]	Accuracy: 74.38%	Loss: 0.520609
# Train epoch: 5 [100/625]	Accuracy: 74.38%	Loss: 0.496759
# Train epoch: 5 [110/625]	Accuracy: 75.31%	Loss: 0.545730
# Train epoch: 5 [120/625]	Accuracy: 71.88%	Loss: 0.570303
# Train epoch: 5 [130/625]	Accuracy: 75.00%	Loss: 0.490831
# Train epoch: 5 [140/625]	Accuracy: 72.50%	Loss: 0.508108
# Train epoch: 5 [150/625]	Accuracy: 75.00%	Loss: 0.482724
# Train epoch: 5 [160/625]	Accuracy: 76.88%	Loss: 0.499206
# Train epoch: 5 [170/625]	Accuracy: 76.56%	Loss: 0.470835
# Train epoch: 5 [180/625]	Accuracy: 74.38%	Loss: 0.502678
# Train epoch: 5 [190/625]	Accuracy: 78.44%	Loss: 0.469336
# Train epoch: 5 [200/625]	Accuracy: 73.12%	Loss: 0.507235
# Train epoch: 5 [210/625]	Accuracy: 75.62%	Loss: 0.492345
# Train epoch: 5 [220/625]	Accuracy: 73.12%	Loss: 0.522491
# Train epoch: 5 [230/625]	Accuracy: 78.12%	Loss: 0.461796
# Train epoch: 5 [240/625]	Accuracy: 75.62%	Loss: 0.489798
# Train epoch: 5 [250/625]	Accuracy: 72.81%	Loss: 0.500325
# Train epoch: 5 [260/625]	Accuracy: 73.12%	Loss: 0.497313
# Train epoch: 5 [270/625]	Accuracy: 78.75%	Loss: 0.449561
# Train epoch: 5 [280/625]	Accuracy: 73.75%	Loss: 0.510281
# Train epoch: 5 [290/625]	Accuracy: 75.62%	Loss: 0.489713
# Train epoch: 5 [300/625]	Accuracy: 78.44%	Loss: 0.446999
# Train epoch: 5 [310/625]	Accuracy: 76.25%	Loss: 0.495356
# Train epoch: 5 [320/625]	Accuracy: 77.50%	Loss: 0.474107
# Train epoch: 5 [330/625]	Accuracy: 75.00%	Loss: 0.510754
# Train epoch: 5 [340/625]	Accuracy: 74.38%	Loss: 0.591004
# Train epoch: 5 [350/625]	Accuracy: 73.75%	Loss: 0.494757
# Train epoch: 5 [360/625]	Accuracy: 74.06%	Loss: 0.481335
# Train epoch: 5 [370/625]	Accuracy: 76.25%	Loss: 0.481710
# Train epoch: 5 [380/625]	Accuracy: 74.06%	Loss: 0.533607
# Train epoch: 5 [390/625]	Accuracy: 75.94%	Loss: 0.483878
# Train epoch: 5 [400/625]	Accuracy: 78.75%	Loss: 0.468201
# Train epoch: 5 [410/625]	Accuracy: 72.19%	Loss: 0.543645
# Train epoch: 5 [420/625]	Accuracy: 76.25%	Loss: 0.469766
# Train epoch: 5 [430/625]	Accuracy: 76.25%	Loss: 0.460811
# Train epoch: 5 [440/625]	Accuracy: 76.25%	Loss: 0.481443
# Train epoch: 5 [450/625]	Accuracy: 76.56%	Loss: 0.490006
# Train epoch: 5 [460/625]	Accuracy: 79.38%	Loss: 0.450718
# Train epoch: 5 [470/625]	Accuracy: 76.25%	Loss: 0.486186
# Train epoch: 5 [480/625]	Accuracy: 77.50%	Loss: 0.467853
# Train epoch: 5 [490/625]	Accuracy: 73.44%	Loss: 0.529663
# Train epoch: 5 [500/625]	Accuracy: 78.44%	Loss: 0.416888
# Train epoch: 5 [510/625]	Accuracy: 79.06%	Loss: 0.460169
# Train epoch: 5 [520/625]	Accuracy: 76.25%	Loss: 0.467804
# Train epoch: 5 [530/625]	Accuracy: 76.88%	Loss: 0.484612
# Train epoch: 5 [540/625]	Accuracy: 78.44%	Loss: 0.499970
# Train epoch: 5 [550/625]	Accuracy: 79.06%	Loss: 0.489351
# Train epoch: 5 [560/625]	Accuracy: 78.12%	Loss: 0.463168
# Train epoch: 5 [570/625]	Accuracy: 78.12%	Loss: 0.500149
# Train epoch: 5 [580/625]	Accuracy: 78.44%	Loss: 0.461738
# Train epoch: 5 [590/625]	Accuracy: 75.62%	Loss: 0.500661
# Train epoch: 5 [600/625]	Accuracy: 74.06%	Loss: 0.503292
# Train epoch: 5 [610/625]	Accuracy: 73.75%	Loss: 0.481309
# Train epoch: 5 [620/625]	Accuracy: 78.44%	Loss: 0.440002
# Test set: Loss: 0.8528, Accuracy: 62.64%)
# Train epoch: 6 [10/625]	Accuracy: 79.69%	Loss: 0.442788
# Train epoch: 6 [20/625]	Accuracy: 71.88%	Loss: 0.528929
# Train epoch: 6 [30/625]	Accuracy: 77.50%	Loss: 0.472109
# Train epoch: 6 [40/625]	Accuracy: 77.50%	Loss: 0.439071
# Train epoch: 6 [50/625]	Accuracy: 74.06%	Loss: 0.472576
# Train epoch: 6 [60/625]	Accuracy: 74.38%	Loss: 0.500881
# Train epoch: 6 [70/625]	Accuracy: 75.94%	Loss: 0.497556
# Train epoch: 6 [80/625]	Accuracy: 74.69%	Loss: 0.489878
# Train epoch: 6 [90/625]	Accuracy: 72.50%	Loss: 0.538588
# Train epoch: 6 [100/625]	Accuracy: 77.19%	Loss: 0.471554
# Train epoch: 6 [110/625]	Accuracy: 74.69%	Loss: 0.508310
# Train epoch: 6 [120/625]	Accuracy: 79.06%	Loss: 0.447894
# Train epoch: 6 [130/625]	Accuracy: 76.88%	Loss: 0.504862
# Train epoch: 6 [140/625]	Accuracy: 76.88%	Loss: 0.497669
# Train epoch: 6 [150/625]	Accuracy: 77.19%	Loss: 0.487596
# Train epoch: 6 [160/625]	Accuracy: 73.44%	Loss: 0.511524
# Train epoch: 6 [170/625]	Accuracy: 78.44%	Loss: 0.434352
# Train epoch: 6 [180/625]	Accuracy: 81.88%	Loss: 0.415373
# Train epoch: 6 [190/625]	Accuracy: 75.00%	Loss: 0.528011
# Train epoch: 6 [200/625]	Accuracy: 78.12%	Loss: 0.478045
# Train epoch: 6 [210/625]	Accuracy: 78.44%	Loss: 0.499214
# Train epoch: 6 [220/625]	Accuracy: 75.31%	Loss: 0.505438
# Train epoch: 6 [230/625]	Accuracy: 77.50%	Loss: 0.497990
# Train epoch: 6 [240/625]	Accuracy: 76.56%	Loss: 0.490543
# Train epoch: 6 [250/625]	Accuracy: 76.25%	Loss: 0.462447
# Train epoch: 6 [260/625]	Accuracy: 72.19%	Loss: 0.522348
# Train epoch: 6 [270/625]	Accuracy: 82.50%	Loss: 0.420716
# Train epoch: 6 [280/625]	Accuracy: 79.38%	Loss: 0.466306
# Train epoch: 6 [290/625]	Accuracy: 77.19%	Loss: 0.491803
# Train epoch: 6 [300/625]	Accuracy: 75.31%	Loss: 0.486808
# Train epoch: 6 [310/625]	Accuracy: 81.25%	Loss: 0.458714
# Train epoch: 6 [320/625]	Accuracy: 74.06%	Loss: 0.475045
# Train epoch: 6 [330/625]	Accuracy: 74.69%	Loss: 0.498259
# Train epoch: 6 [340/625]	Accuracy: 74.06%	Loss: 0.523788
# Train epoch: 6 [350/625]	Accuracy: 79.69%	Loss: 0.445816
# Train epoch: 6 [360/625]	Accuracy: 76.88%	Loss: 0.462696
# Train epoch: 6 [370/625]	Accuracy: 76.25%	Loss: 0.497326
# Train epoch: 6 [380/625]	Accuracy: 77.81%	Loss: 0.467735
# Train epoch: 6 [390/625]	Accuracy: 78.44%	Loss: 0.480836
# Train epoch: 6 [400/625]	Accuracy: 80.00%	Loss: 0.422598
# Train epoch: 6 [410/625]	Accuracy: 80.31%	Loss: 0.458891
# Train epoch: 6 [420/625]	Accuracy: 79.69%	Loss: 0.463432
# Train epoch: 6 [430/625]	Accuracy: 79.06%	Loss: 0.464990
# Train epoch: 6 [440/625]	Accuracy: 75.00%	Loss: 0.494651
# Train epoch: 6 [450/625]	Accuracy: 77.19%	Loss: 0.463530
# Train epoch: 6 [460/625]	Accuracy: 76.88%	Loss: 0.484708
# Train epoch: 6 [470/625]	Accuracy: 76.25%	Loss: 0.470061
# Train epoch: 6 [480/625]	Accuracy: 78.12%	Loss: 0.458053
# Train epoch: 6 [490/625]	Accuracy: 79.69%	Loss: 0.476789
# Train epoch: 6 [500/625]	Accuracy: 78.44%	Loss: 0.455102
# Train epoch: 6 [510/625]	Accuracy: 74.69%	Loss: 0.488653
# Train epoch: 6 [520/625]	Accuracy: 78.44%	Loss: 0.462061
# Train epoch: 6 [530/625]	Accuracy: 79.06%	Loss: 0.445620
# Train epoch: 6 [540/625]	Accuracy: 76.25%	Loss: 0.486648
# Train epoch: 6 [550/625]	Accuracy: 79.06%	Loss: 0.493522
# Train epoch: 6 [560/625]	Accuracy: 79.38%	Loss: 0.463181
# Train epoch: 6 [570/625]	Accuracy: 75.31%	Loss: 0.511491
# Train epoch: 6 [580/625]	Accuracy: 76.56%	Loss: 0.506394
# Train epoch: 6 [590/625]	Accuracy: 77.50%	Loss: 0.459163
# Train epoch: 6 [600/625]	Accuracy: 77.81%	Loss: 0.451592
# Train epoch: 6 [610/625]	Accuracy: 76.88%	Loss: 0.480175
# Train epoch: 6 [620/625]	Accuracy: 80.62%	Loss: 0.440324
# Test set: Loss: 0.7245, Accuracy: 60.69%)
# Train epoch: 7 [10/625]	Accuracy: 76.56%	Loss: 0.453790
# Train epoch: 7 [20/625]	Accuracy: 79.69%	Loss: 0.463244
# Train epoch: 7 [30/625]	Accuracy: 75.00%	Loss: 0.485765
# Train epoch: 7 [40/625]	Accuracy: 78.75%	Loss: 0.441310
# Train epoch: 7 [50/625]	Accuracy: 79.69%	Loss: 0.453916
# Train epoch: 7 [60/625]	Accuracy: 76.56%	Loss: 0.462288
# Train epoch: 7 [70/625]	Accuracy: 78.12%	Loss: 0.438048
# Train epoch: 7 [80/625]	Accuracy: 82.50%	Loss: 0.394166
# Train epoch: 7 [90/625]	Accuracy: 79.06%	Loss: 0.432588
# Train epoch: 7 [100/625]	Accuracy: 78.75%	Loss: 0.459626
# Train epoch: 7 [110/625]	Accuracy: 75.94%	Loss: 0.490012
# Train epoch: 7 [120/625]	Accuracy: 80.31%	Loss: 0.467268
# Train epoch: 7 [130/625]	Accuracy: 80.94%	Loss: 0.469118
# Train epoch: 7 [140/625]	Accuracy: 76.88%	Loss: 0.475932
# Train epoch: 7 [150/625]	Accuracy: 76.56%	Loss: 0.512785
# Train epoch: 7 [160/625]	Accuracy: 77.19%	Loss: 0.474879
# Train epoch: 7 [170/625]	Accuracy: 75.62%	Loss: 0.452510
# Train epoch: 7 [180/625]	Accuracy: 78.44%	Loss: 0.451204
# Train epoch: 7 [190/625]	Accuracy: 78.12%	Loss: 0.488447
# Train epoch: 7 [200/625]	Accuracy: 76.25%	Loss: 0.449004
# Train epoch: 7 [210/625]	Accuracy: 74.69%	Loss: 0.502077
# Train epoch: 7 [220/625]	Accuracy: 80.94%	Loss: 0.433488
# Train epoch: 7 [230/625]	Accuracy: 78.44%	Loss: 0.440475
# Train epoch: 7 [240/625]	Accuracy: 78.75%	Loss: 0.440663
# Train epoch: 7 [250/625]	Accuracy: 77.81%	Loss: 0.466149
# Train epoch: 7 [260/625]	Accuracy: 78.12%	Loss: 0.432450
# Train epoch: 7 [270/625]	Accuracy: 78.12%	Loss: 0.450223
# Train epoch: 7 [280/625]	Accuracy: 77.81%	Loss: 0.434212
# Train epoch: 7 [290/625]	Accuracy: 76.88%	Loss: 0.436982
# Train epoch: 7 [300/625]	Accuracy: 80.62%	Loss: 0.436727
# Train epoch: 7 [310/625]	Accuracy: 80.00%	Loss: 0.434321
# Train epoch: 7 [320/625]	Accuracy: 76.88%	Loss: 0.470578
# Train epoch: 7 [330/625]	Accuracy: 72.50%	Loss: 0.506683
# Train epoch: 7 [340/625]	Accuracy: 79.38%	Loss: 0.456250
# Train epoch: 7 [350/625]	Accuracy: 78.12%	Loss: 0.448109
# Train epoch: 7 [360/625]	Accuracy: 78.12%	Loss: 0.506790
# Train epoch: 7 [370/625]	Accuracy: 79.69%	Loss: 0.459393
# Train epoch: 7 [380/625]	Accuracy: 83.44%	Loss: 0.392101
# Train epoch: 7 [390/625]	Accuracy: 76.56%	Loss: 0.495379
# Train epoch: 7 [400/625]	Accuracy: 78.44%	Loss: 0.446631
# Train epoch: 7 [410/625]	Accuracy: 79.69%	Loss: 0.427461
# Train epoch: 7 [420/625]	Accuracy: 76.25%	Loss: 0.486565
# Train epoch: 7 [430/625]	Accuracy: 75.31%	Loss: 0.451897
# Train epoch: 7 [440/625]	Accuracy: 76.56%	Loss: 0.459286
# Train epoch: 7 [450/625]	Accuracy: 76.88%	Loss: 0.462507
# Train epoch: 7 [460/625]	Accuracy: 79.06%	Loss: 0.434306
# Train epoch: 7 [470/625]	Accuracy: 70.00%	Loss: 0.522469
# Train epoch: 7 [480/625]	Accuracy: 78.12%	Loss: 0.461133
# Train epoch: 7 [490/625]	Accuracy: 79.69%	Loss: 0.420499
# Train epoch: 7 [500/625]	Accuracy: 79.06%	Loss: 0.433612
# Train epoch: 7 [510/625]	Accuracy: 78.12%	Loss: 0.441678
# Train epoch: 7 [520/625]	Accuracy: 78.75%	Loss: 0.452116
# Train epoch: 7 [530/625]	Accuracy: 71.88%	Loss: 0.523952
# Train epoch: 7 [540/625]	Accuracy: 71.56%	Loss: 0.538633
# Train epoch: 7 [550/625]	Accuracy: 73.12%	Loss: 0.508697
# Train epoch: 7 [560/625]	Accuracy: 80.94%	Loss: 0.435423
# Train epoch: 7 [570/625]	Accuracy: 78.44%	Loss: 0.453991
# Train epoch: 7 [580/625]	Accuracy: 76.56%	Loss: 0.440185
# Train epoch: 7 [590/625]	Accuracy: 78.75%	Loss: 0.470722
# Train epoch: 7 [600/625]	Accuracy: 73.75%	Loss: 0.508878
# Train epoch: 7 [610/625]	Accuracy: 78.75%	Loss: 0.443553
# Train epoch: 7 [620/625]	Accuracy: 79.38%	Loss: 0.457577
# Test set: Loss: 1.0308, Accuracy: 53.96%)
# Train epoch: 8 [10/625]	Accuracy: 77.50%	Loss: 0.507563
# Train epoch: 8 [20/625]	Accuracy: 80.62%	Loss: 0.450140
# Train epoch: 8 [30/625]	Accuracy: 79.69%	Loss: 0.433076
# Train epoch: 8 [40/625]	Accuracy: 80.94%	Loss: 0.411720
# Train epoch: 8 [50/625]	Accuracy: 82.19%	Loss: 0.395602
# Train epoch: 8 [60/625]	Accuracy: 83.75%	Loss: 0.402813
# Train epoch: 8 [70/625]	Accuracy: 75.00%	Loss: 0.486834
# Train epoch: 8 [80/625]	Accuracy: 77.50%	Loss: 0.482864
# Train epoch: 8 [90/625]	Accuracy: 73.44%	Loss: 0.510269
# Train epoch: 8 [100/625]	Accuracy: 83.44%	Loss: 0.390144
# Train epoch: 8 [110/625]	Accuracy: 79.06%	Loss: 0.446148
# Train epoch: 8 [120/625]	Accuracy: 79.69%	Loss: 0.432255
# Train epoch: 8 [130/625]	Accuracy: 75.31%	Loss: 0.463797
# Train epoch: 8 [140/625]	Accuracy: 80.62%	Loss: 0.457866
# Train epoch: 8 [150/625]	Accuracy: 77.81%	Loss: 0.450980
# Train epoch: 8 [160/625]	Accuracy: 80.31%	Loss: 0.415190
# Train epoch: 8 [170/625]	Accuracy: 79.38%	Loss: 0.470608
# Train epoch: 8 [180/625]	Accuracy: 77.81%	Loss: 0.463758
# Train epoch: 8 [190/625]	Accuracy: 77.50%	Loss: 0.446844
# Train epoch: 8 [200/625]	Accuracy: 80.94%	Loss: 0.419876
# Train epoch: 8 [210/625]	Accuracy: 82.81%	Loss: 0.411851
# Train epoch: 8 [220/625]	Accuracy: 78.12%	Loss: 0.437923
# Train epoch: 8 [230/625]	Accuracy: 80.94%	Loss: 0.458583
# Train epoch: 8 [240/625]	Accuracy: 79.06%	Loss: 0.437151
# Train epoch: 8 [250/625]	Accuracy: 80.94%	Loss: 0.422036
# Train epoch: 8 [260/625]	Accuracy: 84.06%	Loss: 0.382676
# Train epoch: 8 [270/625]	Accuracy: 80.62%	Loss: 0.441121
# Train epoch: 8 [280/625]	Accuracy: 79.06%	Loss: 0.412408
# Train epoch: 8 [290/625]	Accuracy: 77.19%	Loss: 0.428733
# Train epoch: 8 [300/625]	Accuracy: 78.12%	Loss: 0.447385
# Train epoch: 8 [310/625]	Accuracy: 80.31%	Loss: 0.423690
# Train epoch: 8 [320/625]	Accuracy: 80.00%	Loss: 0.453503
# Train epoch: 8 [330/625]	Accuracy: 78.12%	Loss: 0.460559
# Train epoch: 8 [340/625]	Accuracy: 74.69%	Loss: 0.483853
# Train epoch: 8 [350/625]	Accuracy: 77.50%	Loss: 0.439060
# Train epoch: 8 [360/625]	Accuracy: 75.94%	Loss: 0.464892
# Train epoch: 8 [370/625]	Accuracy: 81.88%	Loss: 0.390136
# Train epoch: 8 [380/625]	Accuracy: 78.75%	Loss: 0.432135
# Train epoch: 8 [390/625]	Accuracy: 75.94%	Loss: 0.497020
# Train epoch: 8 [400/625]	Accuracy: 79.38%	Loss: 0.420315
# Train epoch: 8 [410/625]	Accuracy: 77.50%	Loss: 0.478641
# Train epoch: 8 [420/625]	Accuracy: 81.56%	Loss: 0.428962
# Train epoch: 8 [430/625]	Accuracy: 75.94%	Loss: 0.463425
# Train epoch: 8 [440/625]	Accuracy: 80.62%	Loss: 0.441425
# Train epoch: 8 [450/625]	Accuracy: 79.38%	Loss: 0.430296
# Train epoch: 8 [460/625]	Accuracy: 77.50%	Loss: 0.441006
# Train epoch: 8 [470/625]	Accuracy: 75.31%	Loss: 0.459396
# Train epoch: 8 [480/625]	Accuracy: 75.94%	Loss: 0.465111
# Train epoch: 8 [490/625]	Accuracy: 79.38%	Loss: 0.428959
# Train epoch: 8 [500/625]	Accuracy: 80.94%	Loss: 0.390118
# Train epoch: 8 [510/625]	Accuracy: 77.81%	Loss: 0.455488
# Train epoch: 8 [520/625]	Accuracy: 79.06%	Loss: 0.452557
# Train epoch: 8 [530/625]	Accuracy: 77.81%	Loss: 0.450272
# Train epoch: 8 [540/625]	Accuracy: 81.88%	Loss: 0.419613
# Train epoch: 8 [550/625]	Accuracy: 75.94%	Loss: 0.461259
# Train epoch: 8 [560/625]	Accuracy: 77.19%	Loss: 0.495971
# Train epoch: 8 [570/625]	Accuracy: 77.50%	Loss: 0.434305
# Train epoch: 8 [580/625]	Accuracy: 82.19%	Loss: 0.394513
# Train epoch: 8 [590/625]	Accuracy: 79.06%	Loss: 0.427821
# Train epoch: 8 [600/625]	Accuracy: 82.19%	Loss: 0.435673
# Train epoch: 8 [610/625]	Accuracy: 80.00%	Loss: 0.415947
# Train epoch: 8 [620/625]	Accuracy: 78.44%	Loss: 0.426955
# Test set: Loss: 0.8624, Accuracy: 55.39%)
# Train epoch: 9 [10/625]	Accuracy: 81.88%	Loss: 0.429199
# Train epoch: 9 [20/625]	Accuracy: 79.38%	Loss: 0.426104
# Train epoch: 9 [30/625]	Accuracy: 81.56%	Loss: 0.403056
# Train epoch: 9 [40/625]	Accuracy: 80.62%	Loss: 0.432935
# Train epoch: 9 [50/625]	Accuracy: 82.50%	Loss: 0.395427
# Train epoch: 9 [60/625]	Accuracy: 79.06%	Loss: 0.440202
# Train epoch: 9 [70/625]	Accuracy: 82.19%	Loss: 0.422514
# Train epoch: 9 [80/625]	Accuracy: 77.81%	Loss: 0.457794
# Train epoch: 9 [90/625]	Accuracy: 81.56%	Loss: 0.403809
# Train epoch: 9 [100/625]	Accuracy: 84.06%	Loss: 0.416095
# Train epoch: 9 [110/625]	Accuracy: 80.00%	Loss: 0.440407
# Train epoch: 9 [120/625]	Accuracy: 79.38%	Loss: 0.446307
# Train epoch: 9 [130/625]	Accuracy: 75.00%	Loss: 0.454865
# Train epoch: 9 [140/625]	Accuracy: 77.50%	Loss: 0.432809
# Train epoch: 9 [150/625]	Accuracy: 78.12%	Loss: 0.424456
# Train epoch: 9 [160/625]	Accuracy: 76.56%	Loss: 0.448659
# Train epoch: 9 [170/625]	Accuracy: 81.88%	Loss: 0.416552
# Train epoch: 9 [180/625]	Accuracy: 73.12%	Loss: 0.501647
# Train epoch: 9 [190/625]	Accuracy: 76.88%	Loss: 0.469085
# Train epoch: 9 [200/625]	Accuracy: 78.12%	Loss: 0.436200
# Train epoch: 9 [210/625]	Accuracy: 78.44%	Loss: 0.464105
# Train epoch: 9 [220/625]	Accuracy: 82.81%	Loss: 0.410198
# Train epoch: 9 [230/625]	Accuracy: 77.50%	Loss: 0.451523
# Train epoch: 9 [240/625]	Accuracy: 73.44%	Loss: 0.477403
# Train epoch: 9 [250/625]	Accuracy: 80.00%	Loss: 0.434221
# Train epoch: 9 [260/625]	Accuracy: 74.69%	Loss: 0.492620
# Train epoch: 9 [270/625]	Accuracy: 78.44%	Loss: 0.415230
# Train epoch: 9 [280/625]	Accuracy: 81.56%	Loss: 0.429239
# Train epoch: 9 [290/625]	Accuracy: 76.56%	Loss: 0.472254
# Train epoch: 9 [300/625]	Accuracy: 76.56%	Loss: 0.476138
# Train epoch: 9 [310/625]	Accuracy: 78.12%	Loss: 0.466169
# Train epoch: 9 [320/625]	Accuracy: 80.31%	Loss: 0.418627
# Train epoch: 9 [330/625]	Accuracy: 80.62%	Loss: 0.442200
# Train epoch: 9 [340/625]	Accuracy: 78.12%	Loss: 0.432997
# Train epoch: 9 [350/625]	Accuracy: 84.38%	Loss: 0.388267
# Train epoch: 9 [360/625]	Accuracy: 78.75%	Loss: 0.436661
# Train epoch: 9 [370/625]	Accuracy: 78.44%	Loss: 0.452854
# Train epoch: 9 [380/625]	Accuracy: 76.56%	Loss: 0.454448
# Train epoch: 9 [390/625]	Accuracy: 82.81%	Loss: 0.412568
# Train epoch: 9 [400/625]	Accuracy: 79.69%	Loss: 0.446016
# Train epoch: 9 [410/625]	Accuracy: 79.69%	Loss: 0.417096
# Train epoch: 9 [420/625]	Accuracy: 77.50%	Loss: 0.428323
# Train epoch: 9 [430/625]	Accuracy: 84.38%	Loss: 0.383608
# Train epoch: 9 [440/625]	Accuracy: 78.44%	Loss: 0.447147
# Train epoch: 9 [450/625]	Accuracy: 80.00%	Loss: 0.444636
# Train epoch: 9 [460/625]	Accuracy: 78.44%	Loss: 0.424781
# Train epoch: 9 [470/625]	Accuracy: 77.50%	Loss: 0.459649
# Train epoch: 9 [480/625]	Accuracy: 81.88%	Loss: 0.418836
# Train epoch: 9 [490/625]	Accuracy: 80.31%	Loss: 0.412496
# Train epoch: 9 [500/625]	Accuracy: 81.56%	Loss: 0.418972
# Train epoch: 9 [510/625]	Accuracy: 76.88%	Loss: 0.479051
# Train epoch: 9 [520/625]	Accuracy: 81.25%	Loss: 0.393120
# Train epoch: 9 [530/625]	Accuracy: 81.25%	Loss: 0.432121
# Train epoch: 9 [540/625]	Accuracy: 78.44%	Loss: 0.447625
# Train epoch: 9 [550/625]	Accuracy: 76.25%	Loss: 0.485730
# Train epoch: 9 [560/625]	Accuracy: 83.12%	Loss: 0.408362
# Train epoch: 9 [570/625]	Accuracy: 81.88%	Loss: 0.428099
# Train epoch: 9 [580/625]	Accuracy: 81.56%	Loss: 0.386965
# Train epoch: 9 [590/625]	Accuracy: 82.19%	Loss: 0.417409
# Train epoch: 9 [600/625]	Accuracy: 80.31%	Loss: 0.399842
# Train epoch: 9 [610/625]	Accuracy: 79.38%	Loss: 0.411011
# Train epoch: 9 [620/625]	Accuracy: 84.06%	Loss: 0.359093
# Test set: Loss: 0.7289, Accuracy: 63.04%)
# Train epoch: 10 [10/625]	Accuracy: 81.25%	Loss: 0.446283
# Train epoch: 10 [20/625]	Accuracy: 79.38%	Loss: 0.445718
# Train epoch: 10 [30/625]	Accuracy: 80.31%	Loss: 0.405599
# Train epoch: 10 [40/625]	Accuracy: 77.81%	Loss: 0.439704
# Train epoch: 10 [50/625]	Accuracy: 77.50%	Loss: 0.453050
# Train epoch: 10 [60/625]	Accuracy: 80.94%	Loss: 0.428472
# Train epoch: 10 [70/625]	Accuracy: 81.56%	Loss: 0.371790
# Train epoch: 10 [80/625]	Accuracy: 82.50%	Loss: 0.389992
# Train epoch: 10 [90/625]	Accuracy: 76.88%	Loss: 0.446501
# Train epoch: 10 [100/625]	Accuracy: 79.69%	Loss: 0.423933
# Train epoch: 10 [110/625]	Accuracy: 80.31%	Loss: 0.424989
# Train epoch: 10 [120/625]	Accuracy: 84.69%	Loss: 0.402923
# Train epoch: 10 [130/625]	Accuracy: 80.31%	Loss: 0.416241
# Train epoch: 10 [140/625]	Accuracy: 79.38%	Loss: 0.415471
# Train epoch: 10 [150/625]	Accuracy: 77.50%	Loss: 0.462282
# Train epoch: 10 [160/625]	Accuracy: 75.00%	Loss: 0.462064
# Train epoch: 10 [170/625]	Accuracy: 76.88%	Loss: 0.460185
# Train epoch: 10 [180/625]	Accuracy: 75.62%	Loss: 0.457737
# Train epoch: 10 [190/625]	Accuracy: 80.00%	Loss: 0.416784
# Train epoch: 10 [200/625]	Accuracy: 78.12%	Loss: 0.405302
# Train epoch: 10 [210/625]	Accuracy: 81.25%	Loss: 0.432521
# Train epoch: 10 [220/625]	Accuracy: 79.06%	Loss: 0.409321
# Train epoch: 10 [230/625]	Accuracy: 85.94%	Loss: 0.371045
# Train epoch: 10 [240/625]	Accuracy: 82.81%	Loss: 0.398408
# Train epoch: 10 [250/625]	Accuracy: 83.12%	Loss: 0.390637
# Train epoch: 10 [260/625]	Accuracy: 81.88%	Loss: 0.372247
# Train epoch: 10 [270/625]	Accuracy: 83.75%	Loss: 0.384402
# Train epoch: 10 [280/625]	Accuracy: 82.19%	Loss: 0.400228
# Train epoch: 10 [290/625]	Accuracy: 80.00%	Loss: 0.392597
# Train epoch: 10 [300/625]	Accuracy: 83.12%	Loss: 0.378477
# Train epoch: 10 [310/625]	Accuracy: 80.94%	Loss: 0.396476
# Train epoch: 10 [320/625]	Accuracy: 80.00%	Loss: 0.429318
# Train epoch: 10 [330/625]	Accuracy: 80.62%	Loss: 0.431950
# Train epoch: 10 [340/625]	Accuracy: 81.88%	Loss: 0.388322
# Train epoch: 10 [350/625]	Accuracy: 81.25%	Loss: 0.442781
# Train epoch: 10 [360/625]	Accuracy: 77.81%	Loss: 0.445981
# Train epoch: 10 [370/625]	Accuracy: 80.00%	Loss: 0.405783
# Train epoch: 10 [380/625]	Accuracy: 78.75%	Loss: 0.417617
# Train epoch: 10 [390/625]	Accuracy: 80.31%	Loss: 0.458727
# Train epoch: 10 [400/625]	Accuracy: 80.94%	Loss: 0.389988
# Train epoch: 10 [410/625]	Accuracy: 81.56%	Loss: 0.404425
# Train epoch: 10 [420/625]	Accuracy: 84.38%	Loss: 0.360031
# Train epoch: 10 [430/625]	Accuracy: 81.25%	Loss: 0.397175
# Train epoch: 10 [440/625]	Accuracy: 80.62%	Loss: 0.411368
# Train epoch: 10 [450/625]	Accuracy: 80.00%	Loss: 0.415936
# Train epoch: 10 [460/625]	Accuracy: 81.56%	Loss: 0.418648
# Train epoch: 10 [470/625]	Accuracy: 79.06%	Loss: 0.437814
# Train epoch: 10 [480/625]	Accuracy: 79.69%	Loss: 0.441335
# Train epoch: 10 [490/625]	Accuracy: 83.12%	Loss: 0.351154
# Train epoch: 10 [500/625]	Accuracy: 81.56%	Loss: 0.392014
# Train epoch: 10 [510/625]	Accuracy: 80.62%	Loss: 0.410414
# Train epoch: 10 [520/625]	Accuracy: 83.12%	Loss: 0.395102
# Train epoch: 10 [530/625]	Accuracy: 85.00%	Loss: 0.369849
# Train epoch: 10 [540/625]	Accuracy: 83.44%	Loss: 0.386775
# Train epoch: 10 [550/625]	Accuracy: 80.00%	Loss: 0.469184
# Train epoch: 10 [560/625]	Accuracy: 82.81%	Loss: 0.388750
# Train epoch: 10 [570/625]	Accuracy: 81.25%	Loss: 0.395969
# Train epoch: 10 [580/625]	Accuracy: 83.12%	Loss: 0.380406
# Train epoch: 10 [590/625]	Accuracy: 76.56%	Loss: 0.472700
# Train epoch: 10 [600/625]	Accuracy: 79.69%	Loss: 0.394627
# Train epoch: 10 [610/625]	Accuracy: 80.94%	Loss: 0.369831
# Train epoch: 10 [620/625]	Accuracy: 77.50%	Loss: 0.438213
# Test set: Loss: 1.3860, Accuracy: 57.34%)
# Train epoch: 11 [10/625]	Accuracy: 77.81%	Loss: 0.440816
# Train epoch: 11 [20/625]	Accuracy: 78.44%	Loss: 0.461231
# Train epoch: 11 [30/625]	Accuracy: 81.25%	Loss: 0.404125
# Train epoch: 11 [40/625]	Accuracy: 85.31%	Loss: 0.356339
# Train epoch: 11 [50/625]	Accuracy: 81.25%	Loss: 0.403645
# Train epoch: 11 [60/625]	Accuracy: 82.50%	Loss: 0.367990
# Train epoch: 11 [70/625]	Accuracy: 80.00%	Loss: 0.423411
# Train epoch: 11 [80/625]	Accuracy: 77.50%	Loss: 0.434889
# Train epoch: 11 [90/625]	Accuracy: 77.50%	Loss: 0.445784
# Train epoch: 11 [100/625]	Accuracy: 79.69%	Loss: 0.447454
# Train epoch: 11 [110/625]	Accuracy: 81.25%	Loss: 0.411271
# Train epoch: 11 [120/625]	Accuracy: 80.94%	Loss: 0.423897
# Train epoch: 11 [130/625]	Accuracy: 80.31%	Loss: 0.422561
# Train epoch: 11 [140/625]	Accuracy: 79.69%	Loss: 0.428999
# Train epoch: 11 [150/625]	Accuracy: 81.25%	Loss: 0.393738
# Train epoch: 11 [160/625]	Accuracy: 80.31%	Loss: 0.400939
# Train epoch: 11 [170/625]	Accuracy: 78.12%	Loss: 0.405635
# Train epoch: 11 [180/625]	Accuracy: 85.31%	Loss: 0.366060
# Train epoch: 11 [190/625]	Accuracy: 80.94%	Loss: 0.424003
# Train epoch: 11 [200/625]	Accuracy: 78.44%	Loss: 0.410760
# Train epoch: 11 [210/625]	Accuracy: 83.12%	Loss: 0.376069
# Train epoch: 11 [220/625]	Accuracy: 80.62%	Loss: 0.427580
# Train epoch: 11 [230/625]	Accuracy: 77.81%	Loss: 0.492658
# Train epoch: 11 [240/625]	Accuracy: 82.81%	Loss: 0.416696
# Train epoch: 11 [250/625]	Accuracy: 80.62%	Loss: 0.377602
# Train epoch: 11 [260/625]	Accuracy: 79.06%	Loss: 0.432955
# Train epoch: 11 [270/625]	Accuracy: 79.38%	Loss: 0.410795
# Train epoch: 11 [280/625]	Accuracy: 84.38%	Loss: 0.366761
# Train epoch: 11 [290/625]	Accuracy: 80.00%	Loss: 0.417458
# Train epoch: 11 [300/625]	Accuracy: 85.94%	Loss: 0.338337
# Train epoch: 11 [310/625]	Accuracy: 85.31%	Loss: 0.353376
# Train epoch: 11 [320/625]	Accuracy: 78.75%	Loss: 0.438957
# Train epoch: 11 [330/625]	Accuracy: 82.19%	Loss: 0.368366
# Train epoch: 11 [340/625]	Accuracy: 80.31%	Loss: 0.416387
# Train epoch: 11 [350/625]	Accuracy: 80.00%	Loss: 0.393133
# Train epoch: 11 [360/625]	Accuracy: 80.00%	Loss: 0.399669
# Train epoch: 11 [370/625]	Accuracy: 82.19%	Loss: 0.379391
# Train epoch: 11 [380/625]	Accuracy: 82.81%	Loss: 0.423279
# Train epoch: 11 [390/625]	Accuracy: 81.56%	Loss: 0.389667
# Train epoch: 11 [400/625]	Accuracy: 85.00%	Loss: 0.349653
# Train epoch: 11 [410/625]	Accuracy: 82.19%	Loss: 0.393272
# Train epoch: 11 [420/625]	Accuracy: 77.81%	Loss: 0.409829
# Train epoch: 11 [430/625]	Accuracy: 83.12%	Loss: 0.371491
# Train epoch: 11 [440/625]	Accuracy: 81.25%	Loss: 0.372760
# Train epoch: 11 [450/625]	Accuracy: 84.38%	Loss: 0.384390
# Train epoch: 11 [460/625]	Accuracy: 85.94%	Loss: 0.337382
# Train epoch: 11 [470/625]	Accuracy: 81.25%	Loss: 0.397943
# Train epoch: 11 [480/625]	Accuracy: 80.94%	Loss: 0.374346
# Train epoch: 11 [490/625]	Accuracy: 83.44%	Loss: 0.369645
# Train epoch: 11 [500/625]	Accuracy: 85.00%	Loss: 0.345894
# Train epoch: 11 [510/625]	Accuracy: 82.19%	Loss: 0.403881
# Train epoch: 11 [520/625]	Accuracy: 85.31%	Loss: 0.360874
# Train epoch: 11 [530/625]	Accuracy: 83.44%	Loss: 0.370055
# Train epoch: 11 [540/625]	Accuracy: 77.50%	Loss: 0.441824
# Train epoch: 11 [550/625]	Accuracy: 79.69%	Loss: 0.416038
# Train epoch: 11 [560/625]	Accuracy: 85.62%	Loss: 0.342504
# Train epoch: 11 [570/625]	Accuracy: 81.88%	Loss: 0.351780
# Train epoch: 11 [580/625]	Accuracy: 84.06%	Loss: 0.358422
# Train epoch: 11 [590/625]	Accuracy: 84.38%	Loss: 0.326042
# Train epoch: 11 [600/625]	Accuracy: 80.31%	Loss: 0.409744
# Train epoch: 11 [610/625]	Accuracy: 84.38%	Loss: 0.394599
# Train epoch: 11 [620/625]	Accuracy: 81.25%	Loss: 0.379861
# Test set: Loss: 1.0912, Accuracy: 55.81%)
# Train epoch: 12 [10/625]	Accuracy: 79.69%	Loss: 0.421512
# Train epoch: 12 [20/625]	Accuracy: 82.81%	Loss: 0.391723
# Train epoch: 12 [30/625]	Accuracy: 82.19%	Loss: 0.407345
# Train epoch: 12 [40/625]	Accuracy: 79.38%	Loss: 0.414763
# Train epoch: 12 [50/625]	Accuracy: 80.62%	Loss: 0.407865
# Train epoch: 12 [60/625]	Accuracy: 80.94%	Loss: 0.387975
# Train epoch: 12 [70/625]	Accuracy: 84.06%	Loss: 0.374036
# Train epoch: 12 [80/625]	Accuracy: 82.50%	Loss: 0.360909
# Train epoch: 12 [90/625]	Accuracy: 82.81%	Loss: 0.359809
# Train epoch: 12 [100/625]	Accuracy: 79.06%	Loss: 0.442672
# Train epoch: 12 [110/625]	Accuracy: 83.44%	Loss: 0.365252
# Train epoch: 12 [120/625]	Accuracy: 81.56%	Loss: 0.401668
# Train epoch: 12 [130/625]	Accuracy: 83.12%	Loss: 0.374992
# Train epoch: 12 [140/625]	Accuracy: 85.00%	Loss: 0.333748
# Train epoch: 12 [150/625]	Accuracy: 80.94%	Loss: 0.376027
# Train epoch: 12 [160/625]	Accuracy: 83.12%	Loss: 0.348701
# Train epoch: 12 [170/625]	Accuracy: 83.12%	Loss: 0.351533
# Train epoch: 12 [180/625]	Accuracy: 83.75%	Loss: 0.342921
# Train epoch: 12 [190/625]	Accuracy: 82.50%	Loss: 0.370507
# Train epoch: 12 [200/625]	Accuracy: 78.75%	Loss: 0.416615
# Train epoch: 12 [210/625]	Accuracy: 84.06%	Loss: 0.330098
# Train epoch: 12 [220/625]	Accuracy: 79.38%	Loss: 0.442544
# Train epoch: 12 [230/625]	Accuracy: 85.94%	Loss: 0.377603
# Train epoch: 12 [240/625]	Accuracy: 79.38%	Loss: 0.436181
# Train epoch: 12 [250/625]	Accuracy: 82.50%	Loss: 0.413802
# Train epoch: 12 [260/625]	Accuracy: 85.62%	Loss: 0.365363
# Train epoch: 12 [270/625]	Accuracy: 82.50%	Loss: 0.382742
# Train epoch: 12 [280/625]	Accuracy: 81.25%	Loss: 0.390320
# Train epoch: 12 [290/625]	Accuracy: 83.75%	Loss: 0.380906
# Train epoch: 12 [300/625]	Accuracy: 85.00%	Loss: 0.363528
# Train epoch: 12 [310/625]	Accuracy: 76.88%	Loss: 0.435231
# Train epoch: 12 [320/625]	Accuracy: 78.75%	Loss: 0.410001
# Train epoch: 12 [330/625]	Accuracy: 84.69%	Loss: 0.379627
# Train epoch: 12 [340/625]	Accuracy: 79.69%	Loss: 0.383296
# Train epoch: 12 [350/625]	Accuracy: 84.06%	Loss: 0.368874
# Train epoch: 12 [360/625]	Accuracy: 81.88%	Loss: 0.362456
# Train epoch: 12 [370/625]	Accuracy: 83.44%	Loss: 0.365807
# Train epoch: 12 [380/625]	Accuracy: 79.06%	Loss: 0.407407
# Train epoch: 12 [390/625]	Accuracy: 78.12%	Loss: 0.420590
# Train epoch: 12 [400/625]	Accuracy: 79.69%	Loss: 0.414134
# Train epoch: 12 [410/625]	Accuracy: 84.69%	Loss: 0.353528
# Train epoch: 12 [420/625]	Accuracy: 84.69%	Loss: 0.342336
# Train epoch: 12 [430/625]	Accuracy: 84.06%	Loss: 0.384484
# Train epoch: 12 [440/625]	Accuracy: 81.88%	Loss: 0.404929
# Train epoch: 12 [450/625]	Accuracy: 82.81%	Loss: 0.399507
# Train epoch: 12 [460/625]	Accuracy: 81.56%	Loss: 0.365049
# Train epoch: 12 [470/625]	Accuracy: 80.62%	Loss: 0.407660
# Train epoch: 12 [480/625]	Accuracy: 82.81%	Loss: 0.380205
# Train epoch: 12 [490/625]	Accuracy: 85.00%	Loss: 0.361846
# Train epoch: 12 [500/625]	Accuracy: 80.94%	Loss: 0.381382
# Train epoch: 12 [510/625]	Accuracy: 83.75%	Loss: 0.401351
# Train epoch: 12 [520/625]	Accuracy: 79.38%	Loss: 0.417362
# Train epoch: 12 [530/625]	Accuracy: 78.44%	Loss: 0.428678
# Train epoch: 12 [540/625]	Accuracy: 83.44%	Loss: 0.363890
# Train epoch: 12 [550/625]	Accuracy: 80.00%	Loss: 0.424870
# Train epoch: 12 [560/625]	Accuracy: 80.00%	Loss: 0.403529
# Train epoch: 12 [570/625]	Accuracy: 80.00%	Loss: 0.414362
# Train epoch: 12 [580/625]	Accuracy: 80.94%	Loss: 0.395459
# Train epoch: 12 [590/625]	Accuracy: 86.25%	Loss: 0.331658
# Train epoch: 12 [600/625]	Accuracy: 82.50%	Loss: 0.395579
# Train epoch: 12 [610/625]	Accuracy: 78.75%	Loss: 0.417139
# Train epoch: 12 [620/625]	Accuracy: 81.88%	Loss: 0.366779
# Test set: Loss: 0.7700, Accuracy: 64.77%)
# Train epoch: 13 [10/625]	Accuracy: 84.06%	Loss: 0.370223
# Train epoch: 13 [20/625]	Accuracy: 83.75%	Loss: 0.330504
# Train epoch: 13 [30/625]	Accuracy: 83.12%	Loss: 0.385683
# Train epoch: 13 [40/625]	Accuracy: 82.81%	Loss: 0.338643
# Train epoch: 13 [50/625]	Accuracy: 80.00%	Loss: 0.392472
# Train epoch: 13 [60/625]	Accuracy: 80.00%	Loss: 0.380976
# Train epoch: 13 [70/625]	Accuracy: 84.06%	Loss: 0.358146
# Train epoch: 13 [80/625]	Accuracy: 86.56%	Loss: 0.351947
# Train epoch: 13 [90/625]	Accuracy: 84.06%	Loss: 0.333310
# Train epoch: 13 [100/625]	Accuracy: 82.19%	Loss: 0.370137
# Train epoch: 13 [110/625]	Accuracy: 80.00%	Loss: 0.389366
# Train epoch: 13 [120/625]	Accuracy: 79.38%	Loss: 0.448807
# Train epoch: 13 [130/625]	Accuracy: 75.62%	Loss: 0.443321
# Train epoch: 13 [140/625]	Accuracy: 81.56%	Loss: 0.392654
# Train epoch: 13 [150/625]	Accuracy: 84.69%	Loss: 0.347228
# Train epoch: 13 [160/625]	Accuracy: 84.38%	Loss: 0.374130
# Train epoch: 13 [170/625]	Accuracy: 83.12%	Loss: 0.345276
# Train epoch: 13 [180/625]	Accuracy: 80.00%	Loss: 0.407533
# Train epoch: 13 [190/625]	Accuracy: 85.94%	Loss: 0.340623
# Train epoch: 13 [200/625]	Accuracy: 80.31%	Loss: 0.412197
# Train epoch: 13 [210/625]	Accuracy: 87.50%	Loss: 0.339427
# Train epoch: 13 [220/625]	Accuracy: 82.19%	Loss: 0.370423
# Train epoch: 13 [230/625]	Accuracy: 83.12%	Loss: 0.363625
# Train epoch: 13 [240/625]	Accuracy: 83.44%	Loss: 0.355421
# Train epoch: 13 [250/625]	Accuracy: 77.81%	Loss: 0.447589
# Train epoch: 13 [260/625]	Accuracy: 84.06%	Loss: 0.412951
# Train epoch: 13 [270/625]	Accuracy: 79.38%	Loss: 0.403403
# Train epoch: 13 [280/625]	Accuracy: 82.81%	Loss: 0.381434
# Train epoch: 13 [290/625]	Accuracy: 83.75%	Loss: 0.361484
# Train epoch: 13 [300/625]	Accuracy: 85.31%	Loss: 0.351884
# Train epoch: 13 [310/625]	Accuracy: 84.69%	Loss: 0.348674
# Train epoch: 13 [320/625]	Accuracy: 82.19%	Loss: 0.391322
# Train epoch: 13 [330/625]	Accuracy: 82.50%	Loss: 0.387265
# Train epoch: 13 [340/625]	Accuracy: 84.69%	Loss: 0.343236
# Train epoch: 13 [350/625]	Accuracy: 80.94%	Loss: 0.391899
# Train epoch: 13 [360/625]	Accuracy: 86.88%	Loss: 0.325794
# Train epoch: 13 [370/625]	Accuracy: 83.44%	Loss: 0.400885
# Train epoch: 13 [380/625]	Accuracy: 84.69%	Loss: 0.344010
# Train epoch: 13 [390/625]	Accuracy: 85.00%	Loss: 0.347934
# Train epoch: 13 [400/625]	Accuracy: 82.50%	Loss: 0.378874
# Train epoch: 13 [410/625]	Accuracy: 85.94%	Loss: 0.319640
# Train epoch: 13 [420/625]	Accuracy: 81.88%	Loss: 0.357568
# Train epoch: 13 [430/625]	Accuracy: 84.38%	Loss: 0.372946
# Train epoch: 13 [440/625]	Accuracy: 84.38%	Loss: 0.348656
# Train epoch: 13 [450/625]	Accuracy: 84.06%	Loss: 0.360659
# Train epoch: 13 [460/625]	Accuracy: 83.75%	Loss: 0.402604
# Train epoch: 13 [470/625]	Accuracy: 84.38%	Loss: 0.395802
# Train epoch: 13 [480/625]	Accuracy: 81.25%	Loss: 0.390919
# Train epoch: 13 [490/625]	Accuracy: 77.81%	Loss: 0.445250
# Train epoch: 13 [500/625]	Accuracy: 79.06%	Loss: 0.418273
# Train epoch: 13 [510/625]	Accuracy: 81.56%	Loss: 0.387186
# Train epoch: 13 [520/625]	Accuracy: 80.31%	Loss: 0.403536
# Train epoch: 13 [530/625]	Accuracy: 81.88%	Loss: 0.382812
# Train epoch: 13 [540/625]	Accuracy: 83.44%	Loss: 0.370596
# Train epoch: 13 [550/625]	Accuracy: 80.94%	Loss: 0.386426
# Train epoch: 13 [560/625]	Accuracy: 81.88%	Loss: 0.373358
# Train epoch: 13 [570/625]	Accuracy: 81.56%	Loss: 0.388647
# Train epoch: 13 [580/625]	Accuracy: 80.94%	Loss: 0.389802
# Train epoch: 13 [590/625]	Accuracy: 83.75%	Loss: 0.401365
# Train epoch: 13 [600/625]	Accuracy: 85.94%	Loss: 0.339442
# Train epoch: 13 [610/625]	Accuracy: 85.62%	Loss: 0.330754
# Train epoch: 13 [620/625]	Accuracy: 84.38%	Loss: 0.338241
# Test set: Loss: 0.6430, Accuracy: 64.75%)
# Train epoch: 14 [10/625]	Accuracy: 83.12%	Loss: 0.334191
# Train epoch: 14 [20/625]	Accuracy: 79.38%	Loss: 0.412584
# Train epoch: 14 [30/625]	Accuracy: 83.12%	Loss: 0.370907
# Train epoch: 14 [40/625]	Accuracy: 85.94%	Loss: 0.328787
# Train epoch: 14 [50/625]	Accuracy: 84.69%	Loss: 0.390321
# Train epoch: 14 [60/625]	Accuracy: 84.38%	Loss: 0.351638
# Train epoch: 14 [70/625]	Accuracy: 87.19%	Loss: 0.323298
# Train epoch: 14 [80/625]	Accuracy: 83.44%	Loss: 0.384157
# Train epoch: 14 [90/625]	Accuracy: 78.12%	Loss: 0.428375
# Train epoch: 14 [100/625]	Accuracy: 83.44%	Loss: 0.366031
# Train epoch: 14 [110/625]	Accuracy: 83.44%	Loss: 0.362544
# Train epoch: 14 [120/625]	Accuracy: 84.06%	Loss: 0.368436
# Train epoch: 14 [130/625]	Accuracy: 85.94%	Loss: 0.313201
# Train epoch: 14 [140/625]	Accuracy: 83.12%	Loss: 0.351875
# Train epoch: 14 [150/625]	Accuracy: 87.81%	Loss: 0.320153
# Train epoch: 14 [160/625]	Accuracy: 83.12%	Loss: 0.351170
# Train epoch: 14 [170/625]	Accuracy: 82.50%	Loss: 0.389458
# Train epoch: 14 [180/625]	Accuracy: 82.81%	Loss: 0.347136
# Train epoch: 14 [190/625]	Accuracy: 83.12%	Loss: 0.354875
# Train epoch: 14 [200/625]	Accuracy: 80.94%	Loss: 0.368646
# Train epoch: 14 [210/625]	Accuracy: 84.38%	Loss: 0.350575
# Train epoch: 14 [220/625]	Accuracy: 82.50%	Loss: 0.363520
# Train epoch: 14 [230/625]	Accuracy: 85.31%	Loss: 0.339393
# ...
# Train epoch: 26 [390/625]	Accuracy: 85.00%	Loss: 0.329108
# Train epoch: 26 [400/625]	Accuracy: 89.06%	Loss: 0.243749
# Train epoch: 26 [410/625]	Accuracy: 86.25%	Loss: 0.266394
# Train epoch: 26 [420/625]	Accuracy: 84.38%	Loss: 0.300905
# Train epoch: 26 [430/625]	Accuracy: 81.56%	Loss: 0.322092
# Train epoch: 26 [440/625]	Accuracy: 90.62%	Loss: 0.263011
# Train epoch: 26 [450/625]	Accuracy: 87.19%	Loss: 0.306217
# Train epoch: 26 [460/625]	Accuracy: 84.38%	Loss: 0.345540
# Train epoch: 26 [470/625]	Accuracy: 85.31%	Loss: 0.310817
# Train epoch: 26 [480/625]	Accuracy: 87.50%	Loss: 0.287667
# Train epoch: 26 [490/625]	Accuracy: 85.94%	Loss: 0.308367
# Train epoch: 26 [500/625]	Accuracy: 86.56%	Loss: 0.296436
# Train epoch: 26 [510/625]	Accuracy: 84.69%	Loss: 0.315995
# Train epoch: 26 [520/625]	Accuracy: 86.56%	Loss: 0.295964
# Train epoch: 26 [530/625]	Accuracy: 89.06%	Loss: 0.318012
# Train epoch: 26 [540/625]	Accuracy: 86.56%	Loss: 0.291267
# Train epoch: 26 [550/625]	Accuracy: 88.75%	Loss: 0.269290
# Train epoch: 26 [560/625]	Accuracy: 87.19%	Loss: 0.308642
# Train epoch: 26 [570/625]	Accuracy: 85.62%	Loss: 0.312470
# Train epoch: 26 [580/625]	Accuracy: 88.12%	Loss: 0.278105
# Train epoch: 26 [590/625]	Accuracy: 83.44%	Loss: 0.349821
# Train epoch: 26 [600/625]	Accuracy: 84.69%	Loss: 0.313287
# Train epoch: 26 [610/625]	Accuracy: 89.69%	Loss: 0.274669
# Train epoch: 26 [620/625]	Accuracy: 90.62%	Loss: 0.253036
# Test set: Loss: 0.5625, Accuracy: 68.39%)
# Train epoch: 27 [10/625]	Accuracy: 87.19%	Loss: 0.281420
# Train epoch: 27 [20/625]	Accuracy: 88.12%	Loss: 0.285599
# Train epoch: 27 [30/625]	Accuracy: 85.00%	Loss: 0.268992
# Train epoch: 27 [40/625]	Accuracy: 86.56%	Loss: 0.286931
# Train epoch: 27 [50/625]	Accuracy: 87.50%	Loss: 0.287958
# Train epoch: 27 [60/625]	Accuracy: 88.12%	Loss: 0.268547
# Train epoch: 27 [70/625]	Accuracy: 87.50%	Loss: 0.285150
# Train epoch: 27 [80/625]	Accuracy: 88.44%	Loss: 0.284797
# Train epoch: 27 [90/625]	Accuracy: 87.19%	Loss: 0.277646
# Train epoch: 27 [100/625]	Accuracy: 89.06%	Loss: 0.269640
# Train epoch: 27 [110/625]	Accuracy: 85.62%	Loss: 0.336086
# Train epoch: 27 [120/625]	Accuracy: 83.75%	Loss: 0.355263
# Train epoch: 27 [130/625]	Accuracy: 82.19%	Loss: 0.352272
# Train epoch: 27 [140/625]	Accuracy: 85.62%	Loss: 0.333002
# Train epoch: 27 [150/625]	Accuracy: 85.31%	Loss: 0.297356
# Train epoch: 27 [160/625]	Accuracy: 86.25%	Loss: 0.304906
# Train epoch: 27 [170/625]	Accuracy: 87.19%	Loss: 0.326270
# Train epoch: 27 [180/625]	Accuracy: 87.81%	Loss: 0.298167
# Train epoch: 27 [190/625]	Accuracy: 82.81%	Loss: 0.324438
# Train epoch: 27 [200/625]	Accuracy: 84.06%	Loss: 0.329863
# Train epoch: 27 [210/625]	Accuracy: 89.69%	Loss: 0.278510
# Train epoch: 27 [220/625]	Accuracy: 89.38%	Loss: 0.245648
# Train epoch: 27 [230/625]	Accuracy: 87.81%	Loss: 0.268935
# Train epoch: 27 [240/625]	Accuracy: 88.44%	Loss: 0.291103
# Train epoch: 27 [250/625]	Accuracy: 88.12%	Loss: 0.269892
# Train epoch: 27 [260/625]	Accuracy: 90.31%	Loss: 0.234984
# Train epoch: 27 [270/625]	Accuracy: 87.50%	Loss: 0.292209
# Train epoch: 27 [280/625]	Accuracy: 88.44%	Loss: 0.265580
# Train epoch: 27 [290/625]	Accuracy: 85.31%	Loss: 0.286730
# Train epoch: 27 [300/625]	Accuracy: 85.31%	Loss: 0.312399
# Train epoch: 27 [310/625]	Accuracy: 88.44%	Loss: 0.295441
# Train epoch: 27 [320/625]	Accuracy: 86.88%	Loss: 0.301753
# Train epoch: 27 [330/625]	Accuracy: 86.56%	Loss: 0.293002
# Train epoch: 27 [340/625]	Accuracy: 90.00%	Loss: 0.264909
# Train epoch: 27 [350/625]	Accuracy: 87.19%	Loss: 0.259797
# Train epoch: 27 [360/625]	Accuracy: 85.31%	Loss: 0.309464
# Train epoch: 27 [370/625]	Accuracy: 85.31%	Loss: 0.327122
# Train epoch: 27 [380/625]	Accuracy: 89.69%	Loss: 0.267613
# Train epoch: 27 [390/625]	Accuracy: 84.06%	Loss: 0.299294
# Train epoch: 27 [400/625]	Accuracy: 87.81%	Loss: 0.264811
# Train epoch: 27 [410/625]	Accuracy: 84.38%	Loss: 0.328401
# Train epoch: 27 [420/625]	Accuracy: 83.75%	Loss: 0.346552
# Train epoch: 27 [430/625]	Accuracy: 86.25%	Loss: 0.290703
# Train epoch: 27 [440/625]	Accuracy: 85.94%	Loss: 0.327072
# Train epoch: 27 [450/625]	Accuracy: 88.12%	Loss: 0.281965
# Train epoch: 27 [460/625]	Accuracy: 86.56%	Loss: 0.320891
# Train epoch: 27 [470/625]	Accuracy: 89.38%	Loss: 0.263332
# Train epoch: 27 [480/625]	Accuracy: 88.44%	Loss: 0.268964
# Train epoch: 27 [490/625]	Accuracy: 89.06%	Loss: 0.280069
# Train epoch: 27 [500/625]	Accuracy: 90.94%	Loss: 0.263196
# Train epoch: 27 [510/625]	Accuracy: 87.50%	Loss: 0.314478
# Train epoch: 27 [520/625]	Accuracy: 89.38%	Loss: 0.304708
# Train epoch: 27 [530/625]	Accuracy: 86.25%	Loss: 0.327044
# Train epoch: 27 [540/625]	Accuracy: 86.88%	Loss: 0.271801
# Train epoch: 27 [550/625]	Accuracy: 85.00%	Loss: 0.314949
# Train epoch: 27 [560/625]	Accuracy: 85.00%	Loss: 0.300557
# Train epoch: 27 [570/625]	Accuracy: 86.88%	Loss: 0.307670
# Train epoch: 27 [580/625]	Accuracy: 85.31%	Loss: 0.336169
# Train epoch: 27 [590/625]	Accuracy: 83.75%	Loss: 0.333856
# Train epoch: 27 [600/625]	Accuracy: 89.06%	Loss: 0.279356
# Train epoch: 27 [610/625]	Accuracy: 86.56%	Loss: 0.259929
# Train epoch: 27 [620/625]	Accuracy: 85.62%	Loss: 0.294964
# Test set: Loss: 0.5789, Accuracy: 68.67%)
# Train epoch: 28 [10/625]	Accuracy: 88.75%	Loss: 0.285997
# Train epoch: 28 [20/625]	Accuracy: 84.38%	Loss: 0.356823
# Train epoch: 28 [30/625]	Accuracy: 86.25%	Loss: 0.321306
# Train epoch: 28 [40/625]	Accuracy: 88.12%	Loss: 0.293631
# Train epoch: 28 [50/625]	Accuracy: 85.31%	Loss: 0.295430
# Train epoch: 28 [60/625]	Accuracy: 85.94%	Loss: 0.302032
# Train epoch: 28 [70/625]	Accuracy: 85.94%	Loss: 0.318278
# Train epoch: 28 [80/625]	Accuracy: 89.06%	Loss: 0.293924
# Train epoch: 28 [90/625]	Accuracy: 87.81%	Loss: 0.305600
# Train epoch: 28 [100/625]	Accuracy: 85.31%	Loss: 0.292669
# Train epoch: 28 [110/625]	Accuracy: 90.31%	Loss: 0.228008
# Train epoch: 28 [120/625]	Accuracy: 89.06%	Loss: 0.253263
# Train epoch: 28 [130/625]	Accuracy: 87.81%	Loss: 0.289877
# Train epoch: 28 [140/625]	Accuracy: 91.25%	Loss: 0.254512
# Train epoch: 28 [150/625]	Accuracy: 85.62%	Loss: 0.274540
# Train epoch: 28 [160/625]	Accuracy: 89.06%	Loss: 0.276099
# Train epoch: 28 [170/625]	Accuracy: 89.38%	Loss: 0.265862
# Train epoch: 28 [180/625]	Accuracy: 87.81%	Loss: 0.296724
# Train epoch: 28 [190/625]	Accuracy: 87.50%	Loss: 0.300837
# Train epoch: 28 [200/625]	Accuracy: 87.50%	Loss: 0.276247
# Train epoch: 28 [210/625]	Accuracy: 83.44%	Loss: 0.321854
# Train epoch: 28 [220/625]	Accuracy: 86.88%	Loss: 0.275187
# Train epoch: 28 [230/625]	Accuracy: 85.00%	Loss: 0.315165
# Train epoch: 28 [240/625]	Accuracy: 85.31%	Loss: 0.314288
# Train epoch: 28 [250/625]	Accuracy: 85.31%	Loss: 0.292179
# Train epoch: 28 [260/625]	Accuracy: 86.25%	Loss: 0.305820
# Train epoch: 28 [270/625]	Accuracy: 86.25%	Loss: 0.339453
# Train epoch: 28 [280/625]	Accuracy: 87.50%	Loss: 0.258667
# Train epoch: 28 [290/625]	Accuracy: 87.50%	Loss: 0.266326
# Train epoch: 28 [300/625]	Accuracy: 84.38%	Loss: 0.346796
# Train epoch: 28 [310/625]	Accuracy: 85.31%	Loss: 0.361098
# Train epoch: 28 [320/625]	Accuracy: 84.06%	Loss: 0.308981
# Train epoch: 28 [330/625]	Accuracy: 86.56%	Loss: 0.293425
# Train epoch: 28 [340/625]	Accuracy: 85.94%	Loss: 0.333286
# Train epoch: 28 [350/625]	Accuracy: 85.94%	Loss: 0.302791
# Train epoch: 28 [360/625]	Accuracy: 85.00%	Loss: 0.308980
# Train epoch: 28 [370/625]	Accuracy: 87.19%	Loss: 0.280333
# Train epoch: 28 [380/625]	Accuracy: 83.12%	Loss: 0.322828
# Train epoch: 28 [390/625]	Accuracy: 85.31%	Loss: 0.316443
# Train epoch: 28 [400/625]	Accuracy: 87.81%	Loss: 0.276969
# Train epoch: 28 [410/625]	Accuracy: 88.12%	Loss: 0.278457
# Train epoch: 28 [420/625]	Accuracy: 87.50%	Loss: 0.300988
# Train epoch: 28 [430/625]	Accuracy: 90.00%	Loss: 0.262033
# Train epoch: 28 [440/625]	Accuracy: 86.88%	Loss: 0.278231
# Train epoch: 28 [450/625]	Accuracy: 90.94%	Loss: 0.239243
# Train epoch: 28 [460/625]	Accuracy: 86.88%	Loss: 0.318389
# Train epoch: 28 [470/625]	Accuracy: 81.25%	Loss: 0.359957
# Train epoch: 28 [480/625]	Accuracy: 84.69%	Loss: 0.291704
# Train epoch: 28 [490/625]	Accuracy: 88.44%	Loss: 0.276234
# Train epoch: 28 [500/625]	Accuracy: 88.44%	Loss: 0.264853
# Train epoch: 28 [510/625]	Accuracy: 85.00%	Loss: 0.295540
# Train epoch: 28 [520/625]	Accuracy: 86.88%	Loss: 0.276830
# Train epoch: 28 [530/625]	Accuracy: 88.75%	Loss: 0.236826
# Train epoch: 28 [540/625]	Accuracy: 84.06%	Loss: 0.307186
# Train epoch: 28 [550/625]	Accuracy: 87.81%	Loss: 0.256418
# Train epoch: 28 [560/625]	Accuracy: 85.31%	Loss: 0.279006
# Train epoch: 28 [570/625]	Accuracy: 88.12%	Loss: 0.255916
# Train epoch: 28 [580/625]	Accuracy: 85.31%	Loss: 0.273492
# Train epoch: 28 [590/625]	Accuracy: 81.88%	Loss: 0.340582
# Train epoch: 28 [600/625]	Accuracy: 89.06%	Loss: 0.279891
# Train epoch: 28 [610/625]	Accuracy: 88.12%	Loss: 0.284078
# Train epoch: 28 [620/625]	Accuracy: 90.00%	Loss: 0.254930
# Test set: Loss: 0.7959, Accuracy: 62.28%)
# Train epoch: 29 [10/625]	Accuracy: 85.00%	Loss: 0.309851
# Train epoch: 29 [20/625]	Accuracy: 89.06%	Loss: 0.275001
# Train epoch: 29 [30/625]	Accuracy: 86.56%	Loss: 0.302785
# Train epoch: 29 [40/625]	Accuracy: 88.75%	Loss: 0.251988
# Train epoch: 29 [50/625]	Accuracy: 88.75%	Loss: 0.264790
# Train epoch: 29 [60/625]	Accuracy: 88.12%	Loss: 0.269068
# Train epoch: 29 [70/625]	Accuracy: 88.75%	Loss: 0.269423
# Train epoch: 29 [80/625]	Accuracy: 89.06%	Loss: 0.241610
# Train epoch: 29 [90/625]	Accuracy: 85.62%	Loss: 0.289781
# Train epoch: 29 [100/625]	Accuracy: 88.75%	Loss: 0.243329
# Train epoch: 29 [110/625]	Accuracy: 86.88%	Loss: 0.304041
# Train epoch: 29 [120/625]	Accuracy: 87.81%	Loss: 0.266781
# Train epoch: 29 [130/625]	Accuracy: 88.12%	Loss: 0.270323
# Train epoch: 29 [140/625]	Accuracy: 86.56%	Loss: 0.272993
# Train epoch: 29 [150/625]	Accuracy: 88.44%	Loss: 0.282961
# Train epoch: 29 [160/625]	Accuracy: 89.06%	Loss: 0.288482
# Train epoch: 29 [170/625]	Accuracy: 84.38%	Loss: 0.342141
# Train epoch: 29 [180/625]	Accuracy: 85.94%	Loss: 0.300706
# Train epoch: 29 [190/625]	Accuracy: 86.56%	Loss: 0.303262
# Train epoch: 29 [200/625]	Accuracy: 86.56%	Loss: 0.287029
# Train epoch: 29 [210/625]	Accuracy: 84.69%	Loss: 0.307957
# Train epoch: 29 [220/625]	Accuracy: 85.94%	Loss: 0.279550
# Train epoch: 29 [230/625]	Accuracy: 87.19%	Loss: 0.276994
# Train epoch: 29 [240/625]	Accuracy: 88.12%	Loss: 0.275236
# Train epoch: 29 [250/625]	Accuracy: 86.25%	Loss: 0.294152
# Train epoch: 29 [260/625]	Accuracy: 86.25%	Loss: 0.303190
# Train epoch: 29 [270/625]	Accuracy: 89.38%	Loss: 0.247564
# Train epoch: 29 [280/625]	Accuracy: 85.94%	Loss: 0.282587
# Train epoch: 29 [290/625]	Accuracy: 89.06%	Loss: 0.265534
# Train epoch: 29 [300/625]	Accuracy: 84.38%	Loss: 0.354880
# Train epoch: 29 [310/625]	Accuracy: 86.25%	Loss: 0.345956
# Train epoch: 29 [320/625]	Accuracy: 86.88%	Loss: 0.259967
# Train epoch: 29 [330/625]	Accuracy: 84.38%	Loss: 0.320975
# Train epoch: 29 [340/625]	Accuracy: 87.81%	Loss: 0.265149
# Train epoch: 29 [350/625]	Accuracy: 90.31%	Loss: 0.258965
# Train epoch: 29 [360/625]	Accuracy: 86.88%	Loss: 0.309810
# Train epoch: 29 [370/625]	Accuracy: 85.31%	Loss: 0.292280
# Train epoch: 29 [380/625]	Accuracy: 87.19%	Loss: 0.301109
# Train epoch: 29 [390/625]	Accuracy: 89.38%	Loss: 0.243656
# Train epoch: 29 [400/625]	Accuracy: 83.44%	Loss: 0.392743
# Train epoch: 29 [410/625]	Accuracy: 88.44%	Loss: 0.257399
# Train epoch: 29 [420/625]	Accuracy: 84.69%	Loss: 0.305403
# Train epoch: 29 [430/625]	Accuracy: 82.81%	Loss: 0.327643
# Train epoch: 29 [440/625]	Accuracy: 85.00%	Loss: 0.310497
# Train epoch: 29 [450/625]	Accuracy: 89.38%	Loss: 0.272565
# Train epoch: 29 [460/625]	Accuracy: 86.88%	Loss: 0.291876
# Train epoch: 29 [470/625]	Accuracy: 88.75%	Loss: 0.275832
# Train epoch: 29 [480/625]	Accuracy: 83.12%	Loss: 0.327997
# Train epoch: 29 [490/625]	Accuracy: 82.50%	Loss: 0.340878
# Train epoch: 29 [500/625]	Accuracy: 85.94%	Loss: 0.329960
# Train epoch: 29 [510/625]	Accuracy: 89.38%	Loss: 0.259746
# Train epoch: 29 [520/625]	Accuracy: 90.62%	Loss: 0.218245
# Train epoch: 29 [530/625]	Accuracy: 87.81%	Loss: 0.291172
# Train epoch: 29 [540/625]	Accuracy: 86.88%	Loss: 0.309957
# Train epoch: 29 [550/625]	Accuracy: 89.38%	Loss: 0.268435
# Train epoch: 29 [560/625]	Accuracy: 87.19%	Loss: 0.278785
# Train epoch: 29 [570/625]	Accuracy: 87.50%	Loss: 0.308173
# Train epoch: 29 [580/625]	Accuracy: 89.06%	Loss: 0.273339
# Train epoch: 29 [590/625]	Accuracy: 87.81%	Loss: 0.284683
# Train epoch: 29 [600/625]	Accuracy: 85.62%	Loss: 0.296362
# Train epoch: 29 [610/625]	Accuracy: 88.44%	Loss: 0.248860
# Train epoch: 29 [620/625]	Accuracy: 85.62%	Loss: 0.327939
# Test set: Loss: 0.9269, Accuracy: 63.89%)
# Train epoch: 30 [10/625]	Accuracy: 86.25%	Loss: 0.290855
# Train epoch: 30 [20/625]	Accuracy: 85.94%	Loss: 0.324092
# Train epoch: 30 [30/625]	Accuracy: 86.56%	Loss: 0.280498
# Train epoch: 30 [40/625]	Accuracy: 89.06%	Loss: 0.243825
# Train epoch: 30 [50/625]	Accuracy: 87.19%	Loss: 0.289876
# Train epoch: 30 [60/625]	Accuracy: 88.75%	Loss: 0.263075
# Train epoch: 30 [70/625]	Accuracy: 88.12%	Loss: 0.267514
# Train epoch: 30 [80/625]	Accuracy: 88.44%	Loss: 0.259643
# Train epoch: 30 [90/625]	Accuracy: 89.38%	Loss: 0.260142
# Train epoch: 30 [100/625]	Accuracy: 86.88%	Loss: 0.248750
# Train epoch: 30 [110/625]	Accuracy: 83.44%	Loss: 0.309980
# Train epoch: 30 [120/625]	Accuracy: 88.12%	Loss: 0.292260
# Train epoch: 30 [130/625]	Accuracy: 87.81%	Loss: 0.264352
# Train epoch: 30 [140/625]	Accuracy: 87.50%	Loss: 0.295062
# Train epoch: 30 [150/625]	Accuracy: 85.00%	Loss: 0.327051
# Train epoch: 30 [160/625]	Accuracy: 87.50%	Loss: 0.267521
# Train epoch: 30 [170/625]	Accuracy: 86.25%	Loss: 0.280730
# Train epoch: 30 [180/625]	Accuracy: 86.25%	Loss: 0.296224
# Train epoch: 30 [190/625]	Accuracy: 85.31%	Loss: 0.298778
# Train epoch: 30 [200/625]	Accuracy: 87.19%	Loss: 0.296862
# Train epoch: 30 [210/625]	Accuracy: 84.38%	Loss: 0.359386
# Train epoch: 30 [220/625]	Accuracy: 89.38%	Loss: 0.249028
# Train epoch: 30 [230/625]	Accuracy: 86.88%	Loss: 0.271001
# Train epoch: 30 [240/625]	Accuracy: 87.81%	Loss: 0.280693
# Train epoch: 30 [250/625]	Accuracy: 85.94%	Loss: 0.318106
# Train epoch: 30 [260/625]	Accuracy: 86.25%	Loss: 0.283457
# Train epoch: 30 [270/625]	Accuracy: 89.06%	Loss: 0.272597
# Train epoch: 30 [280/625]	Accuracy: 86.25%	Loss: 0.280599
# Train epoch: 30 [290/625]	Accuracy: 87.81%	Loss: 0.266674
# Train epoch: 30 [300/625]	Accuracy: 88.44%	Loss: 0.259269
# Train epoch: 30 [310/625]	Accuracy: 87.81%	Loss: 0.269378
# Train epoch: 30 [320/625]	Accuracy: 87.50%	Loss: 0.278854
# Train epoch: 30 [330/625]	Accuracy: 86.88%	Loss: 0.280085
# Train epoch: 30 [340/625]	Accuracy: 85.62%	Loss: 0.295563
# Train epoch: 30 [350/625]	Accuracy: 85.62%	Loss: 0.284119
# Train epoch: 30 [360/625]	Accuracy: 88.75%	Loss: 0.285159
# Train epoch: 30 [370/625]	Accuracy: 88.44%	Loss: 0.288820
# Train epoch: 30 [380/625]	Accuracy: 85.31%	Loss: 0.328341
# Train epoch: 30 [390/625]	Accuracy: 87.50%	Loss: 0.288097
# Train epoch: 30 [400/625]	Accuracy: 88.75%	Loss: 0.265899
# Train epoch: 30 [410/625]	Accuracy: 87.81%	Loss: 0.267340
# Train epoch: 30 [420/625]	Accuracy: 87.19%	Loss: 0.316825
# Train epoch: 30 [430/625]	Accuracy: 86.25%	Loss: 0.290360
# Train epoch: 30 [440/625]	Accuracy: 86.88%	Loss: 0.267135
# Train epoch: 30 [450/625]	Accuracy: 82.19%	Loss: 0.341548
# Train epoch: 30 [460/625]	Accuracy: 84.69%	Loss: 0.315782
# Train epoch: 30 [470/625]	Accuracy: 88.44%	Loss: 0.265193
# Train epoch: 30 [480/625]	Accuracy: 88.12%	Loss: 0.264770
# Train epoch: 30 [490/625]	Accuracy: 85.31%	Loss: 0.326398
# Train epoch: 30 [500/625]	Accuracy: 85.62%	Loss: 0.306817
# Train epoch: 30 [510/625]	Accuracy: 88.12%	Loss: 0.256228
# Train epoch: 30 [520/625]	Accuracy: 90.00%	Loss: 0.251776
# Train epoch: 30 [530/625]	Accuracy: 89.69%	Loss: 0.241375
# Train epoch: 30 [540/625]	Accuracy: 86.56%	Loss: 0.307072
# Train epoch: 30 [550/625]	Accuracy: 84.06%	Loss: 0.346699
# Train epoch: 30 [560/625]	Accuracy: 85.00%	Loss: 0.328997
# Train epoch: 30 [570/625]	Accuracy: 85.00%	Loss: 0.299075
# Train epoch: 30 [580/625]	Accuracy: 85.62%	Loss: 0.268304
# Train epoch: 30 [590/625]	Accuracy: 86.25%	Loss: 0.292559
# Train epoch: 30 [600/625]	Accuracy: 88.75%	Loss: 0.260263
# Train epoch: 30 [610/625]	Accuracy: 89.38%	Loss: 0.247797
# Train epoch: 30 [620/625]	Accuracy: 88.75%	Loss: 0.280883
# Test set: Loss: 0.7990, Accuracy: 66.78%)
